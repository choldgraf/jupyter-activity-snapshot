# %%
import seaborn as sns
import pandas as pd
import numpy as np
import altair as alt
from markdown import markdown
from IPython.display import Markdown
from ipywidgets.widgets import HTML, Tab
from ipywidgets import widgets
from datetime import timedelta
from matplotlib import pyplot as plt

# %%
def author_url(author):
    return f"https://github.com/{author}"

# %%
bot_names = ["stale", "codecov", "jupyterlab-dev-mode", "henchbot"]
comments = pd.read_csv('./data/comments.csv', index_col=0).query('author not in @bot_names')
issues = pd.read_csv('./data/issues.csv', index_col=0).query('author not in @bot_names')
prs = pd.read_csv('./data/prs.csv', index_col=0).query('author not in @bot_names')

# %%
fmt_date = "{:%Y-%m-%d}"

start_date = comments['updatedAt'].min()
end_date = comments['updatedAt'].max()

renderer = "jupyterlab"
github_orgs = ["jupyterhub", "jupyter", "jupyterlab", "jupyter-widgets", "ipython", "binder-examples", "nteract"]
bot_names = ["stale", "codecov", "jupyterlab-dev-mode", "henchbot"]

# %%
# Parameters
end_date = "2019-07-22"
start_date = "2019-06-22"
renderer = "kaggle"

# %%
alt.renderers.enable(renderer);

# %%
# Information about out time window
time_delta = pd.to_datetime(end_date) - pd.to_datetime(start_date)
n_days = time_delta.days

# Information about the data we loaded
github_orgs = comments['org'].unique()

# %% [markdown]
# # GitHub activity
#
# Jupyter also has lots of activity across GitHub repositories. The following sections contain
# overviews of recent activity across the following GitHub organizations:

# %%
# Define colors we'll use for GitHub membership
author_types = ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', "NONE"]

author_palette = sns.palettes.blend_palette(["lightgrey", "lightgreen", "darkgreen"], 4)
author_colors = ["rgb({}, {}, {}, {})".format(*(ii*256)) for ii in author_palette]
author_color_dict = {key: val for key, val in zip(author_types, author_palette)}

# %%
orgs_md = []
for org in github_orgs:
    orgs_md.append(f'* [github.com/{org}](https://github.com/{org})')
Markdown('\n'.join(orgs_md))
# Out:
# * [github.com/jupyterhub](https://github.com/jupyterhub)
# * [github.com/jupyter](https://github.com/jupyter)
# * [github.com/jupyterlab](https://github.com/jupyterlab)
# * [github.com/jupyter-widgets](https://github.com/jupyter-widgets)
# * [github.com/ipython](https://github.com/ipython)
# * [github.com/binder-examples](https://github.com/binder-examples)
# * [github.com/nteract](https://github.com/nteract)

# %%
Markdown(f"Showing GitHub activity from **{start_date}** to **{end_date}**")
# Out:
# Showing GitHub activity from **2019-06-22** to **2019-07-22**

# %% [markdown]
# ## List of all contributors per organization
#
# First, we'll list each contributor that has contributed to each organization in the last several days.
# Contributions to open source projects are diverse, and involve much more than just contributing code and
# code review. Thanks to everybody in the Jupyter communities for all that they do.

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, org in enumerate(github_orgs):
    authors_comments = comments['author']
    authors_prs = prs['author']
    unique_participants = np.unique(np.hstack([authors_comments.values, authors_prs.values]).astype(str)).tolist()
    unique_participants.sort(key=lambda a: a.lower())
    
    all_participants = [f"[{participant}](https://github.com/{participant})" for participant in unique_participants]
    participants_md = " | ".join(all_participants)
    md_html = HTML("<center>{}</center>".format(markdown(participants_md)))
    
    children = list(tabs.children)
    children.append(md_html)
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"All participants across issues and pull requests in each org in the last {n_days} days"))
display(tabs)
# Out:
# All participants across issues and pull requests in each org in the last 30 days
# Tab(children=(HTML(value='<center><p><a href="https://github.com/0anton">0anton</a> | <a href="https://github.…

# %% [markdown]
# ## Merged Pull requests
#
# Here's an analysis of **merged pull requests** across each of the repositories in the Jupyter
# ecosystem.

# %%
merged = prs.query('state == "MERGED"')

# %%
prs_by_repo = merged.groupby(['org', 'repo']).count()['author'].reset_index().sort_values(['org', 'author'], ascending=False)
alt.Chart(data=prs_by_repo, title=f"Merged PRs in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=prs_by_repo['repo'].values.tolist()),
    y='author',
    color='org'
)
# Out:
# Chart({
#   data:                 org                           repo  author
#   58          nteract                        nteract      15
#   57          nteract                       hydrogen      13
#   55          nteract                      bookstore       9
#   60          nteract                      papermill       9
#   59          nteract                     nteract.io       5
#   56          nteract                       commuter       3
#   63          nteract                  vega-embed-v3       2
#   61          nteract                      scrapbook       1
#   62          nteract                           vdom       1
#   45       jupyterlab                     jupyterlab      52
#   47       jupyterlab       jupyterlab-data-explorer       7
#   48       jupyterlab                jupyterlab-demo       5
#   49       jupyterlab                 jupyterlab-git       5
#   44       jupyterlab              jupyter-renderers       2
#   46       jupyterlab          jupyterlab-commenting       2
#   53       jupyterlab  scipy2019-jupyterlab-tutorial       2
#   41       jupyterlab                       debugger       1
#   42       jupyterlab      extension-cookiecutter-js       1
#   43       jupyterlab      extension-cookiecutter-ts       1
#   50       jupyterlab              jupyterlab-github       1
#   51       jupyterlab              jupyterlab_server       1
#   52       jupyterlab     mimerender-cookiecutter-ts       1
#   54       jupyterlab             theme-cookiecutter       1
#   33       jupyterhub            mybinder.org-deploy      21
#   29       jupyterhub                     jupyterhub      11
#   37       jupyterhub        the-littlest-jupyterhub       8
#   31       jupyterhub          kerberosauthenticator       4
#   36       jupyterhub                   team-compass       4
#   38       jupyterhub                  traefik-proxy       3
#   27       jupyterhub                      binderhub       2
#   ..              ...                            ...     ...
#   30       jupyterhub                 jupyterlab-hub       1
#   32       jupyterhub               ltiauthenticator       1
#   34       jupyterhub                 oauthenticator       1
#   35       jupyterhub                    sudospawner       1
#   20  jupyter-widgets                     ipyleaflet      16
#   21  jupyter-widgets                     ipywidgets      16
#   25  jupyter-widgets                       tutorial      13
#   22  jupyter-widgets             jupyterlab-sidecar       1
#   23  jupyter-widgets                   midicontrols       1
#   24  jupyter-widgets                     traittypes       1
#   16          jupyter                       notebook      21
#   18          jupyter                    repo2docker      15
#   19          jupyter                      telemetry      11
#   5           jupyter             enterprise_gateway       9
#   10          jupyter              jupyter.github.io       7
#   11          jupyter                 jupyter_client       7
#   4           jupyter                  docker-stacks       5
#   8           jupyter                   jupyter-book       4
#   9           jupyter                 jupyter-sphinx       4
#   12          jupyter                 jupyter_server       4
#   14          jupyter                      nbconvert       3
#   15          jupyter                       nbviewer       3
#   17          jupyter                      qtconsole       3
#   6           jupyter                     governance       1
#   7           jupyter                        jupyter       1
#   13          jupyter                          nb2kg       1
#   2           ipython                        ipython       8
#   3           ipython                      traitlets       2
#   1           ipython                      ipykernel       1
#   0   binder-examples                     data-quilt       1
#
#   [64 rows x 3 columns],
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: ['nteract', 'hydrogen', 'bookstore', 'papermill', 'nteract.io', 'commuter', 'vega-embed-v3', 'scrapbook', 'vdom', 'jupyterlab', 'jupyterlab-data-explorer', 'jupyterlab-demo', 'jupyterlab-git', 'jupyter-renderers', 'jupyterlab-commenting', 'scipy2019-jupyterlab-tutorial', 'debugger', 'extension-cookiecutter-js', 'extension-cookiecutter-ts', 'jupyterlab-github', 'jupyterlab_server', 'mimerender-cookiecutter-ts', 'theme-cookiecutter', 'mybinder.org-deploy', 'jupyterhub', 'the-littlest-jupyterhub', 'kerberosauthenticator', 'team-compass', 'traefik-proxy', 'binderhub', 'yarnspawner', 'zero-to-jupyterhub-k8s', 'binder', 'jupyter-server-proxy', 'jupyterlab-hub', 'ltiauthenticator', 'oauthenticator', 'sudospawner', 'ipyleaflet', 'ipywidgets', 'tutorial', 'jupyterlab-sidecar', 'midicontrols', 'traittypes', 'notebook', 'repo2docker', 'telemetry', 'enterprise_gateway', 'jupyter.github.io', 'jupyter_client', 'docker-stacks', 'jupyter-book', 'jupyter-sphinx', 'jupyter_server', 'nbconvert', 'nbviewer', 'qtconsole', 'governance', 'jupyter', 'nb2kg', 'ipython', 'traitlets', 'ipykernel', 'data-quilt'],
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'author',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Merged PRs in the last 30 days'
# })

# %% [markdown]
# ### A list of merged PRs by project
#
# Below is a tabbed readout of recently-merged PRs. Check out the title to get an idea for what they
# implemented, and be sure to thank the PR author for their hard work!

# %%
tabs = widgets.Tab(children=[])
merged_by = {}
pr_by = {}
for ii, (org, idata) in enumerate(merged.groupby('org')):
    issue_md = []
    issue_md.append(f"#### Closed PRs for org: `{org}`")
    issue_md.append("")
    for (org, repo), prs in idata.groupby(['org', 'repo']):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")
        for _, pr in prs.iterrows():
            user_name = pr['author']
            user_url = author_url(user_name)
            pr_number = pr['number']
            pr_html = pr['url']
            pr_title = pr['title']
            pr_closedby = pr['mergedBy']
            pr_closedby_url = f"https://github.com/{pr_closedby}"
            if user_name not in pr_by:
                pr_by[user_name] = 1
            else:
                pr_by[user_name] += 1
                
            if pr_closedby not in merged_by:
                merged_by[pr_closedby] = 1
            else:
                merged_by[pr_closedby] += 1
            text = f"* [(#{pr_number})]({pr_html}): _{pr_title}_ by **[@{user_name}]({user_url})** merged by **[@{pr_closedby}]({pr_closedby_url})**"
            issue_md.append(text)
    issue_md.append('')
    markdown_html = markdown('\n'.join(issue_md))
    
    children = list(tabs.children)
    children.append(HTML(markdown_html))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
tabs
# Out:
# Tab(children=(HTML(value='<h4>Closed PRs for org: <code>binder-examples</code></h4>\n<h5><a href="https://gith…

# %% [markdown]
# ### Authoring and merging stats by repository
#
# Let's see who has been doing most of the PR authoring and merging. The PR author is generally the
# person that implemented a change in the repository (code, documentation, etc). The PR merger is
# the person that "pressed the green button" and got the change into the main codebase.

# %%
# Prep our merging DF
merged_by_repo = merged.groupby(['org', 'repo', 'author'], as_index=False).agg({'id': 'count', 'authorAssociation': 'first'}).rename(columns={'id': "authored", 'author': 'username'})
closed_by_repo = merged.groupby(['org', 'repo', 'mergedBy']).count()['id'].reset_index().rename(columns={'id': "closed", "mergedBy": "username"})

# %%
charts = []
for ii, (iorg, idata) in enumerate(merged_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"PR authors for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='authored',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)

alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                org        repo     username  authored authorAssociation
#     0  binder-examples  data-quilt  matheusmota         1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for binder-examples in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:        org       repo        username  authored authorAssociation
#     1  ipython  ipykernel        steff456         1              NONE
#     2  ipython    ipython         Carreau         4            MEMBER
#     3  ipython    ipython      OriolAbril         1       CONTRIBUTOR
#     4  ipython    ipython  brandonwillard         1       CONTRIBUTOR
#     5  ipython    ipython         sunpoet         1       CONTRIBUTOR
#     6  ipython    ipython      sysadmin75         1              NONE
#     7  ipython  traitlets           Jamim         2       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:         org                repo        username  authored authorAssociation
#     8   jupyter       docker-stacks    danielballan         1       CONTRIBUTOR
#     9   jupyter       docker-stacks     jamesdbrock         3       CONTRIBUTOR
#     10  jupyter       docker-stacks           minrk         1            MEMBER
#     11  jupyter  enterprise_gateway        IMAM9AIS         1       CONTRIBUTOR
#     12  jupyter  enterprise_gateway           clkao         1       CONTRIBUTOR
#     13  jupyter  enterprise_gateway     kevin-bates         4            MEMBER
#     14  jupyter  enterprise_gateway        lresende         1            MEMBER
#     15  jupyter  enterprise_gateway   vikasgarg1996         2       CONTRIBUTOR
#     16  jupyter          governance       ellisonbg         1            MEMBER
#     17  jupyter             jupyter       choldgraf         1            MEMBER
#     18  jupyter        jupyter-book           cczhu         1       CONTRIBUTOR
#     19  jupyter        jupyter-book       choldgraf         1            MEMBER
#     20  jupyter        jupyter-book         emdupre         1      COLLABORATOR
#     21  jupyter        jupyter-book            habi         1       CONTRIBUTOR
#     22  jupyter      jupyter-sphinx        akhmerov         3            MEMBER
#     23  jupyter      jupyter-sphinx        jbweston         1            MEMBER
#     24  jupyter   jupyter.github.io          afshin         2            MEMBER
#     25  jupyter   jupyter.github.io    davidanthoff         1       CONTRIBUTOR
#     26  jupyter   jupyter.github.io         jMuzsik         1       CONTRIBUTOR
#     27  jupyter   jupyter.github.io      jasongrout         1            MEMBER
#     28  jupyter   jupyter.github.io       jnovinger         1       CONTRIBUTOR
#     29  jupyter   jupyter.github.io  saulshanabrook         1       CONTRIBUTOR
#     30  jupyter      jupyter_client           Jamim         1       CONTRIBUTOR
#     31  jupyter      jupyter_client    JohanMabille         2       CONTRIBUTOR
#     32  jupyter      jupyter_client           MSeal         1            MEMBER
#     33  jupyter      jupyter_client   SylvainCorlay         2            MEMBER
#     34  jupyter      jupyter_client    flying-sheep         1       CONTRIBUTOR
#     35  jupyter      jupyter_server   SylvainCorlay         2            MEMBER
#     36  jupyter      jupyter_server         Zsailer         2            MEMBER
#     37  jupyter               nb2kg           dleen         1       CONTRIBUTOR
#     38  jupyter           nbconvert           kapsh         1       CONTRIBUTOR
#     39  jupyter           nbconvert       marwahaha         1       CONTRIBUTOR
#     40  jupyter           nbconvert         wwitzel         1       CONTRIBUTOR
#     41  jupyter            nbviewer        krinsman         3       CONTRIBUTOR
#     42  jupyter            notebook   SylvainCorlay         1            MEMBER
#     43  jupyter            notebook         ednut15         2       CONTRIBUTOR
#     44  jupyter            notebook     fabihaahmed         3       CONTRIBUTOR
#     45  jupyter            notebook         gnestor         1            MEMBER
#     46  jupyter            notebook          hdtee1         1       CONTRIBUTOR
#     47  jupyter            notebook   joshuazeltser         4       CONTRIBUTOR
#     48  jupyter            notebook     kevin-bates         2            MEMBER
#     49  jupyter            notebook        lresende         3            MEMBER
#     50  jupyter            notebook         minho42         1       CONTRIBUTOR
#     51  jupyter            notebook        saraedum         1       CONTRIBUTOR
#     52  jupyter            notebook       takluyver         1            MEMBER
#     53  jupyter            notebook        taohan16         1       CONTRIBUTOR
#     54  jupyter           qtconsole           ajtam         1       CONTRIBUTOR
#     55  jupyter           qtconsole        dalthviz         2       CONTRIBUTOR
#     56  jupyter         repo2docker      Xarthisius         1       CONTRIBUTOR
#     57  jupyter         repo2docker         betatim         5            MEMBER
#     58  jupyter         repo2docker      davidrpugh         1       CONTRIBUTOR
#     59  jupyter         repo2docker       eexwhyzee         1       CONTRIBUTOR
#     60  jupyter         repo2docker       fmaussion         1       CONTRIBUTOR
#     61  jupyter         repo2docker   johnjarmitage         1              NONE
#     62  jupyter         repo2docker           minrk         5            MEMBER
#     63  jupyter           telemetry         Zsailer         3            MEMBER
#     64  jupyter           telemetry      jaipreet-s         1      COLLABORATOR
#     65  jupyter           telemetry       yuvipanda         7            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                 org                repo         username  authored  \
#     66  jupyter-widgets          ipyleaflet    SylvainCorlay         4
#     67  jupyter-widgets          ipyleaflet     VasavanThiru         2
#     68  jupyter-widgets          ipyleaflet            jmp75         1
#     69  jupyter-widgets          ipyleaflet            jtpio         1
#     70  jupyter-widgets          ipyleaflet        kgiacobbi         5
#     71  jupyter-widgets          ipyleaflet      martinRenou         2
#     72  jupyter-widgets          ipyleaflet           tgrout         1
#     73  jupyter-widgets          ipywidgets            Jamim         1
#     74  jupyter-widgets          ipywidgets    SylvainCorlay         9
#     75  jupyter-widgets          ipywidgets           ivanov         1
#     76  jupyter-widgets          ipywidgets       jasongrout         2
#     77  jupyter-widgets          ipywidgets            jtpio         1
#     78  jupyter-widgets          ipywidgets       mbektasbbg         1
#     79  jupyter-widgets          ipywidgets          mwcraig         1
#     80  jupyter-widgets  jupyterlab-sidecar      martinRenou         1
#     81  jupyter-widgets        midicontrols            wolfv         1
#     82  jupyter-widgets          traittypes            Jamim         1
#     83  jupyter-widgets            tutorial  maartenbreddels         1
#     84  jupyter-widgets            tutorial      martinRenou         7
#     85  jupyter-widgets            tutorial          mwcraig         5
#
#        authorAssociation
#     66            MEMBER
#     67       CONTRIBUTOR
#     68       CONTRIBUTOR
#     69       CONTRIBUTOR
#     70       CONTRIBUTOR
#     71            MEMBER
#     72       CONTRIBUTOR
#     73       CONTRIBUTOR
#     74            MEMBER
#     75       CONTRIBUTOR
#     76            MEMBER
#     77       CONTRIBUTOR
#     78       CONTRIBUTOR
#     79       CONTRIBUTOR
#     80            MEMBER
#     81       CONTRIBUTOR
#     82       CONTRIBUTOR
#     83            MEMBER
#     84            MEMBER
#     85       CONTRIBUTOR  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:             org                     repo        username  authored  \
#     86   jupyterhub                   binder     jamesdbrock         1
#     87   jupyterhub                binderhub       choldgraf         2
#     88   jupyterhub     jupyter-server-proxy          rcolle         1
#     89   jupyterhub               jupyterhub         Carreau         1
#     90   jupyterhub               jupyterhub  GeorgianaElena         2
#     91   jupyterhub               jupyterhub       bartolone         1
#     92   jupyterhub               jupyterhub          bitnik         1
#     93   jupyterhub               jupyterhub       danlester         1
#     94   jupyterhub               jupyterhub          ilee38         1
#     95   jupyterhub               jupyterhub          jcrist         1
#     96   jupyterhub               jupyterhub           jtpio         1
#     97   jupyterhub               jupyterhub         lumbric         1
#     98   jupyterhub               jupyterhub        remram44         1
#     99   jupyterhub           jupyterlab-hub       blink1073         1
#     100  jupyterhub    kerberosauthenticator        dvalters         1
#     101  jupyterhub    kerberosauthenticator          jcrist         3
#     102  jupyterhub         ltiauthenticator           rtcn2         1
#     103  jupyterhub      mybinder.org-deploy         betatim        13
#     104  jupyterhub      mybinder.org-deploy       choldgraf         2
#     105  jupyterhub      mybinder.org-deploy          henchc         1
#     106  jupyterhub      mybinder.org-deploy           jtpio         1
#     107  jupyterhub      mybinder.org-deploy     mael-le-gal         2
#     108  jupyterhub      mybinder.org-deploy       sgibson91         2
#     109  jupyterhub           oauthenticator           minrk         1
#     110  jupyterhub              sudospawner         lumbric         1
#     111  jupyterhub             team-compass       choldgraf         1
#     112  jupyterhub             team-compass           minrk         2
#     113  jupyterhub             team-compass      ryanlovett         1
#     114  jupyterhub  the-littlest-jupyterhub  GeorgianaElena         4
#     115  jupyterhub  the-littlest-jupyterhub     cornhundred         1
#     116  jupyterhub  the-littlest-jupyterhub           jtpio         2
#     117  jupyterhub  the-littlest-jupyterhub         lumbric         1
#     118  jupyterhub            traefik-proxy  GeorgianaElena         3
#     119  jupyterhub              yarnspawner          jcrist         2
#     120  jupyterhub   zero-to-jupyterhub-k8s         seanmck         1
#     121  jupyterhub   zero-to-jupyterhub-k8s       yuvipanda         1
#
#         authorAssociation
#     86        CONTRIBUTOR
#     87             MEMBER
#     88        CONTRIBUTOR
#     89             MEMBER
#     90        CONTRIBUTOR
#     91               NONE
#     92        CONTRIBUTOR
#     93        CONTRIBUTOR
#     94        CONTRIBUTOR
#     95             MEMBER
#     96        CONTRIBUTOR
#     97        CONTRIBUTOR
#     98        CONTRIBUTOR
#     99       COLLABORATOR
#     100       CONTRIBUTOR
#     101            MEMBER
#     102       CONTRIBUTOR
#     103            MEMBER
#     104            MEMBER
#     105            MEMBER
#     106       CONTRIBUTOR
#     107            MEMBER
#     108            MEMBER
#     109            MEMBER
#     110       CONTRIBUTOR
#     111            MEMBER
#     112            MEMBER
#     113            MEMBER
#     114      COLLABORATOR
#     115       CONTRIBUTOR
#     116       CONTRIBUTOR
#     117       CONTRIBUTOR
#     118      COLLABORATOR
#     119            MEMBER
#     120       CONTRIBUTOR
#     121            MEMBER  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:             org                           repo        username  authored  \
#     122  jupyterlab                       debugger          afshin         1
#     123  jupyterlab      extension-cookiecutter-js       nscozzaro         1
#     124  jupyterlab      extension-cookiecutter-ts           jtpio         1
#     125  jupyterlab              jupyter-renderers         gnestor         2
#     126  jupyterlab                     jupyterlab      AlbertHilb         1
#     127  jupyterlab                     jupyterlab          BoPeng         1
#     128  jupyterlab                     jupyterlab         Zsailer         1
#     129  jupyterlab                     jupyterlab          afshin         3
#     130  jupyterlab                     jupyterlab        aschlaep         2
#     131  jupyterlab                     jupyterlab   balamuruganvg         1
#     132  jupyterlab                     jupyterlab       blink1073         4
#     133  jupyterlab                     jupyterlab        domoritz         1
#     134  jupyterlab                     jupyterlab       ellisonbg         2
#     135  jupyterlab                     jupyterlab      fcollonval         1
#     136  jupyterlab                     jupyterlab         gnestor         1
#     137  jupyterlab                     jupyterlab      ian-r-rose         4
#     138  jupyterlab                     jupyterlab          ivanov         2
#     139  jupyterlab                     jupyterlab      jasongrout         3
#     140  jupyterlab                     jupyterlab           jtpio         2
#     141  jupyterlab                     jupyterlab      krassowski         1
#     142  jupyterlab                     jupyterlab        krinsman         1
#     143  jupyterlab                     jupyterlab      mbektasbbg         1
#     144  jupyterlab                     jupyterlab       nscozzaro         1
#     145  jupyterlab                     jupyterlab     parmentelat         1
#     146  jupyterlab                     jupyterlab         reevejd         1
#     147  jupyterlab                     jupyterlab  saulshanabrook         4
#     148  jupyterlab                     jupyterlab          sbrunk         1
#     149  jupyterlab                     jupyterlab      telamonian         6
#     150  jupyterlab                     jupyterlab         tslaton         2
#     151  jupyterlab                     jupyterlab         vidartf         4
#     152  jupyterlab          jupyterlab-commenting      dependabot         1
#     153  jupyterlab          jupyterlab-commenting          hoo761         1
#     154  jupyterlab       jupyterlab-data-explorer      dependabot         3
#     155  jupyterlab       jupyterlab-data-explorer  saulshanabrook         3
#     156  jupyterlab       jupyterlab-data-explorer      telamonian         1
#     157  jupyterlab                jupyterlab-demo     dharmaquark         4
#     158  jupyterlab                jupyterlab-demo      ian-r-rose         1
#     159  jupyterlab                 jupyterlab-git   danielgruesso         1
#     160  jupyterlab                 jupyterlab-git      dependabot         2
#     161  jupyterlab                 jupyterlab-git      fcollonval         1
#     162  jupyterlab                 jupyterlab-git      jaipreet-s         1
#     163  jupyterlab              jupyterlab-github      ian-r-rose         1
#     164  jupyterlab              jupyterlab_server      ian-r-rose         1
#     165  jupyterlab     mimerender-cookiecutter-ts      jasongrout         1
#     166  jupyterlab  scipy2019-jupyterlab-tutorial       blink1073         1
#     167  jupyterlab  scipy2019-jupyterlab-tutorial     dharmaquark         1
#     168  jupyterlab             theme-cookiecutter       blink1073         1
#
#         authorAssociation
#     122            MEMBER
#     123            MEMBER
#     124            MEMBER
#     125            MEMBER
#     126            MEMBER
#     127            MEMBER
#     128            MEMBER
#     129            MEMBER
#     130            MEMBER
#     131       CONTRIBUTOR
#     132            MEMBER
#     133            MEMBER
#     134            MEMBER
#     135            MEMBER
#     136            MEMBER
#     137            MEMBER
#     138            MEMBER
#     139            MEMBER
#     140            MEMBER
#     141            MEMBER
#     142       CONTRIBUTOR
#     143            MEMBER
#     144            MEMBER
#     145       CONTRIBUTOR
#     146            MEMBER
#     147            MEMBER
#     148       CONTRIBUTOR
#     149            MEMBER
#     150       CONTRIBUTOR
#     151            MEMBER
#     152       CONTRIBUTOR
#     153      COLLABORATOR
#     154       CONTRIBUTOR
#     155            MEMBER
#     156            MEMBER
#     157            MEMBER
#     158            MEMBER
#     159       CONTRIBUTOR
#     160       CONTRIBUTOR
#     161            MEMBER
#     162      COLLABORATOR
#     163            MEMBER
#     164            MEMBER
#     165            MEMBER
#     166            MEMBER
#     167            MEMBER
#     168            MEMBER  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:          org           repo        username  authored authorAssociation
#     169  nteract      bookstore          mpacer         9            MEMBER
#     170  nteract       commuter      dependabot         2       CONTRIBUTOR
#     171  nteract       commuter          taniki         1            MEMBER
#     172  nteract       hydrogen        aviatesk         3            MEMBER
#     173  nteract       hydrogen        hoishing         1            MEMBER
#     174  nteract       hydrogen        renovate         2       CONTRIBUTOR
#     175  nteract       hydrogen  wadethestealth         7            MEMBER
#     176  nteract        nteract      BenRussert         1            MEMBER
#     177  nteract        nteract  CrystallineCat         1            MEMBER
#     178  nteract        nteract    captainsafia         2            MEMBER
#     179  nteract        nteract        renovate        10       CONTRIBUTOR
#     180  nteract        nteract        rganardi         1            MEMBER
#     181  nteract     nteract.io        renovate         5              NONE
#     182  nteract      papermill           MSeal         1            MEMBER
#     183  nteract      papermill     RoelBrouwer         1       CONTRIBUTOR
#     184  nteract      papermill       casperdcl         3            MEMBER
#     185  nteract      papermill    duarteocarmo         3            MEMBER
#     186  nteract      papermill        trallard         1            MEMBER
#     187  nteract      scrapbook        trallard         1            MEMBER
#     188  nteract           vdom         gnestor         1            MEMBER
#     189  nteract  vega-embed-v3  CrystallineCat         2            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %%
charts = []
for ii, (iorg, idata) in enumerate(closed_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"Merges for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='closed',
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                org        repo username  closed
#     0  binder-examples  data-quilt  betatim       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for binder-examples in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:        org       repo  username  closed
#     1  ipython  ipykernel     minrk       1
#     2  ipython    ipython   Carreau       8
#     3  ipython  traitlets  rmorshea       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:         org                repo       username  closed
#     4   jupyter       docker-stacks          minrk       5
#     5   jupyter  enterprise_gateway    kevin-bates       7
#     6   jupyter  enterprise_gateway       lresende       2
#     7   jupyter          governance      choldgraf       1
#     8   jupyter             jupyter      choldgraf       1
#     9   jupyter        jupyter-book      choldgraf       4
#     10  jupyter      jupyter-sphinx       akhmerov       3
#     11  jupyter      jupyter-sphinx       jbweston       1
#     12  jupyter   jupyter.github.io        Carreau       1
#     13  jupyter   jupyter.github.io         afshin       1
#     14  jupyter   jupyter.github.io      choldgraf       2
#     15  jupyter   jupyter.github.io      ellisonbg       1
#     16  jupyter   jupyter.github.io     jasongrout       2
#     17  jupyter      jupyter_client          MSeal       1
#     18  jupyter      jupyter_client  SylvainCorlay       4
#     19  jupyter      jupyter_client          minrk       1
#     20  jupyter      jupyter_client         rgbkrk       1
#     21  jupyter      jupyter_server  SylvainCorlay       2
#     22  jupyter      jupyter_server       rolweber       2
#     23  jupyter               nb2kg    kevin-bates       1
#     24  jupyter           nbconvert          MSeal       3
#     25  jupyter            nbviewer      choldgraf       1
#     26  jupyter            nbviewer        parente       2
#     27  jupyter            notebook  SylvainCorlay       1
#     28  jupyter            notebook         ivanov       1
#     29  jupyter            notebook       lresende       4
#     30  jupyter            notebook          minrk       2
#     31  jupyter            notebook      takluyver      13
#     32  jupyter           qtconsole     ccordoba12       3
#     33  jupyter         repo2docker        betatim      10
#     34  jupyter         repo2docker          minrk       4
#     35  jupyter         repo2docker      yuvipanda       1
#     36  jupyter           telemetry        Zsailer       6
#     37  jupyter           telemetry      yuvipanda       5,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                 org                repo         username  closed
#     38  jupyter-widgets          ipyleaflet    SylvainCorlay       3
#     39  jupyter-widgets          ipyleaflet      martinRenou      13
#     40  jupyter-widgets          ipywidgets    SylvainCorlay      14
#     41  jupyter-widgets          ipywidgets       jasongrout       1
#     42  jupyter-widgets          ipywidgets          vidartf       1
#     43  jupyter-widgets  jupyterlab-sidecar    SylvainCorlay       1
#     44  jupyter-widgets        midicontrols       jasongrout       1
#     45  jupyter-widgets          traittypes    SylvainCorlay       1
#     46  jupyter-widgets            tutorial    SylvainCorlay       1
#     47  jupyter-widgets            tutorial  maartenbreddels       1
#     48  jupyter-widgets            tutorial      martinRenou       1
#     49  jupyter-widgets            tutorial          mwcraig      10,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:            org                     repo        username  closed
#     50  jupyterhub                   binder         betatim       1
#     51  jupyterhub                binderhub         betatim       2
#     52  jupyterhub     jupyter-server-proxy       yuvipanda       1
#     53  jupyterhub               jupyterhub         betatim       2
#     54  jupyterhub               jupyterhub           minrk       4
#     55  jupyterhub               jupyterhub        willingc       3
#     56  jupyterhub               jupyterhub       yuvipanda       2
#     57  jupyterhub           jupyterlab-hub       blink1073       1
#     58  jupyterhub    kerberosauthenticator          jcrist       4
#     59  jupyterhub         ltiauthenticator       yuvipanda       1
#     60  jupyterhub      mybinder.org-deploy         betatim      17
#     61  jupyterhub      mybinder.org-deploy       choldgraf       2
#     62  jupyterhub      mybinder.org-deploy           minrk       1
#     63  jupyterhub      mybinder.org-deploy       sgibson91       1
#     64  jupyterhub           oauthenticator         betatim       1
#     65  jupyterhub              sudospawner    consideRatio       1
#     66  jupyterhub             team-compass         betatim       3
#     67  jupyterhub             team-compass       choldgraf       1
#     68  jupyterhub  the-littlest-jupyterhub  GeorgianaElena       1
#     69  jupyterhub  the-littlest-jupyterhub       yuvipanda       7
#     70  jupyterhub            traefik-proxy           minrk       3
#     71  jupyterhub              yarnspawner          jcrist       2
#     72  jupyterhub   zero-to-jupyterhub-k8s    consideRatio       1
#     73  jupyterhub   zero-to-jupyterhub-k8s           minrk       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:            org                           repo        username  closed
#     74  jupyterlab                       debugger          afshin       1
#     75  jupyterlab      extension-cookiecutter-js           jtpio       1
#     76  jupyterlab      extension-cookiecutter-ts       blink1073       1
#     77  jupyterlab              jupyter-renderers         gnestor       2
#     78  jupyterlab                     jupyterlab        aschlaep       1
#     79  jupyterlab                     jupyterlab       blink1073      22
#     80  jupyterlab                     jupyterlab         gnestor       2
#     81  jupyterlab                     jupyterlab      ian-r-rose      10
#     82  jupyterlab                     jupyterlab          ivanov       1
#     83  jupyterlab                     jupyterlab      jasongrout      10
#     84  jupyterlab                     jupyterlab           jtpio       1
#     85  jupyterlab                     jupyterlab  saulshanabrook       1
#     86  jupyterlab                     jupyterlab      telamonian       3
#     87  jupyterlab                     jupyterlab         vidartf       1
#     88  jupyterlab          jupyterlab-commenting          hoo761       2
#     89  jupyterlab       jupyterlab-data-explorer  saulshanabrook       7
#     90  jupyterlab                jupyterlab-demo     dharmaquark       4
#     91  jupyterlab                jupyterlab-demo      jasongrout       1
#     92  jupyterlab                 jupyterlab-git           dleen       1
#     93  jupyterlab                 jupyterlab-git      jaipreet-s       4
#     94  jupyterlab              jupyterlab-github      ian-r-rose       1
#     95  jupyterlab              jupyterlab_server       blink1073       1
#     96  jupyterlab     mimerender-cookiecutter-ts      jasongrout       1
#     97  jupyterlab  scipy2019-jupyterlab-tutorial         Carreau       2
#     98  jupyterlab             theme-cookiecutter       blink1073       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:          org           repo        username  closed
#     99   nteract      bookstore          mpacer       3
#     100  nteract      bookstore          rgbkrk       3
#     101  nteract      bookstore        willingc       3
#     102  nteract       commuter    captainsafia       3
#     103  nteract       hydrogen      BenRussert       8
#     104  nteract       hydrogen        aviatesk       3
#     105  nteract       hydrogen        renovate       2
#     106  nteract        nteract      BenRussert       1
#     107  nteract        nteract  CrystallineCat       1
#     108  nteract        nteract    captainsafia      12
#     109  nteract        nteract          rgbkrk       1
#     110  nteract     nteract.io        renovate       5
#     111  nteract      papermill           MSeal       5
#     112  nteract      papermill          rgbkrk       3
#     113  nteract      papermill        willingc       1
#     114  nteract      scrapbook           MSeal       1
#     115  nteract           vdom         gnestor       1
#     116  nteract  vega-embed-v3  CrystallineCat       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## Issues
#
# Issues are **conversations** that happen on our GitHub repositories. Here's an
# analysis of issues across the Jupyter organizations.

# %%
created = issues.query('state == "OPEN" and createdAt > @start_date and createdAt < @end_date')
closed = issues.query('state == "CLOSED" and closedAt > @start_date and closedAt < @end_date')

# %%
created_counts = created.groupby(['org', 'repo']).count()['number'].reset_index()
created_counts['org/repo'] = created_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = created_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=created_counts, title=f"Issues created in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                         repo  number  \
#   0           ipython                    ipykernel       1
#   1           ipython                  ipyparallel       1
#   2           ipython                      ipython       6
#   3           ipython             ipython-in-depth       1
#   4           jupyter                accessibility       1
#   5           jupyter                docker-stacks       6
#   6           jupyter           enterprise_gateway       3
#   7           jupyter                      jupyter       4
#   8           jupyter                 jupyter-book       9
#   9           jupyter                jupyter-drive       1
#   10          jupyter               jupyter-sphinx       7
#   11          jupyter               jupyter_client       1
#   12          jupyter               jupyter_server       2
#   13          jupyter                        nb2kg       2
#   14          jupyter                    nbconvert       4
#   15          jupyter                       nbdime       3
#   16          jupyter                     nbgrader       4
#   17          jupyter                     nbviewer       1
#   18          jupyter                     notebook      25
#   19          jupyter                    qtconsole       2
#   20          jupyter                  repo2docker      12
#   21          jupyter                     testpath       1
#   22  jupyter-widgets                   ipyleaflet       4
#   23  jupyter-widgets                   ipywidgets      27
#   24  jupyter-widgets           jupyterlab-sidecar       3
#   25  jupyter-widgets                    pythreejs       1
#   26       jupyterhub                 batchspawner       3
#   27       jupyterhub                    binderhub      10
#   28       jupyterhub                dockerspawner       3
#   29       jupyterhub                   helm-chart       1
#   ..              ...                          ...     ...
#   32       jupyterhub                   jupyterhub      17
#   33       jupyterhub        kerberosauthenticator       1
#   34       jupyterhub                  kubespawner       4
#   35       jupyterhub            ldapauthenticator       3
#   36       jupyterhub          mybinder.org-deploy       4
#   37       jupyterhub          nativeauthenticator       1
#   38       jupyterhub               systemdspawner       3
#   39       jupyterhub                 team-compass       6
#   40       jupyterhub      the-littlest-jupyterhub      11
#   41       jupyterhub                traefik-proxy       2
#   42       jupyterhub                  wrapspawner       1
#   43       jupyterhub       zero-to-jupyterhub-k8s      11
#   44       jupyterlab    extension-cookiecutter-ts       1
#   45       jupyterlab            jupyter-renderers       2
#   46       jupyterlab                   jupyterlab      73
#   47       jupyterlab          jupyterlab-celltags       3
#   48       jupyterlab        jupyterlab-commenting      12
#   49       jupyterlab     jupyterlab-data-explorer      11
#   50       jupyterlab               jupyterlab-git       7
#   51       jupyterlab  jupyterlab-metadata-service       1
#   52       jupyterlab               jupyterlab-toc       1
#   53       jupyterlab              jupyterlab_apod       1
#   54       jupyterlab               jupyterlab_app       1
#   55       jupyterlab                 team-compass       3
#   56          nteract                    bookstore       3
#   57          nteract                  coffee_boat       1
#   58          nteract                     hydrogen      10
#   59          nteract                      nteract       4
#   60          nteract                    papermill       7
#   61          nteract                     semiotic       4
#
#                                     org/repo
#   0                        ipython/ipykernel
#   1                      ipython/ipyparallel
#   2                          ipython/ipython
#   3                 ipython/ipython-in-depth
#   4                    jupyter/accessibility
#   5                    jupyter/docker-stacks
#   6               jupyter/enterprise_gateway
#   7                          jupyter/jupyter
#   8                     jupyter/jupyter-book
#   9                    jupyter/jupyter-drive
#   10                  jupyter/jupyter-sphinx
#   11                  jupyter/jupyter_client
#   12                  jupyter/jupyter_server
#   13                           jupyter/nb2kg
#   14                       jupyter/nbconvert
#   15                          jupyter/nbdime
#   16                        jupyter/nbgrader
#   17                        jupyter/nbviewer
#   18                        jupyter/notebook
#   19                       jupyter/qtconsole
#   20                     jupyter/repo2docker
#   21                        jupyter/testpath
#   22              jupyter-widgets/ipyleaflet
#   23              jupyter-widgets/ipywidgets
#   24      jupyter-widgets/jupyterlab-sidecar
#   25               jupyter-widgets/pythreejs
#   26                 jupyterhub/batchspawner
#   27                    jupyterhub/binderhub
#   28                jupyterhub/dockerspawner
#   29                   jupyterhub/helm-chart
#   ..                                     ...
#   32                   jupyterhub/jupyterhub
#   33        jupyterhub/kerberosauthenticator
#   34                  jupyterhub/kubespawner
#   35            jupyterhub/ldapauthenticator
#   36          jupyterhub/mybinder.org-deploy
#   37          jupyterhub/nativeauthenticator
#   38               jupyterhub/systemdspawner
#   39                 jupyterhub/team-compass
#   40      jupyterhub/the-littlest-jupyterhub
#   41                jupyterhub/traefik-proxy
#   42                  jupyterhub/wrapspawner
#   43       jupyterhub/zero-to-jupyterhub-k8s
#   44    jupyterlab/extension-cookiecutter-ts
#   45            jupyterlab/jupyter-renderers
#   46                   jupyterlab/jupyterlab
#   47          jupyterlab/jupyterlab-celltags
#   48        jupyterlab/jupyterlab-commenting
#   49     jupyterlab/jupyterlab-data-explorer
#   50               jupyterlab/jupyterlab-git
#   51  jupyterlab/jupyterlab-metadata-service
#   52               jupyterlab/jupyterlab-toc
#   53              jupyterlab/jupyterlab_apod
#   54               jupyterlab/jupyterlab_app
#   55                 jupyterlab/team-compass
#   56                       nteract/bookstore
#   57                     nteract/coffee_boat
#   58                        nteract/hydrogen
#   59                         nteract/nteract
#   60                       nteract/papermill
#   61                        nteract/semiotic
#
#   [62 rows x 4 columns],
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['hydrogen', 'papermill', 'nteract', 'semiotic', 'bookstore', 'coffee_boat', 'jupyterlab', 'jupyterlab-commenting', 'jupyterlab-data-explorer', 'jupyterlab-git', 'jupyterlab-celltags', 'team-compass', 'jupyter-renderers', 'extension-cookiecutter-ts', 'jupyterlab-metadata-service', 'jupyterlab-toc', 'jupyterlab_apod', 'jupyterlab_app', 'jupyterhub', 'the-littlest-jupyterhub', 'zero-to-jupyterhub-k8s', 'binderhub', 'team-compass', 'kubespawner', 'mybinder.org-deploy', 'batchspawner', 'dockerspawner', 'ldapauthenticator', 'systemdspawner', 'jupyter-server-proxy', 'traefik-proxy', 'helm-chart', 'jupyter-rsession-proxy', 'kerberosauthenticator', 'nativeauthenticator', 'wrapspawner', 'ipywidgets', 'ipyleaflet', 'jupyterlab-sidecar', 'pythreejs', 'notebook', 'repo2docker', 'jupyter-book', 'jupyter-sphinx', 'docker-stacks', 'jupyter', 'nbconvert', 'nbgrader', 'enterprise_gateway', 'nbdime', 'jupyter_server', 'nb2kg', 'qtconsole', 'accessibility', 'jupyter-drive', 'jupyter_client', 'nbviewer', 'testpath', 'ipython', 'ipykernel', 'ipyparallel', 'ipython-in-depth']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues created in the last 30 days'
# })

# %%
closed_counts = closed.groupby(['org', 'repo']).count()['number'].reset_index()
closed_counts['org/repo'] = closed_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = closed_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=closed_counts, title=f"Issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                       repo  number  \
#   0   binder-examples                 demo-julia       1
#   1           ipython                  ipykernel       1
#   2           ipython                    ipython      16
#   3           ipython                  traitlets       2
#   4           jupyter              docker-stacks       2
#   5           jupyter         enterprise_gateway       6
#   6           jupyter                    jupyter       1
#   7           jupyter               jupyter-book       6
#   8           jupyter             jupyter-sphinx      10
#   9           jupyter          jupyter.github.io       1
#   10          jupyter             jupyter_client       4
#   11          jupyter             jupyter_server       1
#   12          jupyter                      nb2kg       1
#   13          jupyter                  nbconvert       2
#   14          jupyter                     nbdime       1
#   15          jupyter                   nbgrader       1
#   16          jupyter                   nbviewer       3
#   17          jupyter                   notebook      46
#   18          jupyter                  qtconsole       2
#   19          jupyter                repo2docker       7
#   20          jupyter                  telemetry       3
#   21  jupyter-widgets                 ipyleaflet      10
#   22  jupyter-widgets                 ipywidgets      20
#   23  jupyter-widgets         jupyterlab-sidecar       1
#   24  jupyter-widgets               midicontrols       1
#   25  jupyter-widgets                  pythreejs       1
#   26  jupyter-widgets                   tutorial       1
#   27       jupyterhub               batchspawner       1
#   28       jupyterhub                  binderhub       5
#   29       jupyterhub              dockerspawner       3
#   30       jupyterhub       jupyter-server-proxy       1
#   31       jupyterhub                 jupyterhub       6
#   32       jupyterhub   jupyterhub-deploy-docker       1
#   33       jupyterhub      kerberosauthenticator       1
#   34       jupyterhub                kubespawner       1
#   35       jupyterhub        mybinder.org-deploy       5
#   36       jupyterhub             oauthenticator       1
#   37       jupyterhub               team-compass      15
#   38       jupyterhub    the-littlest-jupyterhub       5
#   39       jupyterhub              traefik-proxy       4
#   40       jupyterhub     zero-to-jupyterhub-k8s      10
#   41       jupyterlab  extension-cookiecutter-js       1
#   42       jupyterlab          jupyter-renderers       7
#   43       jupyterlab                 jupyterlab      51
#   44       jupyterlab   jupyterlab-data-explorer       2
#   45       jupyterlab             jupyterlab-git       4
#   46       jupyterlab             jupyterlab-toc       2
#   47          nteract                  bookstore       5
#   48          nteract                   commuter       1
#   49          nteract                   hydrogen      34
#   50          nteract            meeting-minutes       1
#   51          nteract                    nteract      25
#   52          nteract                  papermill       6
#   53          nteract                  scrapbook       1
#   54          nteract                   semiotic       4
#   55          nteract                       vdom       1
#
#                                   org/repo
#   0             binder-examples/demo-julia
#   1                      ipython/ipykernel
#   2                        ipython/ipython
#   3                      ipython/traitlets
#   4                  jupyter/docker-stacks
#   5             jupyter/enterprise_gateway
#   6                        jupyter/jupyter
#   7                   jupyter/jupyter-book
#   8                 jupyter/jupyter-sphinx
#   9              jupyter/jupyter.github.io
#   10                jupyter/jupyter_client
#   11                jupyter/jupyter_server
#   12                         jupyter/nb2kg
#   13                     jupyter/nbconvert
#   14                        jupyter/nbdime
#   15                      jupyter/nbgrader
#   16                      jupyter/nbviewer
#   17                      jupyter/notebook
#   18                     jupyter/qtconsole
#   19                   jupyter/repo2docker
#   20                     jupyter/telemetry
#   21            jupyter-widgets/ipyleaflet
#   22            jupyter-widgets/ipywidgets
#   23    jupyter-widgets/jupyterlab-sidecar
#   24          jupyter-widgets/midicontrols
#   25             jupyter-widgets/pythreejs
#   26              jupyter-widgets/tutorial
#   27               jupyterhub/batchspawner
#   28                  jupyterhub/binderhub
#   29              jupyterhub/dockerspawner
#   30       jupyterhub/jupyter-server-proxy
#   31                 jupyterhub/jupyterhub
#   32   jupyterhub/jupyterhub-deploy-docker
#   33      jupyterhub/kerberosauthenticator
#   34                jupyterhub/kubespawner
#   35        jupyterhub/mybinder.org-deploy
#   36             jupyterhub/oauthenticator
#   37               jupyterhub/team-compass
#   38    jupyterhub/the-littlest-jupyterhub
#   39              jupyterhub/traefik-proxy
#   40     jupyterhub/zero-to-jupyterhub-k8s
#   41  jupyterlab/extension-cookiecutter-js
#   42          jupyterlab/jupyter-renderers
#   43                 jupyterlab/jupyterlab
#   44   jupyterlab/jupyterlab-data-explorer
#   45             jupyterlab/jupyterlab-git
#   46             jupyterlab/jupyterlab-toc
#   47                     nteract/bookstore
#   48                      nteract/commuter
#   49                      nteract/hydrogen
#   50               nteract/meeting-minutes
#   51                       nteract/nteract
#   52                     nteract/papermill
#   53                     nteract/scrapbook
#   54                      nteract/semiotic
#   55                          nteract/vdom  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['hydrogen', 'nteract', 'papermill', 'bookstore', 'semiotic', 'commuter', 'meeting-minutes', 'scrapbook', 'vdom', 'jupyterlab', 'jupyter-renderers', 'jupyterlab-git', 'jupyterlab-data-explorer', 'jupyterlab-toc', 'extension-cookiecutter-js', 'team-compass', 'zero-to-jupyterhub-k8s', 'jupyterhub', 'binderhub', 'mybinder.org-deploy', 'the-littlest-jupyterhub', 'traefik-proxy', 'dockerspawner', 'batchspawner', 'jupyter-server-proxy', 'jupyterhub-deploy-docker', 'kerberosauthenticator', 'kubespawner', 'oauthenticator', 'ipywidgets', 'ipyleaflet', 'jupyterlab-sidecar', 'midicontrols', 'pythreejs', 'tutorial', 'notebook', 'jupyter-sphinx', 'repo2docker', 'enterprise_gateway', 'jupyter-book', 'jupyter_client', 'nbviewer', 'telemetry', 'docker-stacks', 'nbconvert', 'qtconsole', 'jupyter', 'jupyter.github.io', 'jupyter_server', 'nb2kg', 'nbdime', 'nbgrader', 'ipython', 'traitlets', 'ipykernel', 'demo-julia']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues closed in the last 30 days'
# })

# %% [markdown]
# ### A list of recent issues
#
# Below is a list of issues with recent activity in each repository. If they seem of interest
# to you, click on their links and jump in to participate!

# %%
# Add comment count data to issues and PRs
comment_counts = comments.groupby(['org', 'repo', 'issue_id']).count().iloc[:, 0].to_frame()
comment_counts.columns = ['n_comments']
comment_counts = comment_counts.reset_index()

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, (org, idata) in enumerate(comment_counts.groupby('org')):
    issue_md = []
    issue_md.append(f"#### {org}")
    issue_md.append("")
    for (org, repo), i_issues in idata.groupby(['org', 'repo']):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")
        
        top_issues = i_issues.sort_values('n_comments', ascending=False).head(n_plot)
        top_issue_list = pd.merge(issues, top_issues, left_on=['org', 'repo', 'number'], right_on=['org', 'repo', 'issue_id'])
        for _, issue in top_issue_list.sort_values('n_comments', ascending=False).head(n_plot).iterrows():
            user_name = issue['author']
            user_url = author_url(user_name)
            issue_number = issue['number']
            issue_html = issue['url']
            issue_title = issue['title']

            text = f"* [(#{issue_number})]({issue_html}): _{issue_title}_ by **[@{user_name}]({user_url})**"
            issue_md.append(text)
    issue_md.append('')
    md_html = HTML(markdown('\n'.join(issue_md)))
    
    children = list(tabs.children)
    children.append(HTML(markdown('\n'.join(issue_md))))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"Here are the top {n_plot} active issues in each repository in the last {n_days} days"))
display(tabs)
# Out:
# Here are the top 5 active issues in each repository in the last 30 days
# Tab(children=(HTML(value='<h4>binder-examples</h4>\n<h5><a href="https://github.com/binder-examples/data-quilt…

# %% [markdown]
# ## Commenters across repositories
#
# These are commenters across all issues and pull requests in the last several days.
# These are colored by the commenter's association with the organization. For information
# about what these associations mean, [see this StackOverflow post](https://stackoverflow.com/a/28866914/1927102).

# %%
commentors = (
    comments
    .groupby(['org', 'repo', 'author', 'authorAssociation'])
    .count().rename(columns={'id': 'count'})['count']
    .reset_index()
    .sort_values(['org', 'count'], ascending=False)
)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(commentors.groupby(['org'])):
    title = f"Top {n_plot} commentors for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='count',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                org        repo        author authorAssociation  count
#     2  binder-examples  demo-julia     choldgraf            MEMBER      2
#     5  binder-examples  jupyterlab   cornhundred              NONE      2
#     0  binder-examples  data-quilt       betatim            MEMBER      1
#     1  binder-examples  data-quilt   matheusmota              NONE      1
#     3  binder-examples  demo-julia  davidanthoff       CONTRIBUTOR      1
#     4  binder-examples  jupyterlab     choldgraf            MEMBER      1,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for binder-examples in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:         org         repo                 author authorAssociation  count
#     12  ipython      ipython                Carreau            MEMBER     48
#     40  ipython      ipython               gpotter2       CONTRIBUTOR      6
#     14  ipython      ipython         LucianaMarques       CONTRIBUTOR      4
#     28  ipython      ipython             ccordoba12       CONTRIBUTOR      4
#     78  ipython    traitlets                  minrk            MEMBER      3
#     79  ipython    traitlets               rmorshea      COLLABORATOR      3
#     6   ipython    ipykernel             ccordoba12       CONTRIBUTOR      2
#     36  ipython      ipython  faultdiagnosistoolbox              NONE      2
#     37  ipython      ipython               fehiepsi              NONE      2
#     42  ipython      ipython             jamesmyatt              NONE      2
#     47  ipython      ipython               jseabold       CONTRIBUTOR      2
#     62  ipython      ipython              tacaswell       CONTRIBUTOR      2
#     64  ipython      ipython             thrasibule              NONE      2
#     66  ipython      ipython               voronind              NONE      2
#     67  ipython      ipython                wenjuno              NONE      2
#     70  ipython      ipython              ztaylor96              NONE      2
#     75  ipython    traitlets                  Jamim       CONTRIBUTOR      2
#     7   ipython    ipykernel                hroncok       CONTRIBUTOR      1
#     8   ipython    ipykernel                  kribu              NONE      1
#     9   ipython    ipykernel                  minrk            MEMBER      1
#     10  ipython  ipyparallel         stuartthomas25              NONE      1
#     11  ipython      ipython           Benjamin-Lee              NONE      1
#     13  ipython      ipython            ElieGouzien              NONE      1
#     15  ipython      ipython             OriolAbril       CONTRIBUTOR      1
#     16  ipython      ipython                   Qix-              NONE      1
#     17  ipython      ipython               Scowley4              NONE      1
#     18  ipython      ipython                   Suor              NONE      1
#     19  ipython      ipython               YahavFes              NONE      1
#     20  ipython      ipython               aakhmetz              NONE      1
#     21  ipython      ipython           alessioarena              NONE      1
#     22  ipython      ipython             alexmojaki              NONE      1
#     23  ipython      ipython             anentropic              NONE      1
#     24  ipython      ipython                anntzer       CONTRIBUTOR      1
#     25  ipython      ipython               bhodorog              NONE      1
#     26  ipython      ipython         brandonwillard       CONTRIBUTOR      1
#     27  ipython      ipython           brunobeltran              NONE      1
#     29  ipython      ipython            craymichael              NONE      1
#     30  ipython      ipython                dashesy              NONE      1
#     31  ipython      ipython           davidmakovoz              NONE      1
#     32  ipython      ipython              davidnero              NONE      1
#     33  ipython      ipython             denfromufa              NONE      1
#     34  ipython      ipython                dickmao              NONE      1
#     35  ipython      ipython         farisachugthai              NONE      1
#     38  ipython      ipython              gdhameeja              NONE      1
#     39  ipython      ipython            germanesosa              NONE      1
#     41  ipython      ipython               henri-kt              NONE      1
#     43  ipython      ipython               janusson              NONE      1
#     44  ipython      ipython                 jdatin              NONE      1
#     45  ipython      ipython              jmansilla              NONE      1
#     46  ipython      ipython         joaomarcosgris              NONE      1,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:          org                   repo         author authorAssociation  count
#     373  jupyter            repo2docker        betatim            MEMBER     66
#     349  jupyter               notebook      takluyver            MEMBER     42
#     385  jupyter            repo2docker          minrk            MEMBER     28
#     134  jupyter           jupyter-book      choldgraf            MEMBER     22
#     163  jupyter         jupyter_client  SylvainCorlay            MEMBER     21
#     221  jupyter               nbviewer       krinsman       CONTRIBUTOR     21
#     104  jupyter     enterprise_gateway    kevin-bates            MEMBER     19
#     396  jupyter            repo2docker      yuvipanda            MEMBER     16
#     378  jupyter            repo2docker     davidrpugh       CONTRIBUTOR     15
#     145  jupyter         jupyter-sphinx       akhmerov            MEMBER     14
#     376  jupyter            repo2docker   consideRatio      COLLABORATOR     14
#     162  jupyter         jupyter_client          MSeal            MEMBER     12
#     397  jupyter              telemetry        Zsailer            MEMBER     12
#     185  jupyter                  nb2kg    kevin-bates            MEMBER     11
#     310  jupyter               notebook       lresende            MEMBER     11
#     399  jupyter              telemetry      yuvipanda            MEMBER     11
#     213  jupyter               nbgrader       jhamrick            MEMBER     10
#     177  jupyter         jupyter_server  SylvainCorlay            MEMBER      9
#     363  jupyter              qtconsole     ccordoba12      COLLABORATOR      9
#     377  jupyter            repo2docker   davidanthoff       CONTRIBUTOR      9
#     100  jupyter     enterprise_gateway       IMAM9AIS       CONTRIBUTOR      8
#     178  jupyter         jupyter_server        Zsailer            MEMBER      8
#     299  jupyter               notebook  joshuazeltser       CONTRIBUTOR      8
#     381  jupyter            repo2docker        jlperla              NONE      8
#     182  jupyter                  nb2kg       IMAM9AIS              NONE      7
#     183  jupyter                  nb2kg          dleen       CONTRIBUTOR      7
#     102  jupyter     enterprise_gateway         esevan      COLLABORATOR      6
#     135  jupyter           jupyter-book        emdupre      COLLABORATOR      6
#     188  jupyter              nbconvert          MSeal            MEMBER      6
#     268  jupyter               notebook      blink1073            MEMBER      6
#     323  jupyter               notebook         mpacer            MEMBER      6
#     108  jupyter     enterprise_gateway       suryag10              NONE      5
#     126  jupyter                jupyter        parente            MEMBER      5
#     168  jupyter         jupyter_client    kevin-bates            MEMBER      5
#     179  jupyter         jupyter_server       rolweber      COLLABORATOR      5
#     210  jupyter               nbgrader      Yenthe666              NONE      5
#     222  jupyter               nbviewer        parente            MEMBER      5
#     248  jupyter               notebook         Pierek              NONE      5
#     254  jupyter               notebook  SylvainCorlay            MEMBER      5
#     301  jupyter               notebook    kevin-bates            MEMBER      5
#     321  jupyter               notebook          minrk            MEMBER      5
#     346  jupyter               notebook     ssanderson       CONTRIBUTOR      5
#     365  jupyter              qtconsole       dalthviz       CONTRIBUTOR      5
#     371  jupyter            repo2docker         arnavs              NONE      5
#     379  jupyter            repo2docker      eexwhyzee       CONTRIBUTOR      5
#     382  jupyter            repo2docker    mael-le-gal              NONE      5
#     82   jupyter          accessibility         fperez            MEMBER      4
#     90   jupyter          docker-stacks          minrk            MEMBER      4
#     93   jupyter          docker-stacks        rubensa              NONE      4
#     98   jupyter  enhancement-proposals      westurner              NONE      4,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                  org                repo              author  \
#     427  jupyter-widgets          ipywidgets          jasongrout
#     415  jupyter-widgets          ipywidgets       SylvainCorlay
#     407  jupyter-widgets          ipyleaflet         martinRenou
#     439  jupyter-widgets          ipywidgets             vidartf
#     424  jupyter-widgets          ipywidgets               hainm
#     451  jupyter-widgets           pythreejs             vidartf
#     457  jupyter-widgets            tutorial             mwcraig
#     409  jupyter-widgets          ipyleaflet            stonebig
#     447  jupyter-widgets           pythreejs              ataiya
#     456  jupyter-widgets            tutorial         martinRenou
#     437  jupyter-widgets          ipywidgets            stonebig
#     402  jupyter-widgets          ipyleaflet          bill-coman
#     405  jupyter-widgets          ipyleaflet               jtpio
#     406  jupyter-widgets          ipyleaflet           kgiacobbi
#     419  jupyter-widgets          ipywidgets           choldgraf
#     440  jupyter-widgets          ipywidgets         xilunaJumma
#     444  jupyter-widgets  jupyterlab-sidecar          doutriaux1
#     401  jupyter-widgets          ipyleaflet       SylvainCorlay
#     403  jupyter-widgets          ipyleaflet            chbrandt
#     426  jupyter-widgets          ipywidgets           jakirkham
#     431  jupyter-widgets          ipywidgets         martinRenou
#     436  jupyter-widgets          ipywidgets          rskabelund
#     441  jupyter-widgets          ipywidgets         zxzhaixiang
#     445  jupyter-widgets        midicontrols          jasongrout
#     446  jupyter-widgets           pythreejs             TakodaS
#     448  jupyter-widgets           pythreejs          jasongrout
#     453  jupyter-widgets          traittypes       SylvainCorlay
#     404  jupyter-widgets          ipyleaflet            deeplook
#     408  jupyter-widgets          ipyleaflet         paulathomas
#     410  jupyter-widgets          ipywidgets          DYSpider13
#     411  jupyter-widgets          ipywidgets            DevFabrx
#     412  jupyter-widgets          ipywidgets           Juanlu001
#     413  jupyter-widgets          ipywidgets         Martinschei
#     414  jupyter-widgets          ipywidgets            Pabla007
#     416  jupyter-widgets          ipywidgets  amirhosseindavoody
#     417  jupyter-widgets          ipywidgets      artur-trzesiok
#     418  jupyter-widgets          ipywidgets       aungmyohtet07
#     420  jupyter-widgets          ipywidgets         cornhundred
#     421  jupyter-widgets          ipywidgets            dazzag24
#     422  jupyter-widgets          ipywidgets           dovahcrow
#     423  jupyter-widgets          ipywidgets       dustinmichels
#     425  jupyter-widgets          ipywidgets              ivanov
#     428  jupyter-widgets          ipywidgets         jquacinella
#     429  jupyter-widgets          ipywidgets     maartenbreddels
#     430  jupyter-widgets          ipywidgets            makaylas
#     432  jupyter-widgets          ipywidgets               metya
#     433  jupyter-widgets          ipywidgets    mrinalraghupathi
#     434  jupyter-widgets          ipywidgets             mwcraig
#     435  jupyter-widgets          ipywidgets        romain-intel
#     438  jupyter-widgets          ipywidgets             swayson
#
#         authorAssociation  count
#     427            MEMBER     51
#     415            MEMBER     50
#     407            MEMBER     20
#     439            MEMBER     20
#     424              NONE     13
#     451            MEMBER     12
#     457       CONTRIBUTOR     10
#     409       CONTRIBUTOR      7
#     447       CONTRIBUTOR      7
#     456            MEMBER      6
#     437       CONTRIBUTOR      5
#     402              NONE      4
#     405       CONTRIBUTOR      4
#     406       CONTRIBUTOR      4
#     419              NONE      4
#     440              NONE      3
#     444              NONE      3
#     401            MEMBER      2
#     403              NONE      2
#     426              NONE      2
#     431            MEMBER      2
#     436              NONE      2
#     441              NONE      2
#     445            MEMBER      2
#     446              NONE      2
#     448            MEMBER      2
#     453            MEMBER      2
#     404       CONTRIBUTOR      1
#     408              NONE      1
#     410              NONE      1
#     411              NONE      1
#     412       CONTRIBUTOR      1
#     413              NONE      1
#     414              NONE      1
#     416              NONE      1
#     417              NONE      1
#     418              NONE      1
#     420       CONTRIBUTOR      1
#     421              NONE      1
#     422              NONE      1
#     423       CONTRIBUTOR      1
#     425       CONTRIBUTOR      1
#     428              NONE      1
#     429            MEMBER      1
#     430              NONE      1
#     432              NONE      1
#     433              NONE      1
#     434       CONTRIBUTOR      1
#     435              NONE      1
#     438              NONE      1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:             org                     repo              author  \
#     585  jupyterhub             team-compass           choldgraf
#     556  jupyterhub      mybinder.org-deploy             betatim
#     584  jupyterhub             team-compass             betatim
#     466  jupyterhub                binderhub             betatim
#     629  jupyterhub   zero-to-jupyterhub-k8s        consideRatio
#     596  jupyterhub  the-littlest-jupyterhub      GeorgianaElena
#     522  jupyterhub               jupyterhub          nicorikken
#     592  jupyterhub             team-compass           sgibson91
#     590  jupyterhub             team-compass               minrk
#     588  jupyterhub             team-compass              jcrist
#     557  jupyterhub      mybinder.org-deploy           choldgraf
#     612  jupyterhub  the-littlest-jupyterhub           yuvipanda
#     468  jupyterhub                binderhub           choldgraf
#     521  jupyterhub               jupyterhub               minrk
#     540  jupyterhub    kerberosauthenticator              jcrist
#     558  jupyterhub      mybinder.org-deploy              henchc
#     560  jupyterhub      mybinder.org-deploy         mael-le-gal
#     461  jupyterhub             batchspawner             rkdarst
#     516  jupyterhub               jupyterhub           lakshaykc
#     544  jupyterhub              kubespawner        consideRatio
#     561  jupyterhub      mybinder.org-deploy               minrk
#     613  jupyterhub            traefik-proxy      GeorgianaElena
#     638  jupyterhub   zero-to-jupyterhub-k8s           lakshaykc
#     458  jupyterhub             batchspawner               Hoeze
#     473  jupyterhub                binderhub      kaseyhackspace
#     476  jupyterhub                binderhub            memeplex
#     589  jupyterhub             team-compass         mael-le-gal
#     593  jupyterhub             team-compass            willingc
#     601  jupyterhub  the-littlest-jupyterhub          gantheaume
#     614  jupyterhub            traefik-proxy               minrk
#     643  jupyterhub   zero-to-jupyterhub-k8s   sampathkethineedi
#     464  jupyterhub                binderhub            akhmerov
#     470  jupyterhub                binderhub        hugokerstens
#     477  jupyterhub                binderhub               minrk
#     501  jupyterhub               jupyterhub              Yensan
#     534  jupyterhub               jupyterhub           yuvipanda
#     563  jupyterhub      mybinder.org-deploy           yuvipanda
#     569  jupyterhub           oauthenticator         cristiklein
#     571  jupyterhub           oauthenticator          diogozedan
#     574  jupyterhub           oauthenticator               minrk
#     587  jupyterhub             team-compass              henchc
#     626  jupyterhub   zero-to-jupyterhub-k8s            asimb123
#     465  jupyterhub                binderhub               amn41
#     469  jupyterhub                binderhub        consideRatio
#     488  jupyterhub   jupyter-rsession-proxy        anton-khodak
#     510  jupyterhub               jupyterhub            ericdill
#     513  jupyterhub               jupyterhub            katsar0v
#     518  jupyterhub               jupyterhub          m-alekseev
#     519  jupyterhub               jupyterhub              manics
#     528  jupyterhub               jupyterhub  ryanmartinneutrino
#
#         authorAssociation  count
#     585            MEMBER     44
#     556            MEMBER     37
#     584            MEMBER     31
#     466            MEMBER     22
#     629            MEMBER     20
#     596      COLLABORATOR     17
#     522              NONE     16
#     592            MEMBER     15
#     590            MEMBER     12
#     588            MEMBER     11
#     557            MEMBER     10
#     612            MEMBER     10
#     468            MEMBER      9
#     521            MEMBER      9
#     540            MEMBER      8
#     558            MEMBER      8
#     560            MEMBER      8
#     461       CONTRIBUTOR      6
#     516              NONE      6
#     544            MEMBER      6
#     561            MEMBER      6
#     613      COLLABORATOR      6
#     638              NONE      6
#     458              NONE      5
#     473              NONE      5
#     476              NONE      5
#     589            MEMBER      5
#     593            MEMBER      5
#     601              NONE      5
#     614            MEMBER      5
#     643              NONE      5
#     464              NONE      4
#     470              NONE      4
#     477            MEMBER      4
#     501              NONE      4
#     534            MEMBER      4
#     563            MEMBER      4
#     569              NONE      4
#     571              NONE      4
#     574            MEMBER      4
#     587            MEMBER      4
#     626              NONE      4
#     465              NONE      3
#     469            MEMBER      3
#     488       CONTRIBUTOR      3
#     510              NONE      3
#     513              NONE      3
#     518              NONE      3
#     519              NONE      3
#     528              NONE      3  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:             org                         repo            author  \
#     738  jupyterlab                   jupyterlab        jasongrout
#     691  jupyterlab                   jupyterlab         blink1073
#     798  jupyterlab                   jupyterlab           vidartf
#     786  jupyterlab                   jupyterlab        telamonian
#     732  jupyterlab                   jupyterlab        ian-r-rose
#     749  jupyterlab                   jupyterlab        krassowski
#     777  jupyterlab                   jupyterlab    saulshanabrook
#     657  jupyterlab                   jupyterlab            BoPeng
#     842  jupyterlab  jupyterlab-metadata-service            ceteri
#     681  jupyterlab                   jupyterlab          aschlaep
#     676  jupyterlab                   jupyterlab            afshin
#     828  jupyterlab               jupyterlab-git        jaipreet-s
#     819  jupyterlab              jupyterlab-demo        jasongrout
#     716  jupyterlab                   jupyterlab         ellisonbg
#     813  jupyterlab     jupyterlab-data-explorer    saulshanabrook
#     793  jupyterlab                   jupyterlab           tslaton
#     800  jupyterlab                   jupyterlab      vtrokhymenko
#     722  jupyterlab                   jupyterlab      flying-sheep
#     768  jupyterlab                   jupyterlab        nickeubank
#     784  jupyterlab                   jupyterlab          stonebig
#     827  jupyterlab               jupyterlab-git        fcollonval
#     728  jupyterlab                   jupyterlab           gnestor
#     843  jupyterlab  jupyterlab-metadata-service    saulshanabrook
#     673  jupyterlab                   jupyterlab           Zsailer
#     684  jupyterlab                   jupyterlab         athornton
#     696  jupyterlab                   jupyterlab             ciyer
#     709  jupyterlab                   jupyterlab       dharmaquark
#     745  jupyterlab                   jupyterlab             jtpio
#     790  jupyterlab                   jupyterlab         timkpaine
#     650  jupyterlab            jupyter-renderers           gnestor
#     664  jupyterlab                   jupyterlab        IgorDouven
#     690  jupyterlab                   jupyterlab           bjtho08
#     712  jupyterlab                   jupyterlab          domoritz
#     734  jupyterlab                   jupyterlab            ivanov
#     737  jupyterlab                   jupyterlab         jakirkham
#     759  jupyterlab                   jupyterlab       mayanksuman
#     830  jupyterlab               jupyterlab-git        luispuerto
#     653  jupyterlab            jupyter-renderers         jonmmease
#     688  jupyterlab                   jupyterlab           betatim
#     698  jupyterlab                   jupyterlab        daejong123
#     703  jupyterlab                   jupyterlab  david-waterworth
#     707  jupyterlab                   jupyterlab            dclong
#     717  jupyterlab                   jupyterlab           emcangi
#     729  jupyterlab                   jupyterlab          groverj3
#     736  jupyterlab                   jupyterlab           jakevdp
#     753  jupyterlab                   jupyterlab        luispuerto
#     764  jupyterlab                   jupyterlab        michaelaye
#     770  jupyterlab                   jupyterlab        oscar6echo
#     802  jupyterlab                   jupyterlab          willingc
#     817  jupyterlab              jupyterlab-demo         choldgraf
#
#         authorAssociation  count
#     738            MEMBER    112
#     691            MEMBER     82
#     798            MEMBER     74
#     786            MEMBER     51
#     732            MEMBER     49
#     749            MEMBER     26
#     777            MEMBER     21
#     657            MEMBER     17
#     842              NONE     16
#     681            MEMBER     15
#     676            MEMBER     14
#     828      COLLABORATOR     13
#     819            MEMBER     12
#     716            MEMBER     10
#     813            MEMBER     10
#     793       CONTRIBUTOR      9
#     800              NONE      9
#     722              NONE      8
#     768              NONE      8
#     784            MEMBER      8
#     827            MEMBER      8
#     728            MEMBER      7
#     843            MEMBER      7
#     673            MEMBER      6
#     684            MEMBER      6
#     696            MEMBER      6
#     709            MEMBER      6
#     745            MEMBER      6
#     790            MEMBER      6
#     650            MEMBER      5
#     664              NONE      5
#     690              NONE      5
#     712            MEMBER      5
#     734            MEMBER      5
#     737              NONE      5
#     759              NONE      5
#     830              NONE      5
#     653       CONTRIBUTOR      4
#     688              NONE      4
#     698              NONE      4
#     703              NONE      4
#     707            MEMBER      4
#     717              NONE      4
#     729              NONE      4
#     736              NONE      4
#     753              NONE      4
#     764            MEMBER      4
#     770              NONE      4
#     802            MEMBER      4
#     817            MEMBER      4  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:          org        repo           author authorAssociation  count
#     902  nteract    hydrogen   wadethestealth            MEMBER     89
#     879  nteract    hydrogen         aviatesk            MEMBER     43
#     908  nteract     nteract     captainsafia            MEMBER     35
#     926  nteract   papermill            MSeal            MEMBER     22
#     862  nteract   bookstore           mpacer            MEMBER     17
#     870  nteract    hydrogen       BenRussert            MEMBER     17
#     936  nteract   papermill           rgbkrk            MEMBER      9
#     924  nteract  nteract.io              now              NONE      8
#     865  nteract    commuter     captainsafia            MEMBER      7
#     867  nteract    commuter           taniki            MEMBER      7
#     930  nteract   papermill        casperdcl            MEMBER      7
#     932  nteract   papermill     duarteocarmo            MEMBER      7
#     893  nteract    hydrogen        pepicello              NONE      6
#     896  nteract    hydrogen         shr00mie              NONE      6
#     939  nteract   scrapbook            MSeal            MEMBER      6
#     891  nteract    hydrogen     optionsraghu              NONE      5
#     905  nteract     nteract   CrystallineCat            MEMBER      5
#     922  nteract     nteract   wadethestealth            MEMBER      5
#     925  nteract   papermill           0anton              NONE      5
#     864  nteract   bookstore         willingc            MEMBER      4
#     887  nteract    hydrogen      jesusloplar              NONE      4
#     903  nteract     nteract       BenRussert            MEMBER      4
#     911  nteract     nteract      hydrosquall            MEMBER      4
#     919  nteract     nteract           rgbkrk            MEMBER      4
#     927  nteract   papermill      RoelBrouwer       CONTRIBUTOR      4
#     885  nteract    hydrogen         isajacas              NONE      3
#     890  nteract    hydrogen         n-riesco            MEMBER      3
#     899  nteract    hydrogen  terasakisatoshi              NONE      3
#     923  nteract     nteract         willingc            MEMBER      3
#     941  nteract   scrapbook         willingc            MEMBER      3
#     942  nteract    semiotic           emeeks            MEMBER      3
#     861  nteract   bookstore            MSeal            MEMBER      2
#     866  nteract    commuter           guzmud              NONE      2
#     872  nteract    hydrogen           Helveg              NONE      2
#     874  nteract    hydrogen        Mikeymice              NONE      2
#     876  nteract    hydrogen            Tbosa              NONE      2
#     878  nteract    hydrogen          ald0405              NONE      2
#     883  nteract    hydrogen            goi42              NONE      2
#     884  nteract    hydrogen         hoishing            MEMBER      2
#     889  nteract    hydrogen     keaiwangwang              NONE      2
#     898  nteract    hydrogen      smashwilson            MEMBER      2
#     906  nteract     nteract      SpencerPark              NONE      2
#     916  nteract     nteract          ocefpaf              NONE      2
#     921  nteract     nteract             todo              NONE      2
#     931  nteract   papermill        choldgraf            MEMBER      2
#     935  nteract   papermill           mwouts            MEMBER      2
#     937  nteract   papermill         shoelsch              NONE      2
#     940  nteract   scrapbook         trallard            MEMBER      2
#     863  nteract   bookstore             todo              NONE      1
#     868  nteract        docs          nthakor              NONE      1,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## First responders
#
# First responders are the first people to respond to a new issue in one of the repositories.
# The following plots show first responders for recently-created issues.

# %%
first_comments = []
for (org, repo, issue_id), i_comments in comments.groupby(['org', 'repo', 'issue_id']):
    ix_min = pd.to_datetime(i_comments['createdAt']).idxmin()
    first_comments.append(i_comments.loc[ix_min])
first_comments = pd.concat(first_comments, axis=1).T

# %%
first_responder_counts = first_comments.groupby(['org', 'author', 'authorAssociation'], as_index=False).\
    count().rename(columns={'id': 'n_first_responses'}).sort_values(['org', 'n_first_responses'], ascending=False)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(first_responder_counts.groupby(['org'])):
    title = f"Top {n_plot} first responders for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='n_first_responses',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                org       author authorAssociation  createdAt  updatedAt  url  \
#     0  binder-examples      betatim            MEMBER          1          1    1
#     1  binder-examples    choldgraf            MEMBER          1          1    1
#     2  binder-examples  cornhundred              NONE          1          1    1
#
#        repo  issue_id  n_first_responses
#     0     1         1                  1
#     1     1         1                  1
#     2     1         1                  1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for binder-examples in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:         org                 author authorAssociation  createdAt  updatedAt  \
#     4   ipython                Carreau            MEMBER         20         20
#     36  ipython                  minrk            MEMBER          2          2
#     3   ipython           Benjamin-Lee              NONE          1          1
#     5   ipython                  Jamim       CONTRIBUTOR          1          1
#     6   ipython             OriolAbril       CONTRIBUTOR          1          1
#     7   ipython               Scowley4              NONE          1          1
#     8   ipython                   Suor              NONE          1          1
#     9   ipython               YahavFes              NONE          1          1
#     10  ipython             alexmojaki              NONE          1          1
#     11  ipython             anentropic              NONE          1          1
#     12  ipython             ccordoba12       CONTRIBUTOR          1          1
#     13  ipython            craymichael              NONE          1          1
#     14  ipython           davidmakovoz              NONE          1          1
#     15  ipython             denfromufa              NONE          1          1
#     16  ipython                dickmao              NONE          1          1
#     17  ipython         farisachugthai              NONE          1          1
#     18  ipython  faultdiagnosistoolbox              NONE          1          1
#     19  ipython              gdhameeja              NONE          1          1
#     20  ipython            germanesosa              NONE          1          1
#     21  ipython               gpotter2       CONTRIBUTOR          1          1
#     22  ipython                hroncok       CONTRIBUTOR          1          1
#     23  ipython             jamesmyatt              NONE          1          1
#     24  ipython               janusson              NONE          1          1
#     25  ipython             jasongrout            MEMBER          1          1
#     26  ipython                 jdatin              NONE          1          1
#     27  ipython              jmansilla              NONE          1          1
#     28  ipython         joaomarcosgris              NONE          1          1
#     29  ipython              keflavich              NONE          1          1
#     30  ipython                  kernc              NONE          1          1
#     31  ipython                  kribu              NONE          1          1
#     32  ipython                leogout              NONE          1          1
#     33  ipython                 lidd77              NONE          1          1
#     34  ipython               m0nzderr              NONE          1          1
#     35  ipython             matthewgdv              NONE          1          1
#     37  ipython                mjkvaak              NONE          1          1
#     38  ipython                   mx73              NONE          1          1
#     39  ipython               rmorshea      COLLABORATOR          1          1
#     40  ipython         stuartthomas25              NONE          1          1
#     41  ipython                tbeadle              NONE          1          1
#     42  ipython                 torbjo              NONE          1          1
#     43  ipython                wenjuno              NONE          1          1
#     44  ipython             yogevyuval              NONE          1          1
#     45  ipython              ztaylor96              NONE          1          1
#     46  ipython            zthompson47              NONE          1          1
#
#         url  repo  issue_id  n_first_responses
#     4    20    20        20                 20
#     36    2     2         2                  2
#     3     1     1         1                  1
#     5     1     1         1                  1
#     6     1     1         1                  1
#     7     1     1         1                  1
#     8     1     1         1                  1
#     9     1     1         1                  1
#     10    1     1         1                  1
#     11    1     1         1                  1
#     12    1     1         1                  1
#     13    1     1         1                  1
#     14    1     1         1                  1
#     15    1     1         1                  1
#     16    1     1         1                  1
#     17    1     1         1                  1
#     18    1     1         1                  1
#     19    1     1         1                  1
#     20    1     1         1                  1
#     21    1     1         1                  1
#     22    1     1         1                  1
#     23    1     1         1                  1
#     24    1     1         1                  1
#     25    1     1         1                  1
#     26    1     1         1                  1
#     27    1     1         1                  1
#     28    1     1         1                  1
#     29    1     1         1                  1
#     30    1     1         1                  1
#     31    1     1         1                  1
#     32    1     1         1                  1
#     33    1     1         1                  1
#     34    1     1         1                  1
#     35    1     1         1                  1
#     37    1     1         1                  1
#     38    1     1         1                  1
#     39    1     1         1                  1
#     40    1     1         1                  1
#     41    1     1         1                  1
#     42    1     1         1                  1
#     43    1     1         1                  1
#     44    1     1         1                  1
#     45    1     1         1                  1
#     46    1     1         1                  1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:          org           author authorAssociation  createdAt  updatedAt  url  \
#     215  jupyter        takluyver            MEMBER         40         40   40
#     91   jupyter          betatim            MEMBER         20         20   20
#     100  jupyter        choldgraf            MEMBER         16         16   16
#     157  jupyter         krinsman       CONTRIBUTOR         14         14   14
#     154  jupyter      kevin-bates            MEMBER         12         12   12
#     175  jupyter            minrk            MEMBER         12         12   12
#     70   jupyter    SylvainCorlay            MEMBER         10         10   10
#     79   jupyter          Zsailer            MEMBER          6          6    6
#     84   jupyter         akhmerov            MEMBER          6          6    6
#     230  jupyter        yuvipanda            MEMBER          6          6    6
#     151  jupyter    joshuazeltser       CONTRIBUTOR          5          5    5
#     63   jupyter            MSeal            MEMBER          4          4    4
#     98   jupyter       ccordoba12      COLLABORATOR          4          4    4
#     123  jupyter          emdupre      COLLABORATOR          4          4    4
#     149  jupyter         jhamrick            MEMBER          3          3    3
#     162  jupyter         lresende            MEMBER          3          3    3
#     180  jupyter           mwouts              NONE          3          3    3
#     185  jupyter          parente            MEMBER          3          3    3
#     200  jupyter          rubensa              NONE          3          3    3
#     58   jupyter         IMAM9AIS       CONTRIBUTOR          2          2    2
#     69   jupyter          Sefriol              NONE          2          2    2
#     75   jupyter        Yenthe666              NONE          2          2    2
#     90   jupyter        bavaria95              NONE          2          2    2
#     104  jupyter     consideRatio      COLLABORATOR          2          2    2
#     105  jupyter         cqcn1991              NONE          2          2    2
#     109  jupyter         dalthviz       CONTRIBUTOR          2          2    2
#     112  jupyter       davidrpugh       CONTRIBUTOR          2          2    2
#     122  jupyter        ellisonbg            MEMBER          2          2    2
#     126  jupyter           esevan      COLLABORATOR          2          2    2
#     130  jupyter           fperez            MEMBER          2          2    2
#     142  jupyter       jaipreet-s      COLLABORATOR          2          2    2
#     144  jupyter       jasongrout            MEMBER          2          2    2
#     147  jupyter         jbweston            MEMBER          2          2    2
#     152  jupyter         jyu78749              NONE          2          2    2
#     161  jupyter           limbuu              NONE          2          2    2
#     164  jupyter           manics              NONE          2          2    2
#     168  jupyter  meeseeksmachine              NONE          2          2    2
#     177  jupyter           mpacer            MEMBER          2          2    2
#     184  jupyter          ocefpaf              NONE          2          2    2
#     197  jupyter         rolweber      COLLABORATOR          2          2    2
#     225  jupyter        wesinator              NONE          2          2    2
#     229  jupyter         yavalvas              NONE          2          2    2
#     47   jupyter      1998anwesha              NONE          1          1    1
#     48   jupyter           A-Fisk              NONE          1          1    1
#     49   jupyter        AbuditRai              NONE          1          1    1
#     50   jupyter         AmirTIQK              NONE          1          1    1
#     51   jupyter     Bikashiitbhu              NONE          1          1    1
#     52   jupyter          Blizzke              NONE          1          1    1
#     53   jupyter   ClaudeCoulombe              NONE          1          1    1
#     54   jupyter         DBCerigo              NONE          1          1    1
#
#          repo  issue_id  n_first_responses
#     215    40        40                 40
#     91     20        20                 20
#     100    16        16                 16
#     157    14        14                 14
#     154    12        12                 12
#     175    12        12                 12
#     70     10        10                 10
#     79      6         6                  6
#     84      6         6                  6
#     230     6         6                  6
#     151     5         5                  5
#     63      4         4                  4
#     98      4         4                  4
#     123     4         4                  4
#     149     3         3                  3
#     162     3         3                  3
#     180     3         3                  3
#     185     3         3                  3
#     200     3         3                  3
#     58      2         2                  2
#     69      2         2                  2
#     75      2         2                  2
#     90      2         2                  2
#     104     2         2                  2
#     105     2         2                  2
#     109     2         2                  2
#     112     2         2                  2
#     122     2         2                  2
#     126     2         2                  2
#     130     2         2                  2
#     142     2         2                  2
#     144     2         2                  2
#     147     2         2                  2
#     152     2         2                  2
#     161     2         2                  2
#     164     2         2                  2
#     168     2         2                  2
#     177     2         2                  2
#     184     2         2                  2
#     197     2         2                  2
#     225     2         2                  2
#     229     2         2                  2
#     47      1         1                  1
#     48      1         1                  1
#     49      1         1                  1
#     50      1         1                  1
#     51      1         1                  1
#     52      1         1                  1
#     53      1         1                  1
#     54      1         1                  1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                  org              author authorAssociation  createdAt  \
#     234  jupyter-widgets       SylvainCorlay            MEMBER         20
#     252  jupyter-widgets         martinRenou            MEMBER         13
#     246  jupyter-widgets          jasongrout            MEMBER         11
#     257  jupyter-widgets             vidartf            MEMBER          8
#     254  jupyter-widgets             mwcraig       CONTRIBUTOR          7
#     244  jupyter-widgets               hainm              NONE          3
#     239  jupyter-widgets           choldgraf              NONE          2
#     241  jupyter-widgets          doutriaux1              NONE          2
#     249  jupyter-widgets               jtpio       CONTRIBUTOR          2
#     259  jupyter-widgets         zxzhaixiang              NONE          2
#     231  jupyter-widgets            DevFabrx              NONE          1
#     232  jupyter-widgets           Juanlu001       CONTRIBUTOR          1
#     233  jupyter-widgets         Martinschei              NONE          1
#     235  jupyter-widgets             TakodaS              NONE          1
#     236  jupyter-widgets  amirhosseindavoody              NONE          1
#     237  jupyter-widgets       aungmyohtet07              NONE          1
#     238  jupyter-widgets          bill-coman              NONE          1
#     240  jupyter-widgets         cornhundred       CONTRIBUTOR          1
#     242  jupyter-widgets           dovahcrow              NONE          1
#     243  jupyter-widgets       dustinmichels       CONTRIBUTOR          1
#     245  jupyter-widgets              ivanov       CONTRIBUTOR          1
#     247  jupyter-widgets              jmmshn              NONE          1
#     248  jupyter-widgets         jquacinella              NONE          1
#     250  jupyter-widgets           kgiacobbi       CONTRIBUTOR          1
#     251  jupyter-widgets            makaylas              NONE          1
#     253  jupyter-widgets               metya              NONE          1
#     255  jupyter-widgets         paulathomas              NONE          1
#     256  jupyter-widgets          rskabelund              NONE          1
#     258  jupyter-widgets         xilunaJumma              NONE          1
#
#          updatedAt  url  repo  issue_id  n_first_responses
#     234         20   20    20        20                 20
#     252         13   13    13        13                 13
#     246         11   11    11        11                 11
#     257          8    8     8         8                  8
#     254          7    7     7         7                  7
#     244          3    3     3         3                  3
#     239          2    2     2         2                  2
#     241          2    2     2         2                  2
#     249          2    2     2         2                  2
#     259          2    2     2         2                  2
#     231          1    1     1         1                  1
#     232          1    1     1         1                  1
#     233          1    1     1         1                  1
#     235          1    1     1         1                  1
#     236          1    1     1         1                  1
#     237          1    1     1         1                  1
#     238          1    1     1         1                  1
#     240          1    1     1         1                  1
#     242          1    1     1         1                  1
#     243          1    1     1         1                  1
#     245          1    1     1         1                  1
#     247          1    1     1         1                  1
#     248          1    1     1         1                  1
#     250          1    1     1         1                  1
#     251          1    1     1         1                  1
#     253          1    1     1         1                  1
#     255          1    1     1         1                  1
#     256          1    1     1         1                  1
#     258          1    1     1         1                  1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:             org             author authorAssociation  createdAt  updatedAt  \
#     285  jupyterhub            betatim            MEMBER         29         29
#     329  jupyterhub              minrk            MEMBER         18         18
#     288  jupyterhub          choldgraf            MEMBER         17         17
#     355  jupyterhub          yuvipanda            MEMBER         13         13
#     291  jupyterhub       consideRatio            MEMBER         12         12
#     264  jupyterhub     GeorgianaElena      COLLABORATOR         11         11
#     338  jupyterhub            rkdarst       CONTRIBUTOR          5          5
#     272  jupyterhub             Yensan              NONE          4          4
#     316  jupyterhub           katsar0v              NONE          4          4
#     322  jupyterhub          lakshaykc              NONE          4          4
#     344  jupyterhub  sampathkethineedi              NONE          4          4
#     345  jupyterhub          sgibson91            MEMBER          4          4
#     306  jupyterhub             henchc            MEMBER          3          3
#     310  jupyterhub             jcrist            MEMBER          3          3
#     332  jupyterhub         nicorikken              NONE          3          3
#     339  jupyterhub            rkdarst              NONE          3          3
#     262  jupyterhub            EvilMav              NONE          2          2
#     267  jupyterhub              Hoeze              NONE          2          2
#     269  jupyterhub           Redhappy              NONE          2          2
#     281  jupyterhub       anton-khodak       CONTRIBUTOR          2          2
#     286  jupyterhub             bitnik       CONTRIBUTOR          2          2
#     293  jupyterhub             dalg24       CONTRIBUTOR          2          2
#     298  jupyterhub             emirot       CONTRIBUTOR          2          2
#     300  jupyterhub           frouzbeh              NONE          2          2
#     302  jupyterhub         gantheaume              NONE          2          2
#     308  jupyterhub           ingoglia              NONE          2          2
#     324  jupyterhub        mael-le-gal            MEMBER          2          2
#     326  jupyterhub             manics              NONE          2          2
#     328  jupyterhub           memeplex              NONE          2          2
#     330  jupyterhub           mpilosov              NONE          2          2
#     342  jupyterhub         ryanlovett            MEMBER          2          2
#     343  jupyterhub            ryogesh       CONTRIBUTOR          2          2
#     347  jupyterhub     stevenstetzler              NONE          2          2
#     353  jupyterhub           wqh17101              NONE          2          2
#     260  jupyterhub        BidwellNREL              NONE          1          1
#     261  jupyterhub            Carreau            MEMBER          1          1
#     263  jupyterhub          FeatCrush              NONE          1          1
#     265  jupyterhub     GeorgianaElena              NONE          1          1
#     266  jupyterhub    GrahamDumpleton       CONTRIBUTOR          1          1
#     268  jupyterhub              Jnchi              NONE          1          1
#     270  jupyterhub          TiemenSch              NONE          1          1
#     271  jupyterhub        UCSBGauchos              NONE          1          1
#     273  jupyterhub            Zsailer            MEMBER          1          1
#     274  jupyterhub        ahmedanis03              NONE          1          1
#     275  jupyterhub           ahshanmd              NONE          1          1
#     276  jupyterhub         akaszynski              NONE          1          1
#     277  jupyterhub           akhmerov              NONE          1          1
#     278  jupyterhub     albertmichaelj              NONE          1          1
#     279  jupyterhub       aliasmrchips              NONE          1          1
#     280  jupyterhub          alvinhuff              NONE          1          1
#
#          url  repo  issue_id  n_first_responses
#     285   29    29        29                 29
#     329   18    18        18                 18
#     288   17    17        17                 17
#     355   13    13        13                 13
#     291   12    12        12                 12
#     264   11    11        11                 11
#     338    5     5         5                  5
#     272    4     4         4                  4
#     316    4     4         4                  4
#     322    4     4         4                  4
#     344    4     4         4                  4
#     345    4     4         4                  4
#     306    3     3         3                  3
#     310    3     3         3                  3
#     332    3     3         3                  3
#     339    3     3         3                  3
#     262    2     2         2                  2
#     267    2     2         2                  2
#     269    2     2         2                  2
#     281    2     2         2                  2
#     286    2     2         2                  2
#     293    2     2         2                  2
#     298    2     2         2                  2
#     300    2     2         2                  2
#     302    2     2         2                  2
#     308    2     2         2                  2
#     324    2     2         2                  2
#     326    2     2         2                  2
#     328    2     2         2                  2
#     330    2     2         2                  2
#     342    2     2         2                  2
#     343    2     2         2                  2
#     347    2     2         2                  2
#     353    2     2         2                  2
#     260    1     1         1                  1
#     261    1     1         1                  1
#     263    1     1         1                  1
#     265    1     1         1                  1
#     266    1     1         1                  1
#     268    1     1         1                  1
#     270    1     1         1                  1
#     271    1     1         1                  1
#     273    1     1         1                  1
#     274    1     1         1                  1
#     275    1     1         1                  1
#     276    1     1         1                  1
#     277    1     1         1                  1
#     278    1     1         1                  1
#     279    1     1         1                  1
#     280    1     1         1                  1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:             org           author authorAssociation  createdAt  updatedAt  url  \
#     425  jupyterlab       jasongrout            MEMBER         42         42   42
#     419  jupyterlab       ian-r-rose            MEMBER         25         25   25
#     387  jupyterlab        blink1073            MEMBER         24         24   24
#     466  jupyterlab          vidartf            MEMBER         20         20   20
#     456  jupyterlab   saulshanabrook            MEMBER         14         14   14
#     435  jupyterlab       krassowski            MEMBER         12         12   12
#     461  jupyterlab       telamonian            MEMBER          8          8    8
#     414  jupyterlab          gnestor            MEMBER          5          5    5
#     421  jupyterlab       jaipreet-s      COLLABORATOR          5          5    5
#     359  jupyterlab           BoPeng            MEMBER          3          3    3
#     379  jupyterlab         aschlaep            MEMBER          3          3    3
#     402  jupyterlab      dharmaquark            MEMBER          3          3    3
#     464  jupyterlab          tslaton       CONTRIBUTOR          3          3    3
#     360  jupyterlab          Carreau            MEMBER          2          2    2
#     369  jupyterlab    SylvainCorlay            MEMBER          2          2    2
#     373  jupyterlab           afshin            MEMBER          2          2    2
#     382  jupyterlab        athornton            MEMBER          2          2    2
#     390  jupyterlab           ceteri              NONE          2          2    2
#     392  jupyterlab            ciyer            MEMBER          2          2    2
#     394  jupyterlab       daejong123              NONE          2          2    2
#     401  jupyterlab           dclong            MEMBER          2          2    2
#     403  jupyterlab      dhirschfeld            MEMBER          2          2    2
#     408  jupyterlab         echarles            MEMBER          2          2    2
#     409  jupyterlab        ellisonbg            MEMBER          2          2    2
#     410  jupyterlab       fcollonval            MEMBER          2          2    2
#     412  jupyterlab           firasm              NONE          2          2    2
#     431  jupyterlab        jonmmease       CONTRIBUTOR          2          2    2
#     446  jupyterlab       mbektasbbg            MEMBER          2          2    2
#     463  jupyterlab        timkpaine            MEMBER          2          2    2
#     356  jupyterlab       AlbertHilb            MEMBER          1          1    1
#     357  jupyterlab    AlbertUlysses              NONE          1          1    1
#     358  jupyterlab      AlokTakshak              NONE          1          1    1
#     361  jupyterlab    CreationTribe              NONE          1          1    1
#     362  jupyterlab      DiegoPiloni              NONE          1          1    1
#     363  jupyterlab           EloyRD              NONE          1          1    1
#     364  jupyterlab         Ingvar-Y              NONE          1          1    1
#     365  jupyterlab          KevinGG              NONE          1          1    1
#     366  jupyterlab        Koushik95              NONE          1          1    1
#     367  jupyterlab         LarsHill              NONE          1          1    1
#     368  jupyterlab  SultanOrazbayev              NONE          1          1    1
#     370  jupyterlab         ZedTDean              NONE          1          1    1
#     371  jupyterlab       aaronchall              NONE          1          1    1
#     372  jupyterlab          adunlea              NONE          1          1    1
#     374  jupyterlab      alanfalloon              NONE          1          1    1
#     375  jupyterlab       alesgenova              NONE          1          1    1
#     376  jupyterlab         amit1rrr              NONE          1          1    1
#     377  jupyterlab    antonio-rojas              NONE          1          1    1
#     378  jupyterlab     arogozhnikov              NONE          1          1    1
#     380  jupyterlab           asford              NONE          1          1    1
#     381  jupyterlab  ashwinvasudevan              NONE          1          1    1
#
#          repo  issue_id  n_first_responses
#     425    42        42                 42
#     419    25        25                 25
#     387    24        24                 24
#     466    20        20                 20
#     456    14        14                 14
#     435    12        12                 12
#     461     8         8                  8
#     414     5         5                  5
#     421     5         5                  5
#     359     3         3                  3
#     379     3         3                  3
#     402     3         3                  3
#     464     3         3                  3
#     360     2         2                  2
#     369     2         2                  2
#     373     2         2                  2
#     382     2         2                  2
#     390     2         2                  2
#     392     2         2                  2
#     394     2         2                  2
#     401     2         2                  2
#     403     2         2                  2
#     408     2         2                  2
#     409     2         2                  2
#     410     2         2                  2
#     412     2         2                  2
#     431     2         2                  2
#     446     2         2                  2
#     463     2         2                  2
#     356     1         1                  1
#     357     1         1                  1
#     358     1         1                  1
#     361     1         1                  1
#     362     1         1                  1
#     363     1         1                  1
#     364     1         1                  1
#     365     1         1                  1
#     366     1         1                  1
#     367     1         1                  1
#     368     1         1                  1
#     370     1         1                  1
#     371     1         1                  1
#     372     1         1                  1
#     374     1         1                  1
#     375     1         1                  1
#     376     1         1                  1
#     377     1         1                  1
#     378     1         1                  1
#     380     1         1                  1
#     381     1         1                  1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:          org           author authorAssociation  createdAt  updatedAt  url  \
#     519  nteract   wadethestealth            MEMBER         30         30   30
#     484  nteract     captainsafia            MEMBER         28         28   28
#     479  nteract            MSeal            MEMBER         17         17   17
#     482  nteract         aviatesk            MEMBER         13         13   13
#     502  nteract           mpacer            MEMBER         10         10   10
#     505  nteract              now              NONE          8          8    8
#     475  nteract       BenRussert            MEMBER          6          6    6
#     510  nteract           rgbkrk            MEMBER          6          6    6
#     520  nteract         willingc            MEMBER          5          5    5
#     489  nteract           emeeks            MEMBER          3          3    3
#     518  nteract             todo              NONE          3          3    3
#     476  nteract   CrystallineCat            MEMBER          2          2    2
#     485  nteract        casperdcl            MEMBER          2          2    2
#     495  nteract      hydrosquall            MEMBER          2          2    2
#     473  nteract           0anton              NONE          1          1    1
#     474  nteract    AstrickHarren              NONE          1          1    1
#     477  nteract    HatemAlamir90              NONE          1          1    1
#     478  nteract           KC2016              NONE          1          1    1
#     480  nteract      RoelBrouwer       CONTRIBUTOR          1          1    1
#     481  nteract      StevenLi-DS              NONE          1          1    1
#     483  nteract          bnbarak            MEMBER          1          1    1
#     486  nteract           dar10p              NONE          1          1    1
#     487  nteract       dylanross3            MEMBER          1          1    1
#     488  nteract     electiondaze              NONE          1          1    1
#     490  nteract       farmerscut              NONE          1          1    1
#     491  nteract          gnestor            MEMBER          1          1    1
#     492  nteract            goi42              NONE          1          1    1
#     493  nteract           guzmud              NONE          1          1    1
#     494  nteract         hoishing            MEMBER          1          1    1
#     496  nteract         isajacas              NONE          1          1    1
#     497  nteract          jacopok              NONE          1          1    1
#     498  nteract      joselatrans              NONE          1          1    1
#     499  nteract     keaiwangwang              NONE          1          1    1
#     500  nteract       martibosch              NONE          1          1    1
#     501  nteract    mike-seekwell              NONE          1          1    1
#     503  nteract           mwouts            MEMBER          1          1    1
#     504  nteract         n-riesco            MEMBER          1          1    1
#     506  nteract          nthakor              NONE          1          1    1
#     507  nteract        orijjsjje              NONE          1          1    1
#     508  nteract         renovate       CONTRIBUTOR          1          1    1
#     509  nteract         rganardi            MEMBER          1          1    1
#     511  nteract           sammdu              NONE          1          1    1
#     512  nteract         shr00mie              NONE          1          1    1
#     513  nteract         skim2257              NONE          1          1    1
#     514  nteract      smashwilson            MEMBER          1          1    1
#     515  nteract           taniki            MEMBER          1          1    1
#     516  nteract  terasakisatoshi              NONE          1          1    1
#     517  nteract            tkind              NONE          1          1    1
#
#          repo  issue_id  n_first_responses
#     519    30        30                 30
#     484    28        28                 28
#     479    17        17                 17
#     482    13        13                 13
#     502    10        10                 10
#     505     8         8                  8
#     475     6         6                  6
#     510     6         6                  6
#     520     5         5                  5
#     489     3         3                  3
#     518     3         3                  3
#     476     2         2                  2
#     485     2         2                  2
#     495     2         2                  2
#     473     1         1                  1
#     474     1         1                  1
#     477     1         1                  1
#     478     1         1                  1
#     480     1         1                  1
#     481     1         1                  1
#     483     1         1                  1
#     486     1         1                  1
#     487     1         1                  1
#     488     1         1                  1
#     490     1         1                  1
#     491     1         1                  1
#     492     1         1                  1
#     493     1         1                  1
#     494     1         1                  1
#     496     1         1                  1
#     497     1         1                  1
#     498     1         1                  1
#     499     1         1                  1
#     500     1         1                  1
#     501     1         1                  1
#     503     1         1                  1
#     504     1         1                  1
#     506     1         1                  1
#     507     1         1                  1
#     508     1         1                  1
#     509     1         1                  1
#     511     1         1                  1
#     512     1         1                  1
#     513     1         1                  1
#     514     1         1                  1
#     515     1         1                  1
#     516     1         1                  1
#     517     1         1                  1  ,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
