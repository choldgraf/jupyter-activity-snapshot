# %%
import seaborn as sns
import pandas as pd
import numpy as np
import altair as alt
from markdown import markdown
from IPython.display import Markdown
from ipywidgets.widgets import HTML, Tab
from ipywidgets import widgets
from datetime import timedelta
from matplotlib import pyplot as plt
import os.path as op

from mod import load_data, alt_theme

# %%
def author_url(author):
    return f"https://github.com/{author}"

# %%
# Parameters
fmt_date = "{:%Y-%m-%d}"

n_days = 90
start_date = fmt_date.format(pd.datetime.today() - timedelta(days=n_days))
end_date = fmt_date.format(pd.datetime.today())

renderer = "jupyterlab"
github_orgs = ["jupyterhub", "jupyter", "jupyterlab", "jupyter-widgets", "ipython", "binder-examples", "nteract"]

# %%
# Parameters
renderer = "kaggle"
start_date = "2019-04-01"
end_date = "2019-05-01"

# %%
comments, issues, prs = load_data('../data/')
bot_names = pd.read_csv('bot_names.csv')['names'].tolist()
comments = comments.query('author not in @bot_names').drop_duplicates()
issues = issues.query('author not in @bot_names').drop_duplicates()
prs = prs.query('author not in @bot_names').drop_duplicates()
# Out:
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:24: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   comments = pd.concat(comments)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:25: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   issues = pd.concat(issues)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:26: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   prs = pd.concat(prs)

# %%
# Only keep the dates we want
comments = comments.query('updatedAt > @start_date and updatedAt < @end_date')
issues = issues.query('updatedAt > @start_date and updatedAt < @end_date')
prs = prs.query('updatedAt > @start_date and updatedAt < @end_date')

# %%
alt.renderers.enable(renderer);
alt.themes.register('my_theme', alt_theme)
alt.themes.enable("my_theme")
# Out:
# ThemeRegistry.enable('my_theme')

# %%
# Information about out time window
time_delta = pd.to_datetime(end_date) - pd.to_datetime(start_date)
n_days = time_delta.days

# Information about the data we loaded
github_orgs = comments['org'].unique()

# %% [markdown]
# # GitHub activity
#
# Jupyter also has lots of activity across GitHub repositories. The following sections contain
# overviews of recent activity across the following GitHub organizations:

# %%
# Define colors we'll use for GitHub membership
author_types = ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', "NONE"]

author_palette = sns.palettes.blend_palette(["lightgrey", "lightgreen", "darkgreen"], 4)
author_colors = ["rgb({}, {}, {}, {})".format(*(ii*256)) for ii in author_palette]
author_color_dict = {key: val for key, val in zip(author_types, author_palette)}

# %%
orgs_md = []
for org in github_orgs:
    orgs_md.append(f'* [github.com/{org}](https://github.com/{org})')
Markdown('\n'.join(orgs_md))
# Out:
# * [github.com/jupyterlab](https://github.com/jupyterlab)
# * [github.com/jupyter-widgets](https://github.com/jupyter-widgets)
# * [github.com/ipython](https://github.com/ipython)
# * [github.com/binder-examples](https://github.com/binder-examples)
# * [github.com/jupyter](https://github.com/jupyter)
# * [github.com/jupyterhub](https://github.com/jupyterhub)
# * [github.com/nteract](https://github.com/nteract)

# %%
Markdown(f"Showing GitHub activity from **{start_date}** to **{end_date}**")
# Out:
# Showing GitHub activity from **2019-04-01** to **2019-05-01**

# %% [markdown]
# ## List of all contributors per organization
#
# First, we'll list each contributor that has contributed to each organization in the last several days.
# Contributions to open source projects are diverse, and involve much more than just contributing code and
# code review. Thanks to everybody in the Jupyter communities for all that they do.

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, org in enumerate(github_orgs):
    authors_comments = comments.query('org == @org')['author']
    authors_prs = prs.query('org == @org')['author']
    unique_participants = np.unique(np.hstack([authors_comments.values, authors_prs.values]).astype(str)).tolist()
    unique_participants.sort(key=lambda a: a.lower())
    
    all_participants = [f"[{participant}](https://github.com/{participant})" for participant in unique_participants]
    participants_md = " | ".join(all_participants)
    md_html = HTML("<center>{}</center>".format(markdown(participants_md)))
    
    children = list(tabs.children)
    children.append(md_html)
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"All participants across issues and pull requests in each org in the last {n_days} days"))
display(tabs)
# Out:
# All participants across issues and pull requests in each org in the last 30 days
# Tab(children=(HTML(value='<center><p><a href="https://github.com/afshin">afshin</a> | <a href="https://github.…

# %% [markdown]
# ## Merged Pull requests
#
# Here's an analysis of **merged pull requests** across each of the repositories in the Jupyter
# ecosystem.

# %%
merged = prs.query('state == "MERGED" and closedAt > @start_date and closedAt < @end_date')

# %%
prs_by_repo = merged.groupby(['org', 'repo']).count()['author'].reset_index().sort_values(['org', 'author'], ascending=False)
alt.Chart(data=prs_by_repo, title=f"Merged PRs in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=prs_by_repo['repo'].values.tolist()),
    y='author',
    color='org'
)
# Out:
# Chart({
#   data:                 org                      repo  author
#   46          nteract                 papermill       6
#   45          nteract                  hydrogen       2
#   49          nteract                      vdom       2
#   47          nteract                 scrapbook       1
#   48          nteract                  semiotic       1
#   38       jupyterlab                jupyterlab      58
#   41       jupyterlab            jupyterlab-git      11
#   39       jupyterlab       jupyterlab-celltags       3
#   40       jupyterlab  jupyterlab-data-explorer       1
#   42       jupyterlab         jupyterlab-github       1
#   43       jupyterlab   jupyterlab-google-drive       1
#   44       jupyterlab              team-compass       1
#   31       jupyterhub       mybinder.org-deploy      33
#   37       jupyterhub    zero-to-jupyterhub-k8s      19
#   28       jupyterhub                jupyterhub      15
#   24       jupyterhub                 binderhub      12
#   30       jupyterhub               kubespawner       6
#   33       jupyterhub            systemdspawner       5
#   35       jupyterhub   the-littlest-jupyterhub       5
#   22       jupyterhub            binder-billing       3
#   26       jupyterhub             dockerspawner       3
#   29       jupyterhub     kerberosauthenticator       3
#   34       jupyterhub              team-compass       3
#   20       jupyterhub      alabaster-jupyterhub       2
#   27       jupyterhub      jupyter-server-proxy       2
#   36       jupyterhub               yarnspawner       2
#   21       jupyterhub                    binder       1
#   23       jupyterhub               binder-data       1
#   25       jupyterhub   configurable-http-proxy       1
#   32       jupyterhub       nativeauthenticator       1
#   17  jupyter-widgets                ipyleaflet       9
#   19  jupyter-widgets                 pythreejs       4
#   18  jupyter-widgets                ipywidgets       3
#   11          jupyter                 nbconvert      19
#   16          jupyter               repo2docker      13
#   3           jupyter             docker-stacks      12
#   7           jupyter         jupyter.github.io       7
#   5           jupyter                   jupyter       6
#   14          jupyter                  notebook       6
#   4           jupyter        enterprise_gateway       5
#   6           jupyter              jupyter-book       5
#   8           jupyter            jupyter_client       3
#   10          jupyter                     nb2kg       2
#   13          jupyter                  nbviewer       2
#   15          jupyter                 qtconsole       2
#   9           jupyter            kernel_gateway       1
#   12          jupyter                  nbformat       1
#   0           ipython                   ipython       5
#   1           ipython          ipython-in-depth       3
#   2           ipython                 traitlets       3,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: ['papermill', 'hydrogen', 'vdom', 'scrapbook', 'semiotic', 'jupyterlab', 'jupyterlab-git', 'jupyterlab-celltags', 'jupyterlab-data-explorer', 'jupyterlab-github', 'jupyterlab-google-drive', 'team-compass', 'mybinder.org-deploy', 'zero-to-jupyterhub-k8s', 'jupyterhub', 'binderhub', 'kubespawner', 'systemdspawner', 'the-littlest-jupyterhub', 'binder-billing', 'dockerspawner', 'kerberosauthenticator', 'team-compass', 'alabaster-jupyterhub', 'jupyter-server-proxy', 'yarnspawner', 'binder', 'binder-data', 'configurable-http-proxy', 'nativeauthenticator', 'ipyleaflet', 'pythreejs', 'ipywidgets', 'nbconvert', 'repo2docker', 'docker-stacks', 'jupyter.github.io', 'jupyter', 'notebook', 'enterprise_gateway', 'jupyter-book', 'jupyter_client', 'nb2kg', 'nbviewer', 'qtconsole', 'kernel_gateway', 'nbformat', 'ipython', 'ipython-in-depth', 'traitlets'],
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'author',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Merged PRs in the last 30 days'
# })

# %% [markdown]
# ### A list of merged PRs by project
#
# Below is a tabbed readout of recently-merged PRs. Check out the title to get an idea for what they
# implemented, and be sure to thank the PR author for their hard work!

# %%
tabs = widgets.Tab(children=[])
merged_by = {}
pr_by = {}
for ii, (org, idata) in enumerate(merged.groupby('org')):
    issue_md = []
    issue_md.append(f"#### Closed PRs for org: `{org}`")
    issue_md.append("")
    for (org, repo), prs in idata.groupby(['org', 'repo']):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")
        for _, pr in prs.iterrows():
            user_name = pr['author']
            user_url = author_url(user_name)
            pr_number = pr['number']
            pr_html = pr['url']
            pr_title = pr['title']
            pr_closedby = pr['mergedBy']
            pr_closedby_url = f"https://github.com/{pr_closedby}"
            if user_name not in pr_by:
                pr_by[user_name] = 1
            else:
                pr_by[user_name] += 1
                
            if pr_closedby not in merged_by:
                merged_by[pr_closedby] = 1
            else:
                merged_by[pr_closedby] += 1
            text = f"* [(#{pr_number})]({pr_html}): _{pr_title}_ by **[@{user_name}]({user_url})** merged by **[@{pr_closedby}]({pr_closedby_url})**"
            issue_md.append(text)
    issue_md.append('')
    markdown_html = markdown('\n'.join(issue_md))
    
    children = list(tabs.children)
    children.append(HTML(markdown_html))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
tabs
# Out:
# Tab(children=(HTML(value='<h4>Closed PRs for org: <code>ipython</code></h4>\n<h5><a href="https://github.com/i…

# %% [markdown]
# ### Authoring and merging stats by repository
#
# Let's see who has been doing most of the PR authoring and merging. The PR author is generally the
# person that implemented a change in the repository (code, documentation, etc). The PR merger is
# the person that "pressed the green button" and got the change into the main codebase.

# %%
# Prep our merging DF
merged_by_repo = merged.groupby(['org', 'repo', 'author'], as_index=False).agg({'id': 'count', 'authorAssociation': 'first'}).rename(columns={'id': "authored", 'author': 'username'})
closed_by_repo = merged.groupby(['org', 'repo', 'mergedBy']).count()['id'].reset_index().rename(columns={'id': "closed", "mergedBy": "username"})

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(merged_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"PR authors for {iorg} in the last {n_days} days"
    idata = idata.groupby('username', as_index=False).agg({'authored': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('authored', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='authored',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)

alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:        username  authored authorAssociation
#     5     switowski         3       CONTRIBUTOR
#     2    dan-coates         2       CONTRIBUTOR
#     0  NumesSanguis         1              NONE
#     1       albertz         1       CONTRIBUTOR
#     3      pickfire         1       CONTRIBUTOR
#     4      rmorshea         1      COLLABORATOR
#     6       travigd         1       CONTRIBUTOR
#     7          yamt         1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:            username  authored authorAssociation
#     30          parente        14            MEMBER
#     2             MSeal         8            MEMBER
#     7           betatim         8            MEMBER
#     9         choldgraf         8            MEMBER
#     31         t-makaro         6      COLLABORATOR
#     27            minrk         3            MEMBER
#     35           witten         2       CONTRIBUTOR
#     6        alexmorley         2       CONTRIBUTOR
#     22          jhamman         2       CONTRIBUTOR
#     32        takluyver         2            MEMBER
#     0           Carreau         1            MEMBER
#     28           mpacer         1            MEMBER
#     24           kojix2         1       CONTRIBUTOR
#     25  maartenbreddels         1       CONTRIBUTOR
#     26        mattjtodd         1       CONTRIBUTOR
#     33        vilhelmen         1       CONTRIBUTOR
#     29      nils-werner         1       CONTRIBUTOR
#     34         willingc         1            MEMBER
#     36           xmnlab         1       CONTRIBUTOR
#     37           ying-w         1              NONE
#     23      kevin-bates         1            MEMBER
#     19          hroncok         1       CONTRIBUTOR
#     21    ivigamberdiev         1       CONTRIBUTOR
#     12          djhoese         1       CONTRIBUTOR
#     3            Szauka         1       CONTRIBUTOR
#     4         akchinSTC         1      COLLABORATOR
#     5      alasdairtran         1       CONTRIBUTOR
#     8      captainsafia         1            MEMBER
#     10           chuyqa         1       CONTRIBUTOR
#     11            clkao         1       CONTRIBUTOR
#     13          dsblank         1            MEMBER
#     20         impact27         1       CONTRIBUTOR
#     14         emiliotl         1       CONTRIBUTOR
#     15         ericdill         1       CONTRIBUTOR
#     16           esevan         1       CONTRIBUTOR
#     17     flying-sheep         1       CONTRIBUTOR
#     18  henriqueribeiro         1       CONTRIBUTOR
#     1   GrahamDumpleton         1       CONTRIBUTOR
#     38           ykgmfq         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:        username  authored authorAssociation
#     5       vidartf         6            MEMBER
#     1         jtpio         3       CONTRIBUTOR
#     2   martinRenou         3            MEMBER
#     0  VasavanThiru         2       CONTRIBUTOR
#     3       mwcraig         1       CONTRIBUTOR
#     4         pllim         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:           username  authored authorAssociation
#     6          betatim        22            MEMBER
#     9        choldgraf        20            MEMBER
#     26           minrk        20            MEMBER
#     18          jcrist         6            MEMBER
#     15          henchc         6            MEMBER
#     31       sgibson91         4            MEMBER
#     22      leportella         3       CONTRIBUTOR
#     0         RohitK89         3       CONTRIBUTOR
#     35       yuvipanda         2            MEMBER
#     23          manics         2      COLLABORATOR
#     10           cnydw         2       CONTRIBUTOR
#     11    consideRatio         2            MEMBER
#     32     sgloutnikov         2       CONTRIBUTOR
#     34     vmarkovtsev         1       CONTRIBUTOR
#     33             tmc         1       CONTRIBUTOR
#     2          Zsailer         1            MEMBER
#     30         ryogesh         1       CONTRIBUTOR
#     29        rmorshea         1       CONTRIBUTOR
#     28         parente         1            MEMBER
#     27        moschlar         1       CONTRIBUTOR
#     3       alexmorley         1       CONTRIBUTOR
#     25  mariusvniekerk         1       CONTRIBUTOR
#     24      manycoding         1       CONTRIBUTOR
#     8           certik         1       CONTRIBUTOR
#     7           brylie         1       CONTRIBUTOR
#     21          laxdog         1       CONTRIBUTOR
#     20        katylava         1       CONTRIBUTOR
#     19    junctionapps         1       CONTRIBUTOR
#     1        TheBear44         1       CONTRIBUTOR
#     17       javabrett         1       CONTRIBUTOR
#     16        hhuuggoo         1       CONTRIBUTOR
#     5         arturozv         1       CONTRIBUTOR
#     14           dylex         1       CONTRIBUTOR
#     13          dmarth         1       CONTRIBUTOR
#     12          dfeich         1       CONTRIBUTOR
#     4           arokem         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                username  authored authorAssociation
#     14           jasongrout        11            MEMBER
#     12           ian-r-rose         9            MEMBER
#     24       saulshanabrook         7            MEMBER
#     6              aschlaep         6            MEMBER
#     4                afshin         5            MEMBER
#     11              gnestor         5            MEMBER
#     13           jaipreet-s         4      COLLABORATOR
#     17        markellekelly         4            MEMBER
#     27              vidartf         2            MEMBER
#     16             lresende         2            MEMBER
#     7              bollwyvl         2            MEMBER
#     15          kristinauko         2            MEMBER
#     21           rahulpshah         1            MEMBER
#     23          richagadgil         1            MEMBER
#     22         raybellwaves         1            MEMBER
#     19               ohrely         1            MEMBER
#     25           telamonian         1            MEMBER
#     26               tibdex         1            MEMBER
#     20              parente         1            MEMBER
#     0            AlbertHilb         1            MEMBER
#     18  mathematicalmichael         1       CONTRIBUTOR
#     1                BoPeng         1            MEMBER
#     10                dleen         1      COLLABORATOR
#     9                 clkao         1            MEMBER
#     8             bsyouness         1              NONE
#     5               alfsuse         1            MEMBER
#     3               Zsailer         1            MEMBER
#     2            Tom-Nudell         1            MEMBER
#     28               wonsjb         1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:          username  authored authorAssociation
#     1           MSeal         4            MEMBER
#     5        willingc         3            MEMBER
#     4    captainsafia         2            MEMBER
#     0      BenRussert         1            MEMBER
#     2  VincentBLortie         1            MEMBER
#     3        aviatesk         1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %%
charts = []
for ii, (iorg, idata) in enumerate(closed_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"Merges for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='closed',
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:        org              repo   username  closed
#     0  ipython           ipython    Carreau       5
#     1  ipython  ipython-in-depth    Carreau       2
#     2  ipython  ipython-in-depth  blink1073       1
#     3  ipython         traitlets      minrk       3,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:         org                repo     username  closed
#     4   jupyter       docker-stacks        minrk       1
#     5   jupyter       docker-stacks      parente      11
#     6   jupyter  enterprise_gateway  kevin-bates       4
#     7   jupyter  enterprise_gateway     lresende       1
#     8   jupyter             jupyter      Carreau       1
#     9   jupyter             jupyter    choldgraf       2
#     10  jupyter             jupyter      parente       3
#     11  jupyter        jupyter-book    choldgraf       5
#     12  jupyter   jupyter.github.io         Ruv7       1
#     13  jupyter   jupyter.github.io        minrk       1
#     14  jupyter   jupyter.github.io      parente       3
#     15  jupyter   jupyter.github.io     willingc       2
#     16  jupyter      jupyter_client      Carreau       1
#     17  jupyter      jupyter_client        minrk       1
#     18  jupyter      jupyter_client    takluyver       1
#     19  jupyter      kernel_gateway     rolweber       1
#     20  jupyter               nb2kg  kevin-bates       2
#     21  jupyter           nbconvert        MSeal      12
#     22  jupyter           nbconvert       mpacer       6
#     23  jupyter           nbconvert    takluyver       1
#     24  jupyter            nbformat        MSeal       1
#     25  jupyter            nbviewer      parente       2
#     26  jupyter            notebook        minrk       1
#     27  jupyter            notebook    takluyver       5
#     28  jupyter           qtconsole   ccordoba12       2
#     29  jupyter         repo2docker      betatim       7
#     30  jupyter         repo2docker    choldgraf       1
#     31  jupyter         repo2docker       lheagy       1
#     32  jupyter         repo2docker        minrk       2
#     33  jupyter         repo2docker    yuvipanda       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                 org        repo       username  closed
#     34  jupyter-widgets  ipyleaflet    martinRenou       9
#     35  jupyter-widgets  ipywidgets  SylvainCorlay       3
#     36  jupyter-widgets   pythreejs        vidartf       4,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:            org                     repo      username  closed
#     37  jupyterhub     alabaster-jupyterhub       betatim       1
#     38  jupyterhub     alabaster-jupyterhub     choldgraf       1
#     39  jupyterhub                   binder       betatim       1
#     40  jupyterhub           binder-billing     choldgraf       3
#     41  jupyterhub              binder-data     choldgraf       1
#     42  jupyterhub                binderhub       betatim       7
#     43  jupyterhub                binderhub         minrk       3
#     44  jupyterhub                binderhub     sgibson91       1
#     45  jupyterhub                binderhub     yuvipanda       1
#     46  jupyterhub  configurable-http-proxy         minrk       1
#     47  jupyterhub            dockerspawner         minrk       3
#     48  jupyterhub     jupyter-server-proxy       betatim       2
#     49  jupyterhub               jupyterhub       betatim       3
#     50  jupyterhub               jupyterhub  consideRatio       1
#     51  jupyterhub               jupyterhub         minrk      11
#     52  jupyterhub    kerberosauthenticator        jcrist       3
#     53  jupyterhub              kubespawner       betatim       1
#     54  jupyterhub              kubespawner  consideRatio       2
#     55  jupyterhub              kubespawner         minrk       3
#     56  jupyterhub      mybinder.org-deploy       betatim      14
#     57  jupyterhub      mybinder.org-deploy     choldgraf      12
#     58  jupyterhub      mybinder.org-deploy        henchc       5
#     59  jupyterhub      mybinder.org-deploy         minrk       2
#     60  jupyterhub      nativeauthenticator     yuvipanda       1
#     61  jupyterhub           systemdspawner     yuvipanda       5
#     62  jupyterhub             team-compass       betatim       1
#     63  jupyterhub             team-compass     choldgraf       1
#     64  jupyterhub             team-compass         minrk       1
#     65  jupyterhub  the-littlest-jupyterhub     willirath       1
#     66  jupyterhub  the-littlest-jupyterhub     yuvipanda       4
#     67  jupyterhub              yarnspawner        jcrist       2
#     68  jupyterhub   zero-to-jupyterhub-k8s       betatim       4
#     69  jupyterhub   zero-to-jupyterhub-k8s     choldgraf       1
#     70  jupyterhub   zero-to-jupyterhub-k8s  consideRatio       6
#     71  jupyterhub   zero-to-jupyterhub-k8s         minrk       7
#     72  jupyterhub   zero-to-jupyterhub-k8s     sgibson91       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:            org                      repo        username  closed
#     73  jupyterlab                jupyterlab          afshin       4
#     74  jupyterlab                jupyterlab       blink1073      13
#     75  jupyterlab                jupyterlab      ian-r-rose      17
#     76  jupyterlab                jupyterlab      jasongrout      24
#     77  jupyterlab       jupyterlab-celltags   markellekelly       3
#     78  jupyterlab  jupyterlab-data-explorer  saulshanabrook       1
#     79  jupyterlab            jupyterlab-git      jaipreet-s       9
#     80  jupyterlab            jupyterlab-git  saulshanabrook       2
#     81  jupyterlab         jupyterlab-github      ian-r-rose       1
#     82  jupyterlab   jupyterlab-google-drive      ian-r-rose       1
#     83  jupyterlab              team-compass       blink1073       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:         org       repo      username  closed
#     84  nteract   hydrogen    BenRussert       2
#     85  nteract  papermill         MSeal       3
#     86  nteract  papermill        mpacer       2
#     87  nteract  papermill      willingc       1
#     88  nteract  scrapbook         MSeal       1
#     89  nteract   semiotic        emeeks       1
#     90  nteract       vdom  captainsafia       1
#     91  nteract       vdom      rmorshea       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## Issues
#
# Issues are **conversations** that happen on our GitHub repositories. Here's an
# analysis of issues across the Jupyter organizations.

# %%
created = issues.query('state == "OPEN" and createdAt > @start_date and createdAt < @end_date')
closed = issues.query('state == "CLOSED" and closedAt > @start_date and closedAt < @end_date')

# %%
created_counts = created.groupby(['org', 'repo']).count()['number'].reset_index()
created_counts['org/repo'] = created_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = created_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=created_counts, title=f"Issues created in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                     repo  number  \
#   0           ipython                ipykernel       4
#   1           ipython                  ipython      10
#   2           ipython                traitlets       2
#   3           jupyter            accessibility       1
#   4           jupyter            atom-notebook       1
#   5           jupyter                   design       1
#   6           jupyter            docker-stacks       3
#   7           jupyter       enterprise_gateway       2
#   8           jupyter                  jupyter       4
#   9           jupyter             jupyter-book       1
#   10          jupyter           jupyter_client       1
#   11          jupyter          jupyter_console       2
#   12          jupyter     kernel_gateway_demos       1
#   13          jupyter                nbconvert       1
#   14          jupyter                   nbdime       1
#   15          jupyter                 notebook      34
#   16  jupyter-widgets               ipyleaflet       1
#   17  jupyter-widgets               ipywidgets      14
#   18  jupyter-widgets       jupyterlab-sidecar       2
#   19  jupyter-widgets                pythreejs       4
#   20  jupyter-widgets               traittypes       1
#   21  jupyter-widgets      widget-cookiecutter       2
#   22  jupyter-widgets   widget-ts-cookiecutter       1
#   23       jupyterhub     alabaster-jupyterhub       2
#   24       jupyterhub           binder-billing       1
#   25       jupyterhub                binderhub       4
#   26       jupyterhub            dockerspawner       1
#   27       jupyterhub     jupyter-server-proxy       1
#   28       jupyterhub               jupyterhub       4
#   29       jupyterhub     jupyterhub-on-hadoop       2
#   30       jupyterhub           jupyterlab-hub       2
#   31       jupyterhub              kubespawner       7
#   32       jupyterhub        ldapauthenticator       1
#   33       jupyterhub           mybinder-tools       1
#   34       jupyterhub      mybinder.org-deploy       3
#   35       jupyterhub      nativeauthenticator       3
#   36       jupyterhub           oauthenticator       2
#   37       jupyterhub              sudospawner       1
#   38       jupyterhub             team-compass       1
#   39       jupyterhub   zero-to-jupyterhub-k8s      20
#   40       jupyterlab        jupyter-renderers       2
#   41       jupyterlab               jupyterlab      21
#   42       jupyterlab    jupyterlab-commenting       1
#   43       jupyterlab           jupyterlab-git       4
#   44       jupyterlab  jupyterlab-google-drive       3
#   45       jupyterlab         jupyterlab-latex       2
#   46       jupyterlab        jupyterlab-monaco       1
#   47       jupyterlab           jupyterlab-toc       2
#   48       jupyterlab             team-compass       1
#   49          nteract                bookstore       2
#   50          nteract                 commuter       2
#   51          nteract                       dx       1
#   52          nteract                  nteract      14
#   53          nteract                papermill       1
#   54          nteract                scrapbook       3
#   55          nteract                 semiotic       1
#   56          nteract            semiotic-docs       3
#
#                                     org/repo
#   0                        ipython/ipykernel
#   1                          ipython/ipython
#   2                        ipython/traitlets
#   3                    jupyter/accessibility
#   4                    jupyter/atom-notebook
#   5                           jupyter/design
#   6                    jupyter/docker-stacks
#   7               jupyter/enterprise_gateway
#   8                          jupyter/jupyter
#   9                     jupyter/jupyter-book
#   10                  jupyter/jupyter_client
#   11                 jupyter/jupyter_console
#   12            jupyter/kernel_gateway_demos
#   13                       jupyter/nbconvert
#   14                          jupyter/nbdime
#   15                        jupyter/notebook
#   16              jupyter-widgets/ipyleaflet
#   17              jupyter-widgets/ipywidgets
#   18      jupyter-widgets/jupyterlab-sidecar
#   19               jupyter-widgets/pythreejs
#   20              jupyter-widgets/traittypes
#   21     jupyter-widgets/widget-cookiecutter
#   22  jupyter-widgets/widget-ts-cookiecutter
#   23         jupyterhub/alabaster-jupyterhub
#   24               jupyterhub/binder-billing
#   25                    jupyterhub/binderhub
#   26                jupyterhub/dockerspawner
#   27         jupyterhub/jupyter-server-proxy
#   28                   jupyterhub/jupyterhub
#   29         jupyterhub/jupyterhub-on-hadoop
#   30               jupyterhub/jupyterlab-hub
#   31                  jupyterhub/kubespawner
#   32            jupyterhub/ldapauthenticator
#   33               jupyterhub/mybinder-tools
#   34          jupyterhub/mybinder.org-deploy
#   35          jupyterhub/nativeauthenticator
#   36               jupyterhub/oauthenticator
#   37                  jupyterhub/sudospawner
#   38                 jupyterhub/team-compass
#   39       jupyterhub/zero-to-jupyterhub-k8s
#   40            jupyterlab/jupyter-renderers
#   41                   jupyterlab/jupyterlab
#   42        jupyterlab/jupyterlab-commenting
#   43               jupyterlab/jupyterlab-git
#   44      jupyterlab/jupyterlab-google-drive
#   45             jupyterlab/jupyterlab-latex
#   46            jupyterlab/jupyterlab-monaco
#   47               jupyterlab/jupyterlab-toc
#   48                 jupyterlab/team-compass
#   49                       nteract/bookstore
#   50                        nteract/commuter
#   51                              nteract/dx
#   52                         nteract/nteract
#   53                       nteract/papermill
#   54                       nteract/scrapbook
#   55                        nteract/semiotic
#   56                   nteract/semiotic-docs  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['nteract', 'scrapbook', 'semiotic-docs', 'bookstore', 'commuter', 'dx', 'papermill', 'semiotic', 'jupyterlab', 'jupyterlab-git', 'jupyterlab-google-drive', 'jupyter-renderers', 'jupyterlab-latex', 'jupyterlab-toc', 'jupyterlab-commenting', 'jupyterlab-monaco', 'team-compass', 'zero-to-jupyterhub-k8s', 'kubespawner', 'binderhub', 'jupyterhub', 'mybinder.org-deploy', 'nativeauthenticator', 'alabaster-jupyterhub', 'jupyterhub-on-hadoop', 'jupyterlab-hub', 'oauthenticator', 'binder-billing', 'dockerspawner', 'jupyter-server-proxy', 'ldapauthenticator', 'mybinder-tools', 'sudospawner', 'team-compass', 'ipywidgets', 'pythreejs', 'jupyterlab-sidecar', 'widget-cookiecutter', 'ipyleaflet', 'traittypes', 'widget-ts-cookiecutter', 'notebook', 'jupyter', 'docker-stacks', 'enterprise_gateway', 'jupyter_console', 'accessibility', 'atom-notebook', 'design', 'jupyter-book', 'jupyter_client', 'kernel_gateway_demos', 'nbconvert', 'nbdime', 'ipython', 'ipykernel', 'traitlets']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues created in the last 30 days'
# })

# %%
closed_counts = closed.groupby(['org', 'repo']).count()['number'].reset_index()
closed_counts['org/repo'] = closed_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = closed_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=closed_counts, title=f"Issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                     repo  number  \
#   0   binder-examples                        r       2
#   1   binder-examples             requirements       1
#   2           ipython                  ipython       6
#   3           ipython                traitlets      13
#   4           jupyter            docker-stacks       6
#   5           jupyter       enterprise_gateway      10
#   6           jupyter                  jupyter       2
#   7           jupyter             jupyter-book       1
#   8           jupyter           jupyter-sphinx       2
#   9           jupyter           jupyter_client       1
#   10          jupyter                    nb2kg       3
#   11          jupyter                nbconvert       9
#   12          jupyter                   nbdime       1
#   13          jupyter                 nbviewer       2
#   14          jupyter                 notebook      16
#   15          jupyter                qtconsole       2
#   16          jupyter              repo2docker       6
#   17  jupyter-widgets               ipyleaflet       7
#   18  jupyter-widgets               ipywidgets      19
#   19  jupyter-widgets                pythreejs       6
#   20  jupyter-widgets   widget-ts-cookiecutter       1
#   21       jupyterhub                   binder       1
#   22       jupyterhub                binderhub       1
#   23       jupyterhub            dockerspawner       4
#   24       jupyterhub     jupyter-server-proxy       4
#   25       jupyterhub               jupyterhub      16
#   26       jupyterhub     jupyterhub-on-hadoop       5
#   27       jupyterhub              kubespawner       4
#   28       jupyterhub        ldapauthenticator       1
#   29       jupyterhub      mybinder.org-deploy       1
#   30       jupyterhub           oauthenticator       1
#   31       jupyterhub           systemdspawner       1
#   32       jupyterhub             team-compass       7
#   33       jupyterhub  the-littlest-jupyterhub       5
#   34       jupyterhub            traefik-proxy       1
#   35       jupyterhub              yarnspawner       3
#   36       jupyterhub   zero-to-jupyterhub-k8s      11
#   37       jupyterlab               jupyterlab      66
#   38       jupyterlab      jupyterlab-celltags       2
#   39       jupyterlab           jupyterlab-git      15
#   40       jupyterlab        jupyterlab-github       1
#   41       jupyterlab  jupyterlab-google-drive       2
#   42       jupyterlab         jupyterlab-latex       1
#   43       jupyterlab             team-compass       1
#   44          nteract                bookstore       1
#   45          nteract                 commuter       6
#   46          nteract                 hydrogen      12
#   47          nteract           minimal-plotly       1
#   48          nteract                papermill      11
#   49          nteract                scrapbook       1
#   50          nteract                 semiotic       7
#   51          nteract                     vdom       4
#
#                                     org/repo
#   0                        binder-examples/r
#   1             binder-examples/requirements
#   2                          ipython/ipython
#   3                        ipython/traitlets
#   4                    jupyter/docker-stacks
#   5               jupyter/enterprise_gateway
#   6                          jupyter/jupyter
#   7                     jupyter/jupyter-book
#   8                   jupyter/jupyter-sphinx
#   9                   jupyter/jupyter_client
#   10                           jupyter/nb2kg
#   11                       jupyter/nbconvert
#   12                          jupyter/nbdime
#   13                        jupyter/nbviewer
#   14                        jupyter/notebook
#   15                       jupyter/qtconsole
#   16                     jupyter/repo2docker
#   17              jupyter-widgets/ipyleaflet
#   18              jupyter-widgets/ipywidgets
#   19               jupyter-widgets/pythreejs
#   20  jupyter-widgets/widget-ts-cookiecutter
#   21                       jupyterhub/binder
#   22                    jupyterhub/binderhub
#   23                jupyterhub/dockerspawner
#   24         jupyterhub/jupyter-server-proxy
#   25                   jupyterhub/jupyterhub
#   26         jupyterhub/jupyterhub-on-hadoop
#   27                  jupyterhub/kubespawner
#   28            jupyterhub/ldapauthenticator
#   29          jupyterhub/mybinder.org-deploy
#   30               jupyterhub/oauthenticator
#   31               jupyterhub/systemdspawner
#   32                 jupyterhub/team-compass
#   33      jupyterhub/the-littlest-jupyterhub
#   34                jupyterhub/traefik-proxy
#   35                  jupyterhub/yarnspawner
#   36       jupyterhub/zero-to-jupyterhub-k8s
#   37                   jupyterlab/jupyterlab
#   38          jupyterlab/jupyterlab-celltags
#   39               jupyterlab/jupyterlab-git
#   40            jupyterlab/jupyterlab-github
#   41      jupyterlab/jupyterlab-google-drive
#   42             jupyterlab/jupyterlab-latex
#   43                 jupyterlab/team-compass
#   44                       nteract/bookstore
#   45                        nteract/commuter
#   46                        nteract/hydrogen
#   47                  nteract/minimal-plotly
#   48                       nteract/papermill
#   49                       nteract/scrapbook
#   50                        nteract/semiotic
#   51                            nteract/vdom  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['hydrogen', 'papermill', 'semiotic', 'commuter', 'vdom', 'bookstore', 'minimal-plotly', 'scrapbook', 'jupyterlab', 'jupyterlab-git', 'jupyterlab-celltags', 'jupyterlab-google-drive', 'jupyterlab-github', 'jupyterlab-latex', 'team-compass', 'jupyterhub', 'zero-to-jupyterhub-k8s', 'team-compass', 'jupyterhub-on-hadoop', 'the-littlest-jupyterhub', 'dockerspawner', 'jupyter-server-proxy', 'kubespawner', 'yarnspawner', 'binder', 'binderhub', 'ldapauthenticator', 'mybinder.org-deploy', 'oauthenticator', 'systemdspawner', 'traefik-proxy', 'ipywidgets', 'ipyleaflet', 'pythreejs', 'widget-ts-cookiecutter', 'notebook', 'enterprise_gateway', 'nbconvert', 'docker-stacks', 'repo2docker', 'nb2kg', 'jupyter', 'jupyter-sphinx', 'nbviewer', 'qtconsole', 'jupyter-book', 'jupyter_client', 'nbdime', 'traitlets', 'ipython', 'r', 'requirements']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues closed in the last 30 days'
# })

# %%
created_closed = pd.merge(created_counts.rename(columns={'number': 'created'}).drop(columns='org/repo'),
                          closed_counts.rename(columns={'number': 'closed'}).drop(columns='org/repo'),
                          on=['org', 'repo'], how='outer')

created_closed = pd.melt(created_closed, id_vars=['org', 'repo'], var_name="kind", value_name="count").replace(np.nan, 0)

# %%
charts = []
for org in github_orgs:
    # Pick the top 10 repositories
    this_issues = created_closed.query('org == @org')
    top_repos = this_issues.groupby(['repo']).sum().sort_values(by='count', ascending=False).head(10).index
    ch = alt.Chart(this_issues.query('repo in @top_repos'), width=120).mark_bar().encode(
        x=alt.X("kind", axis=alt.Axis(labelFontSize=15, title="")), 
        y=alt.Y('count', axis=alt.Axis(titleFontSize=15, labelFontSize=12)),
        color='kind',
        column=alt.Column("repo", header=alt.Header(title=f"Issue activity, last {n_days} days for {org}", titleFontSize=15, labelFontSize=12))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             org                     repo     kind  count
#     40   jupyterlab        jupyter-renderers  created    2.0
#     41   jupyterlab               jupyterlab  created   21.0
#     42   jupyterlab    jupyterlab-commenting  created    1.0
#     43   jupyterlab           jupyterlab-git  created    4.0
#     44   jupyterlab  jupyterlab-google-drive  created    3.0
#     45   jupyterlab         jupyterlab-latex  created    2.0
#     47   jupyterlab           jupyterlab-toc  created    2.0
#     48   jupyterlab             team-compass  created    1.0
#     69   jupyterlab      jupyterlab-celltags  created    0.0
#     70   jupyterlab        jupyterlab-github  created    0.0
#     114  jupyterlab        jupyter-renderers   closed    0.0
#     115  jupyterlab               jupyterlab   closed   66.0
#     116  jupyterlab    jupyterlab-commenting   closed    0.0
#     117  jupyterlab           jupyterlab-git   closed   15.0
#     118  jupyterlab  jupyterlab-google-drive   closed    2.0
#     119  jupyterlab         jupyterlab-latex   closed    1.0
#     121  jupyterlab           jupyterlab-toc   closed    0.0
#     122  jupyterlab             team-compass   closed    1.0
#     143  jupyterlab      jupyterlab-celltags   closed    2.0
#     144  jupyterlab        jupyterlab-github   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 30 days for jupyterlab',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                 org                    repo     kind  count
#     16  jupyter-widgets              ipyleaflet  created    1.0
#     17  jupyter-widgets              ipywidgets  created   14.0
#     18  jupyter-widgets      jupyterlab-sidecar  created    2.0
#     19  jupyter-widgets               pythreejs  created    4.0
#     20  jupyter-widgets              traittypes  created    1.0
#     21  jupyter-widgets     widget-cookiecutter  created    2.0
#     22  jupyter-widgets  widget-ts-cookiecutter  created    1.0
#     90  jupyter-widgets              ipyleaflet   closed    7.0
#     91  jupyter-widgets              ipywidgets   closed   19.0
#     92  jupyter-widgets      jupyterlab-sidecar   closed    0.0
#     93  jupyter-widgets               pythreejs   closed    6.0
#     94  jupyter-widgets              traittypes   closed    0.0
#     95  jupyter-widgets     widget-cookiecutter   closed    0.0
#     96  jupyter-widgets  widget-ts-cookiecutter   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 30 days for jupyter-widgets',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:         org       repo     kind  count
#     0   ipython  ipykernel  created    4.0
#     1   ipython    ipython  created   10.0
#     2   ipython  traitlets  created    2.0
#     74  ipython  ipykernel   closed    0.0
#     75  ipython    ipython   closed    6.0
#     76  ipython  traitlets   closed   13.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 30 days for ipython',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                  org          repo     kind  count
#     57   binder-examples             r  created    0.0
#     58   binder-examples  requirements  created    0.0
#     131  binder-examples             r   closed    2.0
#     132  binder-examples  requirements   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 30 days for binder-examples',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org                repo     kind  count
#     6    jupyter       docker-stacks  created    3.0
#     7    jupyter  enterprise_gateway  created    2.0
#     8    jupyter             jupyter  created    4.0
#     13   jupyter           nbconvert  created    1.0
#     14   jupyter              nbdime  created    1.0
#     15   jupyter            notebook  created   34.0
#     60   jupyter               nb2kg  created    0.0
#     61   jupyter            nbviewer  created    0.0
#     62   jupyter           qtconsole  created    0.0
#     63   jupyter         repo2docker  created    0.0
#     80   jupyter       docker-stacks   closed    6.0
#     81   jupyter  enterprise_gateway   closed   10.0
#     82   jupyter             jupyter   closed    2.0
#     87   jupyter           nbconvert   closed    9.0
#     88   jupyter              nbdime   closed    1.0
#     89   jupyter            notebook   closed   16.0
#     134  jupyter               nb2kg   closed    3.0
#     135  jupyter            nbviewer   closed    2.0
#     136  jupyter           qtconsole   closed    2.0
#     137  jupyter         repo2docker   closed    6.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 30 days for jupyter',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:             org                     repo     kind  count
#     25   jupyterhub                binderhub  created    4.0
#     26   jupyterhub            dockerspawner  created    1.0
#     27   jupyterhub     jupyter-server-proxy  created    1.0
#     28   jupyterhub               jupyterhub  created    4.0
#     29   jupyterhub     jupyterhub-on-hadoop  created    2.0
#     31   jupyterhub              kubespawner  created    7.0
#     34   jupyterhub      mybinder.org-deploy  created    3.0
#     38   jupyterhub             team-compass  created    1.0
#     39   jupyterhub   zero-to-jupyterhub-k8s  created   20.0
#     66   jupyterhub  the-littlest-jupyterhub  created    0.0
#     99   jupyterhub                binderhub   closed    1.0
#     100  jupyterhub            dockerspawner   closed    4.0
#     101  jupyterhub     jupyter-server-proxy   closed    4.0
#     102  jupyterhub               jupyterhub   closed   16.0
#     103  jupyterhub     jupyterhub-on-hadoop   closed    5.0
#     105  jupyterhub              kubespawner   closed    4.0
#     108  jupyterhub      mybinder.org-deploy   closed    1.0
#     112  jupyterhub             team-compass   closed    7.0
#     113  jupyterhub   zero-to-jupyterhub-k8s   closed   11.0
#     140  jupyterhub  the-littlest-jupyterhub   closed    5.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 30 days for jupyterhub',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org           repo     kind  count
#     49   nteract      bookstore  created    2.0
#     50   nteract       commuter  created    2.0
#     51   nteract             dx  created    1.0
#     52   nteract        nteract  created   14.0
#     53   nteract      papermill  created    1.0
#     54   nteract      scrapbook  created    3.0
#     55   nteract       semiotic  created    1.0
#     56   nteract  semiotic-docs  created    3.0
#     71   nteract       hydrogen  created    0.0
#     73   nteract           vdom  created    0.0
#     123  nteract      bookstore   closed    1.0
#     124  nteract       commuter   closed    6.0
#     125  nteract             dx   closed    0.0
#     126  nteract        nteract   closed    0.0
#     127  nteract      papermill   closed   11.0
#     128  nteract      scrapbook   closed    1.0
#     129  nteract       semiotic   closed    7.0
#     130  nteract  semiotic-docs   closed    0.0
#     145  nteract       hydrogen   closed   12.0
#     147  nteract           vdom   closed    4.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 30 days for nteract',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   })]
# })

# %%
# Set to datetime
for kind in ['createdAt', 'closedAt']:
    closed.loc[:, kind] = pd.to_datetime(closed[kind])
    
closed.loc[:, 'time_open'] = closed['closedAt'] - closed['createdAt']
closed.loc[:, 'time_open'] = closed['time_open'].dt.total_seconds()
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:480: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
time_open = closed.groupby(['org', 'repo']).agg({'time_open': 'median'}).reset_index()
time_open['time_open'] = time_open['time_open'] / (60 * 60 * 24)
time_open['org/repo'] = time_open.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = time_open.sort_values(['org', 'time_open'], ascending=False)['repo'].values
alt.Chart(data=time_open, title=f"Time to close for issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y=alt.Y('time_open', title="Median Days Open"),
    color='org',
)
# Out:
# Chart({
#   data:                 org                     repo   time_open  \
#   0   binder-examples                        r  158.033397
#   1   binder-examples             requirements    0.878611
#   2           ipython                  ipython    3.411250
#   3           ipython                traitlets  524.997407
#   4           jupyter            docker-stacks  135.174954
#   5           jupyter       enterprise_gateway    2.735359
#   6           jupyter                  jupyter  528.921007
#   7           jupyter             jupyter-book    1.337373
#   8           jupyter           jupyter-sphinx  347.251921
#   9           jupyter           jupyter_client   56.048183
#   10          jupyter                    nb2kg    7.627292
#   11          jupyter                nbconvert   47.337720
#   12          jupyter                   nbdime   61.557141
#   13          jupyter                 nbviewer   28.592737
#   14          jupyter                 notebook    7.112940
#   15          jupyter                qtconsole   21.478519
#   16          jupyter              repo2docker   56.813437
#   17  jupyter-widgets               ipyleaflet    1.409132
#   18  jupyter-widgets               ipywidgets    2.938796
#   19  jupyter-widgets                pythreejs   19.376806
#   20  jupyter-widgets   widget-ts-cookiecutter    1.007500
#   21       jupyterhub                   binder    3.087928
#   22       jupyterhub                binderhub   90.219317
#   23       jupyterhub            dockerspawner   26.389468
#   24       jupyterhub     jupyter-server-proxy    1.095995
#   25       jupyterhub               jupyterhub    1.573709
#   26       jupyterhub     jupyterhub-on-hadoop    5.924155
#   27       jupyterhub              kubespawner   76.931319
#   28       jupyterhub        ldapauthenticator    0.075509
#   29       jupyterhub      mybinder.org-deploy   33.330590
#   30       jupyterhub           oauthenticator   47.958796
#   31       jupyterhub           systemdspawner   21.074907
#   32       jupyterhub             team-compass   25.022396
#   33       jupyterhub  the-littlest-jupyterhub   14.536076
#   34       jupyterhub            traefik-proxy    1.121551
#   35       jupyterhub              yarnspawner    0.991076
#   36       jupyterhub   zero-to-jupyterhub-k8s    3.088750
#   37       jupyterlab               jupyterlab   29.154560
#   38       jupyterlab      jupyterlab-celltags  182.726638
#   39       jupyterlab           jupyterlab-git   12.142292
#   40       jupyterlab        jupyterlab-github   52.334549
#   41       jupyterlab  jupyterlab-google-drive   49.187031
#   42       jupyterlab         jupyterlab-latex    0.994745
#   43       jupyterlab             team-compass    5.495081
#   44          nteract                bookstore   21.619711
#   45          nteract                 commuter   86.714855
#   46          nteract                 hydrogen    7.129664
#   47          nteract           minimal-plotly   26.437975
#   48          nteract                papermill   20.318819
#   49          nteract                scrapbook    0.928993
#   50          nteract                 semiotic    5.082326
#   51          nteract                     vdom  106.607894
#
#                                     org/repo
#   0                        binder-examples/r
#   1             binder-examples/requirements
#   2                          ipython/ipython
#   3                        ipython/traitlets
#   4                    jupyter/docker-stacks
#   5               jupyter/enterprise_gateway
#   6                          jupyter/jupyter
#   7                     jupyter/jupyter-book
#   8                   jupyter/jupyter-sphinx
#   9                   jupyter/jupyter_client
#   10                           jupyter/nb2kg
#   11                       jupyter/nbconvert
#   12                          jupyter/nbdime
#   13                        jupyter/nbviewer
#   14                        jupyter/notebook
#   15                       jupyter/qtconsole
#   16                     jupyter/repo2docker
#   17              jupyter-widgets/ipyleaflet
#   18              jupyter-widgets/ipywidgets
#   19               jupyter-widgets/pythreejs
#   20  jupyter-widgets/widget-ts-cookiecutter
#   21                       jupyterhub/binder
#   22                    jupyterhub/binderhub
#   23                jupyterhub/dockerspawner
#   24         jupyterhub/jupyter-server-proxy
#   25                   jupyterhub/jupyterhub
#   26         jupyterhub/jupyterhub-on-hadoop
#   27                  jupyterhub/kubespawner
#   28            jupyterhub/ldapauthenticator
#   29          jupyterhub/mybinder.org-deploy
#   30               jupyterhub/oauthenticator
#   31               jupyterhub/systemdspawner
#   32                 jupyterhub/team-compass
#   33      jupyterhub/the-littlest-jupyterhub
#   34                jupyterhub/traefik-proxy
#   35                  jupyterhub/yarnspawner
#   36       jupyterhub/zero-to-jupyterhub-k8s
#   37                   jupyterlab/jupyterlab
#   38          jupyterlab/jupyterlab-celltags
#   39               jupyterlab/jupyterlab-git
#   40            jupyterlab/jupyterlab-github
#   41      jupyterlab/jupyterlab-google-drive
#   42             jupyterlab/jupyterlab-latex
#   43                 jupyterlab/team-compass
#   44                       nteract/bookstore
#   45                        nteract/commuter
#   46                        nteract/hydrogen
#   47                  nteract/minimal-plotly
#   48                       nteract/papermill
#   49                       nteract/scrapbook
#   50                        nteract/semiotic
#   51                            nteract/vdom  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['vdom', 'commuter', 'minimal-plotly', 'bookstore', 'papermill', 'hydrogen', 'semiotic', 'scrapbook', 'jupyterlab-celltags', 'jupyterlab-github', 'jupyterlab-google-drive', 'jupyterlab', 'jupyterlab-git', 'team-compass', 'jupyterlab-latex', 'binderhub', 'kubespawner', 'oauthenticator', 'mybinder.org-deploy', 'dockerspawner', 'team-compass', 'systemdspawner', 'the-littlest-jupyterhub', 'jupyterhub-on-hadoop', 'zero-to-jupyterhub-k8s', 'binder', 'jupyterhub', 'traefik-proxy', 'jupyter-server-proxy', 'yarnspawner', 'ldapauthenticator', 'pythreejs', 'ipywidgets', 'ipyleaflet', 'widget-ts-cookiecutter', 'jupyter', 'jupyter-sphinx', 'docker-stacks', 'nbdime', 'repo2docker', 'jupyter_client', 'nbconvert', 'nbviewer', 'qtconsole', 'nb2kg', 'notebook', 'enterprise_gateway', 'jupyter-book', 'traitlets', 'ipython', 'r', 'requirements']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'time_open',
#       title: 'Median Days Open',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Time to close for issues closed in the last 30 days'
# })

# %% [markdown]
# ### A list of recent issues
#
# Below is a list of issues with recent activity in each repository. If they seem of interest
# to you, click on their links and jump in to participate!

# %%
# Add comment count data to issues and PRs
comment_counts = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'issue_id'])
    .count().iloc[:, 0].to_frame()
)
comment_counts.columns = ['n_comments']
comment_counts = comment_counts.reset_index()

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, (org, idata) in enumerate(comment_counts.groupby('org')):
    issue_md = []
    issue_md.append(f"#### {org}")
    issue_md.append("")
    for repo, i_issues in idata.groupby('repo'):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")

        top_issues = i_issues.sort_values('n_comments', ascending=False).head(n_plot)
        top_issue_list = pd.merge(issues, top_issues, left_on=['org', 'repo', 'number'], right_on=['org', 'repo', 'issue_id'])
        for _, issue in top_issue_list.sort_values('n_comments', ascending=False).head(n_plot).iterrows():
            user_name = issue['author']
            user_url = author_url(user_name)
            issue_number = issue['number']
            issue_html = issue['url']
            issue_title = issue['title']

            text = f"* [(#{issue_number})]({issue_html}): _{issue_title}_ by **[@{user_name}]({user_url})**"
            issue_md.append(text)

    issue_md.append('')
    md_html = HTML(markdown('\n'.join(issue_md)))
    
    children = list(tabs.children)
    children.append(HTML(markdown('\n'.join(issue_md))))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"Here are the top {n_plot} active issues in each repository in the last {n_days} days"))
display(tabs)
# Out:
# Here are the top 5 active issues in each repository in the last 30 days
# Tab(children=(HTML(value='<h4>binder-examples</h4>\n<h5><a href="https://github.com/binder-examples/r">binder-…

# %% [markdown]
# ## Commenters across repositories
#
# These are commenters across all issues and pull requests in the last several days.
# These are colored by the commenter's association with the organization. For information
# about what these associations mean, [see this StackOverflow post](https://stackoverflow.com/a/28866914/1927102).

# %%
commentors = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'author', 'authorAssociation'])
    .count().rename(columns={'id': 'count'})['count']
    .reset_index()
    .sort_values(['org', 'count'], ascending=False)
)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(commentors.groupby(['org'])):
    title = f"Top {n_plot} commentors for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'count': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('count', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='count',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             author  count authorAssociation
#     4        choldgraf      4            MEMBER
#     0  MarijaStanojcic      1              NONE
#     1       RAJohansen      1              NONE
#     2          betatim      1            MEMBER
#     3         cboettig      1            MEMBER
#     5         schluenz      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for binder-examples in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                 author  count authorAssociation
#     0              Carreau     44            MEMBER
#     49            rmorshea     24      COLLABORATOR
#     5       LucianaMarques     11       CONTRIBUTOR
#     44               minrk      6            MEMBER
#     61              wanick      5              NONE
#     34             jakevdp      4              NONE
#     46             panaali      4              NONE
#     32             hroncok      4       CONTRIBUTOR
#     64             zzzz-qq      3       CONTRIBUTOR
#     39  keisuke-yanagisawa      3              NONE
#     43         martinRenou      3       CONTRIBUTOR
#     2       DanielGoldfarb      3              NONE
#     25        davidszotten      3              NONE
#     20           blackball      2              NONE
#     35          jasongrout      2            MEMBER
#     33           hyperknot      2              NONE
#     28          dwhswenson      2              NONE
#     54       thequackdaddy      2              NONE
#     40                krey      2              NONE
#     10                OW51      2              NONE
#     13       SylvainCorlay      2            MEMBER
#     14           ThetomekK      2              NONE
#     57         tommydevitt      1              NONE
#     48            ressafri      1              NONE
#     63           yuvipanda      1      COLLABORATOR
#     6                MSeal      1       CONTRIBUTOR
#     45              mrrech      1              NONE
#     62             weaming      1              NONE
#     4            Hazarmavi      1              NONE
#     47            prjemian      1              NONE
#     3           DannyFeliz      1              NONE
#     58            tritemio      1              NONE
#     50             sanyam5      1       CONTRIBUTOR
#     51        sjpfenninger      1              NONE
#     52            stphnlyd      1              NONE
#     60              waboke      1              NONE
#     42             lvc0107      1              NONE
#     59         vladserkoff      1              NONE
#     55       thomasaarholt      1              NONE
#     56           tirkarthi      1              NONE
#     53          texadactyl      1              NONE
#     8        MatthewWilkes      1              NONE
#     41             leolinf      1              NONE
#     23              daharn      1       CONTRIBUTOR
#     11             SKPriya      1              NONE
#     12          SimonBiggs      1              NONE
#     15              WestXu      1              NONE
#     16        aquirdTurtle      1              NONE
#     17          aslily1234      1              NONE
#     18          basnijholt      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:               author  count authorAssociation
#     148      kevin-bates    107            MEMBER
#     75           betatim     65            MEMBER
#     31             MSeal     57            MEMBER
#     81         choldgraf     57            MEMBER
#     193          parente     43            MEMBER
#     229         t-makaro     35      COLLABORATOR
#     253           witten     29       CONTRIBUTOR
#     258        yuvipanda     25            MEMBER
#     108           esevan     19      COLLABORATOR
#     179            minrk     16            MEMBER
#     164         lresende     14            MEMBER
#     230        takluyver     14            MEMBER
#     257           xmnlab     12       CONTRIBUTOR
#     181           mpacer     12            MEMBER
#     66          akhmerov     12            MEMBER
#     244          vidartf     11      COLLABORATOR
#     42              Ruv7     11            MEMBER
#     176           mgeier     11       CONTRIBUTOR
#     30      Litchilitchy     10              NONE
#     84      consideRatio     10      COLLABORATOR
#     51     SylvainCorlay      8            MEMBER
#     219          shibbas      8              NONE
#     67        alexmorley      8       CONTRIBUTOR
#     139          jhornig      7              NONE
#     29       KirstieJane      7       CONTRIBUTOR
#     233        tgeorgeux      7            MEMBER
#     133        jasmainak      7       CONTRIBUTOR
#     213          rutujar      7              NONE
#     114          gnestor      7            MEMBER
#     134       jasongrout      6            MEMBER
#     138          jhamman      6       CONTRIBUTOR
#     255            wolfv      6              NONE
#     107          emdupre      6      COLLABORATOR
#     172        mattjtodd      5       CONTRIBUTOR
#     61            afshin      5            MEMBER
#     96          djherbis      5       CONTRIBUTOR
#     167  maartenbreddels      5       CONTRIBUTOR
#     4       AkiraCharles      5              NONE
#     122        iOmar2019      5              NONE
#     78        ccordoba12      5      COLLABORATOR
#     136         jbweston      4            MEMBER
#     180          mlucool      4              NONE
#     150           kfrncs      4              NONE
#     10           Carreau      4            MEMBER
#     220            shihs      4              NONE
#     85       cornhundred      4              NONE
#     49        SolarisYan      4       CONTRIBUTOR
#     228          swayson      4              NONE
#     1           1kastner      4              NONE
#     18            Fdango      4              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     30       jasongrout     83            MEMBER
#     39      martinRenou     62            MEMBER
#     26     fitoprincipe     34       CONTRIBUTOR
#     53          vidartf     28            MEMBER
#     9     SylvainCorlay     28            MEMBER
#     59           xmnlab     27       CONTRIBUTOR
#     55     williamstein     19              NONE
#     37  maartenbreddels     15            MEMBER
#     8        PBrockmann     10              NONE
#     22         deeplook      8              NONE
#     43        nscozzaro      8              NONE
#     60          zerline      6       CONTRIBUTOR
#     16      boustrephon      5              NONE
#     52        timkpaine      4       CONTRIBUTOR
#     7       MaksimMisin      4              NONE
#     20           crahan      3              NONE
#     47         saraedum      3              NONE
#     58       wuqian5000      3              NONE
#     19      cornhundred      3       CONTRIBUTOR
#     33            jtpio      3       CONTRIBUTOR
#     45            pllim      3       CONTRIBUTOR
#     24          drwelby      3       CONTRIBUTOR
#     32     jjennings955      2              NONE
#     36           languy      2              NONE
#     46         rmorshea      2       CONTRIBUTOR
#     29          gnestor      2       CONTRIBUTOR
#     5         MadDenker      2              NONE
#     40          mwcraig      2       CONTRIBUTOR
#     49      scottwsides      2              NONE
#     41      nickpollari      2              NONE
#     50        soerendip      2              NONE
#     25             eteq      2              NONE
#     54      weikang9009      2              NONE
#     3         Kirill888      2       CONTRIBUTOR
#     57       wouellette      2              NONE
#     48   saulshanabrook      1              NONE
#     42           nmearl      1              NONE
#     4            LLyq17      1              NONE
#     56            wolfv      1              NONE
#     44       oscar6echo      1       CONTRIBUTOR
#     2        Fubukimaru      1              NONE
#     51    soerenwolfers      1              NONE
#     12          andyjmc      1              NONE
#     6         Majik0327      1              NONE
#     38  mariobuikhuizen      1              NONE
#     14        astrofrog      1              NONE
#     15         bollwyvl      1       CONTRIBUTOR
#     17             btel      1       CONTRIBUTOR
#     18      cdgreenidge      1              NONE
#     21      danish-monu      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:               author  count authorAssociation
#     30           betatim    121            MEMBER
#     41         choldgraf     75            MEMBER
#     45      consideRatio     74            MEMBER
#     112            minrk     72            MEMBER
#     162        yuvipanda     40            MEMBER
#     102           manics     18       CONTRIBUTOR
#     80            jcrist     14            MEMBER
#     134         rmorshea     13       CONTRIBUTOR
#     53   distortedsignal     12       CONTRIBUTOR
#     138       ryanlovett     11            MEMBER
#     11          RohitK89      9       CONTRIBUTOR
#     141        sgibson91      9            MEMBER
#     163             yvan      8              NONE
#     74            hnykda      8              NONE
#     95        laserninja      8              NONE
#     126  ramkrishnan8994      7              NONE
#     14           Zsailer      7            MEMBER
#     144            sodre      6              NONE
#     139          ryogesh      6       CONTRIBUTOR
#     98        leportella      5       CONTRIBUTOR
#     135        robnagler      5       CONTRIBUTOR
#     67         frier-sam      5              NONE
#     61            emirot      5       CONTRIBUTOR
#     42             clkao      5       CONTRIBUTOR
#     27           azbones      4              NONE
#     71             h4gen      4              NONE
#     70         gtomasson      4              NONE
#     119          parente      4            MEMBER
#     68          frouzbeh      4              NONE
#     26           aurashn      4              NONE
#     157        willirath      4      COLLABORATOR
#     22             arnim      4              NONE
#     13     SylvainCorlay      4              NONE
#     52     dirkcgrunwald      3              NONE
#     49          dcherian      3              NONE
#     47          cslovell      3              NONE
#     148   stevenstetzler      3              NONE
#     12           Seanspt      3              NONE
#     19        alexmorley      3              NONE
#     76        ian-r-rose      3      COLLABORATOR
#     153      vishaldesai      3              NONE
#     156         willingc      3            MEMBER
#     107          mattk08      3              NONE
#     2     GeorgianaElena      3            MEMBER
#     62            erniee      3              NONE
#     25         athornton      3       CONTRIBUTOR
#     152           tregin      2              NONE
#     81          jfautley      2              NONE
#     69     ghezalsherdil      2              NONE
#     85     jonathanballs      2              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     79       jasongrout    293            MEMBER
#     72       ian-r-rose     96            MEMBER
#     33        blink1073     50            MEMBER
#     131  saulshanabrook     44            MEMBER
#     147         vidartf     41            MEMBER
#     76       jaipreet-s     40      COLLABORATOR
#     21           afshin     31            MEMBER
#     64          gnestor     23            MEMBER
#     133     scottwsides     22              NONE
#     143       timkpaine     16            MEMBER
#     20          Zsailer     11            MEMBER
#     68            hainm      9              NONE
#     36         bollwyvl      8            MEMBER
#     57       fcollonval      7            MEMBER
#     27         aschlaep      7            MEMBER
#     150        weihwang      7      COLLABORATOR
#     5     CavalloneChen      7              NONE
#     155       yuvipanda      6       CONTRIBUTOR
#     102   markellekelly      5            MEMBER
#     86            jtpio      5            MEMBER
#     2           Bidek56      5              NONE
#     14          Madhu94      4            MEMBER
#     29            b0noI      4              NONE
#     117          nmearl      4              NONE
#     146        vgensini      4              NONE
#     127       rhsmits91      4              NONE
#     70     hugokerstens      3              NONE
#     156    zeluspudding      3              NONE
#     106      michaelaye      3            MEMBER
#     61   franckjulliard      3              NONE
#     142        timhoffm      3       CONTRIBUTOR
#     49           dclong      3            MEMBER
#     140       tgeorgeux      3            MEMBER
#     157       zuuuhkrit      3              NONE
#     13            MSeal      3              NONE
#     22         agoose77      3            MEMBER
#     30          billpku      2              NONE
#     139      telamonian      2            MEMBER
#     60             fm75      2              NONE
#     137        t-makaro      2              NONE
#     62            fsksf      2              NONE
#     130       rpgoldman      2              NONE
#     129      roachsinai      2              NONE
#     73       indrajitsg      2              NONE
#     122        pisymbol      2              NONE
#     55        ellisonbg      2            MEMBER
#     121      philippjfr      2              NONE
#     88    kavishdahekar      2              NONE
#     90       kdeleeuw11      2              NONE
#     112          n-a-sz      2              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                   author  count authorAssociation
#     1             BenRussert     52            MEMBER
#     26          captainsafia     52            MEMBER
#     33                emeeks     27            MEMBER
#     6                  MSeal     27            MEMBER
#     55                mpacer     11            MEMBER
#     29                dgwyer      9              NONE
#     21              aviatesk      9            MEMBER
#     60              n-riesco      7            MEMBER
#     64                 niwsa      6              NONE
#     73           stormpython      5            MEMBER
#     44                jchaps      5              NONE
#     3                  JNFoo      5              NONE
#     15        VincentBLortie      4            MEMBER
#     67             probonopd      4              NONE
#     5        KnutJaegersberg      3              NONE
#     18                  WyRe      3              NONE
#     68               pybokeh      3              NONE
#     78              willingc      3            MEMBER
#     23               betatim      3            MEMBER
#     79               x1angli      3              NONE
#     53               mbauman      2              NONE
#     54             mbecker20      2              NONE
#     45                jdetle      2            MEMBER
#     61             nagymusic      2              NONE
#     62            nebi-frame      2              NONE
#     24             bridgesra      2              NONE
#     65                obarak      2              NONE
#     17          WhoAteDaCake      2              NONE
#     4                 Jogala      2              NONE
#     70           sagitaninta      2              NONE
#     47             jonmmease      2              NONE
#     69                rgbkrk      1            MEMBER
#     75              torioLuz      1       CONTRIBUTOR
#     50              l-MrMP-l      1              NONE
#     63  nijanthanvijayakumar      1              NONE
#     77                vizhur      1              NONE
#     51           leonelgalan      1              NONE
#     52             markeyser      1              NONE
#     76               travigd      1              NONE
#     74              tgrushka      1              NONE
#     66             onlurking      1              NONE
#     72         stereobooster      1              NONE
#     49            kylebarron      1            MEMBER
#     57               mpjuers      1              NONE
#     58              mstetson      1              NONE
#     59           mstewart141      1              NONE
#     71             sangaline      1              NONE
#     56                mphuie      1              NONE
#     0                  5h4un      1              NONE
#     48            kiwi0fruit      1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## First responders
#
# First responders are the first people to respond to a new issue in one of the repositories.
# The following plots show first responders for recently-created issues.

# %%
first_comments = []
for (org, repo, issue_id), i_comments in comments.groupby(['org', 'repo', 'issue_id']):
    ix_min = pd.to_datetime(i_comments['createdAt']).idxmin()
    first_comment = i_comments.loc[ix_min]
    if isinstance(first_comment, pd.DataFrame):
        first_comment = first_comment.iloc[0]
    first_comments.append(first_comment)
first_comments = pd.concat(first_comments, axis=1).T

# %%
first_responder_counts = first_comments.groupby(['org', 'author', 'authorAssociation'], as_index=False).\
    count().rename(columns={'id': 'n_first_responses'}).sort_values(['org', 'n_first_responses'], ascending=False)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(first_responder_counts.groupby(['org'])):
    title = f"Top {n_plot} first responders for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'n_first_responses': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('n_first_responses', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='n_first_responses',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             author  n_first_responses authorAssociation
#     1        choldgraf                  2            MEMBER
#     0  MarijaStanojcic                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for binder-examples in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                 author  n_first_responses authorAssociation
#     0              Carreau                 24            MEMBER
#     35            rmorshea                 18      COLLABORATOR
#     30               minrk                  3            MEMBER
#     45              wanick                  2              NONE
#     22             hroncok                  2       CONTRIBUTOR
#     8                 OW51                  2              NONE
#     39       thequackdaddy                  2              NONE
#     27          kak-to-tak                  1              NONE
#     28  keisuke-yanagisawa                  1              NONE
#     29         martinRenou                  1       CONTRIBUTOR
#     31              mrrech                  1              NONE
#     32             panaali                  1              NONE
#     33            prjemian                  1              NONE
#     34            ressafri                  1              NONE
#     37        sjpfenninger                  1              NONE
#     36             sanyam5                  1       CONTRIBUTOR
#     25          jclevesque                  1              NONE
#     38          texadactyl                  1              NONE
#     40       thomasaarholt                  1              NONE
#     41           tirkarthi                  1              NONE
#     42         tommydevitt                  1              NONE
#     43            tritemio                  1              NONE
#     44              waboke                  1              NONE
#     46             weaming                  1              NONE
#     26         jerrykaplan                  1              NONE
#     24          jasongrout                  1            MEMBER
#     1            DSamuylov                  1              NONE
#     23           hyperknot                  1              NONE
#     2       DanielGoldfarb                  1              NONE
#     3           DannyFeliz                  1              NONE
#     4       LucianaMarques                  1              NONE
#     5       Manav-Sarvaiya                  1              NONE
#     6        MatthewWilkes                  1              NONE
#     7         NumesSanguis                  1              NONE
#     9            ThetomekK                  1              NONE
#     10              WestXu                  1              NONE
#     11        aquirdTurtle                  1              NONE
#     12          basnijholt                  1              NONE
#     13          bergtholdt                  1       CONTRIBUTOR
#     14           blink1073                  1            MEMBER
#     15               cdeil                  1              NONE
#     16         datdinhquoc                  1              NONE
#     17        davidszotten                  1              NONE
#     18           dedalus94                  1              NONE
#     19       diallobakary4                  1              NONE
#     20          dwhswenson                  1              NONE
#     21   hritikkumarsharma                  1              NONE
#     47             zzzz-qq                  1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for ipython in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                   author  n_first_responses authorAssociation
#     94           kevin-bates                 26            MEMBER
#     19                 MSeal                 25            MEMBER
#     48             choldgraf                 22            MEMBER
#     128              parente                 20            MEMBER
#     149             t-makaro                 15      COLLABORATOR
#     44               betatim                 15            MEMBER
#     39              akhmerov                  7            MEMBER
#     150            takluyver                  7            MEMBER
#     167            yuvipanda                  6            MEMBER
#     118               mpacer                  5            MEMBER
#     117                minrk                  5            MEMBER
#     159              vidartf                  5      COLLABORATOR
#     46            ccordoba12                  4      COLLABORATOR
#     85            jasongrout                  4            MEMBER
#     69               gnestor                  3            MEMBER
#     40            alexmorley                  3       CONTRIBUTOR
#     30            SolarisYan                  3       CONTRIBUTOR
#     105             lresende                  3            MEMBER
#     95                kfrncs                  3              NONE
#     32         SylvainCorlay                  2            MEMBER
#     66                esevan                  2      COLLABORATOR
#     108      maartenbreddels                  2       CONTRIBUTOR
#     12              Gravypan                  2              NONE
#     71               gss2002                  2              NONE
#     37        akarukappadath                  2              NONE
#     141             rolweber                  2      COLLABORATOR
#     116               mgeier                  2       CONTRIBUTOR
#     84             jasmainak                  2       CONTRIBUTOR
#     10          Deepakchawla                  2              NONE
#     87              jbweston                  2            MEMBER
#     147            sindzicat                  2              NONE
#     100                  lc0                  2              NONE
#     25                  Ruv7                  2            MEMBER
#     98               ksaliya                  2              NONE
#     57              djherbis                  2       CONTRIBUTOR
#     164           wmvanvliet                  1              NONE
#     112            mattjtodd                  1       CONTRIBUTOR
#     165             xingshou                  1              NONE
#     166               xmnlab                  1       CONTRIBUTOR
#     119               munick                  1              NONE
#     115              mgasner                  1              NONE
#     120              mwcraig                  1       CONTRIBUTOR
#     114              mdv3101                  1              NONE
#     113      maximilianduell                  1              NONE
#     154              thincal                  1              NONE
#     107           lzyang2000                  1              NONE
#     111  mathematicalmichael                  1              NONE
#     110          martinosorb                  1              NONE
#     109       maracuja-juice                  1              NONE
#     122           netoferraz                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:              author  n_first_responses authorAssociation
#     17       jasongrout                 22            MEMBER
#     21      martinRenou                 14            MEMBER
#     5     SylvainCorlay                 14            MEMBER
#     26          vidartf                 10            MEMBER
#     13         deeplook                  5              NONE
#     20  maartenbreddels                  4            MEMBER
#     31           xmnlab                  3       CONTRIBUTOR
#     23        nscozzaro                  2              NONE
#     9       boustrephon                  2              NONE
#     19           languy                  1              NONE
#     25        timkpaine                  1       CONTRIBUTOR
#     24         rmorshea                  1       CONTRIBUTOR
#     27      weikang9009                  1              NONE
#     28            wolfv                  1              NONE
#     22           nmearl                  1              NONE
#     29       wouellette                  1              NONE
#     30       wuqian5000                  1              NONE
#     0        Alexboiboi                  1              NONE
#     16            fthou                  1              NONE
#     18        konwiddak                  1              NONE
#     1        Fubukimaru                  1              NONE
#     15     fitoprincipe                  1       CONTRIBUTOR
#     14         dfrail24                  1              NONE
#     12      danish-monu                  1              NONE
#     11           crahan                  1              NONE
#     10             btel                  1       CONTRIBUTOR
#     8       andymcarter                  1              NONE
#     7           andyjmc                  1              NONE
#     6           YuyQuan                  1              NONE
#     4        PBrockmann                  1              NONE
#     3         MadDenker                  1              NONE
#     2            LLyq17                  1              NONE
#     32          zerline                  1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter-widgets in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:              author  n_first_responses authorAssociation
#     61            minrk                 41            MEMBER
#     16          betatim                 35            MEMBER
#     25     consideRatio                 27            MEMBER
#     94        yuvipanda                 20            MEMBER
#     22        choldgraf                 20            MEMBER
#     44           jcrist                 10            MEMBER
#     81        sgibson91                  5            MEMBER
#     57           manics                  5       CONTRIBUTOR
#     78       ryanlovett                  4            MEMBER
#     79          ryogesh                  4       CONTRIBUTOR
#     71  ramkrishnan8994                  3              NONE
#     37        frier-sam                  3              NONE
#     34         dwaltrip                  2              NONE
#     39    ghezalsherdil                  2              NONE
#     40            h4gen                  2              NONE
#     27         cslovell                  2              NONE
#     45         jfautley                  2              NONE
#     59         manniche                  2              NONE
#     4          RohitK89                  2       CONTRIBUTOR
#     31  distortedsignal                  2       CONTRIBUTOR
#     70         rabernat                  1              NONE
#     65       oscar6echo                  1              NONE
#     64      nic-hartley                  1              NONE
#     63           mxjeff                  1              NONE
#     62        mjschmidt                  1              NONE
#     60          michelp                  1              NONE
#     66          oulydna                  1              NONE
#     58           manm05                  1              NONE
#     67         pganssle                  1              NONE
#     68     playermanny2                  1              NONE
#     69      poomjuntara                  1              NONE
#     56          ltalirz                  1              NONE
#     0         1krutarth                  1              NONE
#     72        rchossein                  1              NONE
#     85        srams2018                  1              NONE
#     93         yorickvP                  1              NONE
#     92           xmnlab                  1              NONE
#     91        willirath                  1      COLLABORATOR
#     90          vpavlin                  1       CONTRIBUTOR
#     89      vishaldesai                  1              NONE
#     88           timlod                  1              NONE
#     87   stevenstetzler                  1              NONE
#     86      ssssssophia                  1              NONE
#     84     sosiristseng                  1              NONE
#     73         rheiland                  1              NONE
#     83            sodre                  1              NONE
#     82       simonflood                  1              NONE
#     80      seamanjiang                  1              NONE
#     77        rokroskar                  1              NONE
#     76        robnagler                  1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterhub in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:             author  n_first_responses authorAssociation
#     44      jasongrout                 83            MEMBER
#     38      ian-r-rose                 32            MEMBER
#     81  saulshanabrook                 16            MEMBER
#     41      jaipreet-s                 14      COLLABORATOR
#     87         vidartf                 11            MEMBER
#     19       blink1073                 10            MEMBER
#     32         gnestor                  7            MEMBER
#     16        aschlaep                  4            MEMBER
#     60   markellekelly                  4            MEMBER
#     12          afshin                  4            MEMBER
#     90       yuvipanda                  3       CONTRIBUTOR
#     86       timkpaine                  3            MEMBER
#     21        bollwyvl                  3            MEMBER
#     29      fcollonval                  2            MEMBER
#     34           hainm                  2              NONE
#     91    zeluspudding                  2              NONE
#     79      roachsinai                  2              NONE
#     88        weihwang                  2      COLLABORATOR
#     49           jtpio                  2            MEMBER
#     66  mouradmourafiq                  1              NONE
#     59      manycoding                  1              NONE
#     57        louis925                  1              NONE
#     56       linkailuo                  1              NONE
#     55    lapis-zero09                  1              NONE
#     61      martinorpa                  1              NONE
#     54     lambdamusic                  1              NONE
#     62      michaelaye                  1            MEMBER
#     63          mindon                  1              NONE
#     64           minrk                  1            MEMBER
#     65         mocquin                  1              NONE
#     58     lukasmichel                  1              NONE
#     71     nils-werner                  1              NONE
#     67          n-a-sz                  1              NONE
#     77       rhsmits91                  1              NONE
#     89          xmnlab                  1              NONE
#     85       tgeorgeux                  1            MEMBER
#     84        t-makaro                  1              NONE
#     83       sushmit86                  1              NONE
#     82  stephenkraemer                  1              NONE
#     80       rpgoldman                  1              NONE
#     78     richagadgil                  1            MEMBER
#     76      rajabricks                  1              NONE
#     68    neelamgehlot                  1      COLLABORATOR
#     75      rahulpshah                  1            MEMBER
#     74        pisymbol                  1              NONE
#     73         pboulos                  1              NONE
#     72         parente                  1            MEMBER
#     52      krassowski                  1            MEMBER
#     70      nick-brady                  1              NONE
#     69      ngharrison                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterlab in the last 30 days',
#     width: 1000
#   }), Chart({
#     data:                   author  n_first_responses authorAssociation
#     21          captainsafia                 42            MEMBER
#     1             BenRussert                 27            MEMBER
#     26                emeeks                 17            MEMBER
#     5                  MSeal                 12            MEMBER
#     37                mpacer                  8            MEMBER
#     47           stormpython                  3            MEMBER
#     24                dgwyer                  3              NONE
#     49              willingc                  2            MEMBER
#     16              aviatesk                  2            MEMBER
#     11        VincentBLortie                  2            MEMBER
#     41                 niwsa                  2              NONE
#     35           leonelgalan                  1              NONE
#     34              l-MrMP-l                  1              NONE
#     0                  5h4un                  1              NONE
#     33             jonmmease                  1              NONE
#     36             markeyser                  1              NONE
#     31        jacobtomlinson                  1              NONE
#     32                jdetle                  1            MEMBER
#     39            nebi-frame                  1              NONE
#     38                mphuie                  1              NONE
#     29           hydrosquall                  1            MEMBER
#     40  nijanthanvijayakumar                  1              NONE
#     42             probonopd                  1              NONE
#     43               pybokeh                  1              NONE
#     44                rgbkrk                  1            MEMBER
#     45           sagitaninta                  1              NONE
#     46         stereobooster                  1              NONE
#     48               travigd                  1              NONE
#     30          i-am-the-guy                  1              NONE
#     25               eduhh94                  1              NONE
#     28              hmanuel1                  1              NONE
#     12            ViralBShah                  1              NONE
#     2                   IDDT                  1              NONE
#     3                 Jogala                  1              NONE
#     4        KnutJaegersberg                  1              NONE
#     6              Mikeymice                  1              NONE
#     7           Miniland1333                  1              NONE
#     8           NathanHodges                  1              NONE
#     9              RaghuNaik                  1              NONE
#     10               RoyalTS                  1              NONE
#     13          WhoAteDaCake                  1              NONE
#     27        gonsalesarthur                  1              NONE
#     14            artemverbo                  1              NONE
#     15              atronchi                  1              NONE
#     17                badiku                  1              NONE
#     18               betatim                  1            MEMBER
#     19             bridgesra                  1              NONE
#     20           bryanchen-d                  1              NONE
#     22             danhamill                  1              NONE
#     23              deeplook                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for nteract in the last 30 days',
#     width: 1000
#   })]
# })

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
