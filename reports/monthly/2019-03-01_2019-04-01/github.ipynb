# %%
import seaborn as sns
import pandas as pd
import numpy as np
import altair as alt
from markdown import markdown
from IPython.display import Markdown
from ipywidgets.widgets import HTML, Tab
from ipywidgets import widgets
from datetime import timedelta
from matplotlib import pyplot as plt
import os.path as op

from mod import load_data, alt_theme

# %%
def author_url(author):
    return f"https://github.com/{author}"

# %%
# Parameters
fmt_date = "{:%Y-%m-%d}"

n_days = 90
start_date = fmt_date.format(pd.datetime.today() - timedelta(days=n_days))
end_date = fmt_date.format(pd.datetime.today())

renderer = "jupyterlab"
github_orgs = ["jupyterhub", "jupyter", "jupyterlab", "jupyter-widgets", "ipython", "binder-examples", "nteract"]

# %%
# Parameters
renderer = "kaggle"
start_date = "2019-03-01"
end_date = "2019-04-01"

# %%
comments, issues, prs = load_data('../data/')
bot_names = pd.read_csv('bot_names.csv')['names'].tolist()
comments = comments.query('author not in @bot_names').drop_duplicates()
issues = issues.query('author not in @bot_names').drop_duplicates()
prs = prs.query('author not in @bot_names').drop_duplicates()
# Out:
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:24: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   comments = pd.concat(comments)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:25: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   issues = pd.concat(issues)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:26: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   prs = pd.concat(prs)

# %%
# Only keep the dates we want
comments = comments.query('updatedAt > @start_date and updatedAt < @end_date')
issues = issues.query('updatedAt > @start_date and updatedAt < @end_date')
prs = prs.query('updatedAt > @start_date and updatedAt < @end_date')

# %%
alt.renderers.enable(renderer);
alt.themes.register('my_theme', alt_theme)
alt.themes.enable("my_theme")
# Out:
# ThemeRegistry.enable('my_theme')

# %%
# Information about out time window
time_delta = pd.to_datetime(end_date) - pd.to_datetime(start_date)
n_days = time_delta.days

# Information about the data we loaded
github_orgs = comments['org'].unique()

# %% [markdown]
# # GitHub activity
#
# Jupyter also has lots of activity across GitHub repositories. The following sections contain
# overviews of recent activity across the following GitHub organizations:

# %%
# Define colors we'll use for GitHub membership
author_types = ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', "NONE"]

author_palette = sns.palettes.blend_palette(["lightgrey", "lightgreen", "darkgreen"], 4)
author_colors = ["rgb({}, {}, {}, {})".format(*(ii*256)) for ii in author_palette]
author_color_dict = {key: val for key, val in zip(author_types, author_palette)}

# %%
orgs_md = []
for org in github_orgs:
    orgs_md.append(f'* [github.com/{org}](https://github.com/{org})')
Markdown('\n'.join(orgs_md))
# Out:
# * [github.com/jupyterlab](https://github.com/jupyterlab)
# * [github.com/jupyter-widgets](https://github.com/jupyter-widgets)
# * [github.com/ipython](https://github.com/ipython)
# * [github.com/binder-examples](https://github.com/binder-examples)
# * [github.com/jupyter](https://github.com/jupyter)
# * [github.com/jupyterhub](https://github.com/jupyterhub)
# * [github.com/nteract](https://github.com/nteract)

# %%
Markdown(f"Showing GitHub activity from **{start_date}** to **{end_date}**")
# Out:
# Showing GitHub activity from **2019-03-01** to **2019-04-01**

# %% [markdown]
# ## List of all contributors per organization
#
# First, we'll list each contributor that has contributed to each organization in the last several days.
# Contributions to open source projects are diverse, and involve much more than just contributing code and
# code review. Thanks to everybody in the Jupyter communities for all that they do.

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, org in enumerate(github_orgs):
    authors_comments = comments.query('org == @org')['author']
    authors_prs = prs.query('org == @org')['author']
    unique_participants = np.unique(np.hstack([authors_comments.values, authors_prs.values]).astype(str)).tolist()
    unique_participants.sort(key=lambda a: a.lower())
    
    all_participants = [f"[{participant}](https://github.com/{participant})" for participant in unique_participants]
    participants_md = " | ".join(all_participants)
    md_html = HTML("<center>{}</center>".format(markdown(participants_md)))
    
    children = list(tabs.children)
    children.append(md_html)
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"All participants across issues and pull requests in each org in the last {n_days} days"))
display(tabs)
# Out:
# All participants across issues and pull requests in each org in the last 31 days
# Tab(children=(HTML(value='<center><p><a href="https://github.com/acu192">acu192</a> | <a href="https://github.…

# %% [markdown]
# ## Merged Pull requests
#
# Here's an analysis of **merged pull requests** across each of the repositories in the Jupyter
# ecosystem.

# %%
merged = prs.query('state == "MERGED" and closedAt > @start_date and closedAt < @end_date')

# %%
prs_by_repo = merged.groupby(['org', 'repo']).count()['author'].reset_index().sort_values(['org', 'author'], ascending=False)
alt.Chart(data=prs_by_repo, title=f"Merged PRs in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=prs_by_repo['repo'].values.tolist()),
    y='author',
    color='org'
)
# Out:
# Chart({
#   data:                 org                      repo  author
#   46          nteract                  semiotic       4
#   47          nteract             semiotic-docs       4
#   45          nteract                 papermill       3
#   48          nteract                      vdom       3
#   43          nteract                  hydrogen       1
#   44          nteract           meeting-minutes       1
#   40       jupyterlab                jupyterlab      13
#   41       jupyterlab            jupyterlab-git       2
#   42       jupyterlab         jupyterlab-github       1
#   32       jupyterhub                jupyterhub      12
#   39       jupyterhub    zero-to-jupyterhub-k8s      12
#   33       jupyterhub       mybinder.org-deploy      10
#   36       jupyterhub              team-compass       6
#   30       jupyterhub   configurable-http-proxy       5
#   28       jupyterhub                    binder       4
#   29       jupyterhub                 binderhub       4
#   35       jupyterhub               nbgitpuller       4
#   37       jupyterhub   the-littlest-jupyterhub       3
#   34       jupyterhub       nativeauthenticator       2
#   31       jupyterhub             dockerspawner       1
#   38       jupyterhub               yarnspawner       1
#   25  jupyter-widgets                ipyleaflet       8
#   27  jupyter-widgets    widget-ts-cookiecutter       2
#   26  jupyter-widgets       widget-cookiecutter       1
#   14          jupyter              jupyter-book      23
#   11          jupyter        enterprise_gateway      15
#   22          jupyter               repo2docker      15
#   21          jupyter                  notebook      14
#   9           jupyter             docker-stacks      13
#   10          jupyter     enhancement-proposals       7
#   20          jupyter                    nbdime       5
#   24          jupyter                 terminado       3
#   13          jupyter                   jupyter       2
#   15          jupyter         jupyter.github.io       2
#   8           jupyter             accessibility       1
#   12          jupyter                      help       1
#   16          jupyter            jupyter_server       1
#   17          jupyter            kernel_gateway       1
#   18          jupyter                     nb2kg       1
#   19          jupyter                 nbconvert       1
#   23          jupyter  sphinxcontrib_github_alt       1
#   6           ipython                   ipython       5
#   7           ipython                 traitlets       1
#   0   binder-examples               apt_install       3
#   1   binder-examples                     conda       1
#   2   binder-examples          continuous-build       1
#   3   binder-examples                demo-julia       1
#   4   binder-examples        minimal-dockerfile       1
#   5   binder-examples              requirements       1,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: ['semiotic', 'semiotic-docs', 'papermill', 'vdom', 'hydrogen', 'meeting-minutes', 'jupyterlab', 'jupyterlab-git', 'jupyterlab-github', 'jupyterhub', 'zero-to-jupyterhub-k8s', 'mybinder.org-deploy', 'team-compass', 'configurable-http-proxy', 'binder', 'binderhub', 'nbgitpuller', 'the-littlest-jupyterhub', 'nativeauthenticator', 'dockerspawner', 'yarnspawner', 'ipyleaflet', 'widget-ts-cookiecutter', 'widget-cookiecutter', 'jupyter-book', 'enterprise_gateway', 'repo2docker', 'notebook', 'docker-stacks', 'enhancement-proposals', 'nbdime', 'terminado', 'jupyter', 'jupyter.github.io', 'accessibility', 'help', 'jupyter_server', 'kernel_gateway', 'nb2kg', 'nbconvert', 'sphinxcontrib_github_alt', 'ipython', 'traitlets', 'apt_install', 'conda', 'continuous-build', 'demo-julia', 'minimal-dockerfile', 'requirements'],
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'author',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Merged PRs in the last 31 days'
# })

# %% [markdown]
# ### A list of merged PRs by project
#
# Below is a tabbed readout of recently-merged PRs. Check out the title to get an idea for what they
# implemented, and be sure to thank the PR author for their hard work!

# %%
tabs = widgets.Tab(children=[])
merged_by = {}
pr_by = {}
for ii, (org, idata) in enumerate(merged.groupby('org')):
    issue_md = []
    issue_md.append(f"#### Closed PRs for org: `{org}`")
    issue_md.append("")
    for (org, repo), prs in idata.groupby(['org', 'repo']):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")
        for _, pr in prs.iterrows():
            user_name = pr['author']
            user_url = author_url(user_name)
            pr_number = pr['number']
            pr_html = pr['url']
            pr_title = pr['title']
            pr_closedby = pr['mergedBy']
            pr_closedby_url = f"https://github.com/{pr_closedby}"
            if user_name not in pr_by:
                pr_by[user_name] = 1
            else:
                pr_by[user_name] += 1
                
            if pr_closedby not in merged_by:
                merged_by[pr_closedby] = 1
            else:
                merged_by[pr_closedby] += 1
            text = f"* [(#{pr_number})]({pr_html}): _{pr_title}_ by **[@{user_name}]({user_url})** merged by **[@{pr_closedby}]({pr_closedby_url})**"
            issue_md.append(text)
    issue_md.append('')
    markdown_html = markdown('\n'.join(issue_md))
    
    children = list(tabs.children)
    children.append(HTML(markdown_html))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
tabs
# Out:
# Tab(children=(HTML(value='<h4>Closed PRs for org: <code>binder-examples</code></h4>\n<h5><a href="https://gith…

# %% [markdown]
# ### Authoring and merging stats by repository
#
# Let's see who has been doing most of the PR authoring and merging. The PR author is generally the
# person that implemented a change in the repository (code, documentation, etc). The PR merger is
# the person that "pressed the green button" and got the change into the main codebase.

# %%
# Prep our merging DF
merged_by_repo = merged.groupby(['org', 'repo', 'author'], as_index=False).agg({'id': 'count', 'authorAssociation': 'first'}).rename(columns={'id': "authored", 'author': 'username'})
closed_by_repo = merged.groupby(['org', 'repo', 'mergedBy']).count()['id'].reset_index().rename(columns={'id': "closed", "mergedBy": "username"})

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(merged_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"PR authors for {iorg} in the last {n_days} days"
    idata = idata.groupby('username', as_index=False).agg({'authored': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('authored', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='authored',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)

alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:        username  authored authorAssociation
#     4        kannes         3       CONTRIBUTOR
#     0       betatim         2            MEMBER
#     1  davidanthoff         1       CONTRIBUTOR
#     2       davidar         1       CONTRIBUTOR
#     3     emigre459         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:      username  authored authorAssociation
#     0   fchapoton         2       CONTRIBUTOR
#     1     jsnydes         1       CONTRIBUTOR
#     2     lodagro         1       CONTRIBUTOR
#     3  matangover         1       CONTRIBUTOR
#     4   ndtallant         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            username  authored       authorAssociation
#     10        choldgraf        16                  MEMBER
#     31         lresende        13                  MEMBER
#     33            minrk        12                  MEMBER
#     7           betatim         7                  MEMBER
#     35          parente         7                  MEMBER
#     25        javabrett         4             CONTRIBUTOR
#     15     davidanthoff         3             CONTRIBUTOR
#     24        jasmainak         3             CONTRIBUTOR
#     26         jhermann         2             CONTRIBUTOR
#     27       joergbrech         2             CONTRIBUTOR
#     29      kevin-bates         2                  MEMBER
#     16        ellisonbg         2                  MEMBER
#     39         willingc         2                  MEMBER
#     9      captainsafia         2                  MEMBER
#     37          vidartf         2            COLLABORATOR
#     4           Zsailer         2                  MEMBER
#     2            Godley         2             CONTRIBUTOR
#     32  maartenbreddels         1             CONTRIBUTOR
#     36          romainx         1             CONTRIBUTOR
#     30     lisamartin72         1             CONTRIBUTOR
#     28            jtpio         1             CONTRIBUTOR
#     38        vilhelmen         1             CONTRIBUTOR
#     34          mwcraig         1             CONTRIBUTOR
#     0            00Kai0         1                    NONE
#     23      jakelevirne         1  FIRST_TIME_CONTRIBUTOR
#     22           hugovk         1             CONTRIBUTOR
#     21    gitter-badger         1             CONTRIBUTOR
#     1       Athanasiamo         1             CONTRIBUTOR
#     19        fchapoton         1             CONTRIBUTOR
#     18         emiliotl         1             CONTRIBUTOR
#     17          emdupre         1            COLLABORATOR
#     14          cpranav         1                    NONE
#     13            cnydw         1             CONTRIBUTOR
#     12            clkao         1             CONTRIBUTOR
#     11    ciaranlangton         1             CONTRIBUTOR
#     8         blink1073         1                  MEMBER
#     6         akchinSTC         1            COLLABORATOR
#     5           agitter         1             CONTRIBUTOR
#     3           QuLogic         1             CONTRIBUTOR
#     20      fredrikekre         1             CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:        username  authored authorAssociation
#     1   martinRenou         8            MEMBER
#     2       vidartf         2            MEMBER
#     0  VasavanThiru         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                username  authored authorAssociation
#     4               betatim         9            MEMBER
#     22                minrk         9            MEMBER
#     7             choldgraf         5            MEMBER
#     10         consideRatio         4            MEMBER
#     32            yuvipanda         3            MEMBER
#     28            sgibson91         3            MEMBER
#     1               Zsailer         2            MEMBER
#     5                bitnik         2       CONTRIBUTOR
#     19           leportella         2      COLLABORATOR
#     25             rcthomas         2       CONTRIBUTOR
#     24             nickurak         1       CONTRIBUTOR
#     21  mathematicalmichael         1       CONTRIBUTOR
#     23             mpetroff         1       CONTRIBUTOR
#     27     rushikeshraut777         1       CONTRIBUTOR
#     26            robnagler         1       CONTRIBUTOR
#     29           simonflood         1       CONTRIBUTOR
#     30             story645         1       CONTRIBUTOR
#     31            willirath         1      COLLABORATOR
#     20           manycoding         1       CONTRIBUTOR
#     0             JohnPaton         1       CONTRIBUTOR
#     18                jtpio         1       CONTRIBUTOR
#     17               jcrist         1            MEMBER
#     15        haraldschilly         1       CONTRIBUTOR
#     14          greenkeeper         1       CONTRIBUTOR
#     13               emirot         1       CONTRIBUTOR
#     12            dtaniwaki         1       CONTRIBUTOR
#     11                drj11         1       CONTRIBUTOR
#     9                 clkao         1       CONTRIBUTOR
#     8          clancychilds         1              NONE
#     6          captainsafia         1            MEMBER
#     3        albertmichaelj         1       CONTRIBUTOR
#     2             abhismvit         1       CONTRIBUTOR
#     16            javabrett         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:          username  authored authorAssociation
#     6      ian-r-rose         4            MEMBER
#     0      AlbertHilb         2            MEMBER
#     2    consideRatio         2            MEMBER
#     5         gnestor         2            MEMBER
#     1         Madhu94         1            MEMBER
#     3           dbast         1       CONTRIBUTOR
#     4    gcbeltramini         1       CONTRIBUTOR
#     7      jasongrout         1            MEMBER
#     8  saulshanabrook         1            MEMBER
#     9         vidartf         1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:       username  authored authorAssociation
#     2       emeeks         4            MEMBER
#     9     willingc         3            MEMBER
#     7       mpacer         2            MEMBER
#     0        MSeal         1            MEMBER
#     1      Madhu94         1            MEMBER
#     3      gnestor         1            MEMBER
#     4  hydrosquall         1            MEMBER
#     5  janfreyberg         1            MEMBER
#     6   kylebarron         1            MEMBER
#     8       mph006         1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %%
charts = []
for ii, (iorg, idata) in enumerate(closed_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"Merges for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='closed',
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                org                repo   username  closed
#     0  binder-examples         apt_install    betatim       2
#     1  binder-examples         apt_install  yuvipanda       1
#     2  binder-examples               conda  choldgraf       1
#     3  binder-examples    continuous-build    betatim       1
#     4  binder-examples          demo-julia    betatim       1
#     5  binder-examples  minimal-dockerfile      minrk       1
#     6  binder-examples        requirements    betatim       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:        org       repo username  closed
#     7  ipython    ipython  Carreau       5
#     8  ipython  traitlets    minrk       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:         org                      repo       username  closed
#     9   jupyter             accessibility      ellisonbg       1
#     10  jupyter             docker-stacks        parente      13
#     11  jupyter     enhancement-proposals        Zsailer       1
#     12  jupyter     enhancement-proposals   captainsafia       1
#     13  jupyter     enhancement-proposals        parente       2
#     14  jupyter     enhancement-proposals       willingc       3
#     15  jupyter        enterprise_gateway    kevin-bates       6
#     16  jupyter        enterprise_gateway       lresende       9
#     17  jupyter                      help        Carreau       1
#     18  jupyter                   jupyter      choldgraf       1
#     19  jupyter                   jupyter       willingc       1
#     20  jupyter              jupyter-book      choldgraf      23
#     21  jupyter         jupyter.github.io        Carreau       1
#     22  jupyter         jupyter.github.io           Ruv7       1
#     23  jupyter            jupyter_server  SylvainCorlay       1
#     24  jupyter            kernel_gateway       lresende       1
#     25  jupyter                     nb2kg    kevin-bates       1
#     26  jupyter                 nbconvert      takluyver       1
#     27  jupyter                    nbdime        vidartf       5
#     28  jupyter                  notebook          minrk      11
#     29  jupyter                  notebook      takluyver       1
#     30  jupyter                  notebook       willingc       2
#     31  jupyter               repo2docker        betatim       8
#     32  jupyter               repo2docker      choldgraf       2
#     33  jupyter               repo2docker          minrk       3
#     34  jupyter               repo2docker       willingc       1
#     35  jupyter               repo2docker      yuvipanda       1
#     36  jupyter  sphinxcontrib_github_alt      takluyver       1
#     37  jupyter                 terminado      takluyver       3,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                 org                    repo     username  closed
#     38  jupyter-widgets              ipyleaflet  martinRenou       8
#     39  jupyter-widgets     widget-cookiecutter      vidartf       1
#     40  jupyter-widgets  widget-ts-cookiecutter      vidartf       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            org                     repo      username  closed
#     41  jupyterhub                   binder       betatim       4
#     42  jupyterhub                binderhub       betatim       3
#     43  jupyterhub                binderhub  consideRatio       1
#     44  jupyterhub  configurable-http-proxy         minrk       5
#     45  jupyterhub            dockerspawner         minrk       1
#     46  jupyterhub               jupyterhub         minrk       8
#     47  jupyterhub               jupyterhub      willingc       4
#     48  jupyterhub      mybinder.org-deploy       betatim      10
#     49  jupyterhub      nativeauthenticator     yuvipanda       2
#     50  jupyterhub              nbgitpuller     yuvipanda       4
#     51  jupyterhub             team-compass       betatim       2
#     52  jupyterhub             team-compass     choldgraf       1
#     53  jupyterhub             team-compass  consideRatio       1
#     54  jupyterhub             team-compass         minrk       1
#     55  jupyterhub             team-compass      willingc       1
#     56  jupyterhub  the-littlest-jupyterhub     yuvipanda       3
#     57  jupyterhub              yarnspawner        jcrist       1
#     58  jupyterhub   zero-to-jupyterhub-k8s       betatim       1
#     59  jupyterhub   zero-to-jupyterhub-k8s  consideRatio       6
#     60  jupyterhub   zero-to-jupyterhub-k8s         minrk       5,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            org               repo    username  closed
#     61  jupyterlab         jupyterlab      afshin       3
#     62  jupyterlab         jupyterlab   blink1073       1
#     63  jupyterlab         jupyterlab  ian-r-rose       2
#     64  jupyterlab         jupyterlab  jasongrout       6
#     65  jupyterlab         jupyterlab     vidartf       1
#     66  jupyterlab     jupyterlab-git  jaipreet-s       2
#     67  jupyterlab  jupyterlab-github  ian-r-rose       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:         org             repo    username  closed
#     68  nteract         hydrogen  BenRussert       1
#     69  nteract  meeting-minutes    willingc       1
#     70  nteract        papermill       MSeal       2
#     71  nteract        papermill     betatim       1
#     72  nteract         semiotic      emeeks       3
#     73  nteract         semiotic    willingc       1
#     74  nteract    semiotic-docs     susielu       4
#     75  nteract             vdom       MSeal       2
#     76  nteract             vdom      mpacer       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## Issues
#
# Issues are **conversations** that happen on our GitHub repositories. Here's an
# analysis of issues across the Jupyter organizations.

# %%
created = issues.query('state == "OPEN" and createdAt > @start_date and createdAt < @end_date')
closed = issues.query('state == "CLOSED" and closedAt > @start_date and closedAt < @end_date')

# %%
created_counts = created.groupby(['org', 'repo']).count()['number'].reset_index()
created_counts['org/repo'] = created_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = created_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=created_counts, title=f"Issues created in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                      repo  number  \
#   0   binder-examples                demo-julia       1
#   1           ipython                 ipykernel       3
#   2           ipython               ipyparallel       2
#   3           ipython                   ipython      13
#   4           jupyter        enterprise_gateway       1
#   5           jupyter                      help      23
#   6           jupyter                   jupyter       4
#   7           jupyter              jupyter-book       5
#   8           jupyter         jupyter.github.io       1
#   9           jupyter            jupyter_client       3
#   10          jupyter           jupyter_console       2
#   11          jupyter       jupyter_kernel_test       1
#   12          jupyter                 nbconvert       1
#   13          jupyter                    nbdime       1
#   14          jupyter                  nbformat       2
#   15          jupyter                  notebook      37
#   16          jupyter                 qtconsole       1
#   17          jupyter               repo2docker       6
#   18  jupyter-widgets                ipyleaflet       2
#   19  jupyter-widgets                ipywidgets       9
#   20  jupyter-widgets       widget-cookiecutter       2
#   21       jupyterhub                    binder       1
#   22       jupyterhub                 binderhub       4
#   23       jupyterhub             dockerspawner       2
#   24       jupyterhub    jupyter-rsession-proxy       1
#   25       jupyterhub      jupyter-server-proxy       3
#   26       jupyterhub                jupyterhub       9
#   27       jupyterhub  jupyterhub-deploy-docker       1
#   28       jupyterhub               kubespawner       5
#   29       jupyterhub         ldapauthenticator       1
#   30       jupyterhub       mybinder.org-deploy       2
#   31       jupyterhub       nativeauthenticator       1
#   32       jupyterhub            oauthenticator       3
#   33       jupyterhub              team-compass       3
#   34       jupyterhub    zero-to-jupyterhub-k8s       9
#   35       jupyterlab         jupyter-renderers       1
#   36       jupyterlab                jupyterlab      23
#   37       jupyterlab            jupyterlab-git       6
#   38       jupyterlab          jupyterlab-latex       2
#   39       jupyterlab            jupyterlab_app       1
#   40          nteract              kernel-relay      10
#   41          nteract                   nteract       7
#   42          nteract                 papermill       1
#   43          nteract                 scrapbook       3
#   44          nteract                  semiotic      45
#
#                                  org/repo
#   0            binder-examples/demo-julia
#   1                     ipython/ipykernel
#   2                   ipython/ipyparallel
#   3                       ipython/ipython
#   4            jupyter/enterprise_gateway
#   5                          jupyter/help
#   6                       jupyter/jupyter
#   7                  jupyter/jupyter-book
#   8             jupyter/jupyter.github.io
#   9                jupyter/jupyter_client
#   10              jupyter/jupyter_console
#   11          jupyter/jupyter_kernel_test
#   12                    jupyter/nbconvert
#   13                       jupyter/nbdime
#   14                     jupyter/nbformat
#   15                     jupyter/notebook
#   16                    jupyter/qtconsole
#   17                  jupyter/repo2docker
#   18           jupyter-widgets/ipyleaflet
#   19           jupyter-widgets/ipywidgets
#   20  jupyter-widgets/widget-cookiecutter
#   21                    jupyterhub/binder
#   22                 jupyterhub/binderhub
#   23             jupyterhub/dockerspawner
#   24    jupyterhub/jupyter-rsession-proxy
#   25      jupyterhub/jupyter-server-proxy
#   26                jupyterhub/jupyterhub
#   27  jupyterhub/jupyterhub-deploy-docker
#   28               jupyterhub/kubespawner
#   29         jupyterhub/ldapauthenticator
#   30       jupyterhub/mybinder.org-deploy
#   31       jupyterhub/nativeauthenticator
#   32            jupyterhub/oauthenticator
#   33              jupyterhub/team-compass
#   34    jupyterhub/zero-to-jupyterhub-k8s
#   35         jupyterlab/jupyter-renderers
#   36                jupyterlab/jupyterlab
#   37            jupyterlab/jupyterlab-git
#   38          jupyterlab/jupyterlab-latex
#   39            jupyterlab/jupyterlab_app
#   40                 nteract/kernel-relay
#   41                      nteract/nteract
#   42                    nteract/papermill
#   43                    nteract/scrapbook
#   44                     nteract/semiotic  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['semiotic', 'kernel-relay', 'nteract', 'scrapbook', 'papermill', 'jupyterlab', 'jupyterlab-git', 'jupyterlab-latex', 'jupyter-renderers', 'jupyterlab_app', 'jupyterhub', 'zero-to-jupyterhub-k8s', 'kubespawner', 'binderhub', 'jupyter-server-proxy', 'oauthenticator', 'team-compass', 'dockerspawner', 'mybinder.org-deploy', 'binder', 'jupyter-rsession-proxy', 'jupyterhub-deploy-docker', 'ldapauthenticator', 'nativeauthenticator', 'ipywidgets', 'ipyleaflet', 'widget-cookiecutter', 'notebook', 'help', 'repo2docker', 'jupyter-book', 'jupyter', 'jupyter_client', 'jupyter_console', 'nbformat', 'enterprise_gateway', 'jupyter.github.io', 'jupyter_kernel_test', 'nbconvert', 'nbdime', 'qtconsole', 'ipython', 'ipykernel', 'ipyparallel', 'demo-julia']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues created in the last 31 days'
# })

# %%
closed_counts = closed.groupby(['org', 'repo']).count()['number'].reset_index()
closed_counts['org/repo'] = closed_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = closed_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=closed_counts, title=f"Issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                     repo  number  \
#   0   binder-examples              apt_install       3
#   1           ipython                  ipython      19
#   2           ipython          ipython-website       1
#   3           jupyter            docker-stacks      48
#   4           jupyter       enterprise_gateway       8
#   5           jupyter                     help       8
#   6           jupyter                  jupyter       2
#   7           jupyter             jupyter-book       7
#   8           jupyter        jupyter.github.io       1
#   9           jupyter           jupyter_client       2
#   10          jupyter           jupyter_server       1
#   11          jupyter                    nb2kg       2
#   12          jupyter                nbconvert       8
#   13          jupyter                   nbdime       5
#   14          jupyter                 nbformat       2
#   15          jupyter                 nbviewer       1
#   16          jupyter                 notebook      28
#   17          jupyter                qtconsole       1
#   18          jupyter              repo2docker      12
#   19          jupyter                terminado       1
#   20  jupyter-widgets               ipyleaflet       9
#   21  jupyter-widgets               ipywidgets       3
#   22  jupyter-widgets   widget-ts-cookiecutter       1
#   23       jupyterhub                   binder       6
#   24       jupyterhub                binderhub       5
#   25       jupyterhub            dockerspawner       1
#   26       jupyterhub     jupyter-server-proxy       3
#   27       jupyterhub               jupyterhub      21
#   28       jupyterhub        ldapauthenticator       1
#   29       jupyterhub      mybinder.org-deploy       5
#   30       jupyterhub              nbgitpuller       3
#   31       jupyterhub             team-compass      12
#   32       jupyterhub  the-littlest-jupyterhub       3
#   33       jupyterhub   zero-to-jupyterhub-k8s      10
#   34       jupyterlab        jupyter-renderers       1
#   35       jupyterlab               jupyterlab      31
#   36       jupyterlab           jupyterlab-git       6
#   37       jupyterlab         jupyterlab-latex       1
#   38          nteract                       dx       1
#   39          nteract                 examples       1
#   40          nteract                 hydrogen      14
#   41          nteract             kernel-relay       2
#   42          nteract          meeting-minutes       1
#   43          nteract               nteract.io       1
#   44          nteract                papermill      13
#   45          nteract                 semiotic       1
#   46          nteract            semiotic-docs       1
#
#                                     org/repo
#   0              binder-examples/apt_install
#   1                          ipython/ipython
#   2                  ipython/ipython-website
#   3                    jupyter/docker-stacks
#   4               jupyter/enterprise_gateway
#   5                             jupyter/help
#   6                          jupyter/jupyter
#   7                     jupyter/jupyter-book
#   8                jupyter/jupyter.github.io
#   9                   jupyter/jupyter_client
#   10                  jupyter/jupyter_server
#   11                           jupyter/nb2kg
#   12                       jupyter/nbconvert
#   13                          jupyter/nbdime
#   14                        jupyter/nbformat
#   15                        jupyter/nbviewer
#   16                        jupyter/notebook
#   17                       jupyter/qtconsole
#   18                     jupyter/repo2docker
#   19                       jupyter/terminado
#   20              jupyter-widgets/ipyleaflet
#   21              jupyter-widgets/ipywidgets
#   22  jupyter-widgets/widget-ts-cookiecutter
#   23                       jupyterhub/binder
#   24                    jupyterhub/binderhub
#   25                jupyterhub/dockerspawner
#   26         jupyterhub/jupyter-server-proxy
#   27                   jupyterhub/jupyterhub
#   28            jupyterhub/ldapauthenticator
#   29          jupyterhub/mybinder.org-deploy
#   30                  jupyterhub/nbgitpuller
#   31                 jupyterhub/team-compass
#   32      jupyterhub/the-littlest-jupyterhub
#   33       jupyterhub/zero-to-jupyterhub-k8s
#   34            jupyterlab/jupyter-renderers
#   35                   jupyterlab/jupyterlab
#   36               jupyterlab/jupyterlab-git
#   37             jupyterlab/jupyterlab-latex
#   38                              nteract/dx
#   39                        nteract/examples
#   40                        nteract/hydrogen
#   41                    nteract/kernel-relay
#   42                 nteract/meeting-minutes
#   43                      nteract/nteract.io
#   44                       nteract/papermill
#   45                        nteract/semiotic
#   46                   nteract/semiotic-docs  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['hydrogen', 'papermill', 'kernel-relay', 'dx', 'examples', 'meeting-minutes', 'nteract.io', 'semiotic', 'semiotic-docs', 'jupyterlab', 'jupyterlab-git', 'jupyter-renderers', 'jupyterlab-latex', 'jupyterhub', 'team-compass', 'zero-to-jupyterhub-k8s', 'binder', 'binderhub', 'mybinder.org-deploy', 'jupyter-server-proxy', 'nbgitpuller', 'the-littlest-jupyterhub', 'dockerspawner', 'ldapauthenticator', 'ipyleaflet', 'ipywidgets', 'widget-ts-cookiecutter', 'docker-stacks', 'notebook', 'repo2docker', 'enterprise_gateway', 'help', 'nbconvert', 'jupyter-book', 'nbdime', 'jupyter', 'jupyter_client', 'nb2kg', 'nbformat', 'jupyter.github.io', 'jupyter_server', 'nbviewer', 'qtconsole', 'terminado', 'ipython', 'ipython-website', 'apt_install']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues closed in the last 31 days'
# })

# %%
created_closed = pd.merge(created_counts.rename(columns={'number': 'created'}).drop(columns='org/repo'),
                          closed_counts.rename(columns={'number': 'closed'}).drop(columns='org/repo'),
                          on=['org', 'repo'], how='outer')

created_closed = pd.melt(created_closed, id_vars=['org', 'repo'], var_name="kind", value_name="count").replace(np.nan, 0)

# %%
charts = []
for org in github_orgs:
    # Pick the top 10 repositories
    this_issues = created_closed.query('org == @org')
    top_repos = this_issues.groupby(['repo']).sum().sort_values(by='count', ascending=False).head(10).index
    ch = alt.Chart(this_issues.query('repo in @top_repos'), width=120).mark_bar().encode(
        x=alt.X("kind", axis=alt.Axis(labelFontSize=15, title="")), 
        y=alt.Y('count', axis=alt.Axis(titleFontSize=15, labelFontSize=12)),
        color='kind',
        column=alt.Column("repo", header=alt.Header(title=f"Issue activity, last {n_days} days for {org}", titleFontSize=15, labelFontSize=12))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             org               repo     kind  count
#     35   jupyterlab  jupyter-renderers  created    1.0
#     36   jupyterlab         jupyterlab  created   23.0
#     37   jupyterlab     jupyterlab-git  created    6.0
#     38   jupyterlab   jupyterlab-latex  created    2.0
#     39   jupyterlab     jupyterlab_app  created    1.0
#     96   jupyterlab  jupyter-renderers   closed    1.0
#     97   jupyterlab         jupyterlab   closed   31.0
#     98   jupyterlab     jupyterlab-git   closed    6.0
#     99   jupyterlab   jupyterlab-latex   closed    1.0
#     100  jupyterlab     jupyterlab_app   closed    0.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyterlab',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                  org                    repo     kind  count
#     18   jupyter-widgets              ipyleaflet  created    2.0
#     19   jupyter-widgets              ipywidgets  created    9.0
#     20   jupyter-widgets     widget-cookiecutter  created    2.0
#     52   jupyter-widgets  widget-ts-cookiecutter  created    0.0
#     79   jupyter-widgets              ipyleaflet   closed    9.0
#     80   jupyter-widgets              ipywidgets   closed    3.0
#     81   jupyter-widgets     widget-cookiecutter   closed    0.0
#     113  jupyter-widgets  widget-ts-cookiecutter   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyter-widgets',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org             repo     kind  count
#     1    ipython        ipykernel  created    3.0
#     2    ipython      ipyparallel  created    2.0
#     3    ipython          ipython  created   13.0
#     46   ipython  ipython-website  created    0.0
#     62   ipython        ipykernel   closed    0.0
#     63   ipython      ipyparallel   closed    0.0
#     64   ipython          ipython   closed   19.0
#     107  ipython  ipython-website   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for ipython',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                  org         repo     kind  count
#     0    binder-examples   demo-julia  created    1.0
#     45   binder-examples  apt_install  created    0.0
#     61   binder-examples   demo-julia   closed    0.0
#     106  binder-examples  apt_install   closed    3.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for binder-examples',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org                repo     kind  count
#     4    jupyter  enterprise_gateway  created    1.0
#     5    jupyter                help  created   23.0
#     6    jupyter             jupyter  created    4.0
#     7    jupyter        jupyter-book  created    5.0
#     9    jupyter      jupyter_client  created    3.0
#     12   jupyter           nbconvert  created    1.0
#     13   jupyter              nbdime  created    1.0
#     15   jupyter            notebook  created   37.0
#     17   jupyter         repo2docker  created    6.0
#     47   jupyter       docker-stacks  created    0.0
#     65   jupyter  enterprise_gateway   closed    8.0
#     66   jupyter                help   closed    8.0
#     67   jupyter             jupyter   closed    2.0
#     68   jupyter        jupyter-book   closed    7.0
#     70   jupyter      jupyter_client   closed    2.0
#     73   jupyter           nbconvert   closed    8.0
#     74   jupyter              nbdime   closed    5.0
#     76   jupyter            notebook   closed   28.0
#     78   jupyter         repo2docker   closed   12.0
#     108  jupyter       docker-stacks   closed   48.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyter',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:             org                    repo     kind  count
#     21   jupyterhub                  binder  created    1.0
#     22   jupyterhub               binderhub  created    4.0
#     23   jupyterhub           dockerspawner  created    2.0
#     25   jupyterhub    jupyter-server-proxy  created    3.0
#     26   jupyterhub              jupyterhub  created    9.0
#     28   jupyterhub             kubespawner  created    5.0
#     30   jupyterhub     mybinder.org-deploy  created    2.0
#     33   jupyterhub            team-compass  created    3.0
#     34   jupyterhub  zero-to-jupyterhub-k8s  created    9.0
#     53   jupyterhub             nbgitpuller  created    0.0
#     82   jupyterhub                  binder   closed    6.0
#     83   jupyterhub               binderhub   closed    5.0
#     84   jupyterhub           dockerspawner   closed    1.0
#     86   jupyterhub    jupyter-server-proxy   closed    3.0
#     87   jupyterhub              jupyterhub   closed   21.0
#     89   jupyterhub             kubespawner   closed    0.0
#     91   jupyterhub     mybinder.org-deploy   closed    5.0
#     94   jupyterhub            team-compass   closed   12.0
#     95   jupyterhub  zero-to-jupyterhub-k8s   closed   10.0
#     114  jupyterhub             nbgitpuller   closed    3.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyterhub',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org             repo     kind  count
#     40   nteract     kernel-relay  created   10.0
#     41   nteract          nteract  created    7.0
#     42   nteract        papermill  created    1.0
#     43   nteract        scrapbook  created    3.0
#     44   nteract         semiotic  created   45.0
#     55   nteract               dx  created    0.0
#     56   nteract         examples  created    0.0
#     57   nteract         hydrogen  created    0.0
#     58   nteract  meeting-minutes  created    0.0
#     59   nteract       nteract.io  created    0.0
#     101  nteract     kernel-relay   closed    2.0
#     102  nteract          nteract   closed    0.0
#     103  nteract        papermill   closed   13.0
#     104  nteract        scrapbook   closed    0.0
#     105  nteract         semiotic   closed    1.0
#     116  nteract               dx   closed    1.0
#     117  nteract         examples   closed    1.0
#     118  nteract         hydrogen   closed   14.0
#     119  nteract  meeting-minutes   closed    1.0
#     120  nteract       nteract.io   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for nteract',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   })]
# })

# %%
# Set to datetime
for kind in ['createdAt', 'closedAt']:
    closed.loc[:, kind] = pd.to_datetime(closed[kind])
    
closed.loc[:, 'time_open'] = closed['closedAt'] - closed['createdAt']
closed.loc[:, 'time_open'] = closed['time_open'].dt.total_seconds()
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:480: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
time_open = closed.groupby(['org', 'repo']).agg({'time_open': 'median'}).reset_index()
time_open['time_open'] = time_open['time_open'] / (60 * 60 * 24)
time_open['org/repo'] = time_open.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = time_open.sort_values(['org', 'time_open'], ascending=False)['repo'].values
alt.Chart(data=time_open, title=f"Time to close for issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y=alt.Y('time_open', title="Median Days Open"),
    color='org',
)
# Out:
# Chart({
#   data:                 org                     repo   time_open  \
#   0   binder-examples              apt_install    0.050544
#   1           ipython                  ipython    6.707002
#   2           ipython          ipython-website    0.600301
#   3           jupyter            docker-stacks  225.980266
#   4           jupyter       enterprise_gateway    1.738611
#   5           jupyter                     help    0.395110
#   6           jupyter                  jupyter    3.518900
#   7           jupyter             jupyter-book    0.135498
#   8           jupyter        jupyter.github.io    0.077083
#   9           jupyter           jupyter_client  244.560689
#   10          jupyter           jupyter_server    0.833322
#   11          jupyter                    nb2kg    0.530353
#   12          jupyter                nbconvert   73.019317
#   13          jupyter                   nbdime    2.972917
#   14          jupyter                 nbformat  289.033472
#   15          jupyter                 nbviewer    6.889421
#   16          jupyter                 notebook    3.707616
#   17          jupyter                qtconsole    2.596262
#   18          jupyter              repo2docker   18.533420
#   19          jupyter                terminado   14.735301
#   20  jupyter-widgets               ipyleaflet   23.043368
#   21  jupyter-widgets               ipywidgets    1.889109
#   22  jupyter-widgets   widget-ts-cookiecutter    1.047234
#   23       jupyterhub                   binder    0.895885
#   24       jupyterhub                binderhub   12.662407
#   25       jupyterhub            dockerspawner  453.596435
#   26       jupyterhub     jupyter-server-proxy   33.565995
#   27       jupyterhub               jupyterhub    6.655440
#   28       jupyterhub        ldapauthenticator    0.523206
#   29       jupyterhub      mybinder.org-deploy    0.679387
#   30       jupyterhub              nbgitpuller    0.447176
#   31       jupyterhub             team-compass   38.602483
#   32       jupyterhub  the-littlest-jupyterhub   50.864780
#   33       jupyterhub   zero-to-jupyterhub-k8s    9.446024
#   34       jupyterlab        jupyter-renderers  391.798669
#   35       jupyterlab               jupyterlab    1.762928
#   36       jupyterlab           jupyterlab-git   56.930868
#   37       jupyterlab         jupyterlab-latex    0.035741
#   38          nteract                       dx   43.691389
#   39          nteract                 examples   23.276771
#   40          nteract                 hydrogen    2.038843
#   41          nteract             kernel-relay    0.993947
#   42          nteract          meeting-minutes    7.155718
#   43          nteract               nteract.io    0.812778
#   44          nteract                papermill   13.431806
#   45          nteract                 semiotic    4.484850
#   46          nteract            semiotic-docs    7.700521
#
#                                     org/repo
#   0              binder-examples/apt_install
#   1                          ipython/ipython
#   2                  ipython/ipython-website
#   3                    jupyter/docker-stacks
#   4               jupyter/enterprise_gateway
#   5                             jupyter/help
#   6                          jupyter/jupyter
#   7                     jupyter/jupyter-book
#   8                jupyter/jupyter.github.io
#   9                   jupyter/jupyter_client
#   10                  jupyter/jupyter_server
#   11                           jupyter/nb2kg
#   12                       jupyter/nbconvert
#   13                          jupyter/nbdime
#   14                        jupyter/nbformat
#   15                        jupyter/nbviewer
#   16                        jupyter/notebook
#   17                       jupyter/qtconsole
#   18                     jupyter/repo2docker
#   19                       jupyter/terminado
#   20              jupyter-widgets/ipyleaflet
#   21              jupyter-widgets/ipywidgets
#   22  jupyter-widgets/widget-ts-cookiecutter
#   23                       jupyterhub/binder
#   24                    jupyterhub/binderhub
#   25                jupyterhub/dockerspawner
#   26         jupyterhub/jupyter-server-proxy
#   27                   jupyterhub/jupyterhub
#   28            jupyterhub/ldapauthenticator
#   29          jupyterhub/mybinder.org-deploy
#   30                  jupyterhub/nbgitpuller
#   31                 jupyterhub/team-compass
#   32      jupyterhub/the-littlest-jupyterhub
#   33       jupyterhub/zero-to-jupyterhub-k8s
#   34            jupyterlab/jupyter-renderers
#   35                   jupyterlab/jupyterlab
#   36               jupyterlab/jupyterlab-git
#   37             jupyterlab/jupyterlab-latex
#   38                              nteract/dx
#   39                        nteract/examples
#   40                        nteract/hydrogen
#   41                    nteract/kernel-relay
#   42                 nteract/meeting-minutes
#   43                      nteract/nteract.io
#   44                       nteract/papermill
#   45                        nteract/semiotic
#   46                   nteract/semiotic-docs  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['dx', 'examples', 'papermill', 'semiotic-docs', 'meeting-minutes', 'semiotic', 'hydrogen', 'kernel-relay', 'nteract.io', 'jupyter-renderers', 'jupyterlab-git', 'jupyterlab', 'jupyterlab-latex', 'dockerspawner', 'the-littlest-jupyterhub', 'team-compass', 'jupyter-server-proxy', 'binderhub', 'zero-to-jupyterhub-k8s', 'jupyterhub', 'binder', 'mybinder.org-deploy', 'ldapauthenticator', 'nbgitpuller', 'ipyleaflet', 'ipywidgets', 'widget-ts-cookiecutter', 'nbformat', 'jupyter_client', 'docker-stacks', 'nbconvert', 'repo2docker', 'terminado', 'nbviewer', 'notebook', 'jupyter', 'nbdime', 'qtconsole', 'enterprise_gateway', 'jupyter_server', 'nb2kg', 'help', 'jupyter-book', 'jupyter.github.io', 'ipython', 'ipython-website', 'apt_install']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'time_open',
#       title: 'Median Days Open',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Time to close for issues closed in the last 31 days'
# })

# %% [markdown]
# ### A list of recent issues
#
# Below is a list of issues with recent activity in each repository. If they seem of interest
# to you, click on their links and jump in to participate!

# %%
# Add comment count data to issues and PRs
comment_counts = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'issue_id'])
    .count().iloc[:, 0].to_frame()
)
comment_counts.columns = ['n_comments']
comment_counts = comment_counts.reset_index()

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, (org, idata) in enumerate(comment_counts.groupby('org')):
    issue_md = []
    issue_md.append(f"#### {org}")
    issue_md.append("")
    for repo, i_issues in idata.groupby('repo'):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")

        top_issues = i_issues.sort_values('n_comments', ascending=False).head(n_plot)
        top_issue_list = pd.merge(issues, top_issues, left_on=['org', 'repo', 'number'], right_on=['org', 'repo', 'issue_id'])
        for _, issue in top_issue_list.sort_values('n_comments', ascending=False).head(n_plot).iterrows():
            user_name = issue['author']
            user_url = author_url(user_name)
            issue_number = issue['number']
            issue_html = issue['url']
            issue_title = issue['title']

            text = f"* [(#{issue_number})]({issue_html}): _{issue_title}_ by **[@{user_name}]({user_url})**"
            issue_md.append(text)

    issue_md.append('')
    md_html = HTML(markdown('\n'.join(issue_md)))
    
    children = list(tabs.children)
    children.append(HTML(markdown('\n'.join(issue_md))))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"Here are the top {n_plot} active issues in each repository in the last {n_days} days"))
display(tabs)
# Out:
# Here are the top 5 active issues in each repository in the last 31 days
# Tab(children=(HTML(value='<h4>binder-examples</h4>\n<h5><a href="https://github.com/binder-examples/apt_instal…

# %% [markdown]
# ## Commenters across repositories
#
# These are commenters across all issues and pull requests in the last several days.
# These are colored by the commenter's association with the organization. For information
# about what these associations mean, [see this StackOverflow post](https://stackoverflow.com/a/28866914/1927102).

# %%
commentors = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'author', 'authorAssociation'])
    .count().rename(columns={'id': 'count'})['count']
    .reset_index()
    .sort_values(['org', 'count'], ascending=False)
)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(commentors.groupby(['org'])):
    title = f"Top {n_plot} commentors for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'count': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('count', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='count',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             author  count authorAssociation
#     1        choldgraf      7            MEMBER
#     3           kannes      7       CONTRIBUTOR
#     0          betatim      6            MEMBER
#     4  matthewfeickert      4              NONE
#     6        yuvipanda      3            MEMBER
#     2     davidanthoff      2       CONTRIBUTOR
#     5            minrk      1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                 author  count authorAssociation
#     3              Carreau     51            MEMBER
#     54         martinRenou     19              NONE
#     66            rmorshea     11      COLLABORATOR
#     55          matangover      6       CONTRIBUTOR
#     71           tacaswell      6       CONTRIBUTOR
#     51     maartenbreddels      5              NONE
#     59               minrk      5            MEMBER
#     76             travigd      4              NONE
#     62         rainwoodman      4              NONE
#     58            mimakaev      3              NONE
#     29              daharn      3       CONTRIBUTOR
#     56      mathieulongtin      3              NONE
#     16        Viktor-Demin      3              NONE
#     69              stas00      3              NONE
#     26          ccordoba12      2       CONTRIBUTOR
#     34           eranegozy      2              NONE
#     45             jsnydes      2       CONTRIBUTOR
#     64           redhermes      2              NONE
#     35         flutefreak7      2              NONE
#     46                krey      2              NONE
#     12      LucianaMarques      2       CONTRIBUTOR
#     11           KelSolaar      2              NONE
#     72           takluyver      2            MEMBER
#     75              tomyun      2       CONTRIBUTOR
#     47            letalvoj      2              NONE
#     32       drscotthawley      2              NONE
#     53               mapio      1       CONTRIBUTOR
#     52          mangecoeur      1              NONE
#     50             litesam      1              NONE
#     49        lisamartin72      1              NONE
#     48        liquidcarbon      1              NONE
#     0      AasthaTimalsina      1              NONE
#     57         meeseeksdev      1       CONTRIBUTOR
#     60           ndtallant      1       CONTRIBUTOR
#     61          pabloslash      1              NONE
#     65           rmbrannan      1              NONE
#     67           softarmpl      1              NONE
#     68          sonofagunn      1              NONE
#     70            stevengj      1              NONE
#     73           techtonik      1       CONTRIBUTOR
#     74          texadactyl      1              NONE
#     77           wuqiaomin      1              NONE
#     78               yc-zc      1              NONE
#     79           yiran7324      1              NONE
#     63             red8012      1              NONE
#     40           hriday535      1              NONE
#     44  jorisvandenbossche      1       CONTRIBUTOR
#     10             JockeTF      1              NONE
#     19               abaar      1              NONE
#     18            YubinXie      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                author  count authorAssociation
#     160         choldgraf    133            MEMBER
#     363           parente    103            MEMBER
#     277       kevin-bates     91            MEMBER
#     142           betatim     59            MEMBER
#     336             minrk     52            MEMBER
#     249         jasmainak     49       CONTRIBUTOR
#     182      davidanthoff     34       CONTRIBUTOR
#     251        jasongrout     32            MEMBER
#     202           emdupre     30      COLLABORATOR
#     60              MSeal     26            MEMBER
#     222          glorysdj     22              NONE
#     460           vidartf     21      COLLABORATOR
#     472          willingc     21            MEMBER
#     441         takluyver     17            MEMBER
#     301          lresende     17            MEMBER
#     201         ellisonbg     13            MEMBER
#     19            Carreau     13            MEMBER
#     67             NHDaly     12       CONTRIBUTOR
#     0            1kastner     10              NONE
#     255         javabrett      9       CONTRIBUTOR
#     258          jhermann      9       CONTRIBUTOR
#     152      captainsafia      9            MEMBER
#     154        ccordoba12      9      COLLABORATOR
#     308   maartenbreddels      9       CONTRIBUTOR
#     314   mathieuboudreau      8       CONTRIBUTOR
#     400   saipradeepkumar      8              NONE
#     274         keflavich      7              NONE
#     207            esevan      7      COLLABORATOR
#     422         sindzicat      7              NONE
#     300       lovettchris      7              NONE
#     481         yuvipanda      7            MEMBER
#     89      SylvainCorlay      7            MEMBER
#     36           Gsbreddy      7              NONE
#     11        Athanasiamo      6       CONTRIBUTOR
#     265        joergbrech      6       CONTRIBUTOR
#     237          iamtodor      6              NONE
#     203          emiliotl      6       CONTRIBUTOR
#     52        KirstieJane      5              NONE
#     101           Zsailer      5            MEMBER
#     232           hroncok      5       CONTRIBUTOR
#     382         rahuldave      5              NONE
#     403  sarthaksahni1989      4              NONE
#     452       transtrades      4              NONE
#     144              bjce      4              NONE
#     219            ggrrll      4              NONE
#     164          ciupicri      4              NONE
#     310         manaimran      4              NONE
#     342            mpacer      4            MEMBER
#     170           cpranav      4              NONE
#     346           mwcraig      4       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     20       jasongrout     32            MEMBER
#     25      martinRenou     28            MEMBER
#     37          vidartf     25            MEMBER
#     41          zerline      9       CONTRIBUTOR
#     9           TK-21st      5              NONE
#     8     SylvainCorlay      4            MEMBER
#     24  maartenbreddels      4            MEMBER
#     12             btel      3       CONTRIBUTOR
#     13         deeplook      3              NONE
#     7        PBrockmann      3              NONE
#     11         ankostis      2              NONE
#     39          xoolive      2              NONE
#     23             krey      2              NONE
#     15          djhoese      2              NONE
#     22         koren88i      2              NONE
#     4       LukaPitamic      2              NONE
#     31        robnagler      1              NONE
#     40           yiakwy      1              NONE
#     30   richardagalvez      1              NONE
#     32        rocknamx8      1              NONE
#     36       twalker309      1              NONE
#     33    steviestevepy      1              NONE
#     34          sytelus      1              NONE
#     35          technic      1              NONE
#     28      psychemedia      1              NONE
#     38           vishma      1              NONE
#     29         rheiland      1              NONE
#     0        Gabrielvon      1              NONE
#     27       oscar6echo      1       CONTRIBUTOR
#     26          mwcraig      1       CONTRIBUTOR
#     1   JosephKarpinski      1              NONE
#     19          gnestor      1       CONTRIBUTOR
#     18           garra2      1              NONE
#     17       fsteinmetz      1              NONE
#     16     flying-sheep      1       CONTRIBUTOR
#     14          dipsm15      1              NONE
#     10     VasavanThiru      1       CONTRIBUTOR
#     6         NaNitrate      1              NONE
#     5          Milania1      1              NONE
#     3         Liwellyen      1              NONE
#     2         Juanlu001      1       CONTRIBUTOR
#     21       kirkanshin      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                  author  count authorAssociation
#     46              betatim    127            MEMBER
#     61         consideRatio     98            MEMBER
#     57            choldgraf     80            MEMBER
#     133               minrk     53            MEMBER
#     33               ablekh     35              NONE
#     177            willingc     22            MEMBER
#     116          leportella     21              NONE
#     29              Zsailer     20            MEMBER
#     122              manics     18       CONTRIBUTOR
#     180           yuvipanda     14            MEMBER
#     47               bitnik      8       CONTRIBUTOR
#     38       albertmichaelj      7       CONTRIBUTOR
#     118              lheagy      7            MEMBER
#     37              agitter      7              NONE
#     96               jcrist      7            MEMBER
#     179               yucai      6              NONE
#     154          ryanlovett      5            MEMBER
#     178           willirath      5      COLLABORATOR
#     66          dhirschfeld      5      COLLABORATOR
#     121             ltetrel      5              NONE
#     68        divatemangesh      5              NONE
#     83             frouzbeh      5              NONE
#     104             jrcblue      5              NONE
#     102            joshbode      4       CONTRIBUTOR
#     53               certik      4              NONE
#     87             hansen-m      4              NONE
#     39           alexmorley      4       CONTRIBUTOR
#     32               abinet      4              NONE
#     75            emigre459      4              NONE
#     171            vlizanae      4              NONE
#     159           sgibson91      4            MEMBER
#     25        SylvainCorlay      4              NONE
#     132             mgnfcnt      3              NONE
#     160             shibbas      3       CONTRIBUTOR
#     105        jrmlhermitte      3              NONE
#     30      abdidarmawan007      3              NONE
#     110                 kif      3              NONE
#     91            hugoJuhel      3              NONE
#     64          datachannel      3              NONE
#     151             rgaiacs      3              NONE
#     150            rcthomas      3       CONTRIBUTOR
#     6               Carreau      3            MEMBER
#     22   PaluchowskiMatthew      3              NONE
#     144            qzchenwl      3              NONE
#     142        playermanny2      3              NONE
#     74            ellisonbg      3            MEMBER
#     35             ageorgou      3              NONE
#     71                drj11      3              NONE
#     59                clkao      3       CONTRIBUTOR
#     84                garej      2              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                   author  count authorAssociation
#     81            jasongrout    132            MEMBER
#     61             ellisonbg     48            MEMBER
#     129       saulshanabrook     37            MEMBER
#     146              vidartf     30            MEMBER
#     16               Madhu94     29            MEMBER
#     76            ian-r-rose     25            MEMBER
#     80            jaipreet-s     12      COLLABORATOR
#     71               gnestor     11            MEMBER
#     26              agoose77      9            MEMBER
#     25                afshin      8            MEMBER
#     143            tgeorgeux      8            MEMBER
#     115           nickeubank      7              NONE
#     107               mgeier      6       CONTRIBUTOR
#     67          flying-sheep      5              NONE
#     108     mihai-dinculescu      4              NONE
#     109                minrk      4            MEMBER
#     33              aschlaep      4            MEMBER
#     144               tibdex      4            MEMBER
#     36             blink1073      4            MEMBER
#     149           weitongwei      4              NONE
#     3                 BoPeng      4            MEMBER
#     58              domoritz      4            MEMBER
#     50                 cquah      4            MEMBER
#     39              bollwyvl      3            MEMBER
#     82             javabrett      3              NONE
#     37                 blois      3              NONE
#     153             zuoyuanh      3            MEMBER
#     44             choldgraf      3            MEMBER
#     79                ivanov      3            MEMBER
#     35         balamuruganvg      3       CONTRIBUTOR
#     49          consideRatio      3            MEMBER
#     74             hugoJuhel      3              NONE
#     69               ghuname      3              NONE
#     46               cocoaaa      3              NONE
#     66           flutefreak7      3              NONE
#     93                kboxk7      3              NONE
#     152                 yt87      3              NONE
#     145            timkpaine      3            MEMBER
#     113              nealmcb      3              NONE
#     118         passengeryjy      3              NONE
#     121  quigleyj-mavenomics      3              NONE
#     88       jonathan-durbin      2              NONE
#     128               rowles      2              NONE
#     151               xmnlab      2      COLLABORATOR
#     70           glass-ships      2              NONE
#     134            simonnier      2              NONE
#     72                gsemet      2              NONE
#     73                 hadim      2            MEMBER
#     130          scottwsides      2              NONE
#     124         renatoviolin      2              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:               author  count authorAssociation
#     39        kylebarron     31            MEMBER
#     7              MSeal     27            MEMBER
#     22      captainsafia     24            MEMBER
#     1         BenRussert     23            MEMBER
#     63          willingc     16            MEMBER
#     4             Jogala     11              NONE
#     33  hp8wvvvgnj6asjm7     10              NONE
#     59       stormpython      8            MEMBER
#     41             mbrio      8              NONE
#     43            mpacer      8            MEMBER
#     27            emeeks      6            MEMBER
#     8            Madhu94      5            MEMBER
#     60           susielu      5            MEMBER
#     10          Nicbecoz      5              NONE
#     54            rgbkrk      4            MEMBER
#     38             jzazo      4              NONE
#     29           gnestor      3            MEMBER
#     44           mscipio      3              NONE
#     40           lgeiger      3            MEMBER
#     35      jarmokivekas      3            MEMBER
#     31    grahamanderson      3              NONE
#     23         choldgraf      3            MEMBER
#     64          zachwill      3              NONE
#     21             blois      2              NONE
#     52          rekham23      2              NONE
#     62           utibeno      2              NONE
#     17           alendit      2              NONE
#     19           betatim      2            MEMBER
#     48             niwsa      2              NONE
#     24      davidanthoff      2              NONE
#     12         RaghuNaik      2              NONE
#     55          rmorshea      2            MEMBER
#     25        dylanross3      2            MEMBER
#     49    nl-datascience      1              NONE
#     57          rpalloni      1              NONE
#     50        philippjfr      1              NONE
#     58         sinemetu1      1              NONE
#     47         nikitakit      1       CONTRIBUTOR
#     46       mstewart141      1              NONE
#     53        renefritze      1              NONE
#     61    thomasbazeille      1              NONE
#     51           pybokeh      1              NONE
#     45          mstetson      1              NONE
#     56           romeran      1              NONE
#     0         AWTammsaar      1              NONE
#     42      mckev-amazon      1              NONE
#     37    jibraniqbal666      1              NONE
#     2           DizzyNDL      1              NONE
#     3         GagandeepS      1              NONE
#     5               KLzC      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## First responders
#
# First responders are the first people to respond to a new issue in one of the repositories.
# The following plots show first responders for recently-created issues.

# %%
first_comments = []
for (org, repo, issue_id), i_comments in comments.groupby(['org', 'repo', 'issue_id']):
    ix_min = pd.to_datetime(i_comments['createdAt']).idxmin()
    first_comment = i_comments.loc[ix_min]
    if isinstance(first_comment, pd.DataFrame):
        first_comment = first_comment.iloc[0]
    first_comments.append(first_comment)
first_comments = pd.concat(first_comments, axis=1).T

# %%
first_responder_counts = first_comments.groupby(['org', 'author', 'authorAssociation'], as_index=False).\
    count().rename(columns={'id': 'n_first_responses'}).sort_values(['org', 'n_first_responses'], ascending=False)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(first_responder_counts.groupby(['org'])):
    title = f"Top {n_plot} first responders for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'n_first_responses': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('n_first_responses', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='n_first_responses',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             author  n_first_responses authorAssociation
#     1        choldgraf                  3            MEMBER
#     2           kannes                  3       CONTRIBUTOR
#     0          betatim                  1            MEMBER
#     3  matthewfeickert                  1              NONE
#     4            minrk                  1            MEMBER
#     5        yuvipanda                  1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                     author  n_first_responses authorAssociation
#     1                  Carreau                 26            MEMBER
#     41               tacaswell                  4       CONTRIBUTOR
#     37                rmorshea                  4      COLLABORATOR
#     22             flutefreak7                  2              NONE
#     44                 travigd                  2       CONTRIBUTOR
#     39                  stas00                  2              NONE
#     31              matangover                  2       CONTRIBUTOR
#     33               ndtallant                  1       CONTRIBUTOR
#     26              jasonzhouu                  1              NONE
#     27                    krey                  1              NONE
#     28                letalvoj                  1              NONE
#     29            liquidcarbon                  1              NONE
#     30              mangecoeur                  1              NONE
#     32                   minrk                  1            MEMBER
#     0   AbsurdMagpieScrutinies                  1              NONE
#     34              pabloslash                  1              NONE
#     25                gpotter2                  1       CONTRIBUTOR
#     36               rmbrannan                  1              NONE
#     38              sonofagunn                  1              NONE
#     40                stevengj                  1              NONE
#     42               techtonik                  1       CONTRIBUTOR
#     43                  tomyun                  1       CONTRIBUTOR
#     45               wuqiaomin                  1              NONE
#     35                 red8012                  1              NONE
#     23            flying-sheep                  1       CONTRIBUTOR
#     24                   funic                  1              NONE
#     21              dwhswenson                  1              NONE
#     2          DouglasRaillard                  1              NONE
#     3                   Evidlo                  1              NONE
#     4           GunaDhannarapu                  1              NONE
#     5                KelSolaar                  1              NONE
#     6           LucianaMarques                  1       CONTRIBUTOR
#     7            Pierre-Bartet                  1              NONE
#     8            SylvainCorlay                  1            MEMBER
#     9             Viktor-Demin                  1              NONE
#     10             VorpalBlade                  1              NONE
#     11                   abaar                  1              NONE
#     12            alexgawrilow                  1              NONE
#     13                alexpdp7                  1              NONE
#     14           arianccbasile                  1              NONE
#     15             assafmuller                  1              NONE
#     16               astrofrog                  1              NONE
#     17              ccordoba12                  1       CONTRIBUTOR
#     18            cirosantilli                  1              NONE
#     19                 czf1009                  1              NONE
#     20                   dinya                  1              NONE
#     46                   yc-zc                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                author  n_first_responses authorAssociation
#     175           parente                 65            MEMBER
#     83          choldgraf                 40            MEMBER
#     136       kevin-bates                 23            MEMBER
#     74            betatim                 22            MEMBER
#     163             minrk                 19            MEMBER
#     31              MSeal                 11            MEMBER
#     224           vidartf                  9      COLLABORATOR
#     123         jasmainak                  9       CONTRIBUTOR
#     217         takluyver                  6            MEMBER
#     127         javabrett                  6       CONTRIBUTOR
#     124        jasongrout                  6            MEMBER
#     96       davidanthoff                  6       CONTRIBUTOR
#     230          willingc                  5            MEMBER
#     145          lresende                  5            MEMBER
#     129          jhermann                  4       CONTRIBUTOR
#     103           emdupre                  3      COLLABORATOR
#     115           hroncok                  3       CONTRIBUTOR
#     36             NHDaly                  3       CONTRIBUTOR
#     53            Zsailer                  3            MEMBER
#     102         ellisonbg                  3            MEMBER
#     184  pushpendrapratap                  2              NONE
#     41            RoyalTS                  2              NONE
#     42               Ruv7                  2            MEMBER
#     61           akhmerov                  2            MEMBER
#     89            cpranav                  2              NONE
#     64             alifuk                  2              NONE
#     130            jkmgeo                  2              NONE
#     79         ccordoba12                  2      COLLABORATOR
#     104          emiliotl                  2       CONTRIBUTOR
#     132        joergbrech                  2       CONTRIBUTOR
#     208         sindzicat                  2              NONE
#     118          impact27                  2       CONTRIBUTOR
#     12             EloyRD                  2              NONE
#     235         yuvipanda                  2            MEMBER
#     234             yc-zc                  2              NONE
#     232            xmnlab                  2       CONTRIBUTOR
#     222           ucgummy                  2              NONE
#     22            Irfan-X                  2              NONE
#     21             Ian-An                  2              NONE
#     157    mennowitteveen                  1              NONE
#     151   mathieuboudreau                  1       CONTRIBUTOR
#     152  mattearllongshot                  1              NONE
#     153             mattn                  1              NONE
#     154        maxfrei750                  1              NONE
#     155   maxwellmckinnon                  1              NONE
#     225       vikasavnish                  1              NONE
#     156      mckev-amazon                  1              NONE
#     209            skully                  1              NONE
#     158            mgeier                  1       CONTRIBUTOR
#     226          viral810                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  n_first_responses authorAssociation
#     17      martinRenou                 14            MEMBER
#     26          vidartf                 12            MEMBER
#     15       jasongrout                  7            MEMBER
#     4     SylvainCorlay                  3            MEMBER
#     5           TK-21st                  2              NONE
#     7          ankostis                  2              NONE
#     0   JosephKarpinski                  1              NONE
#     27           vishma                  1              NONE
#     25       twalker309                  1              NONE
#     24          technic                  1              NONE
#     23          sytelus                  1              NONE
#     22    steviestevepy                  1              NONE
#     21        rocknamx8                  1              NONE
#     20         rheiland                  1              NONE
#     19      psychemedia                  1              NONE
#     18          mwcraig                  1       CONTRIBUTOR
#     14          gnestor                  1       CONTRIBUTOR
#     16  maartenbreddels                  1            MEMBER
#     1       LukaPitamic                  1              NONE
#     13           garra2                  1              NONE
#     12       fsteinmetz                  1              NONE
#     11     flying-sheep                  1       CONTRIBUTOR
#     10          djhoese                  1              NONE
#     9           dipsm15                  1              NONE
#     8              btel                  1       CONTRIBUTOR
#     6      VasavanThiru                  1       CONTRIBUTOR
#     3         NaNitrate                  1              NONE
#     2          Milania1                  1              NONE
#     28           yiakwy                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:             author  n_first_responses authorAssociation
#     27         betatim                 35            MEMBER
#     38    consideRatio                 32            MEMBER
#     35       choldgraf                 29            MEMBER
#     80           minrk                 28            MEMBER
#     74          manics                  8       CONTRIBUTOR
#     109      yuvipanda                  5            MEMBER
#     107       willingc                  5            MEMBER
#     70      leportella                  5      COLLABORATOR
#     23          ablekh                  4              NONE
#     28          bitnik                  4       CONTRIBUTOR
#     21         Zsailer                  4            MEMBER
#     52        hansen-m                  3              NONE
#     4          Carreau                  3            MEMBER
#     71          lheagy                  3            MEMBER
#     43   divatemangesh                  3              NONE
#     79         mgnfcnt                  3              NONE
#     98       sgibson91                  2            MEMBER
#     50        frouzbeh                  2              NONE
#     49           flixr                  2              NONE
#     42     dhirschfeld                  2      COLLABORATOR
#     93      ryanlovett                  2            MEMBER
#     67          kkmann                  2              NONE
#     66             kif                  2              NONE
#     84        nickurak                  2       CONTRIBUTOR
#     78        metrofun                  1              NONE
#     0           00Kai0                  1              NONE
#     77           mdivk                  1              NONE
#     76      manycoding                  1       CONTRIBUTOR
#     75        manniche                  1              NONE
#     81       mjschmidt                  1              NONE
#     72        lresende                  1      COLLABORATOR
#     69         kyeotic                  1              NONE
#     68          knkski                  1              NONE
#     65        kfox1111                  1              NONE
#     64           ker2x                  1              NONE
#     73         ltetrel                  1              NONE
#     86        pjmartel                  1              NONE
#     82        mpetroff                  1       CONTRIBUTOR
#     97         serlina                  1              NONE
#     110   yuyueugene84                  1              NONE
#     108          yucai                  1              NONE
#     106       wierzba3                  1              NONE
#     105      weisong82                  1              NONE
#     104          vnijs                  1              NONE
#     103      user919lx                  1              NONE
#     102       trallard                  1       CONTRIBUTOR
#     101   taylorreiter                  1              NONE
#     100     sven-mayer                  1              NONE
#     99        story645                  1       CONTRIBUTOR
#     96         sciffer                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:               author  n_first_responses authorAssociation
#     45        jasongrout                 39            MEMBER
#     69    saulshanabrook                 16            MEMBER
#     32         ellisonbg                 11            MEMBER
#     80           vidartf                 10            MEMBER
#     44        jaipreet-s                 10      COLLABORATOR
#     8            Madhu94                  9            MEMBER
#     41        ian-r-rose                  8            MEMBER
#     29          domoritz                  4            MEMBER
#     77         tgeorgeux                  4            MEMBER
#     38           gnestor                  4            MEMBER
#     19         blink1073                  3            MEMBER
#     79         timkpaine                  3            MEMBER
#     13            afshin                  3            MEMBER
#     37       glass-ships                  2              NONE
#     14          agoose77                  2            MEMBER
#     34       flutefreak7                  2              NONE
#     21          bollwyvl                  2            MEMBER
#     57     markellekelly                  1            MEMBER
#     59  mihai-dinculescu                  1              NONE
#     58        mellowjoey                  1              NONE
#     0         ArcticSnow                  1              NONE
#     56      mahercapo123                  1              NONE
#     55           magnucb                  1              NONE
#     54            maegul                  1              NONE
#     53          lresende                  1            MEMBER
#     52          llinfeng                  1              NONE
#     51           labarba                  1              NONE
#     60             minrk                  1            MEMBER
#     65        rajabricks                  1              NONE
#     61         moazmagdy                  1              NONE
#     72       shivendra90                  1              NONE
#     82              yt87                  1              NONE
#     81          whyboris                  1              NONE
#     78            tibdex                  1            MEMBER
#     76         techgopal                  1              NONE
#     75     soha-namnabat                  1              NONE
#     74          snovaisg                  1              NONE
#     73         simonnier                  1              NONE
#     71       shinta4ever                  1              NONE
#     62              ned2                  1              NONE
#     70       scottwsides                  1              NONE
#     68            rowles                  1              NONE
#     67             ronid                  1              NONE
#     66      robertocarta                  1              NONE
#     49        jpculp2010                  1              NONE
#     64      passengeryjy                  1              NONE
#     63        nickeubank                  1              NONE
#     50          kfox1111                  1              NONE
#     42          ivanjz93                  1              NONE
#     48           jlperla                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                 author  n_first_responses authorAssociation
#     5                MSeal                 17            MEMBER
#     16        captainsafia                 15            MEMBER
#     25          kylebarron                 14            MEMBER
#     1           BenRussert                 13            MEMBER
#     41            willingc                 12            MEMBER
#     28              mpacer                  6            MEMBER
#     38         stormpython                  4            MEMBER
#     20              emeeks                  4            MEMBER
#     39             susielu                  3            MEMBER
#     34              rgbkrk                  2            MEMBER
#     2               Jogala                  2              NONE
#     6              Madhu94                  2            MEMBER
#     29             mscipio                  2              NONE
#     31               niwsa                  2              NONE
#     27        mckev-amazon                  1              NONE
#     30           nikitakit                  1       CONTRIBUTOR
#     0           AWTammsaar                  1              NONE
#     32      nl-datascience                  1              NONE
#     33          philippjfr                  1              NONE
#     35            rmorshea                  1            MEMBER
#     36             romeran                  1              NONE
#     37            rpalloni                  1              NONE
#     40      thomasbazeille                  1              NONE
#     26               mbrio                  1              NONE
#     21  gordon-n-stevenson                  1              NONE
#     24      jibraniqbal666                  1              NONE
#     23        jarmokivekas                  1            MEMBER
#     3                 KLzC                  1              NONE
#     4      KnutJaegersberg                  1              NONE
#     7             Nicbecoz                  1              NONE
#     8            RaghuNaik                  1              NONE
#     9           RobertAron                  1              NONE
#     10               SKalt                  1              NONE
#     11             Zsailer                  1            MEMBER
#     12            abradle2                  1              NONE
#     13             alendit                  1              NONE
#     14                asyd                  1              NONE
#     15                bjce                  1              NONE
#     17           choldgraf                  1            MEMBER
#     18        davidanthoff                  1              NONE
#     19          dylanross3                  1            MEMBER
#     22             gunwoo7                  1              NONE
#     42            zachwill                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
