# %%
import seaborn as sns
import pandas as pd
import numpy as np
import altair as alt
from markdown import markdown
from IPython.display import Markdown
from ipywidgets.widgets import HTML, Tab
from ipywidgets import widgets
from datetime import timedelta
from matplotlib import pyplot as plt
import os.path as op

from mod import load_data, alt_theme

# %%
def author_url(author):
    return f"https://github.com/{author}"

# %%
# Parameters
fmt_date = "{:%Y-%m-%d}"

n_days = 90
start_date = fmt_date.format(pd.datetime.today() - timedelta(days=n_days))
end_date = fmt_date.format(pd.datetime.today())

renderer = "jupyterlab"
github_orgs = ["jupyterhub", "jupyter", "jupyterlab", "jupyter-widgets", "ipython", "binder-examples", "nteract"]

# %%
# Parameters
renderer = "kaggle"
start_date = "2019-01-01"
end_date = "2019-02-01"

# %%
comments, issues, prs = load_data('../data/')
bot_names = pd.read_csv('bot_names.csv')['names'].tolist()
comments = comments.query('author not in @bot_names').drop_duplicates()
issues = issues.query('author not in @bot_names').drop_duplicates()
prs = prs.query('author not in @bot_names').drop_duplicates()
# Out:
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:24: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   comments = pd.concat(comments)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:25: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   issues = pd.concat(issues)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:26: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   prs = pd.concat(prs)

# %%
# Only keep the dates we want
comments = comments.query('updatedAt > @start_date and updatedAt < @end_date')
issues = issues.query('updatedAt > @start_date and updatedAt < @end_date')
prs = prs.query('updatedAt > @start_date and updatedAt < @end_date')

# %%
alt.renderers.enable(renderer);
alt.themes.register('my_theme', alt_theme)
alt.themes.enable("my_theme")
# Out:
# ThemeRegistry.enable('my_theme')

# %%
# Information about out time window
time_delta = pd.to_datetime(end_date) - pd.to_datetime(start_date)
n_days = time_delta.days

# Information about the data we loaded
github_orgs = comments['org'].unique()

# %% [markdown]
# # GitHub activity
#
# Jupyter also has lots of activity across GitHub repositories. The following sections contain
# overviews of recent activity across the following GitHub organizations:

# %%
# Define colors we'll use for GitHub membership
author_types = ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', "NONE"]

author_palette = sns.palettes.blend_palette(["lightgrey", "lightgreen", "darkgreen"], 4)
author_colors = ["rgb({}, {}, {}, {})".format(*(ii*256)) for ii in author_palette]
author_color_dict = {key: val for key, val in zip(author_types, author_palette)}

# %%
orgs_md = []
for org in github_orgs:
    orgs_md.append(f'* [github.com/{org}](https://github.com/{org})')
Markdown('\n'.join(orgs_md))
# Out:
# * [github.com/jupyterlab](https://github.com/jupyterlab)
# * [github.com/jupyter-widgets](https://github.com/jupyter-widgets)
# * [github.com/ipython](https://github.com/ipython)
# * [github.com/binder-examples](https://github.com/binder-examples)
# * [github.com/jupyterhub](https://github.com/jupyterhub)
# * [github.com/jupyter](https://github.com/jupyter)
# * [github.com/nteract](https://github.com/nteract)

# %%
Markdown(f"Showing GitHub activity from **{start_date}** to **{end_date}**")
# Out:
# Showing GitHub activity from **2019-01-01** to **2019-02-01**

# %% [markdown]
# ## List of all contributors per organization
#
# First, we'll list each contributor that has contributed to each organization in the last several days.
# Contributions to open source projects are diverse, and involve much more than just contributing code and
# code review. Thanks to everybody in the Jupyter communities for all that they do.

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, org in enumerate(github_orgs):
    authors_comments = comments.query('org == @org')['author']
    authors_prs = prs.query('org == @org')['author']
    unique_participants = np.unique(np.hstack([authors_comments.values, authors_prs.values]).astype(str)).tolist()
    unique_participants.sort(key=lambda a: a.lower())
    
    all_participants = [f"[{participant}](https://github.com/{participant})" for participant in unique_participants]
    participants_md = " | ".join(all_participants)
    md_html = HTML("<center>{}</center>".format(markdown(participants_md)))
    
    children = list(tabs.children)
    children.append(md_html)
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"All participants across issues and pull requests in each org in the last {n_days} days"))
display(tabs)
# Out:
# All participants across issues and pull requests in each org in the last 31 days
# Tab(children=(HTML(value='<center><p><a href="https://github.com/adobs">adobs</a> | <a href="https://github.co…

# %% [markdown]
# ## Merged Pull requests
#
# Here's an analysis of **merged pull requests** across each of the repositories in the Jupyter
# ecosystem.

# %%
merged = prs.query('state == "MERGED" and closedAt > @start_date and closedAt < @end_date')

# %%
prs_by_repo = merged.groupby(['org', 'repo']).count()['author'].reset_index().sort_values(['org', 'author'], ascending=False)
alt.Chart(data=prs_by_repo, title=f"Merged PRs in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=prs_by_repo['repo'].values.tolist()),
    y='author',
    color='org'
)
# Out:
# Chart({
#   data:                 org                         repo  author
#   47          nteract                    papermill      13
#   44          nteract                     hydrogen       4
#   42          nteract                         docs       3
#   41          nteract                     commuter       2
#   43          nteract                     examples       2
#   45          nteract                          nes       1
#   46          nteract                   nteract.io       1
#   34       jupyterlab                   jupyterlab      32
#   35       jupyterlab        jupyterlab-commenting       5
#   33       jupyterlab            jupyter-renderers       2
#   40       jupyterlab               jupyterlab-toc       2
#   36       jupyterlab      jupyterlab-google-drive       1
#   37       jupyterlab             jupyterlab-latex       1
#   38       jupyterlab  jupyterlab-metadata-service       1
#   39       jupyterlab        jupyterlab-shortcutui       1
#   23       jupyterhub         jupyter-server-proxy      17
#   32       jupyterhub       zero-to-jupyterhub-k8s      17
#   27       jupyterhub          nativeauthenticator      16
#   18       jupyterhub                    binderhub      11
#   26       jupyterhub          mybinder.org-deploy      10
#   29       jupyterhub      the-littlest-jupyterhub       8
#   22       jupyterhub       jupyter-rsession-proxy       7
#   30       jupyterhub                traefik-proxy       6
#   24       jupyterhub                   jupyterhub       5
#   28       jupyterhub                 team-compass       4
#   31       jupyterhub                  yarnspawner       4
#   16       jupyterhub         alabaster-jupyterhub       2
#   17       jupyterhub                       binder       1
#   19       jupyterhub      configurable-http-proxy       1
#   20       jupyterhub        firstuseauthenticator       1
#   21       jupyterhub                   helm-chart       1
#   25       jupyterhub                  kubespawner       1
#   15  jupyter-widgets                   ipyleaflet       8
#   3           jupyter           enterprise_gateway      17
#   5           jupyter                 jupyter-book      13
#   13          jupyter                  repo2docker      10
#   12          jupyter                     notebook       7
#   2           jupyter                docker-stacks       6
#   11          jupyter                     nbviewer       5
#   7           jupyter                     jvm-repr       4
#   6           jupyter            jupyter.github.io       3
#   8           jupyter                    nbconvert       3
#   4           jupyter                      jupyter       2
#   10          jupyter                     nbgrader       2
#   1           jupyter   cookiecutter-docker-stacks       1
#   9           jupyter           nbconvert-examples       1
#   14          jupyter                      surveys       1
#   0           ipython                      ipython       9,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: ['papermill', 'hydrogen', 'docs', 'commuter', 'examples', 'nes', 'nteract.io', 'jupyterlab', 'jupyterlab-commenting', 'jupyter-renderers', 'jupyterlab-toc', 'jupyterlab-google-drive', 'jupyterlab-latex', 'jupyterlab-metadata-service', 'jupyterlab-shortcutui', 'jupyter-server-proxy', 'zero-to-jupyterhub-k8s', 'nativeauthenticator', 'binderhub', 'mybinder.org-deploy', 'the-littlest-jupyterhub', 'jupyter-rsession-proxy', 'traefik-proxy', 'jupyterhub', 'team-compass', 'yarnspawner', 'alabaster-jupyterhub', 'binder', 'configurable-http-proxy', 'firstuseauthenticator', 'helm-chart', 'kubespawner', 'ipyleaflet', 'enterprise_gateway', 'jupyter-book', 'repo2docker', 'notebook', 'docker-stacks', 'nbviewer', 'jvm-repr', 'jupyter.github.io', 'nbconvert', 'jupyter', 'nbgrader', 'cookiecutter-docker-stacks', 'nbconvert-examples', 'surveys', 'ipython'],
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'author',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Merged PRs in the last 31 days'
# })

# %% [markdown]
# ### A list of merged PRs by project
#
# Below is a tabbed readout of recently-merged PRs. Check out the title to get an idea for what they
# implemented, and be sure to thank the PR author for their hard work!

# %%
tabs = widgets.Tab(children=[])
merged_by = {}
pr_by = {}
for ii, (org, idata) in enumerate(merged.groupby('org')):
    issue_md = []
    issue_md.append(f"#### Closed PRs for org: `{org}`")
    issue_md.append("")
    for (org, repo), prs in idata.groupby(['org', 'repo']):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")
        for _, pr in prs.iterrows():
            user_name = pr['author']
            user_url = author_url(user_name)
            pr_number = pr['number']
            pr_html = pr['url']
            pr_title = pr['title']
            pr_closedby = pr['mergedBy']
            pr_closedby_url = f"https://github.com/{pr_closedby}"
            if user_name not in pr_by:
                pr_by[user_name] = 1
            else:
                pr_by[user_name] += 1
                
            if pr_closedby not in merged_by:
                merged_by[pr_closedby] = 1
            else:
                merged_by[pr_closedby] += 1
            text = f"* [(#{pr_number})]({pr_html}): _{pr_title}_ by **[@{user_name}]({user_url})** merged by **[@{pr_closedby}]({pr_closedby_url})**"
            issue_md.append(text)
    issue_md.append('')
    markdown_html = markdown('\n'.join(issue_md))
    
    children = list(tabs.children)
    children.append(HTML(markdown_html))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
tabs
# Out:
# Tab(children=(HTML(value='<h4>Closed PRs for org: <code>ipython</code></h4>\n<h5><a href="https://github.com/i…

# %% [markdown]
# ### Authoring and merging stats by repository
#
# Let's see who has been doing most of the PR authoring and merging. The PR author is generally the
# person that implemented a change in the repository (code, documentation, etc). The PR merger is
# the person that "pressed the green button" and got the change into the main codebase.

# %%
# Prep our merging DF
merged_by_repo = merged.groupby(['org', 'repo', 'author'], as_index=False).agg({'id': 'count', 'authorAssociation': 'first'}).rename(columns={'id': "authored", 'author': 'username'})
closed_by_repo = merged.groupby(['org', 'repo', 'mergedBy']).count()['id'].reset_index().rename(columns={'id': "closed", "mergedBy": "username"})

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(merged_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"PR authors for {iorg} in the last {n_days} days"
    idata = idata.groupby('username', as_index=False).agg({'authored': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('authored', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='authored',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)

alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:     username  authored authorAssociation
#     0    BoboTiG         2       CONTRIBUTOR
#     1     SSteve         1       CONTRIBUTOR
#     2   gpotter2         1       CONTRIBUTOR
#     3      ibell         1       CONTRIBUTOR
#     4    sanyam5         1       CONTRIBUTOR
#     5  techtonik         1       CONTRIBUTOR
#     6     tomyun         1       CONTRIBUTOR
#     7   tonyfast         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                username  authored authorAssociation
#     9             choldgraf        11            MEMBER
#     26             lresende         6            MEMBER
#     24          kevin-bates         6            MEMBER
#     34            takluyver         4            MEMBER
#     32              parente         4            MEMBER
#     6       alexarchambault         4            MEMBER
#     39            yuvipanda         3            MEMBER
#     37              winni2k         2       CONTRIBUTOR
#     28                minrk         2            MEMBER
#     20             jhamrick         2            MEMBER
#     5             akchinSTC         2      COLLABORATOR
#     10           clayadavis         1       CONTRIBUTOR
#     11         craig-willis         1       CONTRIBUTOR
#     38            xhumanoid         1       CONTRIBUTOR
#     2              JarnoRFB         1       CONTRIBUTOR
#     36             willingc         1            MEMBER
#     35           wgcostello         1       CONTRIBUTOR
#     3           RomanKornev         1       CONTRIBUTOR
#     33              rkdarst         1       CONTRIBUTOR
#     4                afshin         1            MEMBER
#     31            nyanshell         1       CONTRIBUTOR
#     30              mwcraig         1       CONTRIBUTOR
#     29              mlucool         1       CONTRIBUTOR
#     27               mgeier         1       CONTRIBUTOR
#     7             benjaminr         1       CONTRIBUTOR
#     25               lheagy         1      COLLABORATOR
#     8               bskarda         1       CONTRIBUTOR
#     23      katrinleinweber         1       CONTRIBUTOR
#     22                jtpio         1       CONTRIBUTOR
#     21           joergbrech         1       CONTRIBUTOR
#     1              JMerrill         1       CONTRIBUTOR
#     19                 heoa         1       CONTRIBUTOR
#     18                 gaow         1       CONTRIBUTOR
#     17             fresende         1       CONTRIBUTOR
#     16                flixr         1       CONTRIBUTOR
#     15              fisache         1       CONTRIBUTOR
#     14  durwasa-chakraborty         1       CONTRIBUTOR
#     13          damianavila         1            MEMBER
#     12                csoja         1       CONTRIBUTOR
#     0        GladysNalvarte         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:        username  authored authorAssociation
#     1   martinRenou         7            MEMBER
#     0  VasavanThiru         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            username  authored authorAssociation
#     26        yuvipanda        26            MEMBER
#     16       leportella        16      COLLABORATOR
#     9         choldgraf        11            MEMBER
#     20            minrk        10            MEMBER
#     6            bitnik         7       CONTRIBUTOR
#     19           manics         5      COLLABORATOR
#     11     consideRatio         5            MEMBER
#     15           jcrist         4            MEMBER
#     7      captainsafia         4            MEMBER
#     0    GeorgianaElena         3            MEMBER
#     5           betatim         3            MEMBER
#     24        willirath         2      COLLABORATOR
#     8            cbjuan         2       CONTRIBUTOR
#     10     clancychilds         1              NONE
#     2          adelcast         1       CONTRIBUTOR
#     25           xmnlab         1       CONTRIBUTOR
#     23         willingc         1            MEMBER
#     22       ryanlovett         1            MEMBER
#     21         rcthomas         1       CONTRIBUTOR
#     18           lheagy         1            MEMBER
#     3   alanjcastonguay         1       CONTRIBUTOR
#     17          lesteve         1       CONTRIBUTOR
#     4            arokem         1       CONTRIBUTOR
#     14         huhuhang         1       CONTRIBUTOR
#     1           Zsailer         1            MEMBER
#     12        dnelson86         1       CONTRIBUTOR
#     13        dtaniwaki         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:           username  authored authorAssociation
#     10      ian-r-rose        11            MEMBER
#     4           afshin         6            MEMBER
#     7          gnestor         4            MEMBER
#     11      jasongrout         3            MEMBER
#     8           hoo761         3      COLLABORATOR
#     0       AlbertHilb         3            MEMBER
#     6        ellisonbg         1            MEMBER
#     5         bollwyvl         1            MEMBER
#     3            adobs         1            MEMBER
#     9          horstle         1       CONTRIBUTOR
#     1          Madhu94         1            MEMBER
#     2          Zsailer         1            MEMBER
#     12           jtpio         1            MEMBER
#     13          lheagy         1       CONTRIBUTOR
#     14   markellekelly         1            MEMBER
#     15           minrk         1            MEMBER
#     16         mlucool         1       CONTRIBUTOR
#     17           ntdef         1       CONTRIBUTOR
#     18         parente         1            MEMBER
#     19  saulshanabrook         1            MEMBER
#     20          xmnlab         1      COLLABORATOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:           username  authored authorAssociation
#     7           rgbkrk         5            MEMBER
#     10        willingc         5            MEMBER
#     0            MSeal         4            MEMBER
#     5       kylebarron         3            MEMBER
#     2            bnaul         2            MEMBER
#     3     captainsafia         2            MEMBER
#     1   VincentBLortie         1            MEMBER
#     4              ctb         1       CONTRIBUTOR
#     6          mlucool         1            MEMBER
#     8          thewtex         1            MEMBER
#     9        wesinator         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %%
charts = []
for ii, (iorg, idata) in enumerate(closed_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"Merges for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='closed',
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:        org     repo username  closed
#     0  ipython  ipython  Carreau       9,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:         org                        repo     username  closed
#     1   jupyter  cookiecutter-docker-stacks      parente       1
#     2   jupyter               docker-stacks      parente       6
#     3   jupyter          enterprise_gateway  kevin-bates       5
#     4   jupyter          enterprise_gateway     lresende      12
#     5   jupyter                     jupyter      jzf2101       2
#     6   jupyter                jupyter-book    choldgraf      13
#     7   jupyter           jupyter.github.io       afshin       1
#     8   jupyter           jupyter.github.io      parente       1
#     9   jupyter           jupyter.github.io     willingc       1
#     10  jupyter                    jvm-repr       rdblue       4
#     11  jupyter                   nbconvert    takluyver       3
#     12  jupyter          nbconvert-examples      parente       1
#     13  jupyter                    nbgrader     jhamrick       2
#     14  jupyter                    nbviewer      parente       5
#     15  jupyter                    notebook    takluyver       7
#     16  jupyter                 repo2docker      betatim       3
#     17  jupyter                 repo2docker    choldgraf       1
#     18  jupyter                 repo2docker        minrk       2
#     19  jupyter                 repo2docker    yuvipanda       4
#     20  jupyter                     surveys      parente       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                 org        repo     username  closed
#     21  jupyter-widgets  ipyleaflet  martinRenou       8,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            org                     repo      username  closed
#     22  jupyterhub     alabaster-jupyterhub       betatim       1
#     23  jupyterhub     alabaster-jupyterhub     choldgraf       1
#     24  jupyterhub                   binder     choldgraf       1
#     25  jupyterhub                binderhub       betatim       2
#     26  jupyterhub                binderhub  captainsafia       1
#     27  jupyterhub                binderhub         minrk       5
#     28  jupyterhub                binderhub      willingc       2
#     29  jupyterhub                binderhub     yuvipanda       1
#     30  jupyterhub  configurable-http-proxy         minrk       1
#     31  jupyterhub    firstuseauthenticator     yuvipanda       1
#     32  jupyterhub               helm-chart     yuvipanda       1
#     33  jupyterhub   jupyter-rsession-proxy    ryanlovett       7
#     34  jupyterhub     jupyter-server-proxy    ryanlovett      13
#     35  jupyterhub     jupyter-server-proxy     yuvipanda       4
#     36  jupyterhub               jupyterhub         minrk       5
#     37  jupyterhub              kubespawner  consideRatio       1
#     38  jupyterhub      mybinder.org-deploy       betatim       2
#     39  jupyterhub      mybinder.org-deploy  captainsafia       1
#     40  jupyterhub      mybinder.org-deploy     choldgraf       2
#     41  jupyterhub      mybinder.org-deploy  consideRatio       1
#     42  jupyterhub      mybinder.org-deploy         minrk       3
#     43  jupyterhub      mybinder.org-deploy     yuvipanda       1
#     44  jupyterhub      nativeauthenticator    leportella      13
#     45  jupyterhub      nativeauthenticator     yuvipanda       3
#     46  jupyterhub             team-compass       betatim       1
#     47  jupyterhub             team-compass     choldgraf       3
#     48  jupyterhub  the-littlest-jupyterhub     yuvipanda       8
#     49  jupyterhub            traefik-proxy         minrk       6
#     50  jupyterhub              yarnspawner        jcrist       4
#     51  jupyterhub   zero-to-jupyterhub-k8s       betatim       1
#     52  jupyterhub   zero-to-jupyterhub-k8s     choldgraf       1
#     53  jupyterhub   zero-to-jupyterhub-k8s  consideRatio       8
#     54  jupyterhub   zero-to-jupyterhub-k8s         minrk       4
#     55  jupyterhub   zero-to-jupyterhub-k8s     yuvipanda       3,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            org                         repo        username  closed
#     56  jupyterlab            jupyter-renderers         gnestor       2
#     57  jupyterlab                   jupyterlab      AlbertHilb       1
#     58  jupyterlab                   jupyterlab          afshin       4
#     59  jupyterlab                   jupyterlab      ian-r-rose      15
#     60  jupyterlab                   jupyterlab      jasongrout       4
#     61  jupyterlab                   jupyterlab  saulshanabrook       8
#     62  jupyterlab        jupyterlab-commenting  saulshanabrook       5
#     63  jupyterlab      jupyterlab-google-drive      ian-r-rose       1
#     64  jupyterlab             jupyterlab-latex      ian-r-rose       1
#     65  jupyterlab  jupyterlab-metadata-service  saulshanabrook       1
#     66  jupyterlab        jupyterlab-shortcutui          afshin       1
#     67  jupyterlab               jupyterlab-toc      ian-r-rose       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:         org        repo      username  closed
#     68  nteract    commuter        rgbkrk       2
#     69  nteract        docs  captainsafia       1
#     70  nteract        docs        rgbkrk       2
#     71  nteract    examples        rgbkrk       2
#     72  nteract    hydrogen    BenRussert       2
#     73  nteract    hydrogen    kylebarron       2
#     74  nteract         nes      willingc       1
#     75  nteract  nteract.io        rgbkrk       1
#     76  nteract   papermill         MSeal      10
#     77  nteract   papermill       betatim       3,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## Issues
#
# Issues are **conversations** that happen on our GitHub repositories. Here's an
# analysis of issues across the Jupyter organizations.

# %%
created = issues.query('state == "OPEN" and createdAt > @start_date and createdAt < @end_date')
closed = issues.query('state == "CLOSED" and closedAt > @start_date and closedAt < @end_date')

# %%
created_counts = created.groupby(['org', 'repo']).count()['number'].reset_index()
created_counts['org/repo'] = created_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = created_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=created_counts, title=f"Issues created in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                         repo  number  \
#   0           ipython                    ipykernel       4
#   1           ipython                        ipynb       2
#   2           ipython                  ipyparallel       1
#   3           ipython                      ipython      10
#   4           jupyter           enterprise_gateway       1
#   5           jupyter                         help      23
#   6           jupyter                      jupyter       1
#   7           jupyter                     notebook      24
#   8           jupyter                    qtconsole       1
#   9   jupyter-widgets                   ipyleaflet       6
#   10  jupyter-widgets                   ipywidgets      10
#   11  jupyter-widgets           jupyterlab-sidecar       1
#   12  jupyter-widgets                 midicontrols       1
#   13  jupyter-widgets                    pythreejs       4
#   14  jupyter-widgets       widget-ts-cookiecutter       1
#   15       jupyterhub                       binder       1
#   16       jupyterhub                    binderhub       4
#   17       jupyterhub                dockerspawner       1
#   18       jupyterhub                   helm-chart       1
#   19       jupyterhub         jupyter-server-proxy       1
#   20       jupyterhub                   jupyterhub      11
#   21       jupyterhub            ldapauthenticator       1
#   22       jupyterhub          mybinder.org-deploy       3
#   23       jupyterhub          nativeauthenticator       1
#   24       jupyterhub               oauthenticator       1
#   25       jupyterhub                 team-compass       1
#   26       jupyterhub       zero-to-jupyterhub-k8s       4
#   27       jupyterlab            jupyter-renderers       2
#   28       jupyterlab                   jupyterlab      17
#   29       jupyterlab        jupyterlab-commenting       3
#   30       jupyterlab             jupyterlab-latex       1
#   31       jupyterlab  jupyterlab-metadata-service       1
#   32       jupyterlab               jupyterlab-toc       2
#   33          nteract                      nteract      15
#   34          nteract                   nteract.io       1
#   35          nteract                         play       1
#   36          nteract                     semiotic       3
#
#                                     org/repo
#   0                        ipython/ipykernel
#   1                            ipython/ipynb
#   2                      ipython/ipyparallel
#   3                          ipython/ipython
#   4               jupyter/enterprise_gateway
#   5                             jupyter/help
#   6                          jupyter/jupyter
#   7                         jupyter/notebook
#   8                        jupyter/qtconsole
#   9               jupyter-widgets/ipyleaflet
#   10              jupyter-widgets/ipywidgets
#   11      jupyter-widgets/jupyterlab-sidecar
#   12            jupyter-widgets/midicontrols
#   13               jupyter-widgets/pythreejs
#   14  jupyter-widgets/widget-ts-cookiecutter
#   15                       jupyterhub/binder
#   16                    jupyterhub/binderhub
#   17                jupyterhub/dockerspawner
#   18                   jupyterhub/helm-chart
#   19         jupyterhub/jupyter-server-proxy
#   20                   jupyterhub/jupyterhub
#   21            jupyterhub/ldapauthenticator
#   22          jupyterhub/mybinder.org-deploy
#   23          jupyterhub/nativeauthenticator
#   24               jupyterhub/oauthenticator
#   25                 jupyterhub/team-compass
#   26       jupyterhub/zero-to-jupyterhub-k8s
#   27            jupyterlab/jupyter-renderers
#   28                   jupyterlab/jupyterlab
#   29        jupyterlab/jupyterlab-commenting
#   30             jupyterlab/jupyterlab-latex
#   31  jupyterlab/jupyterlab-metadata-service
#   32               jupyterlab/jupyterlab-toc
#   33                         nteract/nteract
#   34                      nteract/nteract.io
#   35                            nteract/play
#   36                        nteract/semiotic  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['nteract', 'semiotic', 'nteract.io', 'play', 'jupyterlab', 'jupyterlab-commenting', 'jupyter-renderers', 'jupyterlab-toc', 'jupyterlab-latex', 'jupyterlab-metadata-service', 'jupyterhub', 'binderhub', 'zero-to-jupyterhub-k8s', 'mybinder.org-deploy', 'binder', 'dockerspawner', 'helm-chart', 'jupyter-server-proxy', 'ldapauthenticator', 'nativeauthenticator', 'oauthenticator', 'team-compass', 'ipywidgets', 'ipyleaflet', 'pythreejs', 'jupyterlab-sidecar', 'midicontrols', 'widget-ts-cookiecutter', 'notebook', 'help', 'enterprise_gateway', 'jupyter', 'qtconsole', 'ipython', 'ipykernel', 'ipynb', 'ipyparallel']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues created in the last 31 days'
# })

# %%
closed_counts = closed.groupby(['org', 'repo']).count()['number'].reset_index()
closed_counts['org/repo'] = closed_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = closed_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=closed_counts, title=f"Issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                        repo  number  \
#   0           ipython                     ipython       7
#   1           ipython                   traitlets       2
#   2           jupyter  cookiecutter-docker-stacks       2
#   3           jupyter               docker-stacks       4
#   4           jupyter          enterprise_gateway      10
#   5           jupyter                        help       4
#   6           jupyter                     jupyter       1
#   7           jupyter                jupyter-book       9
#   8           jupyter               jupyter-drive       1
#   9           jupyter              kernel_gateway       1
#   10          jupyter                   nbconvert       3
#   11          jupyter                      nbdime       2
#   12          jupyter                    nbgrader       1
#   13          jupyter                    notebook      24
#   14          jupyter                   qtconsole       1
#   15          jupyter                 repo2docker      10
#   16  jupyter-widgets                  ipyleaflet       8
#   17  jupyter-widgets                  ipywidgets       2
#   18       jupyterhub                      binder       1
#   19       jupyterhub                   binderhub       6
#   20       jupyterhub     configurable-http-proxy       1
#   21       jupyterhub       firstuseauthenticator       2
#   22       jupyterhub      jupyter-rsession-proxy       2
#   23       jupyterhub        jupyter-server-proxy       6
#   24       jupyterhub                  jupyterhub       3
#   25       jupyterhub  jupyterhub-deploy-teaching       1
#   26       jupyterhub              jupyterlab-hub       1
#   27       jupyterhub         nativeauthenticator      13
#   28       jupyterhub                team-compass       4
#   29       jupyterhub     the-littlest-jupyterhub       2
#   30       jupyterhub               traefik-proxy       4
#   31       jupyterhub      zero-to-jupyterhub-k8s      17
#   32       jupyterlab           jupyter-renderers       1
#   33       jupyterlab                  jupyterlab      41
#   34       jupyterlab     jupyterlab-google-drive       3
#   35       jupyterlab              jupyterlab-toc       4
#   36          nteract                   bookstore       4
#   37          nteract                    commuter       1
#   38          nteract                    hydrogen       3
#   39          nteract                  nteract.io       1
#   40          nteract                   papermill      13
#   41          nteract                    semiotic       6
#
#                                    org/repo
#   0                         ipython/ipython
#   1                       ipython/traitlets
#   2      jupyter/cookiecutter-docker-stacks
#   3                   jupyter/docker-stacks
#   4              jupyter/enterprise_gateway
#   5                            jupyter/help
#   6                         jupyter/jupyter
#   7                    jupyter/jupyter-book
#   8                   jupyter/jupyter-drive
#   9                  jupyter/kernel_gateway
#   10                      jupyter/nbconvert
#   11                         jupyter/nbdime
#   12                       jupyter/nbgrader
#   13                       jupyter/notebook
#   14                      jupyter/qtconsole
#   15                    jupyter/repo2docker
#   16             jupyter-widgets/ipyleaflet
#   17             jupyter-widgets/ipywidgets
#   18                      jupyterhub/binder
#   19                   jupyterhub/binderhub
#   20     jupyterhub/configurable-http-proxy
#   21       jupyterhub/firstuseauthenticator
#   22      jupyterhub/jupyter-rsession-proxy
#   23        jupyterhub/jupyter-server-proxy
#   24                  jupyterhub/jupyterhub
#   25  jupyterhub/jupyterhub-deploy-teaching
#   26              jupyterhub/jupyterlab-hub
#   27         jupyterhub/nativeauthenticator
#   28                jupyterhub/team-compass
#   29     jupyterhub/the-littlest-jupyterhub
#   30               jupyterhub/traefik-proxy
#   31      jupyterhub/zero-to-jupyterhub-k8s
#   32           jupyterlab/jupyter-renderers
#   33                  jupyterlab/jupyterlab
#   34     jupyterlab/jupyterlab-google-drive
#   35              jupyterlab/jupyterlab-toc
#   36                      nteract/bookstore
#   37                       nteract/commuter
#   38                       nteract/hydrogen
#   39                     nteract/nteract.io
#   40                      nteract/papermill
#   41                       nteract/semiotic  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['papermill', 'semiotic', 'bookstore', 'hydrogen', 'commuter', 'nteract.io', 'jupyterlab', 'jupyterlab-toc', 'jupyterlab-google-drive', 'jupyter-renderers', 'zero-to-jupyterhub-k8s', 'nativeauthenticator', 'binderhub', 'jupyter-server-proxy', 'team-compass', 'traefik-proxy', 'jupyterhub', 'firstuseauthenticator', 'jupyter-rsession-proxy', 'the-littlest-jupyterhub', 'binder', 'configurable-http-proxy', 'jupyterhub-deploy-teaching', 'jupyterlab-hub', 'ipyleaflet', 'ipywidgets', 'notebook', 'enterprise_gateway', 'repo2docker', 'jupyter-book', 'docker-stacks', 'help', 'nbconvert', 'cookiecutter-docker-stacks', 'nbdime', 'jupyter', 'jupyter-drive', 'kernel_gateway', 'nbgrader', 'qtconsole', 'ipython', 'traitlets']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues closed in the last 31 days'
# })

# %%
created_closed = pd.merge(created_counts.rename(columns={'number': 'created'}).drop(columns='org/repo'),
                          closed_counts.rename(columns={'number': 'closed'}).drop(columns='org/repo'),
                          on=['org', 'repo'], how='outer')

created_closed = pd.melt(created_closed, id_vars=['org', 'repo'], var_name="kind", value_name="count").replace(np.nan, 0)

# %%
charts = []
for org in github_orgs:
    # Pick the top 10 repositories
    this_issues = created_closed.query('org == @org')
    top_repos = this_issues.groupby(['repo']).sum().sort_values(by='count', ascending=False).head(10).index
    ch = alt.Chart(this_issues.query('repo in @top_repos'), width=120).mark_bar().encode(
        x=alt.X("kind", axis=alt.Axis(labelFontSize=15, title="")), 
        y=alt.Y('count', axis=alt.Axis(titleFontSize=15, labelFontSize=12)),
        color='kind',
        column=alt.Column("repo", header=alt.Header(title=f"Issue activity, last {n_days} days for {org}", titleFontSize=15, labelFontSize=12))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/altair/utils/core.py:90: UserWarning: I don't know how to infer vegalite type from 'empty'.  Defaulting to nominal.
#   "Defaulting to nominal.".format(typ))
# HConcatChart({
#   hconcat: [Chart({
#     data:             org                         repo     kind  count
#     27   jupyterlab            jupyter-renderers  created    2.0
#     28   jupyterlab                   jupyterlab  created   17.0
#     29   jupyterlab        jupyterlab-commenting  created    3.0
#     30   jupyterlab             jupyterlab-latex  created    1.0
#     31   jupyterlab  jupyterlab-metadata-service  created    1.0
#     32   jupyterlab               jupyterlab-toc  created    2.0
#     54   jupyterlab      jupyterlab-google-drive  created    0.0
#     86   jupyterlab            jupyter-renderers   closed    1.0
#     87   jupyterlab                   jupyterlab   closed   41.0
#     88   jupyterlab        jupyterlab-commenting   closed    0.0
#     89   jupyterlab             jupyterlab-latex   closed    0.0
#     90   jupyterlab  jupyterlab-metadata-service   closed    0.0
#     91   jupyterlab               jupyterlab-toc   closed    4.0
#     113  jupyterlab      jupyterlab-google-drive   closed    3.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyterlab',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                 org                    repo     kind  count
#     9   jupyter-widgets              ipyleaflet  created    6.0
#     10  jupyter-widgets              ipywidgets  created   10.0
#     11  jupyter-widgets      jupyterlab-sidecar  created    1.0
#     12  jupyter-widgets            midicontrols  created    1.0
#     13  jupyter-widgets               pythreejs  created    4.0
#     14  jupyter-widgets  widget-ts-cookiecutter  created    1.0
#     68  jupyter-widgets              ipyleaflet   closed    8.0
#     69  jupyter-widgets              ipywidgets   closed    2.0
#     70  jupyter-widgets      jupyterlab-sidecar   closed    0.0
#     71  jupyter-widgets            midicontrols   closed    0.0
#     72  jupyter-widgets               pythreejs   closed    0.0
#     73  jupyter-widgets  widget-ts-cookiecutter   closed    0.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyter-widgets',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:         org         repo     kind  count
#     0   ipython    ipykernel  created    4.0
#     1   ipython        ipynb  created    2.0
#     2   ipython  ipyparallel  created    1.0
#     3   ipython      ipython  created   10.0
#     37  ipython    traitlets  created    0.0
#     59  ipython    ipykernel   closed    0.0
#     60  ipython        ipynb   closed    0.0
#     61  ipython  ipyparallel   closed    0.0
#     62  ipython      ipython   closed    7.0
#     96  ipython    traitlets   closed    2.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for ipython',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data: Empty DataFrame
#     Columns: [org, repo, kind, count]
#     Index: [],
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for binder-examples',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:             org                     repo     kind  count
#     15   jupyterhub                   binder  created    1.0
#     16   jupyterhub                binderhub  created    4.0
#     19   jupyterhub     jupyter-server-proxy  created    1.0
#     20   jupyterhub               jupyterhub  created   11.0
#     22   jupyterhub      mybinder.org-deploy  created    3.0
#     23   jupyterhub      nativeauthenticator  created    1.0
#     25   jupyterhub             team-compass  created    1.0
#     26   jupyterhub   zero-to-jupyterhub-k8s  created    4.0
#     52   jupyterhub  the-littlest-jupyterhub  created    0.0
#     53   jupyterhub            traefik-proxy  created    0.0
#     74   jupyterhub                   binder   closed    1.0
#     75   jupyterhub                binderhub   closed    6.0
#     78   jupyterhub     jupyter-server-proxy   closed    6.0
#     79   jupyterhub               jupyterhub   closed    3.0
#     81   jupyterhub      mybinder.org-deploy   closed    0.0
#     82   jupyterhub      nativeauthenticator   closed   13.0
#     84   jupyterhub             team-compass   closed    4.0
#     85   jupyterhub   zero-to-jupyterhub-k8s   closed   17.0
#     111  jupyterhub  the-littlest-jupyterhub   closed    2.0
#     112  jupyterhub            traefik-proxy   closed    4.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyterhub',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org                        repo     kind  count
#     4    jupyter          enterprise_gateway  created    1.0
#     5    jupyter                        help  created   23.0
#     6    jupyter                     jupyter  created    1.0
#     7    jupyter                    notebook  created   24.0
#     38   jupyter  cookiecutter-docker-stacks  created    0.0
#     39   jupyter               docker-stacks  created    0.0
#     40   jupyter                jupyter-book  created    0.0
#     43   jupyter                   nbconvert  created    0.0
#     44   jupyter                      nbdime  created    0.0
#     46   jupyter                 repo2docker  created    0.0
#     63   jupyter          enterprise_gateway   closed   10.0
#     64   jupyter                        help   closed    4.0
#     65   jupyter                     jupyter   closed    1.0
#     66   jupyter                    notebook   closed   24.0
#     97   jupyter  cookiecutter-docker-stacks   closed    2.0
#     98   jupyter               docker-stacks   closed    4.0
#     99   jupyter                jupyter-book   closed    9.0
#     102  jupyter                   nbconvert   closed    3.0
#     103  jupyter                      nbdime   closed    2.0
#     105  jupyter                 repo2docker   closed   10.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyter',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org        repo     kind  count
#     33   nteract     nteract  created   15.0
#     34   nteract  nteract.io  created    1.0
#     35   nteract        play  created    1.0
#     36   nteract    semiotic  created    3.0
#     55   nteract   bookstore  created    0.0
#     56   nteract    commuter  created    0.0
#     57   nteract    hydrogen  created    0.0
#     58   nteract   papermill  created    0.0
#     92   nteract     nteract   closed    0.0
#     93   nteract  nteract.io   closed    1.0
#     94   nteract        play   closed    0.0
#     95   nteract    semiotic   closed    6.0
#     114  nteract   bookstore   closed    4.0
#     115  nteract    commuter   closed    1.0
#     116  nteract    hydrogen   closed    3.0
#     117  nteract   papermill   closed   13.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for nteract',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   })]
# })

# %%
# Set to datetime
for kind in ['createdAt', 'closedAt']:
    closed.loc[:, kind] = pd.to_datetime(closed[kind])
    
closed.loc[:, 'time_open'] = closed['closedAt'] - closed['createdAt']
closed.loc[:, 'time_open'] = closed['time_open'].dt.total_seconds()
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:480: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
time_open = closed.groupby(['org', 'repo']).agg({'time_open': 'median'}).reset_index()
time_open['time_open'] = time_open['time_open'] / (60 * 60 * 24)
time_open['org/repo'] = time_open.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = time_open.sort_values(['org', 'time_open'], ascending=False)['repo'].values
alt.Chart(data=time_open, title=f"Time to close for issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y=alt.Y('time_open', title="Median Days Open"),
    color='org',
)
# Out:
# Chart({
#   data:                 org                        repo    time_open  \
#   0           ipython                     ipython    18.652037
#   1           ipython                   traitlets   568.811424
#   2           jupyter  cookiecutter-docker-stacks    36.618924
#   3           jupyter               docker-stacks    16.190828
#   4           jupyter          enterprise_gateway    31.396458
#   5           jupyter                        help     0.160307
#   6           jupyter                     jupyter     1.284792
#   7           jupyter                jupyter-book    17.853819
#   8           jupyter               jupyter-drive  1181.490556
#   9           jupyter              kernel_gateway     1.053657
#   10          jupyter                   nbconvert    24.043310
#   11          jupyter                      nbdime     2.668154
#   12          jupyter                    nbgrader    73.154028
#   13          jupyter                    notebook    12.960943
#   14          jupyter                   qtconsole     0.234039
#   15          jupyter                 repo2docker     1.427124
#   16  jupyter-widgets                  ipyleaflet     6.196238
#   17  jupyter-widgets                  ipywidgets    13.684062
#   18       jupyterhub                      binder     0.218102
#   19       jupyterhub                   binderhub    31.665810
#   20       jupyterhub     configurable-http-proxy   509.415787
#   21       jupyterhub       firstuseauthenticator     3.203177
#   22       jupyterhub      jupyter-rsession-proxy     6.126684
#   23       jupyterhub        jupyter-server-proxy     6.139520
#   24       jupyterhub                  jupyterhub     0.559734
#   25       jupyterhub  jupyterhub-deploy-teaching   589.675150
#   26       jupyterhub              jupyterlab-hub   312.035937
#   27       jupyterhub         nativeauthenticator     9.950301
#   28       jupyterhub                team-compass    15.555093
#   29       jupyterhub     the-littlest-jupyterhub    32.174884
#   30       jupyterhub               traefik-proxy    28.486742
#   31       jupyterhub      zero-to-jupyterhub-k8s     3.351644
#   32       jupyterlab           jupyter-renderers     0.964826
#   33       jupyterlab                  jupyterlab    60.363657
#   34       jupyterlab     jupyterlab-google-drive    13.978056
#   35       jupyterlab              jupyterlab-toc    78.610365
#   36          nteract                   bookstore    25.910156
#   37          nteract                    commuter   405.695463
#   38          nteract                    hydrogen    91.341262
#   39          nteract                  nteract.io   637.332813
#   40          nteract                   papermill    30.204271
#   41          nteract                    semiotic     5.054873
#
#                                    org/repo
#   0                         ipython/ipython
#   1                       ipython/traitlets
#   2      jupyter/cookiecutter-docker-stacks
#   3                   jupyter/docker-stacks
#   4              jupyter/enterprise_gateway
#   5                            jupyter/help
#   6                         jupyter/jupyter
#   7                    jupyter/jupyter-book
#   8                   jupyter/jupyter-drive
#   9                  jupyter/kernel_gateway
#   10                      jupyter/nbconvert
#   11                         jupyter/nbdime
#   12                       jupyter/nbgrader
#   13                       jupyter/notebook
#   14                      jupyter/qtconsole
#   15                    jupyter/repo2docker
#   16             jupyter-widgets/ipyleaflet
#   17             jupyter-widgets/ipywidgets
#   18                      jupyterhub/binder
#   19                   jupyterhub/binderhub
#   20     jupyterhub/configurable-http-proxy
#   21       jupyterhub/firstuseauthenticator
#   22      jupyterhub/jupyter-rsession-proxy
#   23        jupyterhub/jupyter-server-proxy
#   24                  jupyterhub/jupyterhub
#   25  jupyterhub/jupyterhub-deploy-teaching
#   26              jupyterhub/jupyterlab-hub
#   27         jupyterhub/nativeauthenticator
#   28                jupyterhub/team-compass
#   29     jupyterhub/the-littlest-jupyterhub
#   30               jupyterhub/traefik-proxy
#   31      jupyterhub/zero-to-jupyterhub-k8s
#   32           jupyterlab/jupyter-renderers
#   33                  jupyterlab/jupyterlab
#   34     jupyterlab/jupyterlab-google-drive
#   35              jupyterlab/jupyterlab-toc
#   36                      nteract/bookstore
#   37                       nteract/commuter
#   38                       nteract/hydrogen
#   39                     nteract/nteract.io
#   40                      nteract/papermill
#   41                       nteract/semiotic  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['nteract.io', 'commuter', 'hydrogen', 'papermill', 'bookstore', 'semiotic', 'jupyterlab-toc', 'jupyterlab', 'jupyterlab-google-drive', 'jupyter-renderers', 'jupyterhub-deploy-teaching', 'configurable-http-proxy', 'jupyterlab-hub', 'the-littlest-jupyterhub', 'binderhub', 'traefik-proxy', 'team-compass', 'nativeauthenticator', 'jupyter-server-proxy', 'jupyter-rsession-proxy', 'zero-to-jupyterhub-k8s', 'firstuseauthenticator', 'jupyterhub', 'binder', 'ipywidgets', 'ipyleaflet', 'jupyter-drive', 'nbgrader', 'cookiecutter-docker-stacks', 'enterprise_gateway', 'nbconvert', 'jupyter-book', 'docker-stacks', 'notebook', 'nbdime', 'repo2docker', 'jupyter', 'kernel_gateway', 'qtconsole', 'help', 'traitlets', 'ipython']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'time_open',
#       title: 'Median Days Open',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Time to close for issues closed in the last 31 days'
# })

# %% [markdown]
# ### A list of recent issues
#
# Below is a list of issues with recent activity in each repository. If they seem of interest
# to you, click on their links and jump in to participate!

# %%
# Add comment count data to issues and PRs
comment_counts = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'issue_id'])
    .count().iloc[:, 0].to_frame()
)
comment_counts.columns = ['n_comments']
comment_counts = comment_counts.reset_index()

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, (org, idata) in enumerate(comment_counts.groupby('org')):
    issue_md = []
    issue_md.append(f"#### {org}")
    issue_md.append("")
    for repo, i_issues in idata.groupby('repo'):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")

        top_issues = i_issues.sort_values('n_comments', ascending=False).head(n_plot)
        top_issue_list = pd.merge(issues, top_issues, left_on=['org', 'repo', 'number'], right_on=['org', 'repo', 'issue_id'])
        for _, issue in top_issue_list.sort_values('n_comments', ascending=False).head(n_plot).iterrows():
            user_name = issue['author']
            user_url = author_url(user_name)
            issue_number = issue['number']
            issue_html = issue['url']
            issue_title = issue['title']

            text = f"* [(#{issue_number})]({issue_html}): _{issue_title}_ by **[@{user_name}]({user_url})**"
            issue_md.append(text)

    issue_md.append('')
    md_html = HTML(markdown('\n'.join(issue_md)))
    
    children = list(tabs.children)
    children.append(HTML(markdown('\n'.join(issue_md))))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"Here are the top {n_plot} active issues in each repository in the last {n_days} days"))
display(tabs)
# Out:
# Here are the top 5 active issues in each repository in the last 31 days
# Tab(children=(HTML(value='<h4>binder-examples</h4>\n<h5><a href="https://github.com/binder-examples/continuous…

# %% [markdown]
# ## Commenters across repositories
#
# These are commenters across all issues and pull requests in the last several days.
# These are colored by the commenter's association with the organization. For information
# about what these associations mean, [see this StackOverflow post](https://stackoverflow.com/a/28866914/1927102).

# %%
commentors = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'author', 'authorAssociation'])
    .count().rename(columns={'id': 'count'})['count']
    .reset_index()
    .sort_values(['org', 'count'], ascending=False)
)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(commentors.groupby(['org'])):
    title = f"Top {n_plot} commentors for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'count': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('count', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='count',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:     author  count authorAssociation
#     0  betatim      1            MEMBER
#     1  jhamman      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     2           Carreau     50            MEMBER
#     58        takluyver     25            MEMBER
#     55           stas00     15              NONE
#     59        techtonik     11       CONTRIBUTOR
#     5    LucianaMarques      8       CONTRIBUTOR
#     30   kubaraczkowski      4              NONE
#     32         memeplex      4       CONTRIBUTOR
#     48         rmorshea      3      COLLABORATOR
#     54            spott      3              NONE
#     1           BoboTiG      3       CONTRIBUTOR
#     56           stuaxo      3              NONE
#     24          jakevdp      2              NONE
#     22            ibell      2       CONTRIBUTOR
#     50          sanyam5      2       CONTRIBUTOR
#     16          dsblank      2       CONTRIBUTOR
#     38          njsmith      2       CONTRIBUTOR
#     34            minrk      2            MEMBER
#     64           tomyun      2       CONTRIBUTOR
#     13        billtubbs      2              NONE
#     46           rgbkrk      1            MEMBER
#     43         prittjam      1              NONE
#     42       philippjfr      1              NONE
#     44          pwm1234      1              NONE
#     41         pganssle      1       CONTRIBUTOR
#     45       rexendevar      1              NONE
#     40          panaali      1              NONE
#     0       ArtinSarraf      1              NONE
#     47          rjurney      1              NONE
#     49             rsvp      1              NONE
#     51         shakedel      1              NONE
#     39          noragen      1              NONE
#     53        sixtyfive      1              NONE
#     57        tacaswell      1       CONTRIBUTOR
#     60       thadguidry      1              NONE
#     61    thequackdaddy      1              NONE
#     62         thinkjrs      1              NONE
#     63           tomerk      1              NONE
#     65          vmalloc      1              NONE
#     52     sigmavirus24      1              NONE
#     33     michael-pont      1              NONE
#     37        neighthan      1              NONE
#     17          esha-sg      1              NONE
#     3       JafarShaik6      1              NONE
#     4          LiranDan      1              NONE
#     6         MehrdadDS      1              NONE
#     7     SylvainCorlay      1            MEMBER
#     8     TomAugspurger      1              NONE
#     9           albertz      1              NONE
#     10  ambareeshsrja16      1              NONE
#     11      andrewarchi      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:               author  count authorAssociation
#     109        choldgraf     74            MEMBER
#     289        takluyver     74            MEMBER
#     195      kevin-bates     47            MEMBER
#     323        yuvipanda     35            MEMBER
#     93           betatim     29            MEMBER
#     238          parente     23            MEMBER
#     257           rgbkrk     15            MEMBER
#     177       jasongrout     14              NONE
#     151          gnestor     12            MEMBER
#     148             gaow     12       CONTRIBUTOR
#     114     craig-willis      9       CONTRIBUTOR
#     221            minrk      8            MEMBER
#     260         rolweber      8      COLLABORATOR
#     217           mgeier      8       CONTRIBUTOR
#     184         jhamrick      7            MEMBER
#     1        15050050972      7              NONE
#     94       betteridiot      7              NONE
#     210         lresende      7            MEMBER
#     74          akhmerov      6            MEMBER
#     32            Hyaxia      6              NONE
#     187       joergbrech      6       CONTRIBUTOR
#     224        mmagnuski      6              NONE
#     84            arokem      6       CONTRIBUTOR
#     175            janba      6              NONE
#     253           rdblue      6            MEMBER
#     280             slel      6              NONE
#     118      damianavila      5            MEMBER
#     139           esevan      5      COLLABORATOR
#     246           pylang      5              NONE
#     144     flying-sheep      5              NONE
#     137          emdupre      5      COLLABORATOR
#     170           ivanov      4            MEMBER
#     239     parewa-aswin      4              NONE
#     3          314cascio      4              NONE
#     211          ltetrel      4              NONE
#     316        xhumanoid      4       CONTRIBUTOR
#     17           Carreau      4            MEMBER
#     52     ReddyKilowatt      4              NONE
#     313         willingc      4            MEMBER
#     77   alexarchambault      4            MEMBER
#     303          vidartf      4      COLLABORATOR
#     281           stas00      4              NONE
#     138         ericdill      4       CONTRIBUTOR
#     245      psychemedia      4              NONE
#     58              Ruv7      3            MEMBER
#     104       ccordoba12      3      COLLABORATOR
#     78         alimanfoo      3       CONTRIBUTOR
#     97         blink1073      3            MEMBER
#     160       ian-r-rose      3            MEMBER
#     326          zlashie      3              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     19      martinRenou     29            MEMBER
#     14       jasongrout     20            MEMBER
#     3     SylvainCorlay     14            MEMBER
#     8          deeplook     11       CONTRIBUTOR
#     7     davidbrochart      8       CONTRIBUTOR
#     29          vidartf      7            MEMBER
#     25        pslacerda      5              NONE
#     10     fitoprincipe      4       CONTRIBUTOR
#     18  maartenbreddels      4            MEMBER
#     23         norrisan      3              NONE
#     12       fsteinmetz      2              NONE
#     30      zachrouseFE      2              NONE
#     9       eran-pinhas      2              NONE
#     6     chdhr-harshal      2              NONE
#     4          amueller      2              NONE
#     20        msuperina      2              NONE
#     27            spott      1              NONE
#     26         rmorshea      1       CONTRIBUTOR
#     22          nickc92      1              NONE
#     24         pbugnion      1            MEMBER
#     28       tlimpanont      1              NONE
#     0         Juanlu001      1       CONTRIBUTOR
#     21          mwcraig      1       CONTRIBUTOR
#     17        krerkkiat      1              NONE
#     16            jog39      1              NONE
#     1           Madhu94      1       CONTRIBUTOR
#     13       gustavogpf      1              NONE
#     11        flothesof      1              NONE
#     5       chaoukiiiii      1              NONE
#     2          Salbinus      1              NONE
#     15          jbednar      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                                author  count authorAssociation
#     120                         yuvipanda    115            MEMBER
#     31                       consideRatio     78            MEMBER
#     28                          choldgraf     70            MEMBER
#     83                              minrk     61            MEMBER
#     21                            betatim     37            MEMBER
#     73                             manics     29       CONTRIBUTOR
#     112                             vnijs     27              NONE
#     39                           dkipping     16              NONE
#     69                         leportella     13      COLLABORATOR
#     13                            Zsailer     10            MEMBER
#     99                         ryanlovett      9            MEMBER
#     119                      yugushihuang      9              NONE
#     114                          willingc      8            MEMBER
#     115                         willirath      8      COLLABORATOR
#     14                             ablekh      8              NONE
#     8                      GeorgianaElena      7            MEMBER
#     118                            xmnlab      7       CONTRIBUTOR
#     111                         vilhelmen      7       CONTRIBUTOR
#     53                             hnykda      7              NONE
#     42                          ellisonbg      6            MEMBER
#     22                             bitnik      6       CONTRIBUTOR
#     25                       captainsafia      6            MEMBER
#     61                            jhamman      5       CONTRIBUTOR
#     92                        psychemedia      5              NONE
#     65                            jzf2101      5            MEMBER
#     56                         ian-r-rose      5      COLLABORATOR
#     26                             cbjuan      5       CONTRIBUTOR
#     30                       clancychilds      4              NONE
#     74                 mannevijayakrishna      4              NONE
#     1    01100010011001010110010101110000      4              NONE
#     41                          dtaniwaki      4       CONTRIBUTOR
#     44                             feriat      4              NONE
#     63                           joshbode      4       CONTRIBUTOR
#     59                             jcrist      3            MEMBER
#     104                      stefansedich      3              NONE
#     100                    saulshanabrook      3              NONE
#     85                          myidealab      3              NONE
#     108                          tkang007      3              NONE
#     110                            tregin      3              NONE
#     116                  wlohman-surfsara      3       CONTRIBUTOR
#     76                      marketneutral      3              NONE
#     88                         oscar6echo      3              NONE
#     84                         mirestrepo      3              NONE
#     67                            kavemun      2              NONE
#     70                             lheagy      2            MEMBER
#     72                              ma010      2              NONE
#     75                    marinalopez2110      2              NONE
#     60                              jflam      2              NONE
#     77                mathematicalmichael      2              NONE
#     95                             rgbkrk      2            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                author  count authorAssociation
#     65         ian-r-rose    160            MEMBER
#     70         jasongrout    150            MEMBER
#     114    saulshanabrook     69            MEMBER
#     134         yuvipanda     27       CONTRIBUTOR
#     30           bollwyvl     24            MEMBER
#     19             afshin     20            MEMBER
#     49          ellisonbg     17            MEMBER
#     59            gnestor     15            MEMBER
#     131            xmnlab     13      COLLABORATOR
#     122        telamonian     12            MEMBER
#     127           vidartf     10            MEMBER
#     95              ntdef      9       CONTRIBUTOR
#     123         tgeorgeux      9            MEMBER
#     51         fcollonval      9            MEMBER
#     118          sntgluca      8              NONE
#     34          choldgraf      8            MEMBER
#     10            Madhu94      7            MEMBER
#     20           agoose77      6            MEMBER
#     69              janba      6              NONE
#     1              BoPeng      6            MEMBER
#     58            ghuname      5              NONE
#     68         jaipreet-s      5      COLLABORATOR
#     105            pwwang      5              NONE
#     83          martinbel      5              NONE
#     0          AlbertHilb      5            MEMBER
#     25           aschlaep      4            MEMBER
#     42        dhirschfeld      4            MEMBER
#     125         timkpaine      4            MEMBER
#     6        DonJayamanne      4       CONTRIBUTOR
#     61             hoo761      4      COLLABORATOR
#     82      markellekelly      4            MEMBER
#     62            horstle      3       CONTRIBUTOR
#     104            pmav99      3              NONE
#     80             lheagy      3       CONTRIBUTOR
#     90            mocquin      3              NONE
#     100         paris0120      3              NONE
#     11       PhilosopherZ      3              NONE
#     103          phil-zxx      3              NONE
#     110            rgbkrk      3            MEMBER
#     53       flying-sheep      2              NONE
#     102          pestrela      2              NONE
#     17            Zsailer      2            MEMBER
#     7         GordonSmith      2              NONE
#     116         seawolf42      2            MEMBER
#     73              jtpio      2            MEMBER
#     108              reem      2              NONE
#     13         SimonBiggs      2            MEMBER
#     111          ryan4yin      2              NONE
#     21      alex-delacruz      2              NONE
#     15   WesleyTheGeolien      2              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     48           rgbkrk    254            MEMBER
#     56      stormpython     55            MEMBER
#     40       kylebarron     37            MEMBER
#     22     captainsafia     35            MEMBER
#     58         willingc     33            MEMBER
#     8             MSeal     27            MEMBER
#     1        BenRussert     25            MEMBER
#     43           mpacer     16            MEMBER
#     25           emeeks     13            MEMBER
#     10      Shinigami92     11            MEMBER
#     50        saber7165      7              NONE
#     38  kelleyblackmore      6            MEMBER
#     19          betatim      6            MEMBER
#     12   VincentBLortie      5            MEMBER
#     30         guntbert      5              NONE
#     3    CrystallineCat      5            MEMBER
#     26         erolosty      4              NONE
#     20            bnaul      4            MEMBER
#     21          bnbarak      3            MEMBER
#     41          lgeiger      3            MEMBER
#     37      keitakurita      3              NONE
#     39       kiwi0fruit      3       CONTRIBUTOR
#     18        bengarvey      3              NONE
#     60        wrathagom      3              NONE
#     24         danielsc      2              NONE
#     51        samghelms      2              NONE
#     57        wesinator      2       CONTRIBUTOR
#     29         greena13      2              NONE
#     44         n-riesco      1            MEMBER
#     59          wodecki      1              NONE
#     42            minrk      1            MEMBER
#     55       stillmatic      1            MEMBER
#     54  spencerbertsch1      1              NONE
#     45     neo-anderson      1              NONE
#     49          riordan      1              NONE
#     53          spektom      1              NONE
#     46       psmaragdis      1              NONE
#     47          puma314      1              NONE
#     52     silvestre125      1              NONE
#     0           314eter      1              NONE
#     31        jameskoch      1            MEMBER
#     36           jpenev      1              NONE
#     14       aidan-fitz      1              NONE
#     2           Carreau      1            MEMBER
#     4       FranciscoRZ      1              NONE
#     5       JannesKlaas      1              NONE
#     6          JarnoRFB      1              NONE
#     7            Lokdal      1              NONE
#     9     MatthieuMayer      1              NONE
#     11      Sivli-Embir      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## First responders
#
# First responders are the first people to respond to a new issue in one of the repositories.
# The following plots show first responders for recently-created issues.

# %%
first_comments = []
for (org, repo, issue_id), i_comments in comments.groupby(['org', 'repo', 'issue_id']):
    ix_min = pd.to_datetime(i_comments['createdAt']).idxmin()
    first_comment = i_comments.loc[ix_min]
    if isinstance(first_comment, pd.DataFrame):
        first_comment = first_comment.iloc[0]
    first_comments.append(first_comment)
first_comments = pd.concat(first_comments, axis=1).T

# %%
first_responder_counts = first_comments.groupby(['org', 'author', 'authorAssociation'], as_index=False).\
    count().rename(columns={'id': 'n_first_responses'}).sort_values(['org', 'n_first_responses'], ascending=False)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(first_responder_counts.groupby(['org'])):
    title = f"Top {n_plot} first responders for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'n_first_responses': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('n_first_responses', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='n_first_responses',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:     author  n_first_responses authorAssociation
#     0  jhamman                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:               author  n_first_responses authorAssociation
#     0            Carreau                 26            MEMBER
#     37         takluyver                 12            MEMBER
#     32          rmorshea                  3      COLLABORATOR
#     20          memeplex                  2       CONTRIBUTOR
#     33              rsvp                  1              NONE
#     25         neighthan                  1              NONE
#     26           noragen                  1              NONE
#     27           panaali                  1              NONE
#     28        philippjfr                  1              NONE
#     29          prittjam                  1              NONE
#     30           pwm1234                  1              NONE
#     31           rjurney                  1              NONE
#     34          shakedel                  1              NONE
#     23  mohammedyunus009                  1              NONE
#     35         sixtyfive                  1              NONE
#     36            stas00                  1              NONE
#     38         techtonik                  1       CONTRIBUTOR
#     39     thequackdaddy                  1              NONE
#     40          thinkjrs                  1              NONE
#     41            tomerk                  1              NONE
#     42            tomyun                  1       CONTRIBUTOR
#     43           vmalloc                  1              NONE
#     24         musicnerd                  1              NONE
#     22             minrk                  1            MEMBER
#     1        JafarShaik6                  1              NONE
#     10           dsblank                  1       CONTRIBUTOR
#     2           LiranDan                  1              NONE
#     3     LucianaMarques                  1       CONTRIBUTOR
#     4          MehrdadDS                  1              NONE
#     5      SylvainCorlay                  1            MEMBER
#     6            albertz                  1              NONE
#     7        andrewarchi                  1              NONE
#     8          billtubbs                  1              NONE
#     9           cedriczg                  1              NONE
#     11           esha-sg                  1              NONE
#     21      michael-pont                  1              NONE
#     12            fabrei                  1              NONE
#     13          fianitnz                  1              NONE
#     14            gitlio                  1              NONE
#     15           jash101                  1              NONE
#     16         jlstevens                  1       CONTRIBUTOR
#     17            juckuc                  1              NONE
#     18       jvanheugten                  1              NONE
#     19          mazzma12                  1              NONE
#     44         yuvipanda                  1      COLLABORATOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                author  n_first_responses authorAssociation
#     184         takluyver                 45            MEMBER
#     123       kevin-bates                 20            MEMBER
#     72          choldgraf                 18            MEMBER
#     208         yuvipanda                 12            MEMBER
#     148           parente                 11            MEMBER
#     63            betatim                  9            MEMBER
#     135            mgeier                  5       CONTRIBUTOR
#     117          jhamrick                  5            MEMBER
#     114        jasongrout                  4            MEMBER
#     195           vidartf                  3      COLLABORATOR
#     137             minrk                  3            MEMBER
#     138         mmagnuski                  3              NONE
#     200         westurner                  3       CONTRIBUTOR
#     160            rgbkrk                  3            MEMBER
#     164           romainx                  2       CONTRIBUTOR
#     90           ericdill                  2       CONTRIBUTOR
#     50    alexarchambault                  2            MEMBER
#     132           ltetrel                  2              NONE
#     131          lresende                  2            MEMBER
#     177    skycreeper2000                  2              NONE
#     183          t-makaro                  2      COLLABORATOR
#     158            rdblue                  2            MEMBER
#     58             auwsom                  2              NONE
#     209           zlashie                  2              NONE
#     98            gnestor                  2            MEMBER
#     192      toddsundsted                  2              NONE
#     189     thomasaarholt                  2              NONE
#     187           technic                  2              NONE
#     99          gnumoksha                  2              NONE
#     194          ttimbers                  2              NONE
#     116           jhamman                  2       CONTRIBUTOR
#     142         mroettgen                  1              NONE
#     143              msto                  1              NONE
#     115    jediwarpraptor                  1              NONE
#     124            kirk86                  1              NONE
#     141   mosfiqur-rahman                  1              NONE
#     113        jasch-shah                  1              NONE
#     145    nirajdevpandey                  1              NONE
#     146           nkarnev                  1              NONE
#     147         o-smirnov                  1              NONE
#     112         jameskoch                  1            MEMBER
#     111         jakirkham                  1            MEMBER
#     149        parthi2929                  1              NONE
#     144          mtd91429                  1       CONTRIBUTOR
#     118    jordangarrison                  1              NONE
#     140       moondra2017                  1              NONE
#     139  mohammedyunus009                  1              NONE
#     119           jzf2101                  1            MEMBER
#     136        michaelaye                  1              NONE
#     134           mengban                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  n_first_responses authorAssociation
#     10       jasongrout                  9            MEMBER
#     13      martinRenou                  8            MEMBER
#     20          vidartf                  5            MEMBER
#     2     SylvainCorlay                  4            MEMBER
#     12  maartenbreddels                  2            MEMBER
#     6     davidbrochart                  2       CONTRIBUTOR
#     19            spott                  1              NONE
#     18         rmorshea                  1       CONTRIBUTOR
#     17         pbugnion                  1            MEMBER
#     16         norrisan                  1              NONE
#     15          mwcraig                  1       CONTRIBUTOR
#     14        msuperina                  1              NONE
#     3          amueller                  1              NONE
#     4       chaoukiiiii                  1              NONE
#     11            jog39                  1              NONE
#     1           Madhu94                  1       CONTRIBUTOR
#     9        gustavogpf                  1              NONE
#     8         flothesof                  1              NONE
#     7          deeplook                  1       CONTRIBUTOR
#     5     chdhr-harshal                  1              NONE
#     0         Juanlu001                  1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                 author  n_first_responses authorAssociation
#     90           yuvipanda                 35            MEMBER
#     26        consideRatio                 27            MEMBER
#     61               minrk                 26            MEMBER
#     24           choldgraf                 20            MEMBER
#     54              manics                 11       CONTRIBUTOR
#     18             betatim                  8            MEMBER
#     51          leportella                  8      COLLABORATOR
#     75          ryanlovett                  5            MEMBER
#     31           dtaniwaki                  4       CONTRIBUTOR
#     11             Zsailer                  4            MEMBER
#     12              ablekh                  4              NONE
#     63           myidealab                  3              NONE
#     44             jhamman                  3       CONTRIBUTOR
#     38              hnykda                  3              NONE
#     19              bitnik                  3       CONTRIBUTOR
#     55  mannevijayakrishna                  3              NONE
#     81            tkang007                  2              NONE
#     84               vnijs                  2              NONE
#     86           willirath                  2      COLLABORATOR
#     7       GeorgianaElena                  2            MEMBER
#     34               flixr                  2              NONE
#     9           SolarisYan                  2              NONE
#     29            dkipping                  2              NONE
#     25        clancychilds                  2              NONE
#     48             jzf2101                  2            MEMBER
#     23              cbjuan                  2       CONTRIBUTOR
#     79        stefansedich                  2              NONE
#     53               ma010                  2              NONE
#     59           memoatwit                  1              NONE
#     60           mikanyman                  1              NONE
#     67         payalbhatia                  1              NONE
#     89        yugushihuang                  1              NONE
#     88              xmnlab                  1       CONTRIBUTOR
#     58             maxious                  1              NONE
#     62          mirestrepo                  1              NONE
#     87    wlohman-surfsara                  1       CONTRIBUTOR
#     64          nschiraldi                  1              NONE
#     65          orionjeong                  1              NONE
#     91            zhouanbo                  1              NONE
#     66            oschuett                  1              NONE
#     70                 rbq                  1              NONE
#     68          pratik-lal                  1              NONE
#     69         psychemedia                  1              NONE
#     80          swallace21                  1              NONE
#     71         reynoldsnlp                  1              NONE
#     72             rkdarst                  1       CONTRIBUTOR
#     73           robomotic                  1              NONE
#     74             robotsp                  1              NONE
#     57       marketneutral                  1              NONE
#     76      saulshanabrook                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  n_first_responses authorAssociation
#     32       ian-r-rose                 60            MEMBER
#     36       jasongrout                 51            MEMBER
#     59   saulshanabrook                 22            MEMBER
#     70        yuvipanda                  6       CONTRIBUTOR
#     64        tgeorgeux                  6            MEMBER
#     22       fcollonval                  5            MEMBER
#     12         bollwyvl                  4            MEMBER
#     66          vidartf                  4            MEMBER
#     7            afshin                  4            MEMBER
#     21        ellisonbg                  4            MEMBER
#     63       telamonian                  3            MEMBER
#     48            ntdef                  3       CONTRIBUTOR
#     0        AlbertHilb                  3            MEMBER
#     5           Madhu94                  3            MEMBER
#     28          gnestor                  2            MEMBER
#     68           xmnlab                  2      COLLABORATOR
#     34       jaipreet-s                  2      COLLABORATOR
#     1            BoPeng                  2            MEMBER
#     56             reem                  2              NONE
#     8          agoose77                  2            MEMBER
#     2          BrenBarn                  2              NONE
#     49          otayeby                  1              NONE
#     50    padraiglennon                  1              NONE
#     57         ryan57bh                  1              NONE
#     52         pestrela                  1              NONE
#     53           pmav99                  1              NONE
#     47         nilinykh                  1              NONE
#     54           pwwang                  1              NONE
#     55       rahulpshah                  1            MEMBER
#     51       pdeffebach                  1              NONE
#     13            cbuhl                  1              NONE
#     58           satary                  1              NONE
#     45  naga-pakalapati                  1              NONE
#     6      PhilosopherZ                  1              NONE
#     60         schluenz                  1              NONE
#     61         sntgluca                  1              NONE
#     62    takashimokobe                  1              NONE
#     4           Jakeler                  1              NONE
#     65        timkpaine                  1            MEMBER
#     3      DonJayamanne                  1       CONTRIBUTOR
#     67   vinaykumar2491                  1              NONE
#     69          yoonghm                  1              NONE
#     71      zhengdayday                  1              NONE
#     46     neelamgehlot                  1      COLLABORATOR
#     43          mlucool                  1       CONTRIBUTOR
#     44        msuperina                  1              NONE
#     14  concretevitamin                  1              NONE
#     15     consideRatio                  1            MEMBER
#     16       danimateos                  1              NONE
#     17           dclong                  1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterlab in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  n_first_responses authorAssociation
#     29           rgbkrk                116            MEMBER
#     36      stormpython                 25            MEMBER
#     13     captainsafia                 19            MEMBER
#     38         willingc                 15            MEMBER
#     4             MSeal                 10            MEMBER
#     23       kylebarron                  9            MEMBER
#     15           emeeks                  9            MEMBER
#     0        BenRussert                  6            MEMBER
#     25           mpacer                  5            MEMBER
#     5       Shinigami92                  4            MEMBER
#     10          betatim                  3            MEMBER
#     22  kelleyblackmore                  3            MEMBER
#     7    VincentBLortie                  2            MEMBER
#     11            bnaul                  2            MEMBER
#     24          lgeiger                  2            MEMBER
#     39        wrathagom                  2              NONE
#     16         erolosty                  2              NONE
#     9         bengarvey                  2              NONE
#     30          riordan                  1              NONE
#     33     silvestre125                  1              NONE
#     31        saber7165                  1              NONE
#     32        samghelms                  1              NONE
#     37        wesinator                  1       CONTRIBUTOR
#     34          spektom                  1              NONE
#     27     neo-anderson                  1              NONE
#     35  spencerbertsch1                  1              NONE
#     28          puma314                  1              NONE
#     20         jdfreder                  1            MEMBER
#     26         n-riesco                  1            MEMBER
#     21       jimdowling                  1              NONE
#     1    CrystallineCat                  1            MEMBER
#     19        jameskoch                  1            MEMBER
#     18         guntbert                  1              NONE
#     17          gnestor                  1            MEMBER
#     14        casperdcl                  1            MEMBER
#     12          bnbarak                  1            MEMBER
#     8         bballcode                  1              NONE
#     6       Sivli-Embir                  1              NONE
#     3            Lokdal                  1              NONE
#     2       FranciscoRZ                  1              NONE
#     40             wsjz                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for nteract in the last 31 days',
#     width: 1000
#   })]
# })

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
