# %%
import seaborn as sns
import pandas as pd
import numpy as np
import altair as alt
from markdown import markdown
from IPython.display import Markdown
from ipywidgets.widgets import HTML, Tab
from ipywidgets import widgets
from datetime import timedelta
from matplotlib import pyplot as plt
import os.path as op

from mod import load_data, alt_theme

from warnings import simplefilter
simplefilter('ignore')

# %%
def author_url(author):
    return f"https://github.com/{author}"

# %%
# Parameters
fmt_date = "{:%Y-%m-%d}"

n_days = 90
start_date = fmt_date.format(pd.datetime.today() - timedelta(days=n_days))
end_date = fmt_date.format(pd.datetime.today())

renderer = "jupyterlab"
github_orgs = ["jupyterhub", "jupyter", "jupyterlab", "jupyter-widgets", "ipython", "binder-examples", "nteract"]

# %%
# Parameters
renderer = "kaggle"
github_orgs = ["jupyterhub", "jupyter", "jupyterlab", "jupyter-widgets", "ipython", "binder-examples"]
start_date = "2019-07-01"
end_date = "2019-08-01"

# %%
comments, issues, prs = load_data('../data/')
bot_names = pd.read_csv('bot_names.csv')['names'].tolist()
comments = comments.query('author not in @bot_names').drop_duplicates()
issues = issues.query('author not in @bot_names').drop_duplicates()
prs = prs.query('author not in @bot_names').drop_duplicates()

# %%
# Only keep the datapoints we want
query_data = 'updatedAt > @start_date and updatedAt < @end_date and org in @github_orgs'
comments = comments.query(query_data)
issues = issues.query(query_data)
prs = prs.query(query_data)

# %%
alt.renderers.enable(renderer);
alt.themes.register('my_theme', alt_theme)
alt.themes.enable("my_theme")
# Out:
# ThemeRegistry.enable('my_theme')

# %%
# Information about out time window
time_delta = pd.to_datetime(end_date) - pd.to_datetime(start_date)
n_days = time_delta.days

# Information about the data we loaded
github_orgs = comments['org'].unique()

# %% [markdown]
# # GitHub activity
#
# Jupyter also has lots of activity across GitHub repositories. The following sections contain
# overviews of recent activity across the following GitHub organizations:

# %%
# Define colors we'll use for GitHub membership
author_types = ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', "NONE"]

author_palette = sns.palettes.blend_palette(["lightgrey", "lightgreen", "darkgreen"], 4)
author_colors = ["rgb({}, {}, {}, {})".format(*(ii*256)) for ii in author_palette]
author_color_dict = {key: val for key, val in zip(author_types, author_palette)}

# %%
orgs_md = []
for org in github_orgs:
    orgs_md.append(f'* [github.com/{org}](https://github.com/{org})')
Markdown('\n'.join(orgs_md))
# Out:
# * [github.com/jupyterlab](https://github.com/jupyterlab)
# * [github.com/ipython](https://github.com/ipython)
# * [github.com/jupyter-widgets](https://github.com/jupyter-widgets)
# * [github.com/binder-examples](https://github.com/binder-examples)
# * [github.com/jupyter](https://github.com/jupyter)
# * [github.com/jupyterhub](https://github.com/jupyterhub)

# %%
Markdown(f"Showing GitHub activity from **{start_date}** to **{end_date}**")
# Out:
# Showing GitHub activity from **2019-07-01** to **2019-08-01**

# %% [markdown]
# ## List of all contributors per organization
#
# First, we'll list each contributor that has contributed to each organization in the last several days.
# Contributions to open source projects are diverse, and involve much more than just contributing code and
# code review. Thanks to everybody in the Jupyter communities for all that they do.

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, org in enumerate(github_orgs):
    authors_comments = comments.query('org == @org')['author']
    authors_prs = prs.query('org == @org')['author']
    unique_participants = np.unique(np.hstack([authors_comments.values, authors_prs.values]).astype(str)).tolist()
    unique_participants.sort(key=lambda a: a.lower())
    
    all_participants = [f"[{participant}](https://github.com/{participant})" for participant in unique_participants]
    participants_md = " | ".join(all_participants)
    md_html = HTML("<center>{}</center>".format(markdown(participants_md)))
    
    children = list(tabs.children)
    children.append(md_html)
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"All participants across issues and pull requests in each org in the last {n_days} days"))
display(tabs)
# Out:
# All participants across issues and pull requests in each org in the last 31 days
# Tab(children=(HTML(value='<center><p><a href="https://github.com/adriendelsalle">adriendelsalle</a> | <a href=…

# %% [markdown]
# ## Merged Pull requests
#
# Here's an analysis of **merged pull requests** across each of the repositories in the Jupyter
# ecosystem.

# %%
merged = prs.query('state == "MERGED" and closedAt > @start_date and closedAt < @end_date')

# %%
prs_by_repo = merged.groupby(['org', 'repo']).count()['author'].reset_index().sort_values(['org', 'author'], ascending=False)
alt.Chart(data=prs_by_repo, title=f"Merged PRs in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=prs_by_repo['repo'].values.tolist()),
    y='author',
    color='org'
)
# Out:
# Chart({
#   data:                 org                      repo  author
#   55       jupyterlab                jupyterlab      51
#   57       jupyterlab  jupyterlab-data-explorer       9
#   54       jupyterlab         jupyter-renderers       5
#   58       jupyterlab           jupyterlab-demo       5
#   59       jupyterlab            jupyterlab-git       5
#   ..              ...                       ...     ...
#   3           ipython                   ipython      10
#   1           ipython                 ipykernel       3
#   2           ipython               ipyparallel       2
#   4           ipython                 traitlets       2
#   0   binder-examples                data-quilt       1
#
#   [64 rows x 3 columns],
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: ['jupyterlab', 'jupyterlab-data-explorer', 'jupyter-renderers', 'jupyterlab-demo', 'jupyterlab-git', 'debugger', 'jupyterlab-github', 'extension-cookiecutter-ts', 'jupyterlab-commenting', 'theme-cookiecutter', 'scipy2019-jupyterlab-tutorial', 'extension-cookiecutter-js', 'mimerender-cookiecutter-ts', 'mybinder.org-deploy', 'jupyterhub', 'binderhub', 'the-littlest-jupyterhub', 'batchspawner', 'team-compass', 'kerberosauthenticator', 'traefik-proxy', 'binder', 'jupyter-server-proxy', 'ldapauthenticator', 'yarnspawner', 'zero-to-jupyterhub-k8s', 'dockerspawner', 'firstuseauthenticator', 'jupyterlab-hub', 'kubespawner', 'ltiauthenticator', 'nbgitpuller', 'tutorial', 'ipywidgets', 'ipyleaflet', 'jupyterlab-sidecar', 'midicontrols', 'pythreejs', 'notebook', 'jupyter-book', 'telemetry', 'docker-stacks', 'repo2docker', 'enterprise_gateway', 'jupyter.github.io', 'jupyter_client', 'nbconvert', 'jupyter-sphinx', 'jupyter_server', 'qtconsole', 'jupyter', 'jupyter-packaging', 'design', 'nb2kg', 'nbviewer', 'governance', 'nbdime', 'ops-handbook', 'roadmap', 'ipython', 'ipykernel', 'ipyparallel', 'traitlets', 'data-quilt'],
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'author',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Merged PRs in the last 31 days'
# })

# %% [markdown]
# ### A list of merged PRs by project
#
# Below is a tabbed readout of recently-merged PRs. Check out the title to get an idea for what they
# implemented, and be sure to thank the PR author for their hard work!

# %%
tabs = widgets.Tab(children=[])
merged_by = {}
pr_by = {}
for ii, (org, idata) in enumerate(merged.groupby('org')):
    issue_md = []
    issue_md.append(f"#### Closed PRs for org: `{org}`")
    issue_md.append("")
    for (org, repo), prs in idata.groupby(['org', 'repo']):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")
        for _, pr in prs.iterrows():
            user_name = pr['author']
            user_url = author_url(user_name)
            pr_number = pr['number']
            pr_html = pr['url']
            pr_title = pr['title']
            pr_closedby = pr['mergedBy']
            pr_closedby_url = f"https://github.com/{pr_closedby}"
            if user_name not in pr_by:
                pr_by[user_name] = 1
            else:
                pr_by[user_name] += 1
                
            if pr_closedby not in merged_by:
                merged_by[pr_closedby] = 1
            else:
                merged_by[pr_closedby] += 1
            text = f"* [(#{pr_number})]({pr_html}): _{pr_title}_ by **[@{user_name}]({user_url})** merged by **[@{pr_closedby}]({pr_closedby_url})**"
            issue_md.append(text)
    issue_md.append('')
    markdown_html = markdown('\n'.join(issue_md))
    
    children = list(tabs.children)
    children.append(HTML(markdown_html))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
tabs
# Out:
# Tab(children=(HTML(value='<h4>Closed PRs for org: <code>binder-examples</code></h4>\n<h5><a href="https://gith…

# %% [markdown]
# ### Authoring and merging stats by repository
#
# Let's see who has been doing most of the PR authoring and merging. The PR author is generally the
# person that implemented a change in the repository (code, documentation, etc). The PR merger is
# the person that "pressed the green button" and got the change into the main codebase.

# %%
# Prep our merging DF
merged_by_repo = merged.groupby(['org', 'repo', 'author'], as_index=False).agg({'id': 'count', 'authorAssociation': 'first'}).rename(columns={'id': "authored", 'author': 'username'})
closed_by_repo = merged.groupby(['org', 'repo', 'mergedBy']).count()['id'].reset_index().rename(columns={'id': "closed", "mergedBy": "username"})

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(merged_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"PR authors for {iorg} in the last {n_days} days"
    idata = idata.groupby('username', as_index=False).agg({'authored': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('authored', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='authored',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)

alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:       username  authored authorAssociation
#     0  matheusmota         1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                  username  authored authorAssociation
#     0                 Carreau         3            MEMBER
#     1                   Jamim         3       CONTRIBUTOR
#     2   LittleLightLittleFire         1       CONTRIBUTOR
#     3                   MSeal         1       CONTRIBUTOR
#     4              OriolAbril         1       CONTRIBUTOR
#     5          brandonwillard         1       CONTRIBUTOR
#     6                  ellert         1       CONTRIBUTOR
#     7                 hroncok         1       CONTRIBUTOR
#     8              juanis2112         1       CONTRIBUTOR
#     9                 minho42         1       CONTRIBUTOR
#     10                  minrk         1            MEMBER
#     11                sunpoet         1       CONTRIBUTOR
#     12             sysadmin75         1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:           username  authored authorAssociation
#     12       choldgraf        13            MEMBER
#     60       yuvipanda         7            MEMBER
#     47           minrk         6            MEMBER
#     4          Zsailer         5            MEMBER
#     3    SylvainCorlay         4            MEMBER
#     57         vidartf         4      COLLABORATOR
#     10         betatim         4            MEMBER
#     2     JohanMabille         4       CONTRIBUTOR
#     58   vikasgarg1996         3       CONTRIBUTOR
#     7         akhmerov         3            MEMBER
#     50         parente         3            MEMBER
#     24     fabihaahmed         3       CONTRIBUTOR
#     33     jamesdbrock         3       CONTRIBUTOR
#     40     kevin-bates         3            MEMBER
#     36        jbweston         2            MEMBER
#     32      jaipreet-s         2      COLLABORATOR
#     34      jasongrout         2            MEMBER
#     44          maresb         2              NONE
#     38   joshuazeltser         2       CONTRIBUTOR
#     41        krinsman         2       CONTRIBUTOR
#     43        lresende         2            MEMBER
#     52        t-makaro         2      COLLABORATOR
#     1            Jamim         2       CONTRIBUTOR
#     0         IMAM9AIS         2       CONTRIBUTOR
#     5           afshin         2            MEMBER
#     14        dalthviz         2       CONTRIBUTOR
#     19         ednut15         2       CONTRIBUTOR
#     23          esevan         1       CONTRIBUTOR
#     51  saulshanabrook         1       CONTRIBUTOR
#     45          mgeier         1       CONTRIBUTOR
#     46         minho42         1       CONTRIBUTOR
#     11           cczhu         1       CONTRIBUTOR
#     48          njapke         1              NONE
#     49        oscargus         1       CONTRIBUTOR
#     9   artur-trzesiok         1       CONTRIBUTOR
#     8         alexrudy         1       CONTRIBUTOR
#     53       takluyver         1            MEMBER
#     54        taohan16         1       CONTRIBUTOR
#     55        ttimbers         1       CONTRIBUTOR
#     56      vibvibgyor         1       CONTRIBUTOR
#     6            ajtam         1       CONTRIBUTOR
#     59         wwitzel         1       CONTRIBUTOR
#     13           clkao         1       CONTRIBUTOR
#     42         lepture         1       CONTRIBUTOR
#     25    flying-sheep         1       CONTRIBUTOR
#     21       ellisonbg         1            MEMBER
#     26          fperez         1       CONTRIBUTOR
#     27            habi         1       CONTRIBUTOR
#     28          hdtee1         1       CONTRIBUTOR
#     29    hugokerstens         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            username  authored authorAssociation
#     9       martinRenou        10            MEMBER
#     11          mwcraig         7       CONTRIBUTOR
#     1     SylvainCorlay         4            MEMBER
#     4        jasongrout         4            MEMBER
#     7         kgiacobbi         3       CONTRIBUTOR
#     2      VasavanThiru         2       CONTRIBUTOR
#     6             jtpio         2       CONTRIBUTOR
#     0             Jamim         1       CONTRIBUTOR
#     3            ataiya         1       CONTRIBUTOR
#     5             jmp75         1       CONTRIBUTOR
#     8   maartenbreddels         1            MEMBER
#     10       mbektasbbg         1       CONTRIBUTOR
#     12           tgrout         1       CONTRIBUTOR
#     13            wolfv         1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            username  authored authorAssociation
#     6           betatim        13            MEMBER
#     10        choldgraf        10            MEMBER
#     1    GeorgianaElena         9            MEMBER
#     18           jcrist         6            MEMBER
#     29          rkdarst         5       CONTRIBUTOR
#     25            minrk         3            MEMBER
#     23      mael-le-gal         3            MEMBER
#     33        sgibson91         2            MEMBER
#     7            bitnik         2       CONTRIBUTOR
#     26       nicorikken         2       CONTRIBUTOR
#     24  marcusianlevine         2       CONTRIBUTOR
#     19            jtpio         2       CONTRIBUTOR
#     32          seanmck         1       CONTRIBUTOR
#     31       ryanlovett         1            MEMBER
#     30            rtcn2         1       CONTRIBUTOR
#     21          lesteve         1       CONTRIBUTOR
#     28         remram44         1       CONTRIBUTOR
#     27           rcolle         1       CONTRIBUTOR
#     22          lumbric         1       CONTRIBUTOR
#     34          staeiou         1       CONTRIBUTOR
#     0           Carreau         1            MEMBER
#     20         krinsman         1       CONTRIBUTOR
#     17      jamesdbrock         1       CONTRIBUTOR
#     16           ilee38         1       CONTRIBUTOR
#     15           henchc         1            MEMBER
#     14        danlester         1       CONTRIBUTOR
#     13     danielballan         1       CONTRIBUTOR
#     12      cornhundred         1       CONTRIBUTOR
#     11         cmd-ntrf         1       CONTRIBUTOR
#     9    chicocvenancio         1       CONTRIBUTOR
#     8         blink1073         1      COLLABORATOR
#     5         bartolone         1              NONE
#     4         athornton         1       CONTRIBUTOR
#     3             Hoeze         1       CONTRIBUTOR
#     2   GrahamDumpleton         1       CONTRIBUTOR
#     35        yuvipanda         1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:           username  authored authorAssociation
#     9       dependabot        11       CONTRIBUTOR
#     25      telamonian        10            MEMBER
#     23  saulshanabrook         9            MEMBER
#     2           afshin         8            MEMBER
#     16      ian-r-rose         7            MEMBER
#     4        blink1073         6            MEMBER
#     29         vidartf         5            MEMBER
#     17      jasongrout         5            MEMBER
#     10     dharmaquark         5            MEMBER
#     14         gnestor         3            MEMBER
#     18           jtpio         3            MEMBER
#     21       nscozzaro         2            MEMBER
#     12         dsblank         2            MEMBER
#     13      fcollonval         2            MEMBER
#     19      krassowski         2            MEMBER
#     20        krinsman         2       CONTRIBUTOR
#     24          sbrunk         1       CONTRIBUTOR
#     26         tslaton         1       CONTRIBUTOR
#     22         reevejd         1            MEMBER
#     27       urihoenig         1       CONTRIBUTOR
#     28           van-8         1            MEMBER
#     0      AlokTakshak         1       CONTRIBUTOR
#     1           BoPeng         1            MEMBER
#     11        domoritz         1            MEMBER
#     8    danielgruesso         1       CONTRIBUTOR
#     7     danielballan         1            MEMBER
#     6            ciyer         1            MEMBER
#     5        bobmayuze         1            MEMBER
#     3    balamuruganvg         1       CONTRIBUTOR
#     15          hoo761         1      COLLABORATOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterlab in the last 31 days',
#     width: 1000
#   })]
# })

# %%
charts = []
for ii, (iorg, idata) in enumerate(closed_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"Merges for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='closed',
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                org        repo username  closed
#     0  binder-examples  data-quilt  betatim       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:        org         repo  username  closed
#     1  ipython    ipykernel   Carreau       1
#     2  ipython    ipykernel     minrk       1
#     3  ipython    ipykernel  willingc       1
#     4  ipython  ipyparallel     minrk       2
#     5  ipython      ipython   Carreau      10
#     6  ipython    traitlets  rmorshea       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:         org                repo       username  closed
#     7   jupyter              design        Carreau       1
#     8   jupyter              design      blink1073       1
#     9   jupyter       docker-stacks          minrk       6
#     10  jupyter       docker-stacks        parente       5
#     11  jupyter  enterprise_gateway    kevin-bates       8
#     12  jupyter  enterprise_gateway       lresende       2
#     13  jupyter          governance      choldgraf       1
#     14  jupyter             jupyter      choldgraf       2
#     15  jupyter             jupyter        parente       1
#     16  jupyter        jupyter-book      choldgraf      13
#     17  jupyter   jupyter-packaging      blink1073       2
#     18  jupyter   jupyter-packaging        vidartf       1
#     19  jupyter      jupyter-sphinx       akhmerov       5
#     20  jupyter      jupyter-sphinx       jbweston       1
#     21  jupyter   jupyter.github.io        Carreau       1
#     22  jupyter   jupyter.github.io           Ruv7       1
#     23  jupyter   jupyter.github.io         afshin       1
#     24  jupyter   jupyter.github.io      choldgraf       2
#     25  jupyter   jupyter.github.io      ellisonbg       1
#     26  jupyter   jupyter.github.io     jasongrout       2
#     27  jupyter      jupyter_client          MSeal       1
#     28  jupyter      jupyter_client  SylvainCorlay       4
#     29  jupyter      jupyter_client          minrk       3
#     30  jupyter      jupyter_server  SylvainCorlay       3
#     31  jupyter      jupyter_server       rolweber       1
#     32  jupyter               nb2kg    kevin-bates       2
#     33  jupyter           nbconvert          MSeal       8
#     34  jupyter              nbdime        vidartf       1
#     35  jupyter            nbviewer        parente       2
#     36  jupyter            notebook  SylvainCorlay       2
#     37  jupyter            notebook         ivanov       1
#     38  jupyter            notebook       lresende       1
#     39  jupyter            notebook      takluyver      10
#     40  jupyter        ops-handbook         fperez       1
#     41  jupyter           qtconsole     ccordoba12       4
#     42  jupyter         repo2docker        betatim       7
#     43  jupyter         repo2docker      choldgraf       1
#     44  jupyter         repo2docker          minrk       3
#     45  jupyter             roadmap      choldgraf       1
#     46  jupyter           telemetry        Zsailer       6
#     47  jupyter           telemetry     jaipreet-s       1
#     48  jupyter           telemetry      yuvipanda       5,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                 org                repo         username  closed
#     49  jupyter-widgets          ipyleaflet      martinRenou      10
#     50  jupyter-widgets          ipywidgets    SylvainCorlay       7
#     51  jupyter-widgets          ipywidgets       jasongrout       3
#     52  jupyter-widgets          ipywidgets  maartenbreddels       1
#     53  jupyter-widgets          ipywidgets          vidartf       1
#     54  jupyter-widgets  jupyterlab-sidecar    SylvainCorlay       1
#     55  jupyter-widgets        midicontrols       jasongrout       1
#     56  jupyter-widgets           pythreejs          vidartf       1
#     57  jupyter-widgets            tutorial    SylvainCorlay       1
#     58  jupyter-widgets            tutorial  maartenbreddels       1
#     59  jupyter-widgets            tutorial      martinRenou       1
#     60  jupyter-widgets            tutorial          mwcraig      11,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:            org                     repo        username  closed
#     61  jupyterhub             batchspawner      mbmilligan       6
#     62  jupyterhub                   binder         betatim       1
#     63  jupyterhub                   binder       choldgraf       1
#     64  jupyterhub                binderhub         betatim       7
#     65  jupyterhub                binderhub       choldgraf       1
#     66  jupyterhub            dockerspawner           minrk       1
#     67  jupyterhub    firstuseauthenticator  GeorgianaElena       1
#     68  jupyterhub     jupyter-server-proxy       yuvipanda       2
#     69  jupyterhub               jupyterhub         betatim       3
#     70  jupyterhub               jupyterhub           minrk       6
#     71  jupyterhub               jupyterhub        willingc       4
#     72  jupyterhub               jupyterhub       yuvipanda       2
#     73  jupyterhub           jupyterlab-hub       blink1073       1
#     74  jupyterhub    kerberosauthenticator          jcrist       3
#     75  jupyterhub              kubespawner           minrk       1
#     76  jupyterhub        ldapauthenticator         betatim       2
#     77  jupyterhub         ltiauthenticator       yuvipanda       1
#     78  jupyterhub      mybinder.org-deploy         betatim      15
#     79  jupyterhub      mybinder.org-deploy       choldgraf       4
#     80  jupyterhub      mybinder.org-deploy           minrk       1
#     81  jupyterhub      mybinder.org-deploy       sgibson91       1
#     82  jupyterhub              nbgitpuller      ryanlovett       1
#     83  jupyterhub             team-compass         betatim       2
#     84  jupyterhub             team-compass       choldgraf       2
#     85  jupyterhub  the-littlest-jupyterhub           minrk       1
#     86  jupyterhub  the-littlest-jupyterhub       yuvipanda       6
#     87  jupyterhub            traefik-proxy           minrk       3
#     88  jupyterhub              yarnspawner          jcrist       2
#     89  jupyterhub   zero-to-jupyterhub-k8s    consideRatio       1
#     90  jupyterhub   zero-to-jupyterhub-k8s           minrk       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:             org                           repo        username  closed
#     91   jupyterlab                       debugger          afshin       4
#     92   jupyterlab      extension-cookiecutter-js           jtpio       1
#     93   jupyterlab      extension-cookiecutter-ts       blink1073       3
#     94   jupyterlab              jupyter-renderers         gnestor       5
#     95   jupyterlab                     jupyterlab        aschlaep       1
#     96   jupyterlab                     jupyterlab       blink1073      21
#     97   jupyterlab                     jupyterlab      ian-r-rose      11
#     98   jupyterlab                     jupyterlab      jasongrout      10
#     99   jupyterlab                     jupyterlab           jtpio       1
#     100  jupyterlab                     jupyterlab  saulshanabrook       1
#     101  jupyterlab                     jupyterlab      telamonian       5
#     102  jupyterlab                     jupyterlab         vidartf       1
#     103  jupyterlab          jupyterlab-commenting          hoo761       3
#     104  jupyterlab       jupyterlab-data-explorer  saulshanabrook       9
#     105  jupyterlab                jupyterlab-demo     dharmaquark       4
#     106  jupyterlab                jupyterlab-demo      jasongrout       1
#     107  jupyterlab                 jupyterlab-git      jaipreet-s       5
#     108  jupyterlab              jupyterlab-github      ian-r-rose       4
#     109  jupyterlab     mimerender-cookiecutter-ts      jasongrout       1
#     110  jupyterlab  scipy2019-jupyterlab-tutorial         Carreau       2
#     111  jupyterlab             theme-cookiecutter       blink1073       3,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterlab in the last 31 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## Issues
#
# Issues are **conversations** that happen on our GitHub repositories. Here's an
# analysis of issues across the Jupyter organizations.

# %%
created = issues.query('state == "OPEN" and createdAt > @start_date and createdAt < @end_date')
closed = issues.query('state == "CLOSED" and closedAt > @start_date and closedAt < @end_date')

# %%
created_counts = created.groupby(['org', 'repo']).count()['number'].reset_index()
created_counts['org/repo'] = created_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = created_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=created_counts, title=f"Issues created in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                        repo  number  \
#   0           ipython                   ipykernel       3
#   1           ipython                 ipyparallel       4
#   2           ipython                     ipython      10
#   3           ipython            ipython-in-depth       1
#   4           jupyter               docker-stacks       2
#   5           jupyter                     jupyter       3
#   6           jupyter                jupyter-book       1
#   7           jupyter              jupyter-sphinx       6
#   8           jupyter           jupyter.github.io       1
#   9           jupyter              jupyter_client       1
#   10          jupyter                jupyter_core       1
#   11          jupyter                       nb2kg       2
#   12          jupyter                   nbconvert       2
#   13          jupyter                    notebook      24
#   14          jupyter                   qtconsole       2
#   15          jupyter                 repo2docker       7
#   16          jupyter                   telemetry       1
#   17          jupyter                    testpath       1
#   18  jupyter-widgets                  ipyleaflet       3
#   19  jupyter-widgets                  ipywidgets      29
#   20  jupyter-widgets          jupyterlab-sidecar       4
#   21  jupyter-widgets                   pythreejs       1
#   22       jupyterhub                batchspawner       4
#   23       jupyterhub                      binder       3
#   24       jupyterhub                   binderhub      12
#   25       jupyterhub               dockerspawner       2
#   26       jupyterhub                  helm-chart       1
#   27       jupyterhub        jupyter-server-proxy       3
#   28       jupyterhub                  jupyterhub      20
#   29       jupyterhub  jupyterhub-deploy-teaching       1
#   30       jupyterhub                 kubespawner       4
#   31       jupyterhub           ldapauthenticator       4
#   32       jupyterhub         mybinder.org-deploy       3
#   33       jupyterhub         nativeauthenticator       1
#   34       jupyterhub              oauthenticator       2
#   35       jupyterhub               simplespawner       1
#   36       jupyterhub                 sudospawner       1
#   37       jupyterhub              systemdspawner       3
#   38       jupyterhub                team-compass       7
#   39       jupyterhub     the-littlest-jupyterhub       9
#   40       jupyterhub               traefik-proxy       1
#   41       jupyterhub                 wrapspawner       1
#   42       jupyterhub      zero-to-jupyterhub-k8s      11
#   43       jupyterlab           jupyter-renderers       2
#   44       jupyterlab                  jupyterlab      72
#   45       jupyterlab         jupyterlab-celltags       3
#   46       jupyterlab       jupyterlab-commenting       1
#   47       jupyterlab    jupyterlab-data-explorer      11
#   48       jupyterlab              jupyterlab-git       6
#   49       jupyterlab           jupyterlab-monaco       1
#   50       jupyterlab              jupyterlab-toc       1
#   51       jupyterlab             jupyterlab_apod       1
#   52       jupyterlab                team-compass       2
#
#                                    org/repo
#   0                       ipython/ipykernel
#   1                     ipython/ipyparallel
#   2                         ipython/ipython
#   3                ipython/ipython-in-depth
#   4                   jupyter/docker-stacks
#   5                         jupyter/jupyter
#   6                    jupyter/jupyter-book
#   7                  jupyter/jupyter-sphinx
#   8               jupyter/jupyter.github.io
#   9                  jupyter/jupyter_client
#   10                   jupyter/jupyter_core
#   11                          jupyter/nb2kg
#   12                      jupyter/nbconvert
#   13                       jupyter/notebook
#   14                      jupyter/qtconsole
#   15                    jupyter/repo2docker
#   16                      jupyter/telemetry
#   17                       jupyter/testpath
#   18             jupyter-widgets/ipyleaflet
#   19             jupyter-widgets/ipywidgets
#   20     jupyter-widgets/jupyterlab-sidecar
#   21              jupyter-widgets/pythreejs
#   22                jupyterhub/batchspawner
#   23                      jupyterhub/binder
#   24                   jupyterhub/binderhub
#   25               jupyterhub/dockerspawner
#   26                  jupyterhub/helm-chart
#   27        jupyterhub/jupyter-server-proxy
#   28                  jupyterhub/jupyterhub
#   29  jupyterhub/jupyterhub-deploy-teaching
#   30                 jupyterhub/kubespawner
#   31           jupyterhub/ldapauthenticator
#   32         jupyterhub/mybinder.org-deploy
#   33         jupyterhub/nativeauthenticator
#   34              jupyterhub/oauthenticator
#   35               jupyterhub/simplespawner
#   36                 jupyterhub/sudospawner
#   37              jupyterhub/systemdspawner
#   38                jupyterhub/team-compass
#   39     jupyterhub/the-littlest-jupyterhub
#   40               jupyterhub/traefik-proxy
#   41                 jupyterhub/wrapspawner
#   42      jupyterhub/zero-to-jupyterhub-k8s
#   43           jupyterlab/jupyter-renderers
#   44                  jupyterlab/jupyterlab
#   45         jupyterlab/jupyterlab-celltags
#   46       jupyterlab/jupyterlab-commenting
#   47    jupyterlab/jupyterlab-data-explorer
#   48              jupyterlab/jupyterlab-git
#   49           jupyterlab/jupyterlab-monaco
#   50              jupyterlab/jupyterlab-toc
#   51             jupyterlab/jupyterlab_apod
#   52                jupyterlab/team-compass  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['jupyterlab', 'jupyterlab-data-explorer', 'jupyterlab-git', 'jupyterlab-celltags', 'jupyter-renderers', 'team-compass', 'jupyterlab-commenting', 'jupyterlab-monaco', 'jupyterlab-toc', 'jupyterlab_apod', 'jupyterhub', 'binderhub', 'zero-to-jupyterhub-k8s', 'the-littlest-jupyterhub', 'team-compass', 'batchspawner', 'kubespawner', 'ldapauthenticator', 'binder', 'jupyter-server-proxy', 'mybinder.org-deploy', 'systemdspawner', 'dockerspawner', 'oauthenticator', 'helm-chart', 'jupyterhub-deploy-teaching', 'nativeauthenticator', 'simplespawner', 'sudospawner', 'traefik-proxy', 'wrapspawner', 'ipywidgets', 'jupyterlab-sidecar', 'ipyleaflet', 'pythreejs', 'notebook', 'repo2docker', 'jupyter-sphinx', 'jupyter', 'docker-stacks', 'nb2kg', 'nbconvert', 'qtconsole', 'jupyter-book', 'jupyter.github.io', 'jupyter_client', 'jupyter_core', 'telemetry', 'testpath', 'ipython', 'ipyparallel', 'ipykernel', 'ipython-in-depth']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues created in the last 31 days'
# })

# %%
closed_counts = closed.groupby(['org', 'repo']).count()['number'].reset_index()
closed_counts['org/repo'] = closed_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = closed_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=closed_counts, title=f"Issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                       repo  number  \
#   0   binder-examples                 demo-julia       1
#   1           ipython                  ipykernel       1
#   2           ipython                    ipython      19
#   3           ipython                  traitlets       1
#   4           jupyter              docker-stacks       8
#   5           jupyter         enterprise_gateway       6
#   6           jupyter                    jupyter       2
#   7           jupyter               jupyter-book      16
#   8           jupyter             jupyter-sphinx      10
#   9           jupyter          jupyter.github.io       1
#   10          jupyter             jupyter_client       7
#   11          jupyter             jupyter_server       1
#   12          jupyter                      nb2kg       2
#   13          jupyter                  nbconvert       8
#   14          jupyter                     nbdime       3
#   15          jupyter                   nbviewer       3
#   16          jupyter                   notebook      15
#   17          jupyter                  qtconsole       2
#   18          jupyter                repo2docker       5
#   19          jupyter                  telemetry       3
#   20  jupyter-widgets                 ipyleaflet       4
#   21  jupyter-widgets                 ipywidgets      18
#   22  jupyter-widgets         jupyterlab-sidecar       1
#   23  jupyter-widgets               midicontrols       1
#   24  jupyter-widgets                  pythreejs       2
#   25  jupyter-widgets                   tutorial       1
#   26       jupyterhub               batchspawner       3
#   27       jupyterhub                  binderhub       4
#   28       jupyterhub              dockerspawner       3
#   29       jupyterhub       jupyter-server-proxy       1
#   30       jupyterhub                 jupyterhub       9
#   31       jupyterhub      kerberosauthenticator       1
#   32       jupyterhub                kubespawner       3
#   33       jupyterhub          ldapauthenticator       2
#   34       jupyterhub        mybinder.org-deploy       2
#   35       jupyterhub                nbgitpuller       1
#   36       jupyterhub               team-compass      16
#   37       jupyterhub    the-littlest-jupyterhub       5
#   38       jupyterhub              traefik-proxy       3
#   39       jupyterhub     zero-to-jupyterhub-k8s       9
#   40       jupyterlab  extension-cookiecutter-js       1
#   41       jupyterlab          jupyter-renderers       7
#   42       jupyterlab                 jupyterlab      59
#   43       jupyterlab      jupyterlab-commenting       1
#   44       jupyterlab   jupyterlab-data-explorer       7
#   45       jupyterlab             jupyterlab-git       5
#   46       jupyterlab             jupyterlab-toc       2
#   47       jupyterlab               team-compass       1
#
#                                   org/repo
#   0             binder-examples/demo-julia
#   1                      ipython/ipykernel
#   2                        ipython/ipython
#   3                      ipython/traitlets
#   4                  jupyter/docker-stacks
#   5             jupyter/enterprise_gateway
#   6                        jupyter/jupyter
#   7                   jupyter/jupyter-book
#   8                 jupyter/jupyter-sphinx
#   9              jupyter/jupyter.github.io
#   10                jupyter/jupyter_client
#   11                jupyter/jupyter_server
#   12                         jupyter/nb2kg
#   13                     jupyter/nbconvert
#   14                        jupyter/nbdime
#   15                      jupyter/nbviewer
#   16                      jupyter/notebook
#   17                     jupyter/qtconsole
#   18                   jupyter/repo2docker
#   19                     jupyter/telemetry
#   20            jupyter-widgets/ipyleaflet
#   21            jupyter-widgets/ipywidgets
#   22    jupyter-widgets/jupyterlab-sidecar
#   23          jupyter-widgets/midicontrols
#   24             jupyter-widgets/pythreejs
#   25              jupyter-widgets/tutorial
#   26               jupyterhub/batchspawner
#   27                  jupyterhub/binderhub
#   28              jupyterhub/dockerspawner
#   29       jupyterhub/jupyter-server-proxy
#   30                 jupyterhub/jupyterhub
#   31      jupyterhub/kerberosauthenticator
#   32                jupyterhub/kubespawner
#   33          jupyterhub/ldapauthenticator
#   34        jupyterhub/mybinder.org-deploy
#   35                jupyterhub/nbgitpuller
#   36               jupyterhub/team-compass
#   37    jupyterhub/the-littlest-jupyterhub
#   38              jupyterhub/traefik-proxy
#   39     jupyterhub/zero-to-jupyterhub-k8s
#   40  jupyterlab/extension-cookiecutter-js
#   41          jupyterlab/jupyter-renderers
#   42                 jupyterlab/jupyterlab
#   43      jupyterlab/jupyterlab-commenting
#   44   jupyterlab/jupyterlab-data-explorer
#   45             jupyterlab/jupyterlab-git
#   46             jupyterlab/jupyterlab-toc
#   47               jupyterlab/team-compass  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['jupyterlab', 'jupyter-renderers', 'jupyterlab-data-explorer', 'jupyterlab-git', 'jupyterlab-toc', 'extension-cookiecutter-js', 'jupyterlab-commenting', 'team-compass', 'team-compass', 'jupyterhub', 'zero-to-jupyterhub-k8s', 'the-littlest-jupyterhub', 'binderhub', 'batchspawner', 'dockerspawner', 'kubespawner', 'traefik-proxy', 'ldapauthenticator', 'mybinder.org-deploy', 'jupyter-server-proxy', 'kerberosauthenticator', 'nbgitpuller', 'ipywidgets', 'ipyleaflet', 'pythreejs', 'jupyterlab-sidecar', 'midicontrols', 'tutorial', 'jupyter-book', 'notebook', 'jupyter-sphinx', 'docker-stacks', 'nbconvert', 'jupyter_client', 'enterprise_gateway', 'repo2docker', 'nbdime', 'nbviewer', 'telemetry', 'jupyter', 'nb2kg', 'qtconsole', 'jupyter.github.io', 'jupyter_server', 'ipython', 'ipykernel', 'traitlets', 'demo-julia']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues closed in the last 31 days'
# })

# %%
created_closed = pd.merge(created_counts.rename(columns={'number': 'created'}).drop(columns='org/repo'),
                          closed_counts.rename(columns={'number': 'closed'}).drop(columns='org/repo'),
                          on=['org', 'repo'], how='outer')

created_closed = pd.melt(created_closed, id_vars=['org', 'repo'], var_name="kind", value_name="count").replace(np.nan, 0)

# %%
charts = []
for org in github_orgs:
    # Pick the top 10 repositories
    this_issues = created_closed.query('org == @org')
    top_repos = this_issues.groupby(['repo']).sum().sort_values(by='count', ascending=False).head(10).index
    ch = alt.Chart(this_issues.query('repo in @top_repos'), width=120).mark_bar().encode(
        x=alt.X("kind", axis=alt.Axis(labelFontSize=15, title="")), 
        y=alt.Y('count', axis=alt.Axis(titleFontSize=15, labelFontSize=12)),
        color='kind',
        column=alt.Column("repo", header=alt.Header(title=f"Issue activity, last {n_days} days for {org}", titleFontSize=15, labelFontSize=12))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             org                       repo     kind  count
#     43   jupyterlab          jupyter-renderers  created    2.0
#     44   jupyterlab                 jupyterlab  created   72.0
#     45   jupyterlab        jupyterlab-celltags  created    3.0
#     46   jupyterlab      jupyterlab-commenting  created    1.0
#     47   jupyterlab   jupyterlab-data-explorer  created   11.0
#     48   jupyterlab             jupyterlab-git  created    6.0
#     49   jupyterlab          jupyterlab-monaco  created    1.0
#     50   jupyterlab             jupyterlab-toc  created    1.0
#     52   jupyterlab               team-compass  created    2.0
#     63   jupyterlab  extension-cookiecutter-js  created    0.0
#     107  jupyterlab          jupyter-renderers   closed    7.0
#     108  jupyterlab                 jupyterlab   closed   59.0
#     109  jupyterlab        jupyterlab-celltags   closed    0.0
#     110  jupyterlab      jupyterlab-commenting   closed    1.0
#     111  jupyterlab   jupyterlab-data-explorer   closed    7.0
#     112  jupyterlab             jupyterlab-git   closed    5.0
#     113  jupyterlab          jupyterlab-monaco   closed    0.0
#     114  jupyterlab             jupyterlab-toc   closed    2.0
#     116  jupyterlab               team-compass   closed    1.0
#     127  jupyterlab  extension-cookiecutter-js   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyterlab',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org              repo     kind  count
#     0    ipython         ipykernel  created    3.0
#     1    ipython       ipyparallel  created    4.0
#     2    ipython           ipython  created   10.0
#     3    ipython  ipython-in-depth  created    1.0
#     54   ipython         traitlets  created    0.0
#     64   ipython         ipykernel   closed    1.0
#     65   ipython       ipyparallel   closed    0.0
#     66   ipython           ipython   closed   19.0
#     67   ipython  ipython-in-depth   closed    0.0
#     118  ipython         traitlets   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for ipython',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                  org                repo     kind  count
#     18   jupyter-widgets          ipyleaflet  created    3.0
#     19   jupyter-widgets          ipywidgets  created   29.0
#     20   jupyter-widgets  jupyterlab-sidecar  created    4.0
#     21   jupyter-widgets           pythreejs  created    1.0
#     59   jupyter-widgets        midicontrols  created    0.0
#     60   jupyter-widgets            tutorial  created    0.0
#     82   jupyter-widgets          ipyleaflet   closed    4.0
#     83   jupyter-widgets          ipywidgets   closed   18.0
#     84   jupyter-widgets  jupyterlab-sidecar   closed    1.0
#     85   jupyter-widgets           pythreejs   closed    2.0
#     123  jupyter-widgets        midicontrols   closed    1.0
#     124  jupyter-widgets            tutorial   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyter-widgets',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                  org        repo     kind  count
#     53   binder-examples  demo-julia  created    0.0
#     117  binder-examples  demo-julia   closed    1.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for binder-examples',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org                repo     kind  count
#     4    jupyter       docker-stacks  created    2.0
#     5    jupyter             jupyter  created    3.0
#     6    jupyter        jupyter-book  created    1.0
#     7    jupyter      jupyter-sphinx  created    6.0
#     9    jupyter      jupyter_client  created    1.0
#     12   jupyter           nbconvert  created    2.0
#     13   jupyter            notebook  created   24.0
#     15   jupyter         repo2docker  created    7.0
#     16   jupyter           telemetry  created    1.0
#     55   jupyter  enterprise_gateway  created    0.0
#     68   jupyter       docker-stacks   closed    8.0
#     69   jupyter             jupyter   closed    2.0
#     70   jupyter        jupyter-book   closed   16.0
#     71   jupyter      jupyter-sphinx   closed   10.0
#     73   jupyter      jupyter_client   closed    7.0
#     76   jupyter           nbconvert   closed    8.0
#     77   jupyter            notebook   closed   15.0
#     79   jupyter         repo2docker   closed    5.0
#     80   jupyter           telemetry   closed    3.0
#     119  jupyter  enterprise_gateway   closed    6.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyter',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:             org                     repo     kind  count
#     22   jupyterhub             batchspawner  created    4.0
#     24   jupyterhub                binderhub  created   12.0
#     25   jupyterhub            dockerspawner  created    2.0
#     28   jupyterhub               jupyterhub  created   20.0
#     30   jupyterhub              kubespawner  created    4.0
#     31   jupyterhub        ldapauthenticator  created    4.0
#     32   jupyterhub      mybinder.org-deploy  created    3.0
#     38   jupyterhub             team-compass  created    7.0
#     39   jupyterhub  the-littlest-jupyterhub  created    9.0
#     42   jupyterhub   zero-to-jupyterhub-k8s  created   11.0
#     86   jupyterhub             batchspawner   closed    3.0
#     88   jupyterhub                binderhub   closed    4.0
#     89   jupyterhub            dockerspawner   closed    3.0
#     92   jupyterhub               jupyterhub   closed    9.0
#     94   jupyterhub              kubespawner   closed    3.0
#     95   jupyterhub        ldapauthenticator   closed    2.0
#     96   jupyterhub      mybinder.org-deploy   closed    2.0
#     102  jupyterhub             team-compass   closed   16.0
#     103  jupyterhub  the-littlest-jupyterhub   closed    5.0
#     106  jupyterhub   zero-to-jupyterhub-k8s   closed    9.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 31 days for jupyterhub',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   })]
# })

# %%
# Set to datetime
for kind in ['createdAt', 'closedAt']:
    closed.loc[:, kind] = pd.to_datetime(closed[kind])
    
closed.loc[:, 'time_open'] = closed['closedAt'] - closed['createdAt']
closed.loc[:, 'time_open'] = closed['time_open'].dt.total_seconds()

# %%
time_open = closed.groupby(['org', 'repo']).agg({'time_open': 'median'}).reset_index()
time_open['time_open'] = time_open['time_open'] / (60 * 60 * 24)
time_open['org/repo'] = time_open.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = time_open.sort_values(['org', 'time_open'], ascending=False)['repo'].values
alt.Chart(data=time_open, title=f"Time to close for issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y=alt.Y('time_open', title="Median Days Open"),
    color='org',
)
# Out:
# Chart({
#   data:                 org                       repo   time_open  \
#   0   binder-examples                 demo-julia    6.085058
#   1           ipython                  ipykernel   34.939491
#   2           ipython                    ipython    6.007373
#   3           ipython                  traitlets    0.001817
#   4           jupyter              docker-stacks   29.893924
#   5           jupyter         enterprise_gateway    6.011175
#   6           jupyter                    jupyter  115.932251
#   7           jupyter               jupyter-book   81.046586
#   8           jupyter             jupyter-sphinx    6.007975
#   9           jupyter          jupyter.github.io    2.754988
#   10          jupyter             jupyter_client    9.848565
#   11          jupyter             jupyter_server    6.048576
#   12          jupyter                      nb2kg   10.164954
#   13          jupyter                  nbconvert  323.023571
#   14          jupyter                     nbdime   10.806308
#   15          jupyter                   nbviewer   27.010463
#   16          jupyter                   notebook   16.943368
#   17          jupyter                  qtconsole    6.688837
#   18          jupyter                repo2docker    2.884236
#   19          jupyter                  telemetry    0.930949
#   20  jupyter-widgets                 ipyleaflet    8.565475
#   21  jupyter-widgets                 ipywidgets    7.011470
#   22  jupyter-widgets         jupyterlab-sidecar   16.910301
#   23  jupyter-widgets               midicontrols    3.001574
#   24  jupyter-widgets                  pythreejs    2.115446
#   25  jupyter-widgets                   tutorial    2.426273
#   26       jupyterhub               batchspawner  247.168843
#   27       jupyterhub                  binderhub    1.544005
#   28       jupyterhub              dockerspawner    3.970845
#   29       jupyterhub       jupyter-server-proxy    0.577951
#   30       jupyterhub                 jupyterhub   19.687465
#   31       jupyterhub      kerberosauthenticator   35.502523
#   32       jupyterhub                kubespawner    5.357789
#   33       jupyterhub          ldapauthenticator   13.380573
#   34       jupyterhub        mybinder.org-deploy   12.693681
#   35       jupyterhub                nbgitpuller    0.008333
#   36       jupyterhub               team-compass   72.433993
#   37       jupyterhub    the-littlest-jupyterhub   48.672465
#   38       jupyterhub              traefik-proxy    0.844363
#   39       jupyterhub     zero-to-jupyterhub-k8s    8.797431
#   40       jupyterlab  extension-cookiecutter-js    0.977616
#   41       jupyterlab          jupyter-renderers  328.480972
#   42       jupyterlab                 jupyterlab    4.221053
#   43       jupyterlab      jupyterlab-commenting   14.237836
#   44       jupyterlab   jupyterlab-data-explorer    5.240394
#   45       jupyterlab             jupyterlab-git   32.688519
#   46       jupyterlab             jupyterlab-toc    1.095272
#   47       jupyterlab               team-compass    7.733113
#
#                                   org/repo
#   0             binder-examples/demo-julia
#   1                      ipython/ipykernel
#   2                        ipython/ipython
#   3                      ipython/traitlets
#   4                  jupyter/docker-stacks
#   5             jupyter/enterprise_gateway
#   6                        jupyter/jupyter
#   7                   jupyter/jupyter-book
#   8                 jupyter/jupyter-sphinx
#   9              jupyter/jupyter.github.io
#   10                jupyter/jupyter_client
#   11                jupyter/jupyter_server
#   12                         jupyter/nb2kg
#   13                     jupyter/nbconvert
#   14                        jupyter/nbdime
#   15                      jupyter/nbviewer
#   16                      jupyter/notebook
#   17                     jupyter/qtconsole
#   18                   jupyter/repo2docker
#   19                     jupyter/telemetry
#   20            jupyter-widgets/ipyleaflet
#   21            jupyter-widgets/ipywidgets
#   22    jupyter-widgets/jupyterlab-sidecar
#   23          jupyter-widgets/midicontrols
#   24             jupyter-widgets/pythreejs
#   25              jupyter-widgets/tutorial
#   26               jupyterhub/batchspawner
#   27                  jupyterhub/binderhub
#   28              jupyterhub/dockerspawner
#   29       jupyterhub/jupyter-server-proxy
#   30                 jupyterhub/jupyterhub
#   31      jupyterhub/kerberosauthenticator
#   32                jupyterhub/kubespawner
#   33          jupyterhub/ldapauthenticator
#   34        jupyterhub/mybinder.org-deploy
#   35                jupyterhub/nbgitpuller
#   36               jupyterhub/team-compass
#   37    jupyterhub/the-littlest-jupyterhub
#   38              jupyterhub/traefik-proxy
#   39     jupyterhub/zero-to-jupyterhub-k8s
#   40  jupyterlab/extension-cookiecutter-js
#   41          jupyterlab/jupyter-renderers
#   42                 jupyterlab/jupyterlab
#   43      jupyterlab/jupyterlab-commenting
#   44   jupyterlab/jupyterlab-data-explorer
#   45             jupyterlab/jupyterlab-git
#   46             jupyterlab/jupyterlab-toc
#   47               jupyterlab/team-compass  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['jupyter-renderers', 'jupyterlab-git', 'jupyterlab-commenting', 'team-compass', 'jupyterlab-data-explorer', 'jupyterlab', 'jupyterlab-toc', 'extension-cookiecutter-js', 'batchspawner', 'team-compass', 'the-littlest-jupyterhub', 'kerberosauthenticator', 'jupyterhub', 'ldapauthenticator', 'mybinder.org-deploy', 'zero-to-jupyterhub-k8s', 'kubespawner', 'dockerspawner', 'binderhub', 'traefik-proxy', 'jupyter-server-proxy', 'nbgitpuller', 'jupyterlab-sidecar', 'ipyleaflet', 'ipywidgets', 'midicontrols', 'tutorial', 'pythreejs', 'nbconvert', 'jupyter', 'jupyter-book', 'docker-stacks', 'nbviewer', 'notebook', 'nbdime', 'nb2kg', 'jupyter_client', 'qtconsole', 'jupyter_server', 'enterprise_gateway', 'jupyter-sphinx', 'repo2docker', 'jupyter.github.io', 'telemetry', 'ipykernel', 'ipython', 'traitlets', 'demo-julia']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'time_open',
#       title: 'Median Days Open',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Time to close for issues closed in the last 31 days'
# })

# %% [markdown]
# ### A list of recent issues
#
# Below is a list of issues with recent activity in each repository. If they seem of interest
# to you, click on their links and jump in to participate!

# %%
# Add comment count data to issues and PRs
comment_counts = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'issue_id'])
    .count().iloc[:, 0].to_frame()
)
comment_counts.columns = ['n_comments']
comment_counts = comment_counts.reset_index()

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, (org, idata) in enumerate(comment_counts.groupby('org')):
    issue_md = []
    issue_md.append(f"#### {org}")
    issue_md.append("")
    for repo, i_issues in idata.groupby('repo'):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")

        top_issues = i_issues.sort_values('n_comments', ascending=False).head(n_plot)
        top_issue_list = pd.merge(issues, top_issues, left_on=['org', 'repo', 'number'], right_on=['org', 'repo', 'issue_id'])
        for _, issue in top_issue_list.sort_values('n_comments', ascending=False).head(n_plot).iterrows():
            user_name = issue['author']
            user_url = author_url(user_name)
            issue_number = issue['number']
            issue_html = issue['url']
            issue_title = issue['title']

            text = f"* [(#{issue_number})]({issue_html}): _{issue_title}_ by **[@{user_name}]({user_url})**"
            issue_md.append(text)

    issue_md.append('')
    md_html = HTML(markdown('\n'.join(issue_md)))
    
    children = list(tabs.children)
    children.append(HTML(markdown('\n'.join(issue_md))))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"Here are the top {n_plot} active issues in each repository in the last {n_days} days"))
display(tabs)
# Out:
# Here are the top 5 active issues in each repository in the last 31 days
# Tab(children=(HTML(value='<h4>binder-examples</h4>\n<h5><a href="https://github.com/binder-examples/data-quilt…

# %% [markdown]
# ## Commenters across repositories
#
# These are commenters across all issues and pull requests in the last several days.
# These are colored by the commenter's association with the organization. For information
# about what these associations mean, [see this StackOverflow post](https://stackoverflow.com/a/28866914/1927102).

# %%
commentors = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'author', 'authorAssociation'])
    .count().rename(columns={'id': 'count'})['count']
    .reset_index()
    .sort_values(['org', 'count'], ascending=False)
)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(commentors.groupby(['org'])):
    title = f"Top {n_plot} commentors for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'count': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('count', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='count',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:          author  count authorAssociation
#     1     choldgraf      3            MEMBER
#     2   cornhundred      2              NONE
#     0       betatim      1            MEMBER
#     3  davidanthoff      1       CONTRIBUTOR
#     4   matheusmota      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                     author  count authorAssociation
#     4                  Carreau     66            MEMBER
#     10                   MSeal      7       CONTRIBUTOR
#     76               tacaswell      6       CONTRIBUTOR
#     69                 pdeitel      5              NONE
#     70                rmorshea      5      COLLABORATOR
#     64                   minrk      4            MEMBER
#     26               blink1073      4            MEMBER
#     55             kevin-bates      3       CONTRIBUTOR
#     15        RafalSkolasinski      3              NONE
#     24                 anntzer      3       CONTRIBUTOR
#     9           LucianaMarques      3       CONTRIBUTOR
#     42                gpotter2      3       CONTRIBUTOR
#     38                fehiepsi      2              NONE
#     40            flying-sheep      2       CONTRIBUTOR
#     37                ericdill      2              NONE
#     68                oscargus      2              NONE
#     30              ccordoba12      2       CONTRIBUTOR
#     79              thrasibule      2              NONE
#     46              jamesmyatt      2              NONE
#     8                    Jamim      2       CONTRIBUTOR
#     31                cottrell      2       CONTRIBUTOR
#     82                voronind      2              NONE
#     83                 wenjuno      2              NONE
#     84                willingc      2            MEMBER
#     51                jseabold      2       CONTRIBUTOR
#     60                m0nzderr      1              NONE
#     57                   kribu      1              NONE
#     59                 leogout      1              NONE
#     58               leifwalsh      1              NONE
#     62              matthewgdv      1              NONE
#     56                khughitt      1              NONE
#     54                   kernc      1              NONE
#     53               keflavich      1              NONE
#     61                  mag-al      1              NONE
#     0   AbsurdMagpieScrutinies      1              NONE
#     63         maxwellmckinnon      1              NONE
#     65                 mjkvaak      1              NONE
#     66                    mx73      1              NONE
#     67                 nschloe      1              NONE
#     71                 scopatz      1       CONTRIBUTOR
#     72               smerzbach      1              NONE
#     73            sowmyakavali      1              NONE
#     74          stuartthomas25      1              NONE
#     75                 sunpoet      1       CONTRIBUTOR
#     77                 tbeadle      1              NONE
#     78              texadactyl      1              NONE
#     80                  torbjo      1              NONE
#     81             vinklibrary      1              NONE
#     85               yamasampo      1              NONE
#     52              juanis2112      1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     71          betatim     50            MEMBER
#     86        choldgraf     42            MEMBER
#     45    SylvainCorlay     42            MEMBER
#     203           minrk     40            MEMBER
#     171     kevin-bates     37            MEMBER
#     34            MSeal     35            MEMBER
#     221         parente     33            MEMBER
#     61         akhmerov     27            MEMBER
#     52          Zsailer     24            MEMBER
#     176        krinsman     23       CONTRIBUTOR
#     265       takluyver     23            MEMBER
#     280         vidartf     22      COLLABORATOR
#     157      jasongrout     20            MEMBER
#     293       yuvipanda     19            MEMBER
#     263        t-makaro     15      COLLABORATOR
#     154      jaipreet-s     14              NONE
#     23         IMAM9AIS     12              NONE
#     126          esevan     11       CONTRIBUTOR
#     82       ccordoba12     11      COLLABORATOR
#     100      davidrpugh     10       CONTRIBUTOR
#     13          Carreau     10            MEMBER
#     231     psychemedia      9              NONE
#     90     consideRatio      9      COLLABORATOR
#     286        willingc      7            MEMBER
#     159        jbweston      7            MEMBER
#     112           dleen      7       CONTRIBUTOR
#     188        lresende      6            MEMBER
#     285       westurner      6              NONE
#     151        itamarst      6              NONE
#     282   vikasgarg1996      6       CONTRIBUTOR
#     233       raghavven      5              NONE
#     185        llinfeng      5              NONE
#     121         emdupre      5      COLLABORATOR
#     243        rolweber      5      COLLABORATOR
#     149    hugokerstens      5       CONTRIBUTOR
#     116       eexwhyzee      5       CONTRIBUTOR
#     216          njapke      5              NONE
#     266        taohan16      4       CONTRIBUTOR
#     253        scottyhq      4              NONE
#     131    flying-sheep      4       CONTRIBUTOR
#     287      wmvanvliet      4      COLLABORATOR
#     169        jyu78749      4              NONE
#     144           hadim      4              NONE
#     98         dalthviz      4       CONTRIBUTOR
#     247         rubensa      4              NONE
#     205          mpacer      3            MEMBER
#     250  saulshanabrook      3       CONTRIBUTOR
#     101      dbeniamine      3              NONE
#     208         mwcraig      3       CONTRIBUTOR
#     70        bavaria95      3              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                  author  count authorAssociation
#     23           jasongrout     64            MEMBER
#     47              vidartf     34            MEMBER
#     3         SylvainCorlay     31            MEMBER
#     29          martinRenou     20            MEMBER
#     20                hainm     12              NONE
#     35              mwcraig     12       CONTRIBUTOR
#     45             stonebig      8       CONTRIBUTOR
#     7                ataiya      8       CONTRIBUTOR
#     33              moki298      8              NONE
#     28      maartenbreddels      5            MEMBER
#     16        cosmoscalibur      4              NONE
#     12           bill-coman      4              NONE
#     42                sfluo      3              NONE
#     37               piorek      3              NONE
#     11          bernhard-42      3              NONE
#     18           doutriaux1      3              NONE
#     44         stojan-jovic      3              NONE
#     8          banesullivan      3              NONE
#     49          xilunaJumma      3              NONE
#     24               jmmshn      2              NONE
#     41           rskabelund      2              NONE
#     43         solomonvimal      2              NONE
#     51              zerline      2       CONTRIBUTOR
#     26                jtpio      2       CONTRIBUTOR
#     52          zxzhaixiang      2              NONE
#     22            jakirkham      2              NONE
#     4                afshin      2       CONTRIBUTOR
#     25          jquacinella      1              NONE
#     40         romain-intel      1              NONE
#     2           Martinschei      1              NONE
#     50         yatashashank      1              NONE
#     48              waydegg      1              NONE
#     5    amirhosseindavoody      1              NONE
#     46              swayson      1              NONE
#     6        artur-trzesiok      1              NONE
#     9               bbettss      1              NONE
#     10              bermani      1              NONE
#     13              chaffra      1              NONE
#     14            choldgraf      1              NONE
#     39              rchiodo      1              NONE
#     1             Juanlu001      1       CONTRIBUTOR
#     38               piyueh      1              NONE
#     15          cornhundred      1       CONTRIBUTOR
#     36          paulathomas      1              NONE
#     17             dazzag24      1              NONE
#     34     mrinalraghupathi      1              NONE
#     19            dovahcrow      1              NONE
#     32             mkhorton      1              NONE
#     31                metya      1              NONE
#     30  mathematicalmichael      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                 author  count authorAssociation
#     34             betatim     89            MEMBER
#     39           choldgraf     81            MEMBER
#     92               minrk     49            MEMBER
#     8       GeorgianaElena     49            MEMBER
#     42        consideRatio     28            MEMBER
#     134          yuvipanda     18            MEMBER
#     133           wqh17101     18              NONE
#     117          sgibson91     17            MEMBER
#     96          nicorikken     17       CONTRIBUTOR
#     67              jcrist     14            MEMBER
#     109            rkdarst     13       CONTRIBUTOR
#     132           willingc      8            MEMBER
#     85              manics      8              NONE
#     62              henchc      7            MEMBER
#     25      albertmichaelj      6              NONE
#     79           lakshaykc      6              NONE
#     82          m-alekseev      6              NONE
#     86     marcusianlevine      6       CONTRIBUTOR
#     28           alvinhuff      6              NONE
#     78     lachlancampbell      5              NONE
#     4         Edward-liang      5              NONE
#     35              bitnik      5       CONTRIBUTOR
#     26              alexal      5              NONE
#     10               Hoeze      5       CONTRIBUTOR
#     17              Yensan      5              NONE
#     13           JulianTBZ      5              NONE
#     118           shankari      5              NONE
#     43         cristiklein      4              NONE
#     50          diogozedan      4              NONE
#     95            nalui333      4              NONE
#     131           wierzba3      4              NONE
#     84         mael-le-gal      4            MEMBER
#     56            ericdill      4              NONE
#     9      GrahamDumpleton      4       CONTRIBUTOR
#     24            akhmerov      4              NONE
#     113         ryanlovett      4            MEMBER
#     30            asimb123      4              NONE
#     64        hugokerstens      4              NONE
#     115  sampathkethineedi      4              NONE
#     74         kevin-bates      3       CONTRIBUTOR
#     73     juliusvonkohout      3              NONE
#     15           TiemenSch      3              NONE
#     16         UCSBGauchos      3              NONE
#     63              hnykda      3              NONE
#     49         dhirschfeld      3      COLLABORATOR
#     57               fifar      3              NONE
#     0                BertR      3              NONE
#     19              ablekh      3              NONE
#     18             Zsailer      3            MEMBER
#     5              EvilMav      3              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                author  count authorAssociation
#     112        jasongrout    178            MEMBER
#     105        ian-r-rose     91            MEMBER
#     50          blink1073     65            MEMBER
#     188        telamonian     59            MEMBER
#     174    saulshanabrook     53            MEMBER
#     201           vidartf     51            MEMBER
#     129        krassowski     29            MEMBER
#     160        nickeubank     22              NONE
#     110        jaipreet-s     18      COLLABORATOR
#     84          ellisonbg     15            MEMBER
#     30             afshin     12            MEMBER
#     123             jtpio     12            MEMBER
#     87         fcollonval     10            MEMBER
#     72             dclong      9            MEMBER
#     202      vtrokhymenko      9              NONE
#     139        luispuerto      9              NONE
#     88             firasm      9              NONE
#     21        Queuecumber      8              NONE
#     97            gnestor      8            MEMBER
#     5              BoPeng      8            MEMBER
#     191         timkpaine      7            MEMBER
#     161         nscozzaro      7            MEMBER
#     59              ciyer      7            MEMBER
#     79            dsblank      6            MEMBER
#     90       flying-sheep      6              NONE
#     74        dharmaquark      6            MEMBER
#     63         daejong123      6              NONE
#     31          ajbozarth      6              NONE
#     89              flixr      5              NONE
#     56            chbrown      5              NONE
#     111         jakirkham      5              NONE
#     146      mayadebellis      5              NONE
#     106              ibqn      5              NONE
#     17            Madhu94      5            MEMBER
#     199             van-8      4            MEMBER
#     203          willingc      4            MEMBER
#     55             ceteri      4              NONE
#     27            Zsailer      4            MEMBER
#     57          choldgraf      4            MEMBER
#     51           bollwyvl      4            MEMBER
#     47            betatim      4              NONE
#     126        kdeleeuw11      4              NONE
#     68   david-waterworth      4              NONE
#     2         AlokTakshak      4       CONTRIBUTOR
#     134            levidd      4              NONE
#     192          tjbergst      4              NONE
#     120         jonmmease      4       CONTRIBUTOR
#     71             dbl001      3              NONE
#     75        dhirschfeld      3            MEMBER
#     67      danielgruesso      3       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterlab in the last 31 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## First responders
#
# First responders are the first people to respond to a new issue in one of the repositories.
# The following plots show first responders for recently-created issues.

# %%
first_comments = []
for (org, repo, issue_id), i_comments in comments.groupby(['org', 'repo', 'issue_id']):
    ix_min = pd.to_datetime(i_comments['createdAt']).idxmin()
    first_comment = i_comments.loc[ix_min]
    if isinstance(first_comment, pd.DataFrame):
        first_comment = first_comment.iloc[0]
    first_comments.append(first_comment)
first_comments = pd.concat(first_comments, axis=1).T

# %%
first_responder_counts = first_comments.groupby(['org', 'author', 'authorAssociation'], as_index=False).\
    count().rename(columns={'id': 'n_first_responses'}).sort_values(['org', 'n_first_responses'], ascending=False)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(first_responder_counts.groupby(['org'])):
    title = f"Top {n_plot} first responders for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'n_first_responses': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('n_first_responses', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='n_first_responses',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:         author  n_first_responses authorAssociation
#     0      betatim                  1            MEMBER
#     1    choldgraf                  1            MEMBER
#     2  cornhundred                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for binder-examples in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:             author  n_first_responses authorAssociation
#     2          Carreau                 30            MEMBER
#     54        willingc                  2            MEMBER
#     4            Jamim                  2       CONTRIBUTOR
#     0     Benjamin-Lee                  1              NONE
#     42      matthewgdv                  1              NONE
#     31          jdatin                  1              NONE
#     32  joaomarcosgris                  1              NONE
#     33       keflavich                  1              NONE
#     34           kernc                  1              NONE
#     35     kevin-bates                  1       CONTRIBUTOR
#     36        khughitt                  1              NONE
#     37           kribu                  1              NONE
#     38       leifwalsh                  1              NONE
#     39         leogout                  1              NONE
#     40        m0nzderr                  1              NONE
#     41          mag-al                  1              NONE
#     44         mjkvaak                  1              NONE
#     43           minrk                  1            MEMBER
#     29        janusson                  1              NONE
#     45            mx73                  1              NONE
#     46        oscargus                  1              NONE
#     47    sowmyakavali                  1              NONE
#     48  stuartthomas25                  1              NONE
#     49       tacaswell                  1              NONE
#     50         tbeadle                  1              NONE
#     51          torbjo                  1              NONE
#     52     vinklibrary                  1              NONE
#     53         wenjuno                  1              NONE
#     30      jasongrout                  1            MEMBER
#     28      jamesmyatt                  1              NONE
#     1       BryceHaley                  1              NONE
#     27        jaamarks                  1              NONE
#     3           Evidlo                  1              NONE
#     5   LucianaMarques                  1       CONTRIBUTOR
#     6            MSeal                  1       CONTRIBUTOR
#     7       OriolAbril                  1       CONTRIBUTOR
#     8    PietroPasotti                  1              NONE
#     9         Scowley4                  1              NONE
#     10       Shaliniyv                  1              NONE
#     11            Suor                  1              NONE
#     12      alexmojaki                  1              NONE
#     13      anentropic                  1              NONE
#     14       blink1073                  1            MEMBER
#     15       brakedust                  1              NONE
#     16     carrutstick                  1              NONE
#     17      ccordoba12                  1       CONTRIBUTOR
#     18     craymichael                  1              NONE
#     19    davidmakovoz                  1              NONE
#     20       davidnero                  1              NONE
#     21      denfromufa                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for ipython in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:             author  n_first_responses authorAssociation
#     156        parente                 21            MEMBER
#     64       choldgraf                 19            MEMBER
#     186      takluyver                 16            MEMBER
#     142          minrk                 15            MEMBER
#     54         betatim                 15            MEMBER
#     31   SylvainCorlay                 14            MEMBER
#     22           MSeal                 14            MEMBER
#     124       krinsman                 13       CONTRIBUTOR
#     121    kevin-bates                 11            MEMBER
#     184       t-makaro                 10      COLLABORATOR
#     197        vidartf                  8      COLLABORATOR
#     44        akhmerov                  8            MEMBER
#     205      yuvipanda                  8            MEMBER
#     7          Carreau                  6            MEMBER
#     37         Zsailer                  6            MEMBER
#     111     jaipreet-s                  6      COLLABORATOR
#     60      ccordoba12                  5      COLLABORATOR
#     91         emdupre                  4      COLLABORATOR
#     132       lresende                  3            MEMBER
#     94          esevan                  3      COLLABORATOR
#     114       jbweston                  3            MEMBER
#     163    psychemedia                  3              NONE
#     173        rubensa                  3              NONE
#     112     jasongrout                  3            MEMBER
#     204       yavalvas                  3              NONE
#     90       ellisonbg                  2            MEMBER
#     105         henchc                  2      COLLABORATOR
#     168        rkdarst                  2       CONTRIBUTOR
#     53       bavaria95                  2              NONE
#     199      wesinator                  2              NONE
#     120       jyu78749                  2              NONE
#     35       Yenthe666                  2              NONE
#     17           Jamim                  2       CONTRIBUTOR
#     131       louis925                  2              NONE
#     144         mpacer                  2            MEMBER
#     187       taohan16                  2       CONTRIBUTOR
#     108       itamarst                  2              NONE
#     69        cqcn1991                  2              NONE
#     28         Sefriol                  2              NONE
#     75        dalthviz                  2       CONTRIBUTOR
#     169       rolweber                  2      COLLABORATOR
#     133        lwasser                  1              NONE
#     134         manics                  1              NONE
#     135         maresb                  1              NONE
#     185      tacaswell                  1              NONE
#     136       mateolan                  1              NONE
#     137        mforbes                  1              NONE
#     138         mgeier                  1       CONTRIBUTOR
#     139          mhogg                  1              NONE
#     140     michaelaye                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                  author  n_first_responses authorAssociation
#     15           jasongrout                 16            MEMBER
#     3         SylvainCorlay                 12            MEMBER
#     31              vidartf                 10            MEMBER
#     21          martinRenou                  7            MEMBER
#     24              mwcraig                  7       CONTRIBUTOR
#     29         stojan-jovic                  2              NONE
#     10           doutriaux1                  2              NONE
#     35          zxzhaixiang                  2              NONE
#     34              zerline                  2       CONTRIBUTOR
#     30             stonebig                  1       CONTRIBUTOR
#     20      maartenbreddels                  1            MEMBER
#     32              waydegg                  1              NONE
#     27                sfluo                  1              NONE
#     26           rskabelund                  1              NONE
#     25          paulathomas                  1              NONE
#     33          xilunaJumma                  1              NONE
#     23                metya                  1              NONE
#     22  mathematicalmichael                  1              NONE
#     28         solomonvimal                  1              NONE
#     0                 Jamim                  1       CONTRIBUTOR
#     19            kgiacobbi                  1       CONTRIBUTOR
#     1             Juanlu001                  1       CONTRIBUTOR
#     17          jquacinella                  1              NONE
#     16               jmmshn                  1              NONE
#     14            jakirkham                  1              NONE
#     13               ivanov                  1       CONTRIBUTOR
#     12                hainm                  1              NONE
#     11            dovahcrow                  1              NONE
#     9           cornhundred                  1       CONTRIBUTOR
#     8             choldgraf                  1              NONE
#     7               chaffra                  1              NONE
#     6            bill-coman                  1              NONE
#     5    amirhosseindavoody                  1              NONE
#     4                afshin                  1       CONTRIBUTOR
#     2           Martinschei                  1              NONE
#     18                jtpio                  1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter-widgets in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                  author  n_first_responses authorAssociation
#     28              betatim                 30            MEMBER
#     7        GeorgianaElena                 23            MEMBER
#     31            choldgraf                 21            MEMBER
#     72                minrk                 20            MEMBER
#     96            yuvipanda                 11            MEMBER
#     34         consideRatio                 10            MEMBER
#     82              rkdarst                  7       CONTRIBUTOR
#     15               Yensan                  5              NONE
#     88            sgibson91                  5            MEMBER
#     76           nicorikken                  4       CONTRIBUTOR
#     65               manics                  3              NONE
#     95             wqh17101                  3              NONE
#     85           ryanlovett                  3            MEMBER
#     29               bitnik                  3       CONTRIBUTOR
#     66      marcusianlevine                  2       CONTRIBUTOR
#     38          dhirschfeld                  2      COLLABORATOR
#     37           danielmpla                  2              NONE
#     27   baijingetangzichen                  2              NONE
#     61            lakshaykc                  2              NONE
#     73             mpilosov                  2              NONE
#     52               jcrist                  2            MEMBER
#     3          Edward-liang                  2              NONE
#     55      juliusvonkohout                  2              NONE
#     90       stevenstetzler                  2              NONE
#     4               EvilMav                  2              NONE
#     9                 Hoeze                  2       CONTRIBUTOR
#     86    sampathkethineedi                  2              NONE
#     18           aboutaaron                  2              NONE
#     80      ramkrishnan8994                  1              NONE
#     64          mael-le-gal                  1            MEMBER
#     67            maroshmka                  1              NONE
#     91          stormerider                  1              NONE
#     63             lresende                  1      COLLABORATOR
#     69           mbmilligan                  1            MEMBER
#     62               limbuu                  1              NONE
#     92               sysang                  1              NONE
#     60      lachlancampbell                  1              NONE
#     59                kkr78                  1              NONE
#     58            kipstakkr                  1              NONE
#     57              kevmk04                  1              NONE
#     68  mathematicalmichael                  1              NONE
#     71      michaelmiaomiao                  1              NONE
#     70              mgresko                  1              NONE
#     79            raethlein                  1              NONE
#     89              sqqqrly                  1              NONE
#     87           scooper001                  1              NONE
#     74          nadav-robas                  1              NONE
#     75             nalui333                  1              NONE
#     84             rstuckey                  1              NONE
#     93             tdudgeon                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterhub in the last 31 days',
#     width: 1000
#   }), Chart({
#     data:                   author  n_first_responses authorAssociation
#     74            jasongrout                 41            MEMBER
#     69            ian-r-rose                 32            MEMBER
#     37             blink1073                 21            MEMBER
#     113       saulshanabrook                 19            MEMBER
#     87            krassowski                 14            MEMBER
#     125              vidartf                 12            MEMBER
#     119           telamonian                 11            MEMBER
#     62               gnestor                  7            MEMBER
#     72            jaipreet-s                  6      COLLABORATOR
#     83                 jtpio                  4            MEMBER
#     120            timkpaine                  3            MEMBER
#     50           dharmaquark                  3            MEMBER
#     43            daejong123                  3              NONE
#     54              dschaehi                  2              NONE
#     20               Zsailer                  2            MEMBER
#     57            fcollonval                  2            MEMBER
#     56              echarles                  2            MEMBER
#     23             ajbozarth                  2              NONE
#     58                 flixr                  2              NONE
#     22                afshin                  2            MEMBER
#     19                Tych0n                  2              NONE
#     51           dhirschfeld                  2            MEMBER
#     106            nscozzaro                  2            MEMBER
#     12               Madhu94                  2            MEMBER
#     49                dclong                  2            MEMBER
#     81             jonmmease                  2       CONTRIBUTOR
#     124                van-8                  2            MEMBER
#     41                 ciyer                  2            MEMBER
#     105              nibheis                  2              NONE
#     92               madsi1m                  1              NONE
#     91          lorenzznerol                  1              NONE
#     93            marcevrard                  1              NONE
#     0          AlbertUlysses                  1              NONE
#     90               lisanhu                  1              NONE
#     89           lambdamusic                  1              NONE
#     88                 kwlzn                  1              NONE
#     95             marwahaha                  1            MEMBER
#     86               kevmk04                  1              NONE
#     85            kdeleeuw11                  1              NONE
#     84             kanekalla                  1              NONE
#     82         jqluisneumann                  1              NONE
#     80          joekohlsdorf                  1              NONE
#     79                jochym                  1              NONE
#     78               jestemc                  1              NONE
#     94         markellekelly                  1            MEMBER
#     101           mirestrepo                  1              NONE
#     96   mathematicalmichael                  1       CONTRIBUTOR
#     97                 matrs                  1              NONE
#     131             yumaloop                  1              NONE
#     130              yifanwu                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterlab in the last 31 days',
#     width: 1000
#   })]
# })

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
