# %%
import seaborn as sns
import pandas as pd
import numpy as np
import altair as alt
from markdown import markdown
from IPython.display import Markdown
from ipywidgets.widgets import HTML, Tab
from ipywidgets import widgets
from datetime import timedelta
from matplotlib import pyplot as plt
import os.path as op

from mod import load_data, alt_theme

# %%
def author_url(author):
    return f"https://github.com/{author}"

# %%
# Parameters
fmt_date = "{:%Y-%m-%d}"

n_days = 90
start_date = fmt_date.format(pd.datetime.today() - timedelta(days=n_days))
end_date = fmt_date.format(pd.datetime.today())

renderer = "jupyterlab"
github_orgs = ["jupyterhub", "jupyter", "jupyterlab", "jupyter-widgets", "ipython", "binder-examples", "nteract"]

# %%
# Parameters
renderer = "kaggle"
start_date = "2019-02-01"
end_date = "2019-03-01"

# %%
comments, issues, prs = load_data('../data/')
bot_names = pd.read_csv('bot_names.csv')['names'].tolist()
comments = comments.query('author not in @bot_names')
issues = issues.query('author not in @bot_names')
prs = prs.query('author not in @bot_names')
# Out:
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:24: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   comments = pd.concat(comments)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:25: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   issues = pd.concat(issues)
# /c/Users/chold/Dropbox/projects/jupyter-activity-snapshot/templates/mod/__init__.py:26: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   prs = pd.concat(prs)

# %%
# Only keep the dates we want
comments = comments.query('updatedAt > @start_date and updatedAt < @end_date')
issues = issues.query('updatedAt > @start_date and updatedAt < @end_date')
prs = prs.query('updatedAt > @start_date and updatedAt < @end_date')

# %%
alt.renderers.enable(renderer);
alt.themes.register('my_theme', alt_theme)
alt.themes.enable("my_theme")
# Out:
# ThemeRegistry.enable('my_theme')

# %%
# Information about out time window
time_delta = pd.to_datetime(end_date) - pd.to_datetime(start_date)
n_days = time_delta.days

# Information about the data we loaded
github_orgs = comments['org'].unique()

# %% [markdown]
# # GitHub activity
#
# Jupyter also has lots of activity across GitHub repositories. The following sections contain
# overviews of recent activity across the following GitHub organizations:

# %%
# Define colors we'll use for GitHub membership
author_types = ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', "NONE"]

author_palette = sns.palettes.blend_palette(["lightgrey", "lightgreen", "darkgreen"], 4)
author_colors = ["rgb({}, {}, {}, {})".format(*(ii*256)) for ii in author_palette]
author_color_dict = {key: val for key, val in zip(author_types, author_palette)}

# %%
orgs_md = []
for org in github_orgs:
    orgs_md.append(f'* [github.com/{org}](https://github.com/{org})')
Markdown('\n'.join(orgs_md))
# Out:
# * [github.com/jupyterlab](https://github.com/jupyterlab)
# * [github.com/jupyter-widgets](https://github.com/jupyter-widgets)
# * [github.com/ipython](https://github.com/ipython)
# * [github.com/binder-examples](https://github.com/binder-examples)
# * [github.com/jupyter](https://github.com/jupyter)
# * [github.com/jupyterhub](https://github.com/jupyterhub)
# * [github.com/nteract](https://github.com/nteract)

# %%
Markdown(f"Showing GitHub activity from **{start_date}** to **{end_date}**")
# Out:
# Showing GitHub activity from **2019-02-01** to **2019-03-01**

# %% [markdown]
# ## List of all contributors per organization
#
# First, we'll list each contributor that has contributed to each organization in the last several days.
# Contributions to open source projects are diverse, and involve much more than just contributing code and
# code review. Thanks to everybody in the Jupyter communities for all that they do.

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, org in enumerate(github_orgs):
    authors_comments = comments.query('org == @org')['author']
    authors_prs = prs.query('org == @org')['author']
    unique_participants = np.unique(np.hstack([authors_comments.values, authors_prs.values]).astype(str)).tolist()
    unique_participants.sort(key=lambda a: a.lower())
    
    all_participants = [f"[{participant}](https://github.com/{participant})" for participant in unique_participants]
    participants_md = " | ".join(all_participants)
    md_html = HTML("<center>{}</center>".format(markdown(participants_md)))
    
    children = list(tabs.children)
    children.append(md_html)
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"All participants across issues and pull requests in each org in the last {n_days} days"))
display(tabs)
# Out:
# All participants across issues and pull requests in each org in the last 28 days
# Tab(children=(HTML(value='<center><p><a href="https://github.com/2lone2bone">2lone2bone</a> | <a href="https:/…

# %% [markdown]
# ## Merged Pull requests
#
# Here's an analysis of **merged pull requests** across each of the repositories in the Jupyter
# ecosystem.

# %%
merged = prs.query('state == "MERGED" and closedAt > @start_date and closedAt < @end_date')

# %%
prs_by_repo = merged.groupby(['org', 'repo']).count()['author'].reset_index().sort_values(['org', 'author'], ascending=False)
alt.Chart(data=prs_by_repo, title=f"Merged PRs in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=prs_by_repo['repo'].values.tolist()),
    y='author',
    color='org'
)
# Out:
# Chart({
#   data:                 org                         repo  author
#   46          nteract                          nes      16
#   43          nteract                     hydrogen      10
#   49          nteract                    scrapbook      10
#   48          nteract                    papermill       7
#   42          nteract                     examples       2
#   45          nteract              meeting-minutes       2
#   50          nteract                     semiotic       2
#   44          nteract                          ion       1
#   47          nteract                   nteract.io       1
#   33       jupyterlab                   jupyterlab     191
#   38       jupyterlab  jupyterlab-metadata-service      50
#   34       jupyterlab        jupyterlab-commenting      25
#   41       jupyterlab           theme-cookiecutter      25
#   35       jupyterlab            jupyterlab-github      10
#   37       jupyterlab             jupyterlab-latex      10
#   39       jupyterlab               jupyterlab-toc      10
#   32       jupyterlab            jupyter-renderers       5
#   36       jupyterlab      jupyterlab-google-drive       5
#   40       jupyterlab            jupyterlab_server       5
#   23       jupyterhub                   jupyterhub      32
#   26       jupyterhub          nativeauthenticator      30
#   31       jupyterhub       zero-to-jupyterhub-k8s      30
#   19       jupyterhub                    binderhub      20
#   30       jupyterhub                traefik-proxy      20
#   25       jupyterhub          mybinder.org-deploy      18
#   22       jupyterhub         jupyter-server-proxy      12
#   27       jupyterhub               oauthenticator      12
#   21       jupyterhub                dockerspawner       8
#   18       jupyterhub                       binder       6
#   20       jupyterhub                   chartpress       6
#   24       jupyterhub                  kubespawner       6
#   29       jupyterhub      the-littlest-jupyterhub       6
#   28       jupyterhub                 team-compass       4
#   16  jupyter-widgets                   ipyleaflet      48
#   17  jupyter-widgets                     tutorial       4
#   15          jupyter                  repo2docker      14
#   7           jupyter                 jupyter-book      11
#   14          jupyter                     notebook       9
#   6           jupyter           enterprise_gateway       5
#   8           jupyter               jupyter_client       5
#   5           jupyter                docker-stacks       4
#   10          jupyter                        nb2kg       3
#   11          jupyter                    nbconvert       3
#   9           jupyter               kernel_gateway       1
#   12          jupyter                       nbdime       1
#   13          jupyter                     nbformat       1
#   3           ipython                      ipython      12
#   1           ipython                    ipykernel       3
#   2           ipython                  ipyparallel       3
#   4           ipython              ipython-website       3
#   0   binder-examples             continuous-build       2,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: ['nes', 'hydrogen', 'scrapbook', 'papermill', 'examples', 'meeting-minutes', 'semiotic', 'ion', 'nteract.io', 'jupyterlab', 'jupyterlab-metadata-service', 'jupyterlab-commenting', 'theme-cookiecutter', 'jupyterlab-github', 'jupyterlab-latex', 'jupyterlab-toc', 'jupyter-renderers', 'jupyterlab-google-drive', 'jupyterlab_server', 'jupyterhub', 'nativeauthenticator', 'zero-to-jupyterhub-k8s', 'binderhub', 'traefik-proxy', 'mybinder.org-deploy', 'jupyter-server-proxy', 'oauthenticator', 'dockerspawner', 'binder', 'chartpress', 'kubespawner', 'the-littlest-jupyterhub', 'team-compass', 'ipyleaflet', 'tutorial', 'repo2docker', 'jupyter-book', 'notebook', 'enterprise_gateway', 'jupyter_client', 'docker-stacks', 'nb2kg', 'nbconvert', 'kernel_gateway', 'nbdime', 'nbformat', 'ipython', 'ipykernel', 'ipyparallel', 'ipython-website', 'continuous-build'],
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'author',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Merged PRs in the last 28 days'
# })

# %% [markdown]
# ### A list of merged PRs by project
#
# Below is a tabbed readout of recently-merged PRs. Check out the title to get an idea for what they
# implemented, and be sure to thank the PR author for their hard work!

# %%
tabs = widgets.Tab(children=[])
merged_by = {}
pr_by = {}
for ii, (org, idata) in enumerate(merged.groupby('org')):
    issue_md = []
    issue_md.append(f"#### Closed PRs for org: `{org}`")
    issue_md.append("")
    for (org, repo), prs in idata.groupby(['org', 'repo']):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")
        for _, pr in prs.iterrows():
            user_name = pr['author']
            user_url = author_url(user_name)
            pr_number = pr['number']
            pr_html = pr['url']
            pr_title = pr['title']
            pr_closedby = pr['mergedBy']
            pr_closedby_url = f"https://github.com/{pr_closedby}"
            if user_name not in pr_by:
                pr_by[user_name] = 1
            else:
                pr_by[user_name] += 1
                
            if pr_closedby not in merged_by:
                merged_by[pr_closedby] = 1
            else:
                merged_by[pr_closedby] += 1
            text = f"* [(#{pr_number})]({pr_html}): _{pr_title}_ by **[@{user_name}]({user_url})** merged by **[@{pr_closedby}]({pr_closedby_url})**"
            issue_md.append(text)
    issue_md.append('')
    markdown_html = markdown('\n'.join(issue_md))
    
    children = list(tabs.children)
    children.append(HTML(markdown_html))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
tabs
# Out:
# Tab(children=(HTML(value='<h4>Closed PRs for org: <code>binder-examples</code></h4>\n<h5><a href="https://gith…

# %% [markdown]
# ### Authoring and merging stats by repository
#
# Let's see who has been doing most of the PR authoring and merging. The PR author is generally the
# person that implemented a change in the repository (code, documentation, etc). The PR merger is
# the person that "pressed the green button" and got the change into the main codebase.

# %%
# Prep our merging DF
merged_by_repo = merged.groupby(['org', 'repo', 'author'], as_index=False).agg({'id': 'count', 'authorAssociation': 'first'}).rename(columns={'id': "authored", 'author': 'username'})
closed_by_repo = merged.groupby(['org', 'repo', 'mergedBy']).count()['id'].reset_index().rename(columns={'id': "closed", "mergedBy": "username"})

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(merged_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"PR authors for {iorg} in the last {n_days} days"
    idata = idata.groupby('username', as_index=False).agg({'authored': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('authored', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='authored',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)

alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:   username  authored authorAssociation
#     0  davidar         2       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for binder-examples in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:           username  authored authorAssociation
#     0          Carreau         3            MEMBER
#     1  Vlad-Shcherbina         3       CONTRIBUTOR
#     2      flutefreak7         3              NONE
#     3         memeplex         3       CONTRIBUTOR
#     4            minrk         3            MEMBER
#     5         ppmfloss         3       CONTRIBUTOR
#     6          tomoboy         3              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for ipython in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:            username  authored authorAssociation
#     8         choldgraf         7            MEMBER
#     17      kevin-bates         6            MEMBER
#     21            minrk         6            MEMBER
#     7           betatim         5            MEMBER
#     27        takluyver         3            MEMBER
#     1    GladysNalvarte         2       CONTRIBUTOR
#     12           esevan         2      COLLABORATOR
#     30        yuvipanda         2            MEMBER
#     28          travigd         2       CONTRIBUTOR
#     25         steaward         1       CONTRIBUTOR
#     18         lresende         1            MEMBER
#     23         mrakitin         1       CONTRIBUTOR
#     22           mpacer         1            MEMBER
#     26         t-makaro         1      COLLABORATOR
#     20       maxmouchet         1       CONTRIBUTOR
#     29         twalcari         1       CONTRIBUTOR
#     19  mathieuboudreau         1       CONTRIBUTOR
#     24          parente         1            MEMBER
#     0       EvgeniDubov         1       CONTRIBUTOR
#     16       joergbrech         1       CONTRIBUTOR
#     14         impact27         1       CONTRIBUTOR
#     13    haraldschilly         1       CONTRIBUTOR
#     11          emdupre         1      COLLABORATOR
#     10         dylanzjy         1       CONTRIBUTOR
#     9         dmikushin         1       CONTRIBUTOR
#     6            arnavs         1       CONTRIBUTOR
#     5       aayusharyan         1       CONTRIBUTOR
#     4           Zsailer         1            MEMBER
#     3             WrRan         1       CONTRIBUTOR
#     2       SpencerPark         1       CONTRIBUTOR
#     15        jakirkham         1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:        username  authored authorAssociation
#     1  VasavanThiru        20       CONTRIBUTOR
#     3   martinRenou        20            MEMBER
#     0  GalacticMatt         4              NONE
#     2       drwelby         4       CONTRIBUTOR
#     4      scottyhq         4       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyter-widgets in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:           username  authored authorAssociation
#     20           minrk        68            MEMBER
#     17      leportella        26      COLLABORATOR
#     10       choldgraf        22            MEMBER
#     19      manycoding        14       CONTRIBUTOR
#     26       yuvipanda        10            MEMBER
#     8          betatim        10            MEMBER
#     3   GeorgianaElena         6            MEMBER
#     1          Carreau         6            MEMBER
#     11    consideRatio         6            MEMBER
#     24       vilhelmen         4       CONTRIBUTOR
#     0           00Kai0         4       CONTRIBUTOR
#     6         amit1rrr         4       CONTRIBUTOR
#     9           bitnik         2       CONTRIBUTOR
#     12     dhirschfeld         2       CONTRIBUTOR
#     7        athornton         2       CONTRIBUTOR
#     14       guoshimin         2       CONTRIBUTOR
#     15       jakirkham         2       CONTRIBUTOR
#     16           jtpio         2       CONTRIBUTOR
#     18          manics         2      COLLABORATOR
#     5          Zsailer         2            MEMBER
#     4        Misteur-Z         2              NONE
#     21        rcthomas         2       CONTRIBUTOR
#     22       robnagler         2       CONTRIBUTOR
#     23         shibbas         2       CONTRIBUTOR
#     2    Deepakdubey90         2       CONTRIBUTOR
#     25        xuwaters         2       CONTRIBUTOR
#     13       dtaniwaki         2       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterhub in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:            username  authored authorAssociation
#     8        ian-r-rose        95            MEMBER
#     10       jasongrout        40            MEMBER
#     1            afshin        25            MEMBER
#     16       telamonian        25            MEMBER
#     7            hoo761        25      COLLABORATOR
#     15   saulshanabrook        21            MEMBER
#     0            acu192        20      COLLABORATOR
#     6           gnestor        20            MEMBER
#     12       karamba228        10      COLLABORATOR
#     17           xmnlab        10      COLLABORATOR
#     2          aschlaep        10            MEMBER
#     5          domoritz         5            MEMBER
#     11            jtpio         5            MEMBER
#     4   commandlinegirl         5            MEMBER
#     13    markellekelly         5            MEMBER
#     14       mbektasbbg         5            MEMBER
#     3       brettcannon         5       CONTRIBUTOR
#     9            ivanov         5            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for jupyterlab in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:          username  authored authorAssociation
#     1           MSeal         9            MEMBER
#     7      kylebarron         8            MEMBER
#     16       willingc         7            MEMBER
#     13         rgbkrk         6            MEMBER
#     11         ndydng         3            MEMBER
#     5         gogasca         3            MEMBER
#     15       torioLuz         2       CONTRIBUTOR
#     0      BenRussert         2            MEMBER
#     6      jaipreet-s         2            MEMBER
#     3    captainsafia         2            MEMBER
#     9          mjugan         1            MEMBER
#     10         mpacer         1            MEMBER
#     4       choldgraf         1            MEMBER
#     12  pricebenjamin         1            MEMBER
#     14            rs2         1       CONTRIBUTOR
#     2           blois         1       CONTRIBUTOR
#     8         mgasner         1            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'authored',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'PR authors for nteract in the last 28 days',
#     width: 1000
#   })]
# })

# %%
charts = []
for ii, (iorg, idata) in enumerate(closed_by_repo.replace(np.nan, 0).groupby(['org'])):
    title = f"Merges for {iorg} in the last {n_days} days"
    ch = alt.Chart(data=idata, width=1000, title=title).mark_bar().encode(
        x='username',
        y='closed',
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:                org              repo username  closed
#     0  binder-examples  continuous-build  betatim       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for binder-examples in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:        org             repo username  closed
#     1  ipython        ipykernel    minrk       3
#     2  ipython      ipyparallel    minrk       3
#     3  ipython          ipython  Carreau      12
#     4  ipython  ipython-website  Carreau       3,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for ipython in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:         org                repo     username  closed
#     5   jupyter       docker-stacks      parente       4
#     6   jupyter  enterprise_gateway  kevin-bates       5
#     7   jupyter        jupyter-book    choldgraf       9
#     8   jupyter        jupyter-book      emdupre       2
#     9   jupyter      jupyter_client        minrk       4
#     10  jupyter      jupyter_client       rgbkrk       1
#     11  jupyter      kernel_gateway     rolweber       1
#     12  jupyter               nb2kg  kevin-bates       3
#     13  jupyter           nbconvert        MSeal       2
#     14  jupyter           nbconvert     willingc       1
#     15  jupyter              nbdime      vidartf       1
#     16  jupyter            nbformat    takluyver       1
#     17  jupyter            notebook        minrk       8
#     18  jupyter            notebook    takluyver       1
#     19  jupyter         repo2docker      betatim      11
#     20  jupyter         repo2docker        minrk       2
#     21  jupyter         repo2docker     willingc       1,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                 org        repo     username  closed
#     22  jupyter-widgets  ipyleaflet  martinRenou      48
#     23  jupyter-widgets    tutorial      mwcraig       4,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyter-widgets in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:            org                     repo        username  closed
#     24  jupyterhub                   binder         betatim       2
#     25  jupyterhub                   binder       choldgraf       2
#     26  jupyterhub                   binder          lheagy       2
#     27  jupyterhub                binderhub         betatim      10
#     28  jupyterhub                binderhub    captainsafia       2
#     29  jupyterhub                binderhub       choldgraf       4
#     30  jupyterhub                binderhub       yuvipanda       4
#     31  jupyterhub               chartpress           minrk       6
#     32  jupyterhub            dockerspawner           minrk       6
#     33  jupyterhub            dockerspawner        willingc       2
#     34  jupyterhub     jupyter-server-proxy      ryanlovett       4
#     35  jupyterhub     jupyter-server-proxy       yuvipanda       8
#     36  jupyterhub               jupyterhub         Carreau       4
#     37  jupyterhub               jupyterhub         betatim       4
#     38  jupyterhub               jupyterhub           minrk      22
#     39  jupyterhub               jupyterhub        willingc       2
#     40  jupyterhub              kubespawner    consideRatio       2
#     41  jupyterhub              kubespawner           minrk       4
#     42  jupyterhub      mybinder.org-deploy         betatim      10
#     43  jupyterhub      mybinder.org-deploy       choldgraf       6
#     44  jupyterhub      mybinder.org-deploy           minrk       2
#     45  jupyterhub      nativeauthenticator      leportella      22
#     46  jupyterhub      nativeauthenticator       yuvipanda       8
#     47  jupyterhub           oauthenticator           minrk      10
#     48  jupyterhub           oauthenticator        willingc       2
#     49  jupyterhub             team-compass         betatim       2
#     50  jupyterhub             team-compass       choldgraf       2
#     51  jupyterhub  the-littlest-jupyterhub      leportella       2
#     52  jupyterhub  the-littlest-jupyterhub       yuvipanda       4
#     53  jupyterhub            traefik-proxy  GeorgianaElena      12
#     54  jupyterhub            traefik-proxy           minrk       8
#     55  jupyterhub   zero-to-jupyterhub-k8s         betatim       4
#     56  jupyterhub   zero-to-jupyterhub-k8s       choldgraf       6
#     57  jupyterhub   zero-to-jupyterhub-k8s    consideRatio       8
#     58  jupyterhub   zero-to-jupyterhub-k8s           minrk      12,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterhub in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:            org                         repo        username  closed
#     59  jupyterlab            jupyter-renderers      ian-r-rose       5
#     60  jupyterlab                   jupyterlab          afshin      45
#     61  jupyterlab                   jupyterlab       blink1073      20
#     62  jupyterlab                   jupyterlab       ellisonbg       5
#     63  jupyterlab                   jupyterlab      ian-r-rose      40
#     64  jupyterlab                   jupyterlab      jasongrout      75
#     65  jupyterlab                   jupyterlab  saulshanabrook       6
#     66  jupyterlab        jupyterlab-commenting          acu192       5
#     67  jupyterlab        jupyterlab-commenting          hoo761      10
#     68  jupyterlab        jupyterlab-commenting      karamba228       5
#     69  jupyterlab        jupyterlab-commenting  saulshanabrook       5
#     70  jupyterlab            jupyterlab-github      ian-r-rose      10
#     71  jupyterlab      jupyterlab-google-drive      ian-r-rose       5
#     72  jupyterlab             jupyterlab-latex      ian-r-rose      10
#     73  jupyterlab  jupyterlab-metadata-service          acu192      10
#     74  jupyterlab  jupyterlab-metadata-service  saulshanabrook      20
#     75  jupyterlab  jupyterlab-metadata-service          xmnlab      20
#     76  jupyterlab               jupyterlab-toc      ian-r-rose      10
#     77  jupyterlab            jupyterlab_server          afshin       5
#     78  jupyterlab           theme-cookiecutter      telamonian      25,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for jupyterlab in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:         org             repo      username  closed
#     79  nteract         examples       betatim       1
#     80  nteract         examples  captainsafia       1
#     81  nteract         hydrogen    BenRussert       4
#     82  nteract         hydrogen    kylebarron       5
#     83  nteract         hydrogen       lgeiger       1
#     84  nteract              ion        rgbkrk       1
#     85  nteract  meeting-minutes   stormpython       1
#     86  nteract  meeting-minutes      willingc       1
#     87  nteract              nes         MSeal       3
#     88  nteract              nes  captainsafia       3
#     89  nteract              nes        mjugan       1
#     90  nteract              nes        rgbkrk       7
#     91  nteract              nes      willingc       2
#     92  nteract       nteract.io        rgbkrk       1
#     93  nteract        papermill         MSeal       7
#     94  nteract        scrapbook         MSeal       8
#     95  nteract        scrapbook        rgbkrk       1
#     96  nteract        scrapbook      willingc       1
#     97  nteract         semiotic        emeeks       2,
#     encoding: FacetedEncoding({
#       x: X({
#         field: 'username',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'closed',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Merges for nteract in the last 28 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## Issues
#
# Issues are **conversations** that happen on our GitHub repositories. Here's an
# analysis of issues across the Jupyter organizations.

# %%
created = issues.query('state == "OPEN" and createdAt > @start_date and createdAt < @end_date')
closed = issues.query('state == "CLOSED" and closedAt > @start_date and closedAt < @end_date')

# %%
created_counts = created.groupby(['org', 'repo']).count()['number'].reset_index()
created_counts['org/repo'] = created_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = created_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=created_counts, title=f"Issues created in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                         repo  number  \
#   0   binder-examples                 getting-data       2
#   1   binder-examples           minimal-dockerfile       2
#   2           ipython                  ipyparallel       3
#   3           ipython                      ipython      30
#   4           jupyter                         help      10
#   5           jupyter                      jupyter       5
#   6           jupyter                 jupyter-book       2
#   7           jupyter              jupyter_console       1
#   8           jupyter                       nbdime       2
#   9           jupyter                     notebook      35
#   10          jupyter                     steering       1
#   11  jupyter-widgets                   ipyleaflet       9
#   12  jupyter-widgets                   ipywidgets      20
#   13  jupyter-widgets                    pythreejs       4
#   14  jupyter-widgets                   traittypes       4
#   15  jupyter-widgets       widget-ts-cookiecutter       4
#   16       jupyterhub                    binderhub       6
#   17       jupyterhub       jupyter-rsession-proxy       2
#   18       jupyterhub         jupyter-server-proxy       4
#   19       jupyterhub                   jupyterhub       3
#   20       jupyterhub     jupyterhub-deploy-docker       4
#   21       jupyterhub               jupyterlab-hub       2
#   22       jupyterhub                  kubespawner       2
#   23       jupyterhub          mybinder.org-deploy       8
#   24       jupyterhub          nativeauthenticator       3
#   25       jupyterhub               oauthenticator       2
#   26       jupyterhub             tmpauthenticator       2
#   27       jupyterhub                  wrapspawner       2
#   28       jupyterhub       zero-to-jupyterhub-k8s       8
#   29       jupyterlab                   jupyterlab      80
#   30       jupyterlab               jupyterlab-git      10
#   31       jupyterlab            jupyterlab-github       5
#   32       jupyterlab      jupyterlab-google-drive       5
#   33       jupyterlab  jupyterlab-metadata-service      20
#   34       jupyterlab               jupyterlab-toc      10
#   35          nteract                    bookstore       3
#   36          nteract                           dx       1
#   37          nteract                      nteract       6
#   38          nteract                   nteract.io       3
#   39          nteract                    papermill       3
#   40          nteract                    scrapbook       6
#   41          nteract                     semiotic       4
#   42          nteract                  spawnteract       2
#
#                                     org/repo
#   0             binder-examples/getting-data
#   1       binder-examples/minimal-dockerfile
#   2                      ipython/ipyparallel
#   3                          ipython/ipython
#   4                             jupyter/help
#   5                          jupyter/jupyter
#   6                     jupyter/jupyter-book
#   7                  jupyter/jupyter_console
#   8                           jupyter/nbdime
#   9                         jupyter/notebook
#   10                        jupyter/steering
#   11              jupyter-widgets/ipyleaflet
#   12              jupyter-widgets/ipywidgets
#   13               jupyter-widgets/pythreejs
#   14              jupyter-widgets/traittypes
#   15  jupyter-widgets/widget-ts-cookiecutter
#   16                    jupyterhub/binderhub
#   17       jupyterhub/jupyter-rsession-proxy
#   18         jupyterhub/jupyter-server-proxy
#   19                   jupyterhub/jupyterhub
#   20     jupyterhub/jupyterhub-deploy-docker
#   21               jupyterhub/jupyterlab-hub
#   22                  jupyterhub/kubespawner
#   23          jupyterhub/mybinder.org-deploy
#   24          jupyterhub/nativeauthenticator
#   25               jupyterhub/oauthenticator
#   26             jupyterhub/tmpauthenticator
#   27                  jupyterhub/wrapspawner
#   28       jupyterhub/zero-to-jupyterhub-k8s
#   29                   jupyterlab/jupyterlab
#   30               jupyterlab/jupyterlab-git
#   31            jupyterlab/jupyterlab-github
#   32      jupyterlab/jupyterlab-google-drive
#   33  jupyterlab/jupyterlab-metadata-service
#   34               jupyterlab/jupyterlab-toc
#   35                       nteract/bookstore
#   36                              nteract/dx
#   37                         nteract/nteract
#   38                      nteract/nteract.io
#   39                       nteract/papermill
#   40                       nteract/scrapbook
#   41                        nteract/semiotic
#   42                     nteract/spawnteract  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['nteract', 'scrapbook', 'semiotic', 'bookstore', 'nteract.io', 'papermill', 'spawnteract', 'dx', 'jupyterlab', 'jupyterlab-metadata-service', 'jupyterlab-git', 'jupyterlab-toc', 'jupyterlab-github', 'jupyterlab-google-drive', 'mybinder.org-deploy', 'zero-to-jupyterhub-k8s', 'binderhub', 'jupyter-server-proxy', 'jupyterhub-deploy-docker', 'jupyterhub', 'nativeauthenticator', 'jupyter-rsession-proxy', 'jupyterlab-hub', 'kubespawner', 'oauthenticator', 'tmpauthenticator', 'wrapspawner', 'ipywidgets', 'ipyleaflet', 'pythreejs', 'traittypes', 'widget-ts-cookiecutter', 'notebook', 'help', 'jupyter', 'jupyter-book', 'nbdime', 'jupyter_console', 'steering', 'ipython', 'ipyparallel', 'getting-data', 'minimal-dockerfile']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues created in the last 28 days'
# })

# %%
closed_counts = closed.groupby(['org', 'repo']).count()['number'].reset_index()
closed_counts['org/repo'] = closed_counts.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = closed_counts.sort_values(['org', 'number'], ascending=False)['repo'].values
alt.Chart(data=closed_counts, title=f"Issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y='number',
    color='org',
)
# Out:
# Chart({
#   data:                 org                         repo  number  \
#   0           ipython                    ipykernel       3
#   1           ipython                  ipyparallel       3
#   2           ipython                      ipython       9
#   3           jupyter                docker-stacks       3
#   4           jupyter           enterprise_gateway       8
#   5           jupyter                         help       1
#   6           jupyter                      jupyter       1
#   7           jupyter                 jupyter-book      12
#   8           jupyter               jupyter_client       1
#   9           jupyter               kernel_gateway       6
#   10          jupyter                    nbconvert       5
#   11          jupyter                       nbdime       2
#   12          jupyter                     nbformat       1
#   13          jupyter                     notebook       6
#   14          jupyter                  repo2docker       4
#   15  jupyter-widgets                   ipyleaflet      16
#   16  jupyter-widgets                   ipywidgets      16
#   17       jupyterhub                 batchspawner       2
#   18       jupyterhub                    binderhub       6
#   19       jupyterhub                   chartpress       4
#   20       jupyterhub                dockerspawner       2
#   21       jupyterhub         jupyter-server-proxy       4
#   22       jupyterhub                   jupyterhub      38
#   23       jupyterhub                  kubespawner       6
#   24       jupyterhub            ldapauthenticator       2
#   25       jupyterhub          mybinder.org-deploy       2
#   26       jupyterhub          nativeauthenticator       6
#   27       jupyterhub                  nbgitpuller       4
#   28       jupyterhub                 team-compass      16
#   29       jupyterhub      the-littlest-jupyterhub       4
#   30       jupyterhub                traefik-proxy      12
#   31       jupyterhub       zero-to-jupyterhub-k8s      20
#   32       jupyterlab                   jupyterlab     158
#   33       jupyterlab               jupyterlab-git      15
#   34       jupyterlab            jupyterlab-github       5
#   35       jupyterlab  jupyterlab-metadata-service      10
#   36       jupyterlab               jupyterlab-toc       5
#   37       jupyterlab           theme-cookiecutter      10
#   38          nteract                    bookstore       3
#   39          nteract                     examples       1
#   40          nteract                     hydrogen      26
#   41          nteract              meeting-minutes       1
#   42          nteract                    papermill       8
#   43          nteract                    scrapbook       3
#   44          nteract                     semiotic      10
#
#                                     org/repo
#   0                        ipython/ipykernel
#   1                      ipython/ipyparallel
#   2                          ipython/ipython
#   3                    jupyter/docker-stacks
#   4               jupyter/enterprise_gateway
#   5                             jupyter/help
#   6                          jupyter/jupyter
#   7                     jupyter/jupyter-book
#   8                   jupyter/jupyter_client
#   9                   jupyter/kernel_gateway
#   10                       jupyter/nbconvert
#   11                          jupyter/nbdime
#   12                        jupyter/nbformat
#   13                        jupyter/notebook
#   14                     jupyter/repo2docker
#   15              jupyter-widgets/ipyleaflet
#   16              jupyter-widgets/ipywidgets
#   17                 jupyterhub/batchspawner
#   18                    jupyterhub/binderhub
#   19                   jupyterhub/chartpress
#   20                jupyterhub/dockerspawner
#   21         jupyterhub/jupyter-server-proxy
#   22                   jupyterhub/jupyterhub
#   23                  jupyterhub/kubespawner
#   24            jupyterhub/ldapauthenticator
#   25          jupyterhub/mybinder.org-deploy
#   26          jupyterhub/nativeauthenticator
#   27                  jupyterhub/nbgitpuller
#   28                 jupyterhub/team-compass
#   29      jupyterhub/the-littlest-jupyterhub
#   30                jupyterhub/traefik-proxy
#   31       jupyterhub/zero-to-jupyterhub-k8s
#   32                   jupyterlab/jupyterlab
#   33               jupyterlab/jupyterlab-git
#   34            jupyterlab/jupyterlab-github
#   35  jupyterlab/jupyterlab-metadata-service
#   36               jupyterlab/jupyterlab-toc
#   37           jupyterlab/theme-cookiecutter
#   38                       nteract/bookstore
#   39                        nteract/examples
#   40                        nteract/hydrogen
#   41                 nteract/meeting-minutes
#   42                       nteract/papermill
#   43                       nteract/scrapbook
#   44                        nteract/semiotic  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['hydrogen', 'semiotic', 'papermill', 'bookstore', 'scrapbook', 'examples', 'meeting-minutes', 'jupyterlab', 'jupyterlab-git', 'jupyterlab-metadata-service', 'theme-cookiecutter', 'jupyterlab-github', 'jupyterlab-toc', 'jupyterhub', 'zero-to-jupyterhub-k8s', 'team-compass', 'traefik-proxy', 'binderhub', 'kubespawner', 'nativeauthenticator', 'chartpress', 'jupyter-server-proxy', 'nbgitpuller', 'the-littlest-jupyterhub', 'batchspawner', 'dockerspawner', 'ldapauthenticator', 'mybinder.org-deploy', 'ipyleaflet', 'ipywidgets', 'jupyter-book', 'enterprise_gateway', 'kernel_gateway', 'notebook', 'nbconvert', 'repo2docker', 'docker-stacks', 'nbdime', 'help', 'jupyter', 'jupyter_client', 'nbformat', 'ipython', 'ipykernel', 'ipyparallel']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'number',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Issues closed in the last 28 days'
# })

# %%
created_closed = pd.merge(created_counts.rename(columns={'number': 'created'}).drop(columns='org/repo'),
                          closed_counts.rename(columns={'number': 'closed'}).drop(columns='org/repo'),
                          on=['org', 'repo'], how='outer')

created_closed = pd.melt(created_closed, id_vars=['org', 'repo'], var_name="kind", value_name="count").replace(np.nan, 0)

# %%
charts = []
for org in github_orgs:
    # Pick the top 10 repositories
    this_issues = created_closed.query('org == @org')
    top_repos = this_issues.groupby(['repo']).sum().sort_values(by='count', ascending=False).head(10).index
    ch = alt.Chart(this_issues.query('repo in @top_repos'), width=120).mark_bar().encode(
        x=alt.X("kind", axis=alt.Axis(labelFontSize=15, title="")), 
        y=alt.Y('count', axis=alt.Axis(titleFontSize=15, labelFontSize=12)),
        color='kind',
        column=alt.Column("repo", header=alt.Header(title=f"Issue activity, last {n_days} days for {org}", titleFontSize=15, labelFontSize=12))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:             org                         repo     kind  count
#     29   jupyterlab                   jupyterlab  created   80.0
#     30   jupyterlab               jupyterlab-git  created   10.0
#     31   jupyterlab            jupyterlab-github  created    5.0
#     32   jupyterlab      jupyterlab-google-drive  created    5.0
#     33   jupyterlab  jupyterlab-metadata-service  created   20.0
#     34   jupyterlab               jupyterlab-toc  created   10.0
#     59   jupyterlab           theme-cookiecutter  created    0.0
#     92   jupyterlab                   jupyterlab   closed  158.0
#     93   jupyterlab               jupyterlab-git   closed   15.0
#     94   jupyterlab            jupyterlab-github   closed    5.0
#     95   jupyterlab      jupyterlab-google-drive   closed    0.0
#     96   jupyterlab  jupyterlab-metadata-service   closed   10.0
#     97   jupyterlab               jupyterlab-toc   closed    5.0
#     122  jupyterlab           theme-cookiecutter   closed   10.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 28 days for jupyterlab',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                 org                    repo     kind  count
#     11  jupyter-widgets              ipyleaflet  created    9.0
#     12  jupyter-widgets              ipywidgets  created   20.0
#     13  jupyter-widgets               pythreejs  created    4.0
#     14  jupyter-widgets              traittypes  created    4.0
#     15  jupyter-widgets  widget-ts-cookiecutter  created    4.0
#     74  jupyter-widgets              ipyleaflet   closed   16.0
#     75  jupyter-widgets              ipywidgets   closed   16.0
#     76  jupyter-widgets               pythreejs   closed    0.0
#     77  jupyter-widgets              traittypes   closed    0.0
#     78  jupyter-widgets  widget-ts-cookiecutter   closed    0.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 28 days for jupyter-widgets',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org         repo     kind  count
#     2    ipython  ipyparallel  created    3.0
#     3    ipython      ipython  created   30.0
#     43   ipython    ipykernel  created    0.0
#     65   ipython  ipyparallel   closed    3.0
#     66   ipython      ipython   closed    9.0
#     106  ipython    ipykernel   closed    3.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 28 days for ipython',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:                 org                repo     kind  count
#     0   binder-examples        getting-data  created    2.0
#     1   binder-examples  minimal-dockerfile  created    2.0
#     63  binder-examples        getting-data   closed    0.0
#     64  binder-examples  minimal-dockerfile   closed    0.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 28 days for binder-examples',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org                repo     kind  count
#     4    jupyter                help  created   10.0
#     5    jupyter             jupyter  created    5.0
#     6    jupyter        jupyter-book  created    2.0
#     8    jupyter              nbdime  created    2.0
#     9    jupyter            notebook  created   35.0
#     44   jupyter       docker-stacks  created    0.0
#     45   jupyter  enterprise_gateway  created    0.0
#     47   jupyter      kernel_gateway  created    0.0
#     48   jupyter           nbconvert  created    0.0
#     50   jupyter         repo2docker  created    0.0
#     67   jupyter                help   closed    1.0
#     68   jupyter             jupyter   closed    1.0
#     69   jupyter        jupyter-book   closed   12.0
#     71   jupyter              nbdime   closed    2.0
#     72   jupyter            notebook   closed    6.0
#     107  jupyter       docker-stacks   closed    3.0
#     108  jupyter  enterprise_gateway   closed    8.0
#     110  jupyter      kernel_gateway   closed    6.0
#     111  jupyter           nbconvert   closed    5.0
#     113  jupyter         repo2docker   closed    4.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 28 days for jupyter',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:             org                    repo     kind  count
#     16   jupyterhub               binderhub  created    6.0
#     18   jupyterhub    jupyter-server-proxy  created    4.0
#     19   jupyterhub              jupyterhub  created    3.0
#     22   jupyterhub             kubespawner  created    2.0
#     23   jupyterhub     mybinder.org-deploy  created    8.0
#     24   jupyterhub     nativeauthenticator  created    3.0
#     28   jupyterhub  zero-to-jupyterhub-k8s  created    8.0
#     52   jupyterhub              chartpress  created    0.0
#     56   jupyterhub            team-compass  created    0.0
#     58   jupyterhub           traefik-proxy  created    0.0
#     79   jupyterhub               binderhub   closed    6.0
#     81   jupyterhub    jupyter-server-proxy   closed    4.0
#     82   jupyterhub              jupyterhub   closed   38.0
#     85   jupyterhub             kubespawner   closed    6.0
#     86   jupyterhub     mybinder.org-deploy   closed    2.0
#     87   jupyterhub     nativeauthenticator   closed    6.0
#     91   jupyterhub  zero-to-jupyterhub-k8s   closed   20.0
#     115  jupyterhub              chartpress   closed    4.0
#     119  jupyterhub            team-compass   closed   16.0
#     121  jupyterhub           traefik-proxy   closed   12.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 28 days for jupyterhub',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   }), Chart({
#     data:          org         repo     kind  count
#     35   nteract    bookstore  created    3.0
#     36   nteract           dx  created    1.0
#     37   nteract      nteract  created    6.0
#     38   nteract   nteract.io  created    3.0
#     39   nteract    papermill  created    3.0
#     40   nteract    scrapbook  created    6.0
#     41   nteract     semiotic  created    4.0
#     42   nteract  spawnteract  created    2.0
#     60   nteract     examples  created    0.0
#     61   nteract     hydrogen  created    0.0
#     98   nteract    bookstore   closed    3.0
#     99   nteract           dx   closed    0.0
#     100  nteract      nteract   closed    0.0
#     101  nteract   nteract.io   closed    0.0
#     102  nteract    papermill   closed    8.0
#     103  nteract    scrapbook   closed    3.0
#     104  nteract     semiotic   closed   10.0
#     105  nteract  spawnteract   closed    0.0
#     123  nteract     examples   closed    1.0
#     124  nteract     hydrogen   closed   26.0,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'kind',
#         type: 'nominal'
#       }),
#       column: Column({
#         field: 'repo',
#         header: Header({
#           labelFontSize: 12,
#           title: 'Issue activity, last 28 days for nteract',
#           titleFontSize: 15
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         axis: Axis({
#           labelFontSize: 15,
#           title: ''
#         }),
#         field: 'kind',
#         type: 'nominal'
#       }),
#       y: Y({
#         axis: Axis({
#           labelFontSize: 12,
#           titleFontSize: 15
#         }),
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     width: 120
#   })]
# })

# %%
# Set to datetime
for kind in ['createdAt', 'closedAt']:
    closed.loc[:, kind] = pd.to_datetime(closed[kind])
    
closed.loc[:, 'time_open'] = closed['closedAt'] - closed['createdAt']
closed.loc[:, 'time_open'] = closed['time_open'].dt.total_seconds()
# Out:
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:480: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /home/choldgraf/anaconda/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
time_open = closed.groupby(['org', 'repo']).agg({'time_open': 'median'}).reset_index()
time_open['time_open'] = time_open['time_open'] / (60 * 60 * 24)
time_open['org/repo'] = time_open.apply(lambda a: a['org'] + '/' + a['repo'], axis=1)
sorted_vals = time_open.sort_values(['org', 'time_open'], ascending=False)['repo'].values
alt.Chart(data=time_open, title=f"Time to close for issues closed in the last {n_days} days").mark_bar().encode(
    x=alt.X('repo', sort=alt.Sort(sorted_vals.tolist())),
    y=alt.Y('time_open', title="Median Days Open"),
    color='org',
)
# Out:
# Chart({
#   data:                 org                         repo   time_open  \
#   0           ipython                    ipykernel    7.568333
#   1           ipython                  ipyparallel   11.165301
#   2           ipython                      ipython    1.902593
#   3           jupyter                docker-stacks    1.046447
#   4           jupyter           enterprise_gateway    8.655903
#   5           jupyter                         help    0.001782
#   6           jupyter                      jupyter    0.004850
#   7           jupyter                 jupyter-book   24.467315
#   8           jupyter               jupyter_client   93.085324
#   9           jupyter               kernel_gateway  412.736997
#   10          jupyter                    nbconvert   59.929306
#   11          jupyter                       nbdime    4.764259
#   12          jupyter                     nbformat    2.030197
#   13          jupyter                     notebook    8.435613
#   14          jupyter                  repo2docker   62.583200
#   15  jupyter-widgets                   ipyleaflet    3.607106
#   16  jupyter-widgets                   ipywidgets    0.128038
#   17       jupyterhub                 batchspawner    5.036655
#   18       jupyterhub                    binderhub    0.314433
#   19       jupyterhub                   chartpress  116.557072
#   20       jupyterhub                dockerspawner  880.865613
#   21       jupyterhub         jupyter-server-proxy   10.038281
#   22       jupyterhub                   jupyterhub    6.293009
#   23       jupyterhub                  kubespawner   36.807315
#   24       jupyterhub            ldapauthenticator   13.849132
#   25       jupyterhub          mybinder.org-deploy    2.923391
#   26       jupyterhub          nativeauthenticator    2.850926
#   27       jupyterhub                  nbgitpuller    3.640145
#   28       jupyterhub                 team-compass   55.272587
#   29       jupyterhub      the-littlest-jupyterhub    0.132946
#   30       jupyterhub                traefik-proxy   36.941082
#   31       jupyterhub       zero-to-jupyterhub-k8s    2.462292
#   32       jupyterlab                   jupyterlab   45.916910
#   33       jupyterlab               jupyterlab-git   39.041944
#   34       jupyterlab            jupyterlab-github   21.537465
#   35       jupyterlab  jupyterlab-metadata-service   24.574705
#   36       jupyterlab               jupyterlab-toc    0.027986
#   37       jupyterlab           theme-cookiecutter    3.282818
#   38          nteract                    bookstore    6.048241
#   39          nteract                     examples   29.635000
#   40          nteract                     hydrogen  298.636534
#   41          nteract              meeting-minutes    7.854676
#   42          nteract                    papermill    2.190289
#   43          nteract                    scrapbook    8.768148
#   44          nteract                     semiotic    3.479167
#
#                                     org/repo
#   0                        ipython/ipykernel
#   1                      ipython/ipyparallel
#   2                          ipython/ipython
#   3                    jupyter/docker-stacks
#   4               jupyter/enterprise_gateway
#   5                             jupyter/help
#   6                          jupyter/jupyter
#   7                     jupyter/jupyter-book
#   8                   jupyter/jupyter_client
#   9                   jupyter/kernel_gateway
#   10                       jupyter/nbconvert
#   11                          jupyter/nbdime
#   12                        jupyter/nbformat
#   13                        jupyter/notebook
#   14                     jupyter/repo2docker
#   15              jupyter-widgets/ipyleaflet
#   16              jupyter-widgets/ipywidgets
#   17                 jupyterhub/batchspawner
#   18                    jupyterhub/binderhub
#   19                   jupyterhub/chartpress
#   20                jupyterhub/dockerspawner
#   21         jupyterhub/jupyter-server-proxy
#   22                   jupyterhub/jupyterhub
#   23                  jupyterhub/kubespawner
#   24            jupyterhub/ldapauthenticator
#   25          jupyterhub/mybinder.org-deploy
#   26          jupyterhub/nativeauthenticator
#   27                  jupyterhub/nbgitpuller
#   28                 jupyterhub/team-compass
#   29      jupyterhub/the-littlest-jupyterhub
#   30                jupyterhub/traefik-proxy
#   31       jupyterhub/zero-to-jupyterhub-k8s
#   32                   jupyterlab/jupyterlab
#   33               jupyterlab/jupyterlab-git
#   34            jupyterlab/jupyterlab-github
#   35  jupyterlab/jupyterlab-metadata-service
#   36               jupyterlab/jupyterlab-toc
#   37           jupyterlab/theme-cookiecutter
#   38                       nteract/bookstore
#   39                        nteract/examples
#   40                        nteract/hydrogen
#   41                 nteract/meeting-minutes
#   42                       nteract/papermill
#   43                       nteract/scrapbook
#   44                        nteract/semiotic  ,
#   encoding: FacetedEncoding({
#     color: Color({
#       field: 'org',
#       type: 'nominal'
#     }),
#     x: X({
#       field: 'repo',
#       sort: Sort(['hydrogen', 'examples', 'scrapbook', 'meeting-minutes', 'bookstore', 'semiotic', 'papermill', 'jupyterlab', 'jupyterlab-git', 'jupyterlab-metadata-service', 'jupyterlab-github', 'theme-cookiecutter', 'jupyterlab-toc', 'dockerspawner', 'chartpress', 'team-compass', 'traefik-proxy', 'kubespawner', 'ldapauthenticator', 'jupyter-server-proxy', 'jupyterhub', 'batchspawner', 'nbgitpuller', 'mybinder.org-deploy', 'nativeauthenticator', 'zero-to-jupyterhub-k8s', 'binderhub', 'the-littlest-jupyterhub', 'ipyleaflet', 'ipywidgets', 'kernel_gateway', 'jupyter_client', 'repo2docker', 'nbconvert', 'jupyter-book', 'enterprise_gateway', 'notebook', 'nbdime', 'nbformat', 'docker-stacks', 'jupyter', 'help', 'ipyparallel', 'ipykernel', 'ipython']),
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'time_open',
#       title: 'Median Days Open',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'bar',
#   title: 'Time to close for issues closed in the last 28 days'
# })

# %% [markdown]
# ### A list of recent issues
#
# Below is a list of issues with recent activity in each repository. If they seem of interest
# to you, click on their links and jump in to participate!

# %%
# Add comment count data to issues and PRs
comment_counts = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'issue_id'])
    .count().iloc[:, 0].to_frame()
)
comment_counts.columns = ['n_comments']
comment_counts = comment_counts.reset_index()

# %%
n_plot = 5
tabs = widgets.Tab(children=[])
for ii, (org, idata) in enumerate(comment_counts.groupby('org')):
    issue_md = []
    issue_md.append(f"#### {org}")
    issue_md.append("")
    for repo, i_issues in idata.groupby('repo'):
        issue_md.append(f"##### [{org}/{repo}](https://github.com/{org}/{repo})")

        top_issues = i_issues.sort_values('n_comments', ascending=False).head(n_plot)
        top_issue_list = pd.merge(issues, top_issues, left_on=['org', 'repo', 'number'], right_on=['org', 'repo', 'issue_id'])
        for _, issue in top_issue_list.sort_values('n_comments', ascending=False).head(n_plot).iterrows():
            user_name = issue['author']
            user_url = author_url(user_name)
            issue_number = issue['number']
            issue_html = issue['url']
            issue_title = issue['title']

            text = f"* [(#{issue_number})]({issue_html}): _{issue_title}_ by **[@{user_name}]({user_url})**"
            issue_md.append(text)

    issue_md.append('')
    md_html = HTML(markdown('\n'.join(issue_md)))
    
    children = list(tabs.children)
    children.append(HTML(markdown('\n'.join(issue_md))))
    tabs.children = tuple(children)
    tabs.set_title(ii, org)
    
display(Markdown(f"Here are the top {n_plot} active issues in each repository in the last {n_days} days"))
display(tabs)
# Out:
# Here are the top 5 active issues in each repository in the last 28 days
# Tab(children=(HTML(value='<h4>binder-examples</h4>\n<h5><a href="https://github.com/binder-examples/continuous…

# %% [markdown]
# ## Commenters across repositories
#
# These are commenters across all issues and pull requests in the last several days.
# These are colored by the commenter's association with the organization. For information
# about what these associations mean, [see this StackOverflow post](https://stackoverflow.com/a/28866914/1927102).

# %%
commentors = (
    comments
    .query("createdAt > @start_date and createdAt < @end_date")
    .groupby(['org', 'repo', 'author', 'authorAssociation'])
    .count().rename(columns={'id': 'count'})['count']
    .reset_index()
    .sort_values(['org', 'count'], ascending=False)
)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(commentors.groupby(['org'])):
    title = f"Top {n_plot} commentors for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'count': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('count', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='count',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:     author  count authorAssociation
#     0  betatim      4            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for binder-examples in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                  author  count authorAssociation
#     0               Carreau    183            MEMBER
#     4        LucianaMarques     48       CONTRIBUTOR
#     40                minrk     24            MEMBER
#     54            tacaswell     15       CONTRIBUTOR
#     37          meeseeksdev     12       CONTRIBUTOR
#     38             memeplex     12       CONTRIBUTOR
#     45             ppmfloss     12       CONTRIBUTOR
#     12              albertz     12              NONE
#     52               stas00     12              NONE
#     8         SylvainCorlay      9            MEMBER
#     28        happyconcepts      6              NONE
#     55             tinkerjs      6              NONE
#     25          flutefreak7      6              NONE
#     34     joekingTheThird3      6              NONE
#     43              njsmith      6       CONTRIBUTOR
#     39   michaelsilverstein      3              NONE
#     36             luckjiff      3              NONE
#     41             mlazowik      3              NONE
#     42          mrecachinas      3              NONE
#     44                opi9a      3              NONE
#     49             rmorshea      3              NONE
#     46                qgbcs      3              NONE
#     47          rainwoodman      3              NONE
#     48             riow1983      3              NONE
#     50              sintell      3              NONE
#     51              slishak      3              NONE
#     53              stmax82      3              NONE
#     56               vityas      3              NONE
#     57            westurner      3              NONE
#     58               wjakob      3              NONE
#     59             woodrujm      3              NONE
#     60              xiaolai      3              NONE
#     35           josemarfdc      3              NONE
#     31             jdemeyer      3       CONTRIBUTOR
#     33              jkbr-19      3              NONE
#     32                jf---      3              NONE
#     2                 FRidh      3              NONE
#     3   KrishnaMohanRavilla      3              NONE
#     5          PhysicsForce      3              NONE
#     6              Pithikos      3              NONE
#     7              Sapna714      3              NONE
#     9      abduallahmohamed      3              NONE
#     10            achampion      3              NONE
#     11      akshayparopkari      3       CONTRIBUTOR
#     13            altimmons      3              NONE
#     14       andrii-rubtsov      3              NONE
#     15             asmeurer      3       CONTRIBUTOR
#     16         belgiancoder      3              NONE
#     17           benlindsay      3              NONE
#     18            benmezger      3              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for ipython in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:               author  count authorAssociation
#     86         choldgraf     76            MEMBER
#     76           betatim     49            MEMBER
#     145      kevin-bates     33            MEMBER
#     174  mathieuboudreau     28       CONTRIBUTOR
#     103          emdupre     19      COLLABORATOR
#     200          parente     18            MEMBER
#     242        takluyver     17            MEMBER
#     187            minrk     17            MEMBER
#     263        yuvipanda     12            MEMBER
#     250          vidartf     12      COLLABORATOR
#     34             MSeal     11            MEMBER
#     94      davidanthoff     11       CONTRIBUTOR
#     221           rgbkrk     11            MEMBER
#     58           Zsailer     10            MEMBER
#     222         rolweber      9      COLLABORATOR
#     176    matthew-brett      9       CONTRIBUTOR
#     27   IamViditAgarwal      8              NONE
#     0           1kastner      8              NONE
#     258         willingc      8            MEMBER
#     21          Gsbreddy      7              NONE
#     114          gnestor      6            MEMBER
#     80      brettbrocato      5              NONE
#     11           Carreau      5            MEMBER
#     256        westurner      5              NONE
#     197           noklam      5              NONE
#     105           esevan      5      COLLABORATOR
#     137       joergbrech      5       CONTRIBUTOR
#     135          jhamman      5       CONTRIBUTOR
#     55       TomDonoghue      5       CONTRIBUTOR
#     240           stas00      5              NONE
#     64   alexarchambault      4            MEMBER
#     183           mgeier      4       CONTRIBUTOR
#     251        vilhelmen      4       CONTRIBUTOR
#     162           lheagy      4              NONE
#     168         lresende      4            MEMBER
#     128        jameskoch      4            MEMBER
#     153            ktong      4       CONTRIBUTOR
#     61          agoose77      4              NONE
#     83      captainsafia      4            MEMBER
#     33         LuckyJosh      4              NONE
#     28         Juanlu001      4              NONE
#     85        ccordoba12      4       CONTRIBUTOR
#     146           kingjr      3              NONE
#     20          Gormador      3              NONE
#     203        paultopia      3       CONTRIBUTOR
#     17         Datamance      3              NONE
#     260           wstomv      3              NONE
#     26            Hyaxia      3              NONE
#     10          CMobley7      3              NONE
#     179     mckev-amazon      3              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                   author  count authorAssociation
#     20           martinRenou     88            MEMBER
#     13            jasongrout     85            MEMBER
#     3          SylvainCorlay     28            MEMBER
#     33               vidartf     20            MEMBER
#     1              Juanlu001     20       CONTRIBUTOR
#     10            fsteinmetz     20              NONE
#     32  undergroundquizscene     16              NONE
#     9                 feraku     12              NONE
#     14               jhamman     12              NONE
#     22           nickpollari      8              NONE
#     21               mwcraig      8       CONTRIBUTOR
#     12               humitos      8              NONE
#     7                drwelby      8       CONTRIBUTOR
#     5           antlarr-suse      8              NONE
#     23              norrisan      8              NONE
#     2            LukaPitamic      8              NONE
#     17                  krey      8              NONE
#     28             soerendip      4              NONE
#     0                Carreau      4       CONTRIBUTOR
#     29                 spott      4              NONE
#     30   tiagofrepereira2012      4              NONE
#     26        saulshanabrook      4              NONE
#     31          tiagopereira      4              NONE
#     34               xoolive      4              NONE
#     27              scottyhq      4       CONTRIBUTOR
#     18               lpuglia      4              NONE
#     25           rachelglenn      4              NONE
#     24            oscar6echo      4       CONTRIBUTOR
#     19                maresb      4              NONE
#     16             jonmmease      4              NONE
#     15          johnnychen94      4              NONE
#     11               gnestor      4       CONTRIBUTOR
#     8             fcollonval      4       CONTRIBUTOR
#     6              astrofrog      4              NONE
#     4            andymcarter      4              NONE
#     35               zerline      4       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyter-widgets in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                  author  count authorAssociation
#     94                minrk    210            MEMBER
#     31              betatim    152            MEMBER
#     36            choldgraf    138            MEMBER
#     136           yuvipanda     98            MEMBER
#     40         consideRatio     90            MEMBER
#     81           leportella     38      COLLABORATOR
#     130            willingc     32            MEMBER
#     84               manics     32      COLLABORATOR
#     20              Zsailer     28            MEMBER
#     5               Carreau     24            MEMBER
#     24       albertmichaelj     20       CONTRIBUTOR
#     9        GeorgianaElena     20            MEMBER
#     109             rkdarst     20       CONTRIBUTOR
#     99             nickurak     18       CONTRIBUTOR
#     1              1kastner     14              NONE
#     0                00Kai0     14       CONTRIBUTOR
#     105         psychemedia     14              NONE
#     113          ryanlovett     14            MEMBER
#     82               lheagy     12            MEMBER
#     53             frouzbeh     12              NONE
#     27             anderl80     12              NONE
#     126           vilhelmen     10       CONTRIBUTOR
#     87           manycoding     10       CONTRIBUTOR
#     86   mannevijayakrishna     10              NONE
#     26             amit1rrr     10       CONTRIBUTOR
#     32               bitnik     10       CONTRIBUTOR
#     104          pkumar8789      8              NONE
#     38                clkao      8       CONTRIBUTOR
#     62               hnykda      8              NONE
#     66            jason2249      8              NONE
#     28       andrewjohnlowe      8              NONE
#     118            skhadrao      8              NONE
#     124           tathagata      6              NONE
#     73                jtpio      6       CONTRIBUTOR
#     91                mdivk      6              NONE
#     79            laurensdv      6              NONE
#     132              xmnlab      6       CONTRIBUTOR
#     47          dhirschfeld      6       CONTRIBUTOR
#     115             serlina      6              NONE
#     41               dalg24      6       CONTRIBUTOR
#     137         zhengdayday      6              NONE
#     12              JBleher      6              NONE
#     37            clhedrick      6              NONE
#     127            vlizanae      4              NONE
#     80             lbiemans      4              NONE
#     23             akhmerov      4              NONE
#     29       antigenius0910      4              NONE
#     114      saulshanabrook      4              NONE
#     116           sgibson91      4            MEMBER
#     19           YoonHeaLin      4              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterhub in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                  author  count authorAssociation
#     77           jasongrout   1075            MEMBER
#     73           ian-r-rose    551            MEMBER
#     43             bollwyvl    275            MEMBER
#     71              gnestor    235            MEMBER
#     31               afshin    170            MEMBER
#     135             vidartf    155            MEMBER
#     63            ellisonbg    155            MEMBER
#     118      saulshanabrook    142            MEMBER
#     131          telamonian    110            MEMBER
#     76           jaipreet-s     65      COLLABORATOR
#     1            AlbertHilb     50            MEMBER
#     139              xmnlab     40      COLLABORATOR
#     45            choldgraf     40            MEMBER
#     141           yuvipanda     35       CONTRIBUTOR
#     132           tgeorgeux     30            MEMBER
#     5               Carreau     30            MEMBER
#     59             domoritz     25            MEMBER
#     88            kykrueger     25              NONE
#     58          dhirschfeld     25            MEMBER
#     44            cg1008syf     20              NONE
#     74               ivanov     20            MEMBER
#     46      commandlinegirl     20            MEMBER
#     21           RunzheStat     20              NONE
#     3               AlexRig     20              NONE
#     41            blink1073     20            MEMBER
#     20               Rabeez     20              NONE
#     32             agoose77     15            MEMBER
#     68         fearless0307     15              NONE
#     124            sntgluca     15              NONE
#     69         flying-sheep     15              NONE
#     70              ghuname     15              NONE
#     55               dclong     15            MEMBER
#     28             aaa34169     15              NONE
#     6                  Eyas     15              NONE
#     103            narfanar     15              NONE
#     17           MilanMisak     15            MEMBER
#     81                jtpio     15            MEMBER
#     83            kaylangan     15       CONTRIBUTOR
#     14             LongLVNH     15              NONE
#     91           mangecoeur     15              NONE
#     136            vykozlov     15              NONE
#     93        markellekelly     15            MEMBER
#     96              metal3d     10              NONE
#     119             scwolof     10              NONE
#     67           fcollonval     10            MEMBER
#     105             nealmcb     10              NONE
#     64            ericricky     10              NONE
#     92               maresb     10              NONE
#     97   michaelkarlcoleman     10              NONE
#     0            2lone2bone     10              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for jupyterlab in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:              author  count authorAssociation
#     52       kylebarron     89            MEMBER
#     67           rgbkrk     88            MEMBER
#     7             MSeal     56            MEMBER
#     1        BenRussert     34            MEMBER
#     74      stormpython     25            MEMBER
#     84         willingc     22            MEMBER
#     32           emeeks     14            MEMBER
#     20          betatim     13            MEMBER
#     40   grahamanderson     11              NONE
#     47       jasongrout      8              NONE
#     24     captainsafia      7            MEMBER
#     39          gogasca      5            MEMBER
#     51       kiwi0fruit      5       CONTRIBUTOR
#     27        choldgraf      5            MEMBER
#     53          lgeiger      5            MEMBER
#     66       philippjfr      4              NONE
#     65      pashashocky      4              NONE
#     75           taniki      4            MEMBER
#     33            emzeq      4            MEMBER
#     81      weldpua2008      4              NONE
#     82        wesinator      4       CONTRIBUTOR
#     59           mpacer      3            MEMBER
#     50           kashuk      3              NONE
#     9     OnlineVagrant      3              NONE
#     71              rs2      3       CONTRIBUTOR
#     36     fredcallaway      3              NONE
#     57            minrk      3            MEMBER
#     29     davidanthoff      3              NONE
#     55     mckev-amazon      3              NONE
#     63   ondrejtichacek      2              NONE
#     38          gnestor      2            MEMBER
#     58        mohitv789      2              NONE
#     34         erolosty      2              NONE
#     86     zachlanger19      2              NONE
#     70         ronglums      2              NONE
#     78         torioLuz      2       CONTRIBUTOR
#     26        chanonlim      2              NONE
#     23         camall3n      2              NONE
#     19       berbasscor      2              NONE
#     18        bengarvey      2              NONE
#     5   JohnCHarrington      2              NONE
#     10      SelinGungor      2              NONE
#     79      usmcamp0811      2              NONE
#     85        willirath      1              NONE
#     83    williamgilpin      1              NONE
#     80         wctaylor      1              NONE
#     60     neo-anderson      1              NONE
#     68          riordan      1              NONE
#     61        nikitakit      1       CONTRIBUTOR
#     69          romeran      1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'count',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 commentors for nteract in the last 28 days',
#     width: 1000
#   })]
# })

# %% [markdown]
# ## First responders
#
# First responders are the first people to respond to a new issue in one of the repositories.
# The following plots show first responders for recently-created issues.

# %%
first_comments = []
for (org, repo, issue_id), i_comments in comments.groupby(['org', 'repo', 'issue_id']):
    ix_min = pd.to_datetime(i_comments['createdAt']).idxmin()
    first_comment = i_comments.loc[ix_min]
    if isinstance(first_comment, pd.DataFrame):
        first_comment = first_comment.iloc[0]
    first_comments.append(first_comment)
first_comments = pd.concat(first_comments, axis=1).T

# %%
first_responder_counts = first_comments.groupby(['org', 'author', 'authorAssociation'], as_index=False).\
    count().rename(columns={'id': 'n_first_responses'}).sort_values(['org', 'n_first_responses'], ascending=False)

# %%
n_plot = 50
charts = []
for ii, (iorg, idata) in enumerate(first_responder_counts.groupby(['org'])):
    title = f"Top {n_plot} first responders for {iorg} in the last {n_days} days"
    idata = idata.groupby('author', as_index=False).agg({'n_first_responses': 'sum', 'authorAssociation': 'first'})
    idata = idata.sort_values('n_first_responses', ascending=False).head(n_plot)
    ch = alt.Chart(data=idata.head(n_plot), width=1000, title=title).mark_bar().encode(
        x='author',
        y='n_first_responses',
        color=alt.Color('authorAssociation', scale=alt.Scale(domain=author_types, range=author_colors))
    )
    charts.append(ch)
alt.hconcat(*charts)
# Out:
# HConcatChart({
#   hconcat: [Chart({
#     data:     author  n_first_responses authorAssociation
#     0  betatim                  2            MEMBER,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for binder-examples in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:               author  n_first_responses authorAssociation
#     0            Carreau                 25            MEMBER
#     3     LucianaMarques                  4       CONTRIBUTOR
#     27             minrk                  4            MEMBER
#     31          ppmfloss                  3       CONTRIBUTOR
#     26          memeplex                  2       CONTRIBUTOR
#     37            stas00                  2              NONE
#     33          riow1983                  1              NONE
#     25          luckjiff                  1              NONE
#     28          mlazowik                  1              NONE
#     29       mrecachinas                  1              NONE
#     30             opi9a                  1              NONE
#     32             qgbcs                  1              NONE
#     35           sintell                  1              NONE
#     34          rmorshea                  1              NONE
#     23           jkbr-19                  1              NONE
#     36           slishak                  1              NONE
#     38         tacaswell                  1       CONTRIBUTOR
#     39          tinkerjs                  1              NONE
#     40            vityas                  1              NONE
#     41         westurner                  1              NONE
#     42            wjakob                  1              NONE
#     43           xiaolai                  1              NONE
#     24        josemarfdc                  1              NONE
#     22             jf---                  1              NONE
#     1          EPedrotti                  1              NONE
#     11      belgiancoder                  1              NONE
#     2              FRidh                  1              NONE
#     4           Pithikos                  1              NONE
#     5           Sapna714                  1              NONE
#     6   abduallahmohamed                  1              NONE
#     7          achampion                  1              NONE
#     8            albertz                  1              NONE
#     9          altimmons                  1              NONE
#     10    andrii-rubtsov                  1              NONE
#     12        benlindsay                  1              NONE
#     21         jcolonese                  1              NONE
#     13      brettbrocato                  1              NONE
#     14           cemdede                  1              NONE
#     15            cmrfrd                  1              NONE
#     16   drorcohengithub                  1              NONE
#     17       flutefreak7                  1              NONE
#     18       free-4-ever                  1              NONE
#     19          gpotter2                  1       CONTRIBUTOR
#     20        jankukacka                  1              NONE
#     44            zakora                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for ipython in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                author  n_first_responses authorAssociation
#     62          choldgraf                 21            MEMBER
#     54            betatim                 16            MEMBER
#     104       kevin-bates                 14            MEMBER
#     157          rolweber                  8      COLLABORATOR
#     134             minrk                  7            MEMBER
#     143           parente                  7            MEMBER
#     19    IamViditAgarwal                  5              NONE
#     180           vidartf                  5      COLLABORATOR
#     173         takluyver                  4            MEMBER
#     61         ccordoba12                  3      COLLABORATOR
#     75            emdupre                  3      COLLABORATOR
#     130            mgeier                  3       CONTRIBUTOR
#     23              MSeal                  3            MEMBER
#     57       brettbrocato                  3              NONE
#     52              beniz                  2              NONE
#     156            rgbkrk                  2            MEMBER
#     97            jhamman                  2       CONTRIBUTOR
#     101       justmarkham                  2              NONE
#     110             ktong                  2       CONTRIBUTOR
#     67       davidanthoff                  2       CONTRIBUTOR
#     84            gnestor                  2            MEMBER
#     112               lc0                  2              NONE
#     31             Mysh-S                  2              NONE
#     145         paultopia                  2       CONTRIBUTOR
#     15           Gsbreddy                  2              NONE
#     190         yuvipanda                  2            MEMBER
#     186          willingc                  2            MEMBER
#     129       mesutyang97                  1              NONE
#     123             mapio                  1              NONE
#     124   mathieuboudreau                  1       CONTRIBUTOR
#     125          mbassman                  1              NONE
#     126      mckev-amazon                  1              NONE
#     127           meeotch                  1              NONE
#     185         westurner                  1              NONE
#     128       meeseeksdev                  1              NONE
#     171            stas00                  1              NONE
#     121           ltetrel                  1              NONE
#     184         wesinator                  1              NONE
#     131     mhmodmoustafa                  1              NONE
#     132  micromouseonline                  1              NONE
#     133          milensys                  1              NONE
#     183        waspinator                  1              NONE
#     182        vishalpunj                  1              NONE
#     135            mkirch                  1              NONE
#     122         malek2610                  1              NONE
#     120         lordcirth                  1              NONE
#     137            mwouts                  1              NONE
#     119           liujl93                  1              NONE
#     105            kingjr                  1              NONE
#     106           kinpell                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                  author  n_first_responses authorAssociation
#     8           martinRenou                 12            MEMBER
#     3            jasongrout                  9            MEMBER
#     17              vidartf                  3            MEMBER
#     2          antlarr-suse                  2              NONE
#     4               jhamman                  2              NONE
#     0         SylvainCorlay                  1            MEMBER
#     12             rheiland                  1              NONE
#     18              xoolive                  1              NONE
#     16         tiagopereira                  1              NONE
#     15  tiagofrepereira2012                  1              NONE
#     14            soerendip                  1              NONE
#     13       saulshanabrook                  1              NONE
#     10          nickpollari                  1              NONE
#     11             norrisan                  1              NONE
#     1           andymcarter                  1              NONE
#     9               mwcraig                  1       CONTRIBUTOR
#     7                maresb                  1              NONE
#     6               lpuglia                  1              NONE
#     5                  krey                  1              NONE
#     19              zerline                  1       CONTRIBUTOR,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyter-widgets in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                author  n_first_responses authorAssociation
#     58              minrk                 48            MEMBER
#     18            betatim                 24            MEMBER
#     21          choldgraf                 22            MEMBER
#     83          yuvipanda                 17            MEMBER
#     23       consideRatio                 17            MEMBER
#     48         leportella                  9      COLLABORATOR
#     64            rkdarst                  5       CONTRIBUTOR
#     5      GeorgianaElena                  5            MEMBER
#     2             Carreau                  4            MEMBER
#     50             manics                  4      COLLABORATOR
#     63        psychemedia                  3              NONE
#     10            Zsailer                  3            MEMBER
#     13     albertmichaelj                  3       CONTRIBUTOR
#     15           amit1rrr                  3       CONTRIBUTOR
#     82       yugushihuang                  2              NONE
#     28     davidlowryduda                  2              NONE
#     37           hhuuggoo                  2       CONTRIBUTOR
#     39             hnykda                  2              NONE
#     80           willingc                  2            MEMBER
#     24             dalg24                  2       CONTRIBUTOR
#     62         pkumar8789                  2              NONE
#     70            serlina                  2              NONE
#     72           skhadrao                  2              NONE
#     53         manycoding                  2       CONTRIBUTOR
#     0              00Kai0                  2       CONTRIBUTOR
#     22              clkao                  2       CONTRIBUTOR
#     8             JBleher                  2              NONE
#     19             bitnik                  2       CONTRIBUTOR
#     25           dalssaso                  1              NONE
#     7     IamViditAgarwal                  1              NONE
#     12             ablekh                  1              NONE
#     59           nickshch                  1              NONE
#     60           nickurak                  1       CONTRIBUTOR
#     61            phoenom                  1              NONE
#     11      abdollahiazam                  1              NONE
#     9          YoonHeaLin                  1              NONE
#     65          robnagler                  1       CONTRIBUTOR
#     66  rodriguez-facundo                  1              NONE
#     67       ruhidagdelen                  1              NONE
#     68         ryanlovett                  1            MEMBER
#     69     saulshanabrook                  1              NONE
#     71            shibbas                  1       CONTRIBUTOR
#     56           metrofun                  1              NONE
#     6           II-VSB-II                  1              NONE
#     73          soerendip                  1              NONE
#     74       stefansedich                  1              NONE
#     75           stelford                  1              NONE
#     76           tallamjr                  1              NONE
#     77          vilhelmen                  1       CONTRIBUTOR
#     78           vlizanae                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterhub in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:                 author  n_first_responses authorAssociation
#     51          jasongrout                 74            MEMBER
#     47          ian-r-rose                 24            MEMBER
#     89             vidartf                 12            MEMBER
#     80      saulshanabrook                 11            MEMBER
#     50          jaipreet-s                 10      COLLABORATOR
#     45             gnestor                  9            MEMBER
#     24            bollwyvl                  9            MEMBER
#     38           ellisonbg                  7            MEMBER
#     86          telamonian                  7            MEMBER
#     16              afshin                  4            MEMBER
#     91              xmnlab                  4      COLLABORATOR
#     32              dclong                  3            MEMBER
#     34         dhirschfeld                  3            MEMBER
#     83            sntgluca                  2              NONE
#     35            domoritz                  2            MEMBER
#     70            narfanar                  2              NONE
#     17            agoose77                  2            MEMBER
#     60       markellekelly                  2            MEMBER
#     72             nealmcb                  2              NONE
#     11              Rabeez                  2              NONE
#     23           blink1073                  2            MEMBER
#     55           kaylangan                  1       CONTRIBUTOR
#     66          mountain01                  1              NONE
#     65            mmcguffi                  1              NONE
#     58           kykrueger                  1              NONE
#     64  michaelkarlcoleman                  1              NONE
#     62          mbektasbbg                  1            MEMBER
#     61     mathieuboudreau                  1              NONE
#     67      mouradmourafiq                  1              NONE
#     56             kiranik                  1              NONE
#     59            lresende                  1            MEMBER
#     57               krstp                  1              NONE
#     63             metal3d                  1              NONE
#     73       oldgeeksguide                  1              NONE
#     68               naefl                  1              NONE
#     81             scwolof                  1              NONE
#     92           yuvipanda                  1       CONTRIBUTOR
#     90            vykozlov                  1              NONE
#     88           timkpaine                  1            MEMBER
#     87           tgeorgeux                  1            MEMBER
#     85        stevenveenma                  1              NONE
#     84      spencermathews                  1              NONE
#     82         shijianjian                  1              NONE
#     79     santiagobasulto                  1              NONE
#     69             nalagoa                  1              NONE
#     78            ryan4yin                  1              NONE
#     77   riemannzetagambit                  1              NONE
#     76        raybellwaves                  1            MEMBER
#     75            phil-zxx                  1              NONE
#     74                ozel                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for jupyterlab in the last 28 days',
#     width: 1000
#   }), Chart({
#     data:              author  n_first_responses authorAssociation
#     34           rgbkrk                 57            MEMBER
#     25       kylebarron                 31            MEMBER
#     4             MSeal                 25            MEMBER
#     0        BenRussert                 15            MEMBER
#     39      stormpython                 10            MEMBER
#     16           emeeks                  9            MEMBER
#     9           betatim                  8            MEMBER
#     44         willingc                  8            MEMBER
#     41      weldpua2008                  2              NONE
#     40         torioLuz                  2       CONTRIBUTOR
#     11     captainsafia                  2            MEMBER
#     28           mpacer                  1            MEMBER
#     32       philippjfr                  1              NONE
#     29        nikitakit                  1       CONTRIBUTOR
#     27        mohitv789                  1              NONE
#     30   ondrejtichacek                  1              NONE
#     31      pashashocky                  1              NONE
#     37              rs2                  1       CONTRIBUTOR
#     33      randomstuff                  1              NONE
#     35          riordan                  1              NONE
#     36         ronglums                  1              NONE
#     38           saluto                  1              NONE
#     42        wesinator                  1       CONTRIBUTOR
#     43    williamgilpin                  1              NONE
#     26            minrk                  1            MEMBER
#     23           kashuk                  1              NONE
#     24       kiwi0fruit                  1              NONE
#     1   FriedaKallotter                  1              NONE
#     2            Jogala                  1              NONE
#     3   JohnCHarrington                  1              NONE
#     5           aarondt                  1              NONE
#     6   akshayparopkari                  1              NONE
#     7         bballcode                  1              NONE
#     8         bengarvey                  1              NONE
#     10         camall3n                  1              NONE
#     12           cehc84                  1              NONE
#     13     davidanthoff                  1              NONE
#     14      dhirschfeld                  1            MEMBER
#     15             drbh                  1              NONE
#     17         erolosty                  1              NONE
#     18        glitch401                  1              NONE
#     19          gogasca                  1            MEMBER
#     20        guillefix                  1              NONE
#     21           jdetle                  1            MEMBER
#     22     joseppinilla                  1              NONE
#     45        willirath                  1              NONE,
#     encoding: FacetedEncoding({
#       color: Color({
#         field: 'authorAssociation',
#         scale: Scale({
#           domain: ['MEMBER', 'CONTRIBUTOR', 'COLLABORATOR', 'NONE'],
#           range: ['rgb(211.82745098039214, 211.82745098039214, 211.82745098039214, 256.0)', 'rgb(166.98562091503268, 229.89803921568628, 166.98562091503268, 256.0)', 'rgb(96.37647058823529, 192.75294117647059, 96.37647058823529, 256.0)', 'rgb(0.0, 100.3921568627451, 0.0, 256.0)']
#         }),
#         type: 'nominal'
#       }),
#       x: X({
#         field: 'author',
#         type: 'nominal'
#       }),
#       y: Y({
#         field: 'n_first_responses',
#         type: 'quantitative'
#       })
#     }),
#     mark: 'bar',
#     title: 'Top 50 first responders for nteract in the last 28 days',
#     width: 1000
#   })]
# })

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
